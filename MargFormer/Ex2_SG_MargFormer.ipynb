# %% [markdown]
# ## MargFormer - Experiment2 - Star-Galaxy Classification
#
# ## Star-Galaxy Classification (Experiment 2) using Vision Transformer (ViT, Linformer) Model with CLS token derived uisng the Photometric Features. Query is defined using only photometry data in the Cross-Attention.

# %% [markdown]
# #### Import libraries

# %%
import warnings
warnings.filterwarnings("ignore")
git remote set-url origin git@github.com:srinadh99/Astronomical-Source-Classification-using-Machine-Learning.git

import os
import numpy as np
np.random.seed(69)
import pandas as pd
import random
import matplotlib.pyplot as plt
import matplotlib.image as img
import seaborn as sns
sns.set()
# from tqdm.notebook 
import tqdm
from sklearn import metrics
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from statsmodels.stats.proportion import proportion_confint
import time
import pickle

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from linformer import LinformerCA, Linformer
from vit_pytorch.efficient_new import ViT

# %%
out_dir = "/scratch/srinadb/Foundation/Trained_Models/MargFormer/Experiment2/SG/"
os.makedirs(out_dir, exist_ok=True)

# %% [markdown]
# #### 1. Load and extract the dataset

# %%
X = np.load("/scratch/srinadb/Foundation/Dataset/Experiment2/X_exp2.npy")
dnnx = np.load("/scratch/srinadb/Foundation//Dataset/Experiment2/dnnx_exp2.npy")
objlist = np.load("/scratch/srinadb/Foundation//Dataset/Experiment2/objlist_exp2.npy")
y = np.load("/scratch/srinadb/Foundation//Dataset/Experiment2/y_exp2.npy", allow_pickle=True)

idx_drop = np.where(y=="QSO")[0]
X = np.delete(X,idx_drop,axis=0)
dnnx = np.delete(dnnx,idx_drop,axis=0)
y = np.delete(y,idx_drop,axis=0)
objlist = np.delete(objlist,idx_drop,axis=0)
y, label_strings = pd.factorize(y,sort=True)
# y = to_categorical(y)
print('\n')
print(label_strings)
# Out:
# ['GALAXY' 'STAR']

# %%
zipX = list(zip(X, dnnx))
zipy = list(zip(y, objlist))

zipX_train, zipX_test, zipy_train, zipy_test = train_test_split(zipX, zipy, test_size = 0.1,random_state=42)
zipX_train, zipX_val, zipy_train, zipy_val = train_test_split(zipX_train, zipy_train, test_size = 0.111111, random_state=42)

X_train, dnnx_train = zip(*zipX_train)
X_val, dnnx_val = zip(*zipX_val)
X_test, dnnx_test = zip(*zipX_test)

y_train, objlist_train = zip(*zipy_train)
y_val, objlist_val = zip(*zipy_val)
y_test, objlist_test = zip(*zipy_test)

X_train = np.array(X_train)
X_val = np.array(X_val)
X_test = np.array(X_test)

dnnx_train = np.array(dnnx_train)
dnnx_val = np.array(dnnx_val)
dnnx_test = np.array(dnnx_test)

y_train = np.array(y_train)
objlist_train = np.array(objlist_train)
y_val = np.array(y_val)
objlist_val = np.array(objlist_val)
y_test = np.array(y_test)
objlist_test = np.array(objlist_test)

del(zipX,zipX_test,zipX_train,zipX_val, X, zipy, zipy_test, zipy_train, zipy_val, objlist)

X_train = X_train.transpose((0, 3, 1, 2))
X_val = X_val.transpose((0, 3, 1, 2))
X_test = X_test.transpose((0, 3, 1, 2))

print('\n')
print('The shape of the Train data is:', X_train.shape)
print('The shape of the Validation data is:', X_val.shape)
print('The shape of the Test data is:', X_test.shape)
# Out:
# The shape of the Train data is: (79996, 5, 32, 32)
# The shape of the Validation data is: (10000, 5, 32, 32)
# The shape of the Test data is: (10000, 5, 32, 32)

# %%
def get_metrics(y_pred, y_test, labels, to_print=True):
    correct_labels = np.where(y_pred==y_test)[0]
    accuracy = metrics.accuracy_score(y_test, y_pred)
    precision = metrics.precision_score(y_test, y_pred,average='macro')
    recall = metrics.recall_score(y_test, y_pred,average='macro')
    f1score = metrics.f1_score(y_test, y_pred,average='macro')
    # rocscore = metrics.roc_auc_score(y_test, y_pred,average='micro',multi_class="ovo")
    confusion_matrix = metrics.confusion_matrix(y_test, y_pred)  
    classification_report = metrics.classification_report(y_test, y_pred)

    if to_print:
        print("Identified {} correct labels out of {} labels".format(len(correct_labels), y_test.shape[0]))
        print("Accuracy:",accuracy)
        print("Precision:",precision)
        print("Recall:",recall)
        print("F1 Score:",f1score)
        # print("ROC AUC Score:",rocscore)
        print(f"Labels are: {labels}")
        print("Confusion Matrix:\n", confusion_matrix)
        print("Classification_Report:\n", classification_report)

    return (correct_labels, accuracy, precision, recall, confusion_matrix, classification_report)

# %% [markdown]
# ##### Create dataset and dataloader for pytorch training

# %%
class SGData(Dataset):
    def __init__(self, x1, x2, y, transform=None):
        self.n_samples = x2.shape[0]
        self.x1 = torch.tensor(x1, dtype=torch.float32)
        self.x2 = torch.tensor(x2, dtype=torch.float32)
        self.y = torch.tensor(y)
        self.transform = transform

    def __len__(self):
        return self.n_samples

    def __getitem__(self, i):
        inputs_pf, inputs_imgs, targets = self.x1[i], self.x2[i], self.y[i]
        
        if self.transform:
            inputs_pf = inputs_pf
            inputs_imgs = self.transform(inputs_imgs)

        return inputs_pf, inputs_imgs, targets

# Define your data augmentation transformations
image_transform = transforms.Compose([    
    transforms.RandomRotation(180),
    transforms.RandomAffine(degrees = 0, translate = (0.1, 0.1)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
])

# Create DataLoader for training and validation data
train_dataset = SGData(dnnx_train, X_train, y_train, transform=image_transform)
train_loader = DataLoader(train_dataset, batch_size=512, shuffle=True, num_workers=8)
val_dataset = SGData(dnnx_val, X_val, y_val, transform=image_transform)
val_loader = DataLoader(val_dataset, batch_size=512, shuffle=False, num_workers=4)
test_dataset = SGData(dnnx_test, X_test, y_test, transform=None)
test_loader = DataLoader(test_dataset, batch_size=512, shuffle=False, num_workers=4)

# %% [markdown]
# #### 2. Initialize or Define the Model

# %%
# Initialize the PyTorch model
n_classes = 2
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
in_channels = X_train.shape[1]

PATCH_SIZE = 4
DEPTH = 12
HIDDEN_DIM = 64
K_DIM = 64
NUM_HEADS = 8

LR = 1e-3
STEP_SIZE = 5
GAMMA = 0.9

LIN_DROPOUT = 0.1

seq_len = int((32/PATCH_SIZE)**2) + 1

## Linformer
lin = LinformerCA(dim=HIDDEN_DIM, seq_len=seq_len, depth=DEPTH, k=K_DIM, heads=NUM_HEADS,
                dim_head=None, one_kv_head=False, share_kv=False, reversible=False, dropout=LIN_DROPOUT)

## Vision Transformer
model = ViT(image_size=32, patch_size=PATCH_SIZE, num_classes=n_classes, dim=HIDDEN_DIM, transformer=lin, pool='cls', channels=in_channels).to(device)
# Out:
# cuda:0

# %% [markdown]
# #### 3. Training the model

# %%
train_loss_arr = []
train_accuracy_arr = []
val_loss_arr = []
val_accuracy_arr = []

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())

# Early stopping parameters
patience = 30
best_val_loss = float('inf')
best_model_state = None  # Initialize a variable to store the best model state
counter = 0

# Training loop
epochs = 300
epoch1 =0
print('\n')
for epoch in range(epochs):
    epoch1+=1
    model.train()
    train_loss = 0.0
    correct_train = 0
    total_train = 0
    for batch_x1, batch_x2, batch_y in train_loader:
        batch_x1 = batch_x1.to(device)
        batch_x2 = batch_x2.to(device)
        batch_y = batch_y.to(device)
        optimizer.zero_grad()
        output = model(batch_x1, batch_x2)
        loss = criterion(output, batch_y)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = output.max(1)
        total_train += batch_y.size(0)
        correct_train += predicted.eq(batch_y).sum().item()

    train_loss /= len(train_loader)
    train_accuracy = correct_train / total_train
    train_loss_arr.append(train_loss)
    train_accuracy_arr.append(train_accuracy)
    
    model.eval()
    
    val_loss = 0.0
    correct_val = 0
    total_val = 0
    with torch.no_grad():
        for batch_x1, batch_x2, batch_y in val_loader:
            batch_x1 = batch_x1.to(device)
            batch_x2 = batch_x2.to(device)
            batch_y = batch_y.to(device)
            output = model(batch_x1, batch_x2)
            val_loss += criterion(output, batch_y).item()
            _, predicted = output.max(1)
            total_val += batch_y.size(0)
            correct_val += predicted.eq(batch_y).sum().item()

    val_loss /= len(val_loader)
    val_accuracy = correct_val / total_val
    val_loss_arr.append(val_loss)
    val_accuracy_arr.append(val_accuracy)
    
    model.train()
        
    #Check for early stopping and save best model state
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        counter = 0
        best_model_state = model.state_dict()  # Store the current best model state
        torch.save(best_model_state, os.path.join(out_dir, 'EX2_SG_MargFormer_Model.pth'))
    else:
        counter += 1

    if counter >= patience:
        print(f'Early stopping at epoch {epoch+1}')
        if best_model_state is not None:
            model.load_state_dict(best_model_state)  # Restore best model state
        counter = 0  # Reset the counter    
        break

    print(f'Epoch [{epoch+1}/{epochs}] - '
      f'Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, '
      f'Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}')

# Create the range of epochs
epoch_range = range(1, epoch1+1)

# Plot training accuracy in blue
plt.figsize=(8, 6)  # Adjust the size as needed
plt.plot(epoch_range, train_accuracy_arr, label='Train Accuracy', color='blue')

# Plot validation accuracy in red
plt.plot(epoch_range, val_accuracy_arr, label='Validation Accuracy', color='red')

# Add labels and title
plt.xlabel('Epoch', fontsize=14, weight='bold')
plt.ylabel('Accuracy', fontsize=14, weight='bold')
plt.title('Model Accuracy', fontsize=14, weight='bold')

# Add a legend
plt.legend(fontsize=14, title_fontproperties={'weight':'bold'})
plt.savefig(os.path.join(out_dir, "EX2_SG_MargFormer_Accuracy.png"))

# Show the plot
plt.show()
plt.close()

# Plot training accuracy in blue
plt.figsize=(8, 6)  # Adjust the size as needed
plt.plot(epoch_range, train_loss_arr, label='Train Loss', color='blue')

# Plot validation accuracy in red
plt.plot(epoch_range, val_loss_arr, label='Validation Loss', color='red')

# Add labels and title
plt.xlabel('Epoch', fontsize=14, weight='bold')
plt.ylabel('Loss', fontsize=14, weight='bold')
plt.title('Model Loss', fontsize=14, weight='bold')

# Add a legend
plt.legend(fontsize=14, title_fontproperties={'weight':'bold'})
plt.savefig(os.path.join(out_dir, "EX2_SG_MargFormer_Loss.png"))

# Show the plot
plt.show()
plt.close()
# Out:
# Epoch [1/300] - Train Loss: 0.5655, Train Accuracy: 0.6786, Validation Loss: 0.2745, Validation Accuracy: 0.8896
# Epoch [2/300] - Train Loss: 0.2296, Train Accuracy: 0.9134, Validation Loss: 0.1805, Validation Accuracy: 0.9380
# Epoch [3/300] - Train Loss: 0.1853, Train Accuracy: 0.9341, Validation Loss: 0.1660, Validation Accuracy: 0.9405
# Epoch [4/300] - Train Loss: 0.1706, Train Accuracy: 0.9407, Validation Loss: 0.1572, Validation Accuracy: 0.9473
# Epoch [5/300] - Train Loss: 0.1650, Train Accuracy: 0.9429, Validation Loss: 0.1467, Validation Accuracy: 0.9492
# Epoch [6/300] - Train Loss: 0.1579, Train Accuracy: 0.9445, Validation Loss: 0.1456, Validation Accuracy: 0.9501
# Epoch [7/300] - Train Loss: 0.1514, Train Accuracy: 0.9473, Validation Loss: 0.1448, Validation Accuracy: 0.9518
# Epoch [8/300] - Train Loss: 0.1494, Train Accuracy: 0.9471, Validation Loss: 0.1379, Validation Accuracy: 0.9516
# Epoch [9/300] - Train Loss: 0.1462, Train Accuracy: 0.9484, Validation Loss: 0.1369, Validation Accuracy: 0.9521
# Epoch [10/300] - Train Loss: 0.1418, Train Accuracy: 0.9498, Validation Loss: 0.1287, Validation Accuracy: 0.9545
# Epoch [11/300] - Train Loss: 0.1395, Train Accuracy: 0.9501, Validation Loss: 0.1357, Validation Accuracy: 0.9518
# Epoch [12/300] - Train Loss: 0.1370, Train Accuracy: 0.9515, Validation Loss: 0.1435, Validation Accuracy: 0.9471
# Epoch [13/300] - Train Loss: 0.1312, Train Accuracy: 0.9535, Validation Loss: 0.1237, Validation Accuracy: 0.9573
# Epoch [14/300] - Train Loss: 0.1311, Train Accuracy: 0.9536, Validation Loss: 0.1229, Validation Accuracy: 0.9548
# Epoch [15/300] - Train Loss: 0.1305, Train Accuracy: 0.9533, Validation Loss: 0.1391, Validation Accuracy: 0.9514
# Epoch [16/300] - Train Loss: 0.1288, Train Accuracy: 0.9539, Validation Loss: 0.1390, Validation Accuracy: 0.9492
# Epoch [17/300] - Train Loss: 0.1290, Train Accuracy: 0.9541, Validation Loss: 0.1449, Validation Accuracy: 0.9446
# Epoch [18/300] - Train Loss: 0.1239, Train Accuracy: 0.9563, Validation Loss: 0.1190, Validation Accuracy: 0.9570
# Epoch [19/300] - Train Loss: 0.1242, Train Accuracy: 0.9560, Validation Loss: 0.1165, Validation Accuracy: 0.9594
# Epoch [20/300] - Train Loss: 0.1217, Train Accuracy: 0.9568, Validation Loss: 0.1244, Validation Accuracy: 0.9533
# Epoch [21/300] - Train Loss: 0.1230, Train Accuracy: 0.9562, Validation Loss: 0.1171, Validation Accuracy: 0.9567
# Epoch [22/300] - Train Loss: 0.1212, Train Accuracy: 0.9570, Validation Loss: 0.1146, Validation Accuracy: 0.9587
# Epoch [23/300] - Train Loss: 0.1202, Train Accuracy: 0.9569, Validation Loss: 0.1165, Validation Accuracy: 0.9571
# Epoch [24/300] - Train Loss: 0.1185, Train Accuracy: 0.9578, Validation Loss: 0.1126, Validation Accuracy: 0.9603
# Epoch [25/300] - Train Loss: 0.1171, Train Accuracy: 0.9590, Validation Loss: 0.1155, Validation Accuracy: 0.9607
# Epoch [26/300] - Train Loss: 0.1181, Train Accuracy: 0.9581, Validation Loss: 0.1065, Validation Accuracy: 0.9613
# Epoch [27/300] - Train Loss: 0.1176, Train Accuracy: 0.9580, Validation Loss: 0.1082, Validation Accuracy: 0.9618
# Epoch [28/300] - Train Loss: 0.1150, Train Accuracy: 0.9588, Validation Loss: 0.1115, Validation Accuracy: 0.9601
# Epoch [29/300] - Train Loss: 0.1138, Train Accuracy: 0.9597, Validation Loss: 0.1094, Validation Accuracy: 0.9619
# Epoch [30/300] - Train Loss: 0.1153, Train Accuracy: 0.9585, Validation Loss: 0.1191, Validation Accuracy: 0.9586
# Epoch [31/300] - Train Loss: 0.1158, Train Accuracy: 0.9593, Validation Loss: 0.1101, Validation Accuracy: 0.9591
# Epoch [32/300] - Train Loss: 0.1144, Train Accuracy: 0.9592, Validation Loss: 0.1130, Validation Accuracy: 0.9568
# Epoch [33/300] - Train Loss: 0.1122, Train Accuracy: 0.9601, Validation Loss: 0.1053, Validation Accuracy: 0.9618
# Epoch [34/300] - Train Loss: 0.1142, Train Accuracy: 0.9592, Validation Loss: 0.1062, Validation Accuracy: 0.9605
# Epoch [35/300] - Train Loss: 0.1107, Train Accuracy: 0.9608, Validation Loss: 0.1042, Validation Accuracy: 0.9630
# Epoch [36/300] - Train Loss: 0.1110, Train Accuracy: 0.9611, Validation Loss: 0.1074, Validation Accuracy: 0.9607
# Epoch [37/300] - Train Loss: 0.1106, Train Accuracy: 0.9600, Validation Loss: 0.1033, Validation Accuracy: 0.9632
# Epoch [38/300] - Train Loss: 0.1092, Train Accuracy: 0.9611, Validation Loss: 0.1089, Validation Accuracy: 0.9613
# Epoch [39/300] - Train Loss: 0.1110, Train Accuracy: 0.9606, Validation Loss: 0.1152, Validation Accuracy: 0.9593
# Epoch [40/300] - Train Loss: 0.1086, Train Accuracy: 0.9611, Validation Loss: 0.1080, Validation Accuracy: 0.9622
# Epoch [41/300] - Train Loss: 0.1083, Train Accuracy: 0.9621, Validation Loss: 0.1036, Validation Accuracy: 0.9609
# Epoch [42/300] - Train Loss: 0.1070, Train Accuracy: 0.9610, Validation Loss: 0.1033, Validation Accuracy: 0.9635
# Epoch [43/300] - Train Loss: 0.1071, Train Accuracy: 0.9618, Validation Loss: 0.1001, Validation Accuracy: 0.9639
# Epoch [44/300] - Train Loss: 0.1073, Train Accuracy: 0.9615, Validation Loss: 0.1099, Validation Accuracy: 0.9600
# Epoch [45/300] - Train Loss: 0.1074, Train Accuracy: 0.9618, Validation Loss: 0.1113, Validation Accuracy: 0.9616
# Epoch [46/300] - Train Loss: 0.1073, Train Accuracy: 0.9619, Validation Loss: 0.1033, Validation Accuracy: 0.9624
# Epoch [47/300] - Train Loss: 0.1049, Train Accuracy: 0.9624, Validation Loss: 0.0979, Validation Accuracy: 0.9665
# Epoch [48/300] - Train Loss: 0.1042, Train Accuracy: 0.9631, Validation Loss: 0.1054, Validation Accuracy: 0.9619
# Epoch [49/300] - Train Loss: 0.1049, Train Accuracy: 0.9633, Validation Loss: 0.1013, Validation Accuracy: 0.9646
# Epoch [50/300] - Train Loss: 0.1044, Train Accuracy: 0.9630, Validation Loss: 0.1038, Validation Accuracy: 0.9626
# Epoch [51/300] - Train Loss: 0.1051, Train Accuracy: 0.9626, Validation Loss: 0.1003, Validation Accuracy: 0.9638
# Epoch [52/300] - Train Loss: 0.1038, Train Accuracy: 0.9629, Validation Loss: 0.0999, Validation Accuracy: 0.9640
# Epoch [53/300] - Train Loss: 0.1043, Train Accuracy: 0.9626, Validation Loss: 0.0967, Validation Accuracy: 0.9657
# Epoch [54/300] - Train Loss: 0.1036, Train Accuracy: 0.9633, Validation Loss: 0.0993, Validation Accuracy: 0.9619
# Epoch [55/300] - Train Loss: 0.1027, Train Accuracy: 0.9631, Validation Loss: 0.1086, Validation Accuracy: 0.9620
# Epoch [56/300] - Train Loss: 0.1038, Train Accuracy: 0.9629, Validation Loss: 0.1196, Validation Accuracy: 0.9594
# Epoch [57/300] - Train Loss: 0.1009, Train Accuracy: 0.9646, Validation Loss: 0.1021, Validation Accuracy: 0.9635
# Epoch [58/300] - Train Loss: 0.1017, Train Accuracy: 0.9640, Validation Loss: 0.0967, Validation Accuracy: 0.9640
# Epoch [59/300] - Train Loss: 0.1009, Train Accuracy: 0.9644, Validation Loss: 0.1219, Validation Accuracy: 0.9535
# Epoch [60/300] - Train Loss: 0.1023, Train Accuracy: 0.9636, Validation Loss: 0.1018, Validation Accuracy: 0.9642
# Epoch [61/300] - Train Loss: 0.1009, Train Accuracy: 0.9648, Validation Loss: 0.1031, Validation Accuracy: 0.9608
# Epoch [62/300] - Train Loss: 0.1004, Train Accuracy: 0.9645, Validation Loss: 0.0979, Validation Accuracy: 0.9656
# Epoch [63/300] - Train Loss: 0.1005, Train Accuracy: 0.9645, Validation Loss: 0.0999, Validation Accuracy: 0.9647
# Epoch [64/300] - Train Loss: 0.0998, Train Accuracy: 0.9651, Validation Loss: 0.0992, Validation Accuracy: 0.9655
# Epoch [65/300] - Train Loss: 0.1001, Train Accuracy: 0.9642, Validation Loss: 0.0928, Validation Accuracy: 0.9658
# Epoch [66/300] - Train Loss: 0.0996, Train Accuracy: 0.9643, Validation Loss: 0.1007, Validation Accuracy: 0.9647
# Epoch [67/300] - Train Loss: 0.1002, Train Accuracy: 0.9638, Validation Loss: 0.0947, Validation Accuracy: 0.9659
# Epoch [68/300] - Train Loss: 0.0978, Train Accuracy: 0.9654, Validation Loss: 0.0937, Validation Accuracy: 0.9657
# Epoch [69/300] - Train Loss: 0.0968, Train Accuracy: 0.9651, Validation Loss: 0.0954, Validation Accuracy: 0.9655
# Epoch [70/300] - Train Loss: 0.0994, Train Accuracy: 0.9648, Validation Loss: 0.1049, Validation Accuracy: 0.9632
# Epoch [71/300] - Train Loss: 0.0990, Train Accuracy: 0.9641, Validation Loss: 0.0940, Validation Accuracy: 0.9665
# Epoch [72/300] - Train Loss: 0.0965, Train Accuracy: 0.9652, Validation Loss: 0.0976, Validation Accuracy: 0.9655
# Epoch [73/300] - Train Loss: 0.0977, Train Accuracy: 0.9650, Validation Loss: 0.0973, Validation Accuracy: 0.9647
# Epoch [74/300] - Train Loss: 0.0956, Train Accuracy: 0.9652, Validation Loss: 0.0903, Validation Accuracy: 0.9674
# Epoch [75/300] - Train Loss: 0.0954, Train Accuracy: 0.9659, Validation Loss: 0.0942, Validation Accuracy: 0.9656
# Epoch [76/300] - Train Loss: 0.0964, Train Accuracy: 0.9654, Validation Loss: 0.0957, Validation Accuracy: 0.9655
# Epoch [77/300] - Train Loss: 0.0941, Train Accuracy: 0.9664, Validation Loss: 0.0959, Validation Accuracy: 0.9666
# Epoch [78/300] - Train Loss: 0.0952, Train Accuracy: 0.9665, Validation Loss: 0.0994, Validation Accuracy: 0.9638
# Epoch [79/300] - Train Loss: 0.0932, Train Accuracy: 0.9667, Validation Loss: 0.0958, Validation Accuracy: 0.9655
# Epoch [80/300] - Train Loss: 0.0958, Train Accuracy: 0.9658, Validation Loss: 0.0982, Validation Accuracy: 0.9656
# Epoch [81/300] - Train Loss: 0.0949, Train Accuracy: 0.9666, Validation Loss: 0.0939, Validation Accuracy: 0.9660
# Epoch [82/300] - Train Loss: 0.0930, Train Accuracy: 0.9666, Validation Loss: 0.0990, Validation Accuracy: 0.9652
# Epoch [83/300] - Train Loss: 0.0944, Train Accuracy: 0.9665, Validation Loss: 0.0957, Validation Accuracy: 0.9641
# Epoch [84/300] - Train Loss: 0.0924, Train Accuracy: 0.9670, Validation Loss: 0.0973, Validation Accuracy: 0.9651
# Epoch [85/300] - Train Loss: 0.0933, Train Accuracy: 0.9663, Validation Loss: 0.0981, Validation Accuracy: 0.9645
# Epoch [86/300] - Train Loss: 0.0921, Train Accuracy: 0.9666, Validation Loss: 0.0977, Validation Accuracy: 0.9658
# Epoch [87/300] - Train Loss: 0.0935, Train Accuracy: 0.9673, Validation Loss: 0.1034, Validation Accuracy: 0.9619
# Epoch [88/300] - Train Loss: 0.0936, Train Accuracy: 0.9665, Validation Loss: 0.0935, Validation Accuracy: 0.9641
# Epoch [89/300] - Train Loss: 0.0928, Train Accuracy: 0.9670, Validation Loss: 0.0916, Validation Accuracy: 0.9665
# Epoch [90/300] - Train Loss: 0.0928, Train Accuracy: 0.9679, Validation Loss: 0.0983, Validation Accuracy: 0.9660
# Epoch [91/300] - Train Loss: 0.0924, Train Accuracy: 0.9670, Validation Loss: 0.0913, Validation Accuracy: 0.9675
# Epoch [92/300] - Train Loss: 0.0916, Train Accuracy: 0.9670, Validation Loss: 0.0931, Validation Accuracy: 0.9654
# Epoch [93/300] - Train Loss: 0.0896, Train Accuracy: 0.9683, Validation Loss: 0.0979, Validation Accuracy: 0.9650
# Epoch [94/300] - Train Loss: 0.0904, Train Accuracy: 0.9680, Validation Loss: 0.1040, Validation Accuracy: 0.9604
# Epoch [95/300] - Train Loss: 0.0913, Train Accuracy: 0.9675, Validation Loss: 0.1008, Validation Accuracy: 0.9626
# Epoch [96/300] - Train Loss: 0.0909, Train Accuracy: 0.9669, Validation Loss: 0.0900, Validation Accuracy: 0.9661
# Epoch [97/300] - Train Loss: 0.0897, Train Accuracy: 0.9684, Validation Loss: 0.0912, Validation Accuracy: 0.9679
# Epoch [98/300] - Train Loss: 0.0905, Train Accuracy: 0.9677, Validation Loss: 0.0910, Validation Accuracy: 0.9650
# Epoch [99/300] - Train Loss: 0.0881, Train Accuracy: 0.9682, Validation Loss: 0.0902, Validation Accuracy: 0.9685
# Epoch [100/300] - Train Loss: 0.0915, Train Accuracy: 0.9673, Validation Loss: 0.0914, Validation Accuracy: 0.9658
# Epoch [101/300] - Train Loss: 0.0886, Train Accuracy: 0.9686, Validation Loss: 0.0931, Validation Accuracy: 0.9669
# Epoch [102/300] - Train Loss: 0.0904, Train Accuracy: 0.9681, Validation Loss: 0.0882, Validation Accuracy: 0.9672
# Epoch [103/300] - Train Loss: 0.0889, Train Accuracy: 0.9684, Validation Loss: 0.0915, Validation Accuracy: 0.9687
# Epoch [104/300] - Train Loss: 0.0889, Train Accuracy: 0.9684, Validation Loss: 0.0936, Validation Accuracy: 0.9664
# Epoch [105/300] - Train Loss: 0.0898, Train Accuracy: 0.9678, Validation Loss: 0.0952, Validation Accuracy: 0.9653
# Epoch [106/300] - Train Loss: 0.0892, Train Accuracy: 0.9685, Validation Loss: 0.0876, Validation Accuracy: 0.9684
# Epoch [107/300] - Train Loss: 0.0900, Train Accuracy: 0.9678, Validation Loss: 0.0917, Validation Accuracy: 0.9667
# Epoch [108/300] - Train Loss: 0.0885, Train Accuracy: 0.9688, Validation Loss: 0.0971, Validation Accuracy: 0.9645
# Epoch [109/300] - Train Loss: 0.0887, Train Accuracy: 0.9681, Validation Loss: 0.0940, Validation Accuracy: 0.9656
# Epoch [110/300] - Train Loss: 0.0868, Train Accuracy: 0.9688, Validation Loss: 0.0938, Validation Accuracy: 0.9642
# Epoch [111/300] - Train Loss: 0.0877, Train Accuracy: 0.9692, Validation Loss: 0.0934, Validation Accuracy: 0.9684
# Epoch [112/300] - Train Loss: 0.0875, Train Accuracy: 0.9689, Validation Loss: 0.0891, Validation Accuracy: 0.9665
# Epoch [113/300] - Train Loss: 0.0876, Train Accuracy: 0.9688, Validation Loss: 0.0988, Validation Accuracy: 0.9640
# Epoch [114/300] - Train Loss: 0.0877, Train Accuracy: 0.9690, Validation Loss: 0.0906, Validation Accuracy: 0.9651
# Epoch [115/300] - Train Loss: 0.0857, Train Accuracy: 0.9689, Validation Loss: 0.0937, Validation Accuracy: 0.9658
# Epoch [116/300] - Train Loss: 0.0858, Train Accuracy: 0.9692, Validation Loss: 0.1002, Validation Accuracy: 0.9627
# Epoch [117/300] - Train Loss: 0.0865, Train Accuracy: 0.9700, Validation Loss: 0.0896, Validation Accuracy: 0.9675
# Epoch [118/300] - Train Loss: 0.0857, Train Accuracy: 0.9695, Validation Loss: 0.0924, Validation Accuracy: 0.9666
# Epoch [119/300] - Train Loss: 0.0858, Train Accuracy: 0.9702, Validation Loss: 0.0919, Validation Accuracy: 0.9670
# Epoch [120/300] - Train Loss: 0.0854, Train Accuracy: 0.9696, Validation Loss: 0.0994, Validation Accuracy: 0.9640
# Epoch [121/300] - Train Loss: 0.0842, Train Accuracy: 0.9688, Validation Loss: 0.0947, Validation Accuracy: 0.9661
# Epoch [122/300] - Train Loss: 0.0866, Train Accuracy: 0.9692, Validation Loss: 0.0904, Validation Accuracy: 0.9670
# Epoch [123/300] - Train Loss: 0.0840, Train Accuracy: 0.9702, Validation Loss: 0.0916, Validation Accuracy: 0.9668
# Epoch [124/300] - Train Loss: 0.0835, Train Accuracy: 0.9703, Validation Loss: 0.0904, Validation Accuracy: 0.9674
# Epoch [125/300] - Train Loss: 0.0848, Train Accuracy: 0.9694, Validation Loss: 0.0908, Validation Accuracy: 0.9664
# Epoch [126/300] - Train Loss: 0.0836, Train Accuracy: 0.9701, Validation Loss: 0.0928, Validation Accuracy: 0.9658
# Epoch [127/300] - Train Loss: 0.0835, Train Accuracy: 0.9702, Validation Loss: 0.0931, Validation Accuracy: 0.9684
# Epoch [128/300] - Train Loss: 0.0830, Train Accuracy: 0.9705, Validation Loss: 0.0967, Validation Accuracy: 0.9653
# Epoch [129/300] - Train Loss: 0.0845, Train Accuracy: 0.9698, Validation Loss: 0.0883, Validation Accuracy: 0.9680
# Epoch [130/300] - Train Loss: 0.0833, Train Accuracy: 0.9704, Validation Loss: 0.0888, Validation Accuracy: 0.9682
# Epoch [131/300] - Train Loss: 0.0809, Train Accuracy: 0.9713, Validation Loss: 0.0971, Validation Accuracy: 0.9642
# Epoch [132/300] - Train Loss: 0.0818, Train Accuracy: 0.9711, Validation Loss: 0.0903, Validation Accuracy: 0.9672
# Epoch [133/300] - Train Loss: 0.0821, Train Accuracy: 0.9708, Validation Loss: 0.0951, Validation Accuracy: 0.9663
# Epoch [134/300] - Train Loss: 0.0828, Train Accuracy: 0.9706, Validation Loss: 0.0998, Validation Accuracy: 0.9650
# Epoch [135/300] - Train Loss: 0.0816, Train Accuracy: 0.9710, Validation Loss: 0.0899, Validation Accuracy: 0.9689
# Early stopping at epoch 136

# %% [markdown]
# #### 4. Testing the Model

# %%
torch.cuda.empty_cache()

# Set the model to evaluation mode
# if best_model_state is not None:
#     model.load_state_dict(best_model_state)
model.load_state_dict(torch.load(os.path.join(out_dir, "EX2_SG_MargFormer_Model.pth"), map_location=device))
model.eval()
y_test_pred = torch.empty(0).to(device)
print('\n')
# Generate predictions
with torch.no_grad():
    for pf, images, labels in test_loader:
        pf = pf.to(device)
        images = images.to(device)
        labels = labels.to(device)
        pred = model(pf, images)

        y_test_pred = torch.cat((y_test_pred, pred), dim=0)

y_test_pred = y_test_pred.cpu().numpy()
y_test_pred = y_test_pred.argmax(axis=1)
print(get_metrics(y_test_pred, y_test, label_strings))

# https://www.stackvidhya.com/plot-confusion-matrix-in-python-and-why/#google_vignette
# fig = plt.figure()
cf_matrix = metrics.confusion_matrix(y_test, y_test_pred)
cf_matrix_percentage = metrics.confusion_matrix(y_test, y_test_pred, normalize='true')
group_counts = ["{0:0.0f}".format(value) for value in cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_matrix_percentage.flatten()]
labels = [f"{v1}\n({v2})\n" for v1, v2 in
          zip(group_percentages,group_counts)]
labels = np.asarray(labels).reshape(2,2)
fig, ax = plt.subplots(figsize=(8, 6))  # Adjust the size as needed

ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
ax.set_xlabel('\nPredicted', fontsize=14, weight='bold')
ax.set_ylabel('Actual', fontsize=14, weight='bold');
ax.xaxis.set_ticklabels(['GALAXY', 'STAR'], fontsize=14, weight='bold')
ax.yaxis.set_ticklabels(['GALAXY', 'STAR'], fontsize=14, weight='bold')
plt.tight_layout()
plt.savefig(os.path.join(out_dir, "EX2_SG_MargFormer_CM.png"))

plt.show()
plt.close()
# Out:
# Identified 9684 correct labels out of 10000 labels
# Accuracy: 0.9684
# Precision: 0.9684937388685617
# Recall: 0.968391794484184
# F1 Score: 0.9683979774705581
# Labels are: ['GALAXY' 'STAR']
# Confusion Matrix:
#  [[4802  192]
#  [ 124 4882]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      4994
#            1       0.96      0.98      0.97      5006
#
#     accuracy                           0.97     10000
#    macro avg       0.97      0.97      0.97     10000
# weighted avg       0.97      0.97      0.97     10000
#
# (array([   0,    1,    2, ..., 9997, 9998, 9999]), 0.9684, 0.9684937388685617, 0.968391794484184, array([[4802,  192],
#        [ 124, 4882]]), '              precision    recall  f1-score   support\n\n           0       0.97      0.96      0.97      4994\n           1       0.96      0.98      0.97      5006\n\n    accuracy                           0.97     10000\n   macro avg       0.97      0.97      0.97     10000\nweighted avg       0.97      0.97      0.97     10000\n')

# %% [markdown]
# ## Result Analysis

# %%
del(dnnx_train, dnnx_val, dnnx_test, X_train, X_val, X_test)

# %%
X = np.load("/scratch/srinadb/Foundation/Dataset/Experiment2/X_exp2.npy")
dnnx = np.load("/scratch/srinadb/Foundation//Dataset/Experiment2/dnnx_exp2.npy")
objlist = np.load("/scratch/srinadb/Foundation//Dataset/Experiment2/objlist_exp2.npy")
y = np.load("/scratch/srinadb/Foundation//Dataset/Experiment2/y_exp2.npy", allow_pickle=True)

idx_drop = np.where(y=="QSO")[0]
X = np.delete(X,idx_drop,axis=0)
dnnx = np.delete(dnnx,idx_drop,axis=0)
y = np.delete(y,idx_drop,axis=0)
objlist = np.delete(objlist,idx_drop,axis=0)
y, label_strings = pd.factorize(y,sort=True)
# y = to_categorical(y)
print('\n')
print(label_strings)

zipX = list(zip(X, dnnx))
zipy = list(zip(y, objlist))

zipX_train, zipX_test, zipy_train, zipy_test = train_test_split(zipX, zipy, test_size = 0.1,random_state=42)
zipX_train, zipX_val, zipy_train, zipy_val = train_test_split(zipX_train, zipy_train, test_size = 0.1111111, random_state=42)

X_train, dnnx_train = zip(*zipX_train)
X_val, dnnx_val = zip(*zipX_val)
X_test, dnnx_test = zip(*zipX_test)

y_train, objlist_train = zip(*zipy_train)
y_val, objlist_val = zip(*zipy_val)
y_test, objlist_test = zip(*zipy_test)

X_train = np.array(X_train)
X_val = np.array(X_val)
X_test = np.array(X_test)

dnnx_train = np.array(dnnx_train)
dnnx_val = np.array(dnnx_val)
dnnx_test = np.array(dnnx_test)

y_train = np.array(y_train)
objlist_train = np.array(objlist_train)
y_val = np.array(y_val)
objlist_val = np.array(objlist_val)
y_test = np.array(y_test)
objlist_test = np.array(objlist_test)

del(zipX,zipX_test,zipX_train,zipX_val, X, zipy, zipy_test, zipy_train, zipy_val, objlist)

X_train = X_train.transpose((0, 3, 1, 2))
X_val = X_val.transpose((0, 3, 1, 2))
X_test = X_test.transpose((0, 3, 1, 2))

print('\n')
print('The shape of the Train data is:', X_train.shape)
print('The shape of the Validation data is:', X_val.shape)
print('The shape of the Test data is:', X_test.shape)


class SGData(Dataset):
    def __init__(self, x1, x2, y, transform=None):
        self.n_samples = x2.shape[0]
        self.x1 = torch.tensor(x1, dtype=torch.float32)
        self.x2 = torch.tensor(x2, dtype=torch.float32)
        self.y = torch.tensor(y)
        self.transform = transform

    def __len__(self):
        return self.n_samples

    def __getitem__(self, i):
        inputs_pf, inputs_imgs, targets = self.x1[i], self.x2[i], self.y[i]
        
        if self.transform:
            inputs_pf = inputs_pf
            inputs_imgs = self.transform(inputs_imgs)

        return inputs_pf, inputs_imgs, targets

# Create DataLoader for training and validation data
train_dataset = SGData(dnnx_train, X_train, y_train, transform=None)
train_loader = DataLoader(train_dataset, batch_size=512, shuffle=False, num_workers=8)
val_dataset = SGData(dnnx_val, X_val, y_val, transform=None)
val_loader = DataLoader(val_dataset, batch_size=512, shuffle=False, num_workers=4)
test_dataset = SGData(dnnx_test, X_test, y_test, transform=None)
test_loader = DataLoader(test_dataset, batch_size=512, shuffle=False, num_workers=4)
# Out:
# ['GALAXY' 'STAR']
#
#
# The shape of the Train data is: (79996, 5, 32, 32)
# The shape of the Validation data is: (10000, 5, 32, 32)
# The shape of the Test data is: (10000, 5, 32, 32)

# %%
def get_preds(loader):
    model.eval()
    all_logits = []

    with torch.no_grad():
        for pf, images, labels in loader:
            pf = pf.to(device)
            images = images.to(device)
            logits = model(pf, images)      # [batch, 3]
            all_logits.append(logits.cpu())

    all_logits = torch.cat(all_logits, dim=0)   # [N, 3]
    all_probs  = F.softmax(all_logits, dim=1)   # probabilities, rows sum to 1
    all_probs  = all_probs.numpy()

    pred_labels = all_probs.argmax(axis=1)
    return all_probs, pred_labels

preds_train, y_train_pred = get_preds(train_loader)
print(get_metrics(y_train_pred, y_train, label_strings))
print('\n')

preds_val, y_val_pred = get_preds(val_loader)
print(get_metrics(y_val_pred, y_val, label_strings))
print('\n')

preds_test, y_test_pred = get_preds(test_loader)
print(get_metrics(y_test_pred, y_test, label_strings))
# Out:
# Identified 77879 correct labels out of 79996 labels
# Accuracy: 0.9735361768088404
# Precision: 0.9736938532373269
# Recall: 0.9735233779868925
# F1 Score: 0.9735334026624801
# Labels are: ['GALAXY' 'STAR']
# Confusion Matrix:
#  [[38530  1410]
#  [  707 39349]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97     39940
#            1       0.97      0.98      0.97     40056
#
#     accuracy                           0.97     79996
#    macro avg       0.97      0.97      0.97     79996
# weighted avg       0.97      0.97      0.97     79996
#
# (array([    0,     1,     2, ..., 79993, 79994, 79995]), 0.9735361768088404, 0.9736938532373269, 0.9735233779868925, array([[38530,  1410],
#        [  707, 39349]]), '              precision    recall  f1-score   support\n\n           0       0.98      0.96      0.97     39940\n           1       0.97      0.98      0.97     40056\n\n    accuracy                           0.97     79996\n   macro avg       0.97      0.97      0.97     79996\nweighted avg       0.97      0.97      0.97     79996\n')
#
#
# Identified 9680 correct labels out of 10000 labels
# Accuracy: 0.968
# Precision: 0.9679886719546877
# Recall: 0.9680683562303896
# F1 Score: 0.9679981515732349
# Labels are: ['GALAXY' 'STAR']
# Confusion Matrix:
#  [[4878  188]
#  [ 132 4802]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      5066
#            1       0.96      0.97      0.97      4934
#
#     accuracy                           0.97     10000
#    macro avg       0.97      0.97      0.97     10000
# weighted avg       0.97      0.97      0.97     10000
#
# (array([   0,    1,    2, ..., 9997, 9998, 9999]), 0.968, 0.9679886719546877, 0.9680683562303896, array([[4878,  188],
#        [ 132, 4802]]), '              precision    recall  f1-score   support\n\n           0       0.97      0.96      0.97      5066\n           1       0.96      0.97      0.97      4934\n\n    accuracy                           0.97     10000\n   macro avg       0.97      0.97      0.97     10000\nweighted avg       0.97      0.97      0.97     10000\n')
#
#
# Identified 9684 correct labels out of 10000 labels
# Accuracy: 0.9684
# Precision: 0.9684937388685617
# Recall: 0.968391794484184
# F1 Score: 0.9683979774705581
# Labels are: ['GALAXY' 'STAR']
# Confusion Matrix:
#  [[4802  192]
#  [ 124 4882]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      4994
#            1       0.96      0.98      0.97      5006
#
#     accuracy                           0.97     10000
#    macro avg       0.97      0.97      0.97     10000
# weighted avg       0.97      0.97      0.97     10000
#
# (array([   0,    1,    2, ..., 9997, 9998, 9999]), 0.9684, 0.9684937388685617, 0.968391794484184, array([[4802,  192],
#        [ 124, 4882]]), '              precision    recall  f1-score   support\n\n           0       0.97      0.96      0.97      4994\n           1       0.96      0.98      0.97      5006\n\n    accuracy                           0.97     10000\n   macro avg       0.97      0.97      0.97     10000\nweighted avg       0.97      0.97      0.97     10000\n')

# %%
df = pd.read_csv("/scratch/srinadb/Foundation/Dataset/Experiment2/photofeatures_exp2.csv",index_col=0)
df = df[df["class"]!="QSO"].reset_index()
df = df.set_index(["objid"])

df.loc[objlist_train, ["set"]] = "TRAIN"
df.loc[objlist_val, ["set"]] = "VALIDATION"
df.loc[objlist_test, ["set"]] = "TEST"

df.loc[objlist_train, ["pred_class"]] = label_strings[preds_train.argmax(axis=1)]
df.loc[objlist_val, ["pred_class"]] = label_strings[preds_val.argmax(axis=1)]
df.loc[objlist_test, ["pred_class"]] = label_strings[preds_test.argmax(axis=1)]

pgal_train = preds_train[:,np.where(label_strings=="GALAXY")[0][0]]
pstar_train = preds_train[:,np.where(label_strings=="STAR")[0][0]]

pgal_val = preds_val[:,np.where(label_strings=="GALAXY")[0][0]]
pstar_val = preds_val[:,np.where(label_strings=="STAR")[0][0]]

pgal_test = preds_test[:,np.where(label_strings=="GALAXY")[0][0]]
pstar_test = preds_test[:,np.where(label_strings=="STAR")[0][0]]


df.to_csv(os.path.join(out_dir, "EX2_SG_MargFormer_results.csv"))

# %%
sns.set_palette("tab10")

df = pd.read_csv(os.path.join(out_dir, "EX2_SG_MargFormer_results.csv"))

subdflist = []

bin_size = 0.1
lower_bin_list = np.arange(20,23,bin_size)
bad_lower_bin=[]
acclist = []
f1list = []
reportlist = []
num_samplelist = []
starmaglist = []
galmaglist = []

for lower_bin in lower_bin_list:
#     print(f"******************** {lower_bin} < r <= {lower_bin+bin_size} ********************")
    subdf = df[(
        ((df["dered_r"]+df["extinction_r"]) > lower_bin) & 
        ((df["dered_r"]+df["extinction_r"]) <= lower_bin+bin_size)
    )]
    # Choose equal number of stars and galaxies
    min_num = subdf["class"].value_counts().min()
    if min_num < 50:
        bad_lower_bin.append(lower_bin)
        continue
    s1 = subdf[subdf["class"]=="GALAXY"].sample(n=min_num)
    galmaglist.append((s1["dered_r"]+s1["extinction_r"]).to_numpy())
    s2 = subdf[subdf["class"]=="STAR"].sample(n=min_num)
    starmaglist.append((s2["dered_r"]+s2["extinction_r"]).to_numpy())
    num_samplelist.append(min_num)
    subdf = pd.concat([s1,s2])
    subdflist.append(subdf)
    
    accuracy = metrics.accuracy_score(subdf["class"], subdf["pred_class"])
    f1score = metrics.f1_score(subdf["class"], subdf["pred_class"],average='macro')
    report = metrics.classification_report(subdf["class"], subdf["pred_class"],output_dict=True)
    reportlist.append(report)
    acclist.append(accuracy)
    f1list.append(f1score)

bad_lower_bin = np.array(bad_lower_bin)
lower_bin_list = lower_bin_list[~np.in1d(lower_bin_list,bad_lower_bin)]
# elems in lower_bin_list not in bad_lower_bin

galmaglist = np.concatenate(galmaglist)

starmaglist = np.concatenate(starmaglist)

plt.errorbar(lower_bin_list+bin_size/2, np.array(acclist)*100, xerr=bin_size/2, fmt=" ",color="black",label="Bin")
plt.errorbar(lower_bin_list+bin_size/2, np.array(acclist)*100, yerr=0.01*100,fmt=".",color="red",label="Accuracy")
# plt.errorbar(lower_bin_list+bin_size/2, f1list, yerr=0.01,label="F1 Score")
plt.legend()
plt.title("Star-Galaxy")
plt.xlabel("r magnitude bins")
plt.ylabel("Accuracy Score (%)")
# plt.ylim(93, 100)
plt.savefig(os.path.join(out_dir, "EX2_SG_MargFormer_v2.png"))

# %%
subdfs = pd.concat(subdflist)
subdfs["r"]=subdfs["dered_r"]+subdfs["extinction_r"]

gal_recall_list = []
gal_precision_list = []
star_recall_list = []
star_precision_list = []
for r in reportlist:
    gal_recall_list.append(r["GALAXY"]["recall"])
    gal_precision_list.append(r["GALAXY"]["precision"])
    star_recall_list.append(r["STAR"]["recall"])
    star_precision_list.append(r["STAR"]["precision"])
    
    
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1,sharex=True, figsize=(8,18))

galcolor = sns.color_palette("tab10")[1]
starcolor = sns.color_palette("tab10")[2]
acccolor = sns.color_palette("tab10")[3]
f1color = sns.color_palette("tab10")[4]

dyfit = 0.01
x_ax = lower_bin_list+bin_size/2


d1 = subdfs[subdfs["class"]=="GALAXY"]["r"]
d2 = subdfs[subdfs["class"]=="STAR"]["r"]

ax1.hist([d1, d2], color=[galcolor,starcolor],
         alpha=0.8, label=["GALAXY","STAR"],bins=len(lower_bin_list))
ax1.set_ylabel("Count")

ax1.legend()


y_ax1 = np.array(gal_precision_list)
y_ax2 = np.array(star_precision_list)

ax2.errorbar(x_ax, y_ax1*100,fmt="-o", ms=4, label="Galaxy Precision",color=galcolor)
ax2.fill_between(x_ax, y_ax1*100 - dyfit*100, y_ax1*100 + dyfit*100,
             color=sns.color_palette("pastel")[1], alpha=0.3)
ax2.errorbar(x_ax, y_ax2*100,fmt="-o", ms=4, label="Star Precision",color=starcolor)
ax2.fill_between(x_ax, y_ax2*100 - dyfit*100, y_ax2*100 + dyfit*100,
                 color=sns.color_palette("pastel")[2], alpha=0.3)
ax2.set_ylabel("Precision (%)")
ax2.legend()



y_ax1 = np.array(gal_recall_list)
y_ax2 = np.array(star_recall_list)

ax3.errorbar(x_ax, y_ax1*100,fmt="-o", ms=4, label="Galaxy Recall",color=galcolor)
ax3.fill_between(x_ax, y_ax1*100 - dyfit*100, y_ax1*100 + dyfit*100,
             color=sns.color_palette("pastel")[1], alpha=0.3)
ax3.errorbar(x_ax, y_ax2*100,fmt="-o", ms=4, label="Star Recall",color=starcolor)
ax3.fill_between(x_ax, y_ax2*100 - dyfit*100, y_ax2*100 + dyfit*100,
             color=sns.color_palette("pastel")[2], alpha=0.3)
ax3.set_ylabel("Recall (%)")
ax3.legend()



y_ax1 = np.array(acclist)
y_ax2 = np.array(f1list)
ax4.errorbar(x_ax, y_ax1*100,fmt="-o", ms=4, label="Accuracy",color=acccolor)
# ax4.errorbar(x_ax, y_ax2*100,fmt="-o", ms=4, label="F1 Score",color=f1color)
ax4.fill_between(x_ax, y_ax1*100 - dyfit*100, y_ax1*100 + dyfit*100,
             color=sns.color_palette("pastel")[3], alpha=0.3)
ax4.set_ylabel("Accuracy Score (%)")
ax4.legend()

plt.xlabel("r magnitude bins")


# plt.suptitle("Star-Galaxy")
plt.savefig(os.path.join(out_dir, "EX2_SG_MargFormer_v2Set.png")) 

plt.show()
