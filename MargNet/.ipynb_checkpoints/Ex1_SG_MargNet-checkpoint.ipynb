# %% [markdown]
# ## MargNet - Experiment1 - Star-Galaxy Classification
#
# ## Star-Galaxy Classification (Experiment 1) using MargNet. Stacked ensemble of ANN (for Photometric features), and CNN (for images).

# %% [markdown]
# #### Import libraries

# %%
import warnings
warnings.filterwarnings("ignore")

import os
import numpy as np
np.random.seed(69)
import pandas as pd
import random
import matplotlib.pyplot as plt
import matplotlib.image as img
import seaborn as sns
sns.set()
# from tqdm.notebook 
import tqdm
from sklearn import metrics
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import time
import pickle

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader

# %%
out_dir = "/scratch/srinadb/Foundation/Trained_Models/MargNet/Experiment1/SG/"
os.makedirs(out_dir, exist_ok=True)

# %% [markdown]
# #### 1. Load and extract the dataset

# %%
X = np.load("/scratch/srinadb/Foundation/Dataset/Experiment1/X_exp1.npy")
dnnx = np.load("/scratch/srinadb/Foundation//Dataset/Experiment1/dnnx_exp1.npy")
objlist = np.load("/scratch/srinadb/Foundation//Dataset/Experiment1/objlist_exp1.npy")
y = np.load("/scratch/srinadb/Foundation//Dataset/Experiment1/y_exp1.npy", allow_pickle=True)

idx_drop = np.where(y=="QSO")[0]
X = np.delete(X,idx_drop,axis=0)
dnnx = np.delete(dnnx,idx_drop,axis=0)
y = np.delete(y,idx_drop,axis=0)
objlist = np.delete(objlist,idx_drop,axis=0)
y, label_strings = pd.factorize(y,sort=True)
# y = to_categorical(y)
print('\n')
print(label_strings)
# Out:
# ['GALAXY' 'STAR']

# %%
zipX = list(zip(X, dnnx))
zipy = list(zip(y, objlist))

zipX_train, zipX_test, zipy_train, zipy_test = train_test_split(zipX, zipy, test_size = 0.125,random_state=42)
zipX_train, zipX_val, zipy_train, zipy_val = train_test_split(zipX_train, zipy_train, test_size = 0.1428, random_state=42)

X_train, dnnx_train = zip(*zipX_train)
X_val, dnnx_val = zip(*zipX_val)
X_test, dnnx_test = zip(*zipX_test)

y_train, objlist_train = zip(*zipy_train)
y_val, objlist_val = zip(*zipy_val)
y_test, objlist_test = zip(*zipy_test)

X_train = np.array(X_train)
X_val = np.array(X_val)
X_test = np.array(X_test)

dnnx_train = np.array(dnnx_train)
dnnx_val = np.array(dnnx_val)
dnnx_test = np.array(dnnx_test)

y_train = np.array(y_train)
objlist_train = np.array(objlist_train)
y_val = np.array(y_val)
objlist_val = np.array(objlist_val)
y_test = np.array(y_test)
objlist_test = np.array(objlist_test)

del(zipX,zipX_test,zipX_train,zipX_val, X, zipy, zipy_test, zipy_train, zipy_val, objlist)

X_train = X_train.transpose((0, 3, 1, 2))
X_val = X_val.transpose((0, 3, 1, 2))
X_test = X_test.transpose((0, 3, 1, 2))


print('The shape of the Train data is:', dnnx_train.shape)
print('The shape of the Validation data is:', dnnx_val.shape)
print('The shape of the Test data is:', dnnx_test.shape)
print('\n')
print('The shape of the Train data is:', X_train.shape)
print('The shape of the Validation data is:', X_val.shape)
print('The shape of the Test data is:', X_test.shape)
# Out:
# The shape of the Train data is: (120007, 24)
# The shape of the Validation data is: (19992, 24)
# The shape of the Test data is: (20000, 24)
#
#
# The shape of the Train data is: (120007, 5, 32, 32)
# The shape of the Validation data is: (19992, 5, 32, 32)
# The shape of the Test data is: (20000, 5, 32, 32)

# %%
def get_metrics(y_pred, y_test, labels, to_print=True):
    correct_labels = np.where(y_pred==y_test)[0]
    accuracy = metrics.accuracy_score(y_test, y_pred)
    precision = metrics.precision_score(y_test, y_pred,average='macro')
    recall = metrics.recall_score(y_test, y_pred,average='macro')
    f1score = metrics.f1_score(y_test, y_pred,average='macro')
    # rocscore = metrics.roc_auc_score(y_test, y_pred,average='micro',multi_class="ovo")
    confusion_matrix = metrics.confusion_matrix(y_test, y_pred)  
    classification_report = metrics.classification_report(y_test, y_pred)

    if to_print:
        print("Identified {} correct labels out of {} labels".format(len(correct_labels), y_test.shape[0]))
        print("Accuracy:",accuracy)
        print("Precision:",precision)
        print("Recall:",recall)
        print("F1 Score:",f1score)
        # print("ROC AUC Score:",rocscore)
        print(f"Labels are: {labels}")
        print("Confusion Matrix:\n", confusion_matrix)
        print("Classification_Report:\n", classification_report)

    return (correct_labels, accuracy, precision, recall, confusion_matrix, classification_report)

# %% [markdown]
# ### 1. ANN Model using Photometric Features

# %% [markdown]
# ##### Create dataset and dataloader for pytorch training

# %%
class SGData_pf(Dataset):
    def __init__(self, x, y, transform=None):
        self.n_samples = x.shape[0]
        self.x = torch.tensor(x, dtype=torch.float32)
        self.y = torch.tensor(y)
        self.transform = transform

    def __len__(self):
        return self.n_samples

    def __getitem__(self, i):
        inputs, targets = self.x[i], self.y[i]

        if self.transform:
            inputs = self.transform(inputs)

        return inputs, targets

# Create DataLoader for training and validation data
pf_train_dataset = SGData_pf(dnnx_train, y_train, transform=None)
pf_train_loader = DataLoader(pf_train_dataset, batch_size=2048, shuffle=True, num_workers=8)
pf_val_dataset = SGData_pf(dnnx_val, y_val, transform=None)
pf_val_loader = DataLoader(pf_val_dataset, batch_size=2048, shuffle=False, num_workers=4)
pf_test_dataset = SGData_pf(dnnx_test, y_test)
pf_test_loader = DataLoader(pf_test_dataset, batch_size=2048, shuffle=False)

# %% [markdown]
# #### Initialize or Define the Model

# %%
# Define the custom PyTorch model

class DNNModel(nn.Module):
    def __init__(self, input_dim, n_classes):
        super(DNNModel, self).__init__()
        self.fc1 = nn.Linear(input_dim, 1024)
        self.dropout1 = nn.Dropout(0.25)
        # self.activation = torch.nn.sigmoid()
        self.fc2 = nn.Linear(1024, 256)
        self.dropout2 = nn.Dropout(0.25)
        self.fc3 = nn.Linear(256, 128)
        self.dropout3 = nn.Dropout(0.25)
        self.fc4 = nn.Linear(128, 64)
        self.dropout4 = nn.Dropout(0.25)
        self.fc5 = nn.Linear(64, 32)
        self.dropout5 = nn.Dropout(0.25)
        self.fc6 = nn.Linear(32, n_classes)        

    def forward(self, x):
        x = torch.sigmoid(self.fc1(x))
        x = self.dropout1(x)
        x = torch.sigmoid(self.fc2(x))
        x = self.dropout2(x)
        x = torch.sigmoid(self.fc3(x))
        x = self.dropout3(x)
        x = torch.sigmoid(self.fc4(x))
        x = self.dropout4(x)
        x = torch.sigmoid(self.fc5(x))
        x = self.dropout5(x)
        x = self.fc6(x)
        return x

# Initialize the PyTorch model
pf_input_dim = dnnx_train.shape[1]
n_classes = 2
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
pf_model = DNNModel(pf_input_dim, n_classes).to(device)
# Out:
# cuda:0

# %% [markdown]
# #### Training the model

# %%
train_loss_arr = []
train_accuracy_arr = []
val_loss_arr = []
val_accuracy_arr = []

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(pf_model.parameters())

# Early stopping parameters
patience = 100
best_val_loss = float('inf')
best_model_state = None  # Initialize a variable to store the best model state
counter = 0

# Training loop
epochs = 4000
epoch1 =0

for epoch in range(epochs):
    epoch1+=1
    pf_model.train()
    train_loss = 0.0
    correct_train = 0
    total_train = 0
    for batch_x, batch_y in pf_train_loader:
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)
        optimizer.zero_grad()
        output = pf_model(batch_x)
        loss = criterion(output, batch_y)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = output.max(1)
        total_train += batch_y.size(0)
        correct_train += predicted.eq(batch_y).sum().item()

    train_loss /= len(pf_train_loader)
    train_accuracy = correct_train / total_train
    train_loss_arr.append(train_loss)
    train_accuracy_arr.append(train_accuracy)
    
    pf_model.eval()
    
    val_loss = 0.0
    correct_val = 0
    total_val = 0
    with torch.no_grad():
        for batch_x, batch_y in pf_val_loader:
            batch_x = batch_x.to(device)
            batch_y = batch_y.to(device)
            output = pf_model(batch_x)
            val_loss += criterion(output, batch_y).item()
            _, predicted = output.max(1)
            total_val += batch_y.size(0)
            correct_val += predicted.eq(batch_y).sum().item()

    val_loss /= len(pf_val_loader)
    val_accuracy = correct_val / total_val
    val_loss_arr.append(val_loss)
    val_accuracy_arr.append(val_accuracy)
    
    pf_model.train()
        
    #Check for early stopping and save best model state
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        counter = 0
        best_model_state = pf_model.state_dict()  # Store the current best model state 
        torch.save(best_model_state, os.path.join(out_dir, 'EX1_SG_MargNet_DNN_Model.pth'))
    else:
        counter += 1

    if counter >= patience:
        print(f'Early stopping at epoch {epoch+1}')
        if best_model_state is not None:
            pf_model.load_state_dict(best_model_state)  # Restore best model state
        counter = 0  # Reset the counter    
        break

    print(f'Epoch [{epoch+1}/{epochs}] - '
      f'Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, '
      f'Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}')

# Create the range of epochs
epoch_range = range(1, epoch1+1)
    
# Plot training accuracy in blue
plt.figsize=(8, 6)  # Adjust the size as needed
plt.plot(epoch_range, train_accuracy_arr, label='Train Accuracy', color='blue')

# Plot validation accuracy in red
plt.plot(epoch_range, val_accuracy_arr, label='Validation Accuracy', color='red')

# Add labels and title
plt.xlabel('Epoch', fontsize=14, weight='bold')
plt.ylabel('Accuracy', fontsize=14, weight='bold')
plt.title('Model Accuracy', fontsize=14, weight='bold')

# Add a legend
plt.legend(fontsize=14, title_fontproperties={'weight':'bold'})
plt.savefig(os.path.join(out_dir, "EX1_SG_MargNet_DNN_Accuracy.png"))
# Show the plot
plt.show()
plt.close()

# Plot training accuracy in blue
plt.figsize=(8, 6)  # Adjust the size as needed
plt.plot(epoch_range, train_loss_arr, label='Train Loss', color='blue')

# Plot validation accuracy in red
plt.plot(epoch_range, val_loss_arr, label='Validation Loss', color='red')

# Add labels and title
plt.xlabel('Epoch', fontsize=14, weight='bold')
plt.ylabel('Loss', fontsize=14, weight='bold')
plt.title('Model Loss', fontsize=14, weight='bold')

# Add a legend
plt.legend(fontsize=14, title_fontproperties={'weight':'bold'})
plt.savefig(os.path.join(out_dir, "EX1_SG_MargNet_DNN_Loss.png"))

# Show the plot
plt.show()
plt.close()
# Out:
# Epoch [1/4000] - Train Loss: 0.7009, Train Accuracy: 0.4994, Validation Loss: 0.6928, Validation Accuracy: 0.4982
# Epoch [2/4000] - Train Loss: 0.6039, Train Accuracy: 0.6842, Validation Loss: 0.2994, Validation Accuracy: 0.9189
# Epoch [3/4000] - Train Loss: 0.2470, Train Accuracy: 0.9222, Validation Loss: 0.1775, Validation Accuracy: 0.9433
# Epoch [4/4000] - Train Loss: 0.1904, Train Accuracy: 0.9380, Validation Loss: 0.1524, Validation Accuracy: 0.9509
# Epoch [5/4000] - Train Loss: 0.1667, Train Accuracy: 0.9456, Validation Loss: 0.1359, Validation Accuracy: 0.9565
# Epoch [6/4000] - Train Loss: 0.1528, Train Accuracy: 0.9498, Validation Loss: 0.1239, Validation Accuracy: 0.9608
# Epoch [7/4000] - Train Loss: 0.1435, Train Accuracy: 0.9530, Validation Loss: 0.1194, Validation Accuracy: 0.9621
# Epoch [8/4000] - Train Loss: 0.1373, Train Accuracy: 0.9550, Validation Loss: 0.1177, Validation Accuracy: 0.9627
# Epoch [9/4000] - Train Loss: 0.1356, Train Accuracy: 0.9557, Validation Loss: 0.1169, Validation Accuracy: 0.9624
# Epoch [10/4000] - Train Loss: 0.1322, Train Accuracy: 0.9566, Validation Loss: 0.1137, Validation Accuracy: 0.9642
# Epoch [11/4000] - Train Loss: 0.1295, Train Accuracy: 0.9576, Validation Loss: 0.1152, Validation Accuracy: 0.9628
# Epoch [12/4000] - Train Loss: 0.1277, Train Accuracy: 0.9570, Validation Loss: 0.1120, Validation Accuracy: 0.9640
# Epoch [13/4000] - Train Loss: 0.1258, Train Accuracy: 0.9585, Validation Loss: 0.1116, Validation Accuracy: 0.9638
# Epoch [14/4000] - Train Loss: 0.1260, Train Accuracy: 0.9585, Validation Loss: 0.1101, Validation Accuracy: 0.9646
# Epoch [15/4000] - Train Loss: 0.1216, Train Accuracy: 0.9601, Validation Loss: 0.1096, Validation Accuracy: 0.9638
# Epoch [16/4000] - Train Loss: 0.1230, Train Accuracy: 0.9590, Validation Loss: 0.1135, Validation Accuracy: 0.9621
# Epoch [17/4000] - Train Loss: 0.1206, Train Accuracy: 0.9599, Validation Loss: 0.1111, Validation Accuracy: 0.9624
# Epoch [18/4000] - Train Loss: 0.1191, Train Accuracy: 0.9601, Validation Loss: 0.1069, Validation Accuracy: 0.9646
# Epoch [19/4000] - Train Loss: 0.1180, Train Accuracy: 0.9607, Validation Loss: 0.1063, Validation Accuracy: 0.9644
# Epoch [20/4000] - Train Loss: 0.1178, Train Accuracy: 0.9605, Validation Loss: 0.1046, Validation Accuracy: 0.9649
# Epoch [21/4000] - Train Loss: 0.1149, Train Accuracy: 0.9613, Validation Loss: 0.1064, Validation Accuracy: 0.9644
# Epoch [22/4000] - Train Loss: 0.1153, Train Accuracy: 0.9615, Validation Loss: 0.1034, Validation Accuracy: 0.9651
# Epoch [23/4000] - Train Loss: 0.1128, Train Accuracy: 0.9618, Validation Loss: 0.1016, Validation Accuracy: 0.9651
# Epoch [24/4000] - Train Loss: 0.1113, Train Accuracy: 0.9625, Validation Loss: 0.1009, Validation Accuracy: 0.9656
# Epoch [25/4000] - Train Loss: 0.1115, Train Accuracy: 0.9618, Validation Loss: 0.0995, Validation Accuracy: 0.9657
# Epoch [26/4000] - Train Loss: 0.1091, Train Accuracy: 0.9627, Validation Loss: 0.0991, Validation Accuracy: 0.9662
# Epoch [27/4000] - Train Loss: 0.1107, Train Accuracy: 0.9624, Validation Loss: 0.0977, Validation Accuracy: 0.9672
# Epoch [28/4000] - Train Loss: 0.1087, Train Accuracy: 0.9629, Validation Loss: 0.0998, Validation Accuracy: 0.9655
# Epoch [29/4000] - Train Loss: 0.1073, Train Accuracy: 0.9633, Validation Loss: 0.0981, Validation Accuracy: 0.9661
# Epoch [30/4000] - Train Loss: 0.1082, Train Accuracy: 0.9631, Validation Loss: 0.0984, Validation Accuracy: 0.9665
# Epoch [31/4000] - Train Loss: 0.1068, Train Accuracy: 0.9635, Validation Loss: 0.0964, Validation Accuracy: 0.9675
# Epoch [32/4000] - Train Loss: 0.1067, Train Accuracy: 0.9636, Validation Loss: 0.0959, Validation Accuracy: 0.9667
# Epoch [33/4000] - Train Loss: 0.1056, Train Accuracy: 0.9636, Validation Loss: 0.1032, Validation Accuracy: 0.9646
# Epoch [34/4000] - Train Loss: 0.1070, Train Accuracy: 0.9635, Validation Loss: 0.0964, Validation Accuracy: 0.9675
# Epoch [35/4000] - Train Loss: 0.1041, Train Accuracy: 0.9647, Validation Loss: 0.0965, Validation Accuracy: 0.9671
# Epoch [36/4000] - Train Loss: 0.1044, Train Accuracy: 0.9647, Validation Loss: 0.0950, Validation Accuracy: 0.9680
# Epoch [37/4000] - Train Loss: 0.1043, Train Accuracy: 0.9649, Validation Loss: 0.0957, Validation Accuracy: 0.9675
# Epoch [38/4000] - Train Loss: 0.1034, Train Accuracy: 0.9646, Validation Loss: 0.0945, Validation Accuracy: 0.9679
# Epoch [39/4000] - Train Loss: 0.1026, Train Accuracy: 0.9654, Validation Loss: 0.0948, Validation Accuracy: 0.9681
# Epoch [40/4000] - Train Loss: 0.1031, Train Accuracy: 0.9649, Validation Loss: 0.0950, Validation Accuracy: 0.9670
# Epoch [41/4000] - Train Loss: 0.1017, Train Accuracy: 0.9650, Validation Loss: 0.0952, Validation Accuracy: 0.9674
# Epoch [42/4000] - Train Loss: 0.1035, Train Accuracy: 0.9648, Validation Loss: 0.0983, Validation Accuracy: 0.9661
# Epoch [43/4000] - Train Loss: 0.1020, Train Accuracy: 0.9649, Validation Loss: 0.0939, Validation Accuracy: 0.9684
# Epoch [44/4000] - Train Loss: 0.1016, Train Accuracy: 0.9653, Validation Loss: 0.0944, Validation Accuracy: 0.9680
# Epoch [45/4000] - Train Loss: 0.1008, Train Accuracy: 0.9656, Validation Loss: 0.0955, Validation Accuracy: 0.9672
# Epoch [46/4000] - Train Loss: 0.1014, Train Accuracy: 0.9653, Validation Loss: 0.0927, Validation Accuracy: 0.9685
# Epoch [47/4000] - Train Loss: 0.1007, Train Accuracy: 0.9654, Validation Loss: 0.0932, Validation Accuracy: 0.9683
# Epoch [48/4000] - Train Loss: 0.1015, Train Accuracy: 0.9656, Validation Loss: 0.0990, Validation Accuracy: 0.9663
# Epoch [49/4000] - Train Loss: 0.1016, Train Accuracy: 0.9652, Validation Loss: 0.0920, Validation Accuracy: 0.9687
# Epoch [50/4000] - Train Loss: 0.1001, Train Accuracy: 0.9653, Validation Loss: 0.0924, Validation Accuracy: 0.9687
# Epoch [51/4000] - Train Loss: 0.0999, Train Accuracy: 0.9662, Validation Loss: 0.0919, Validation Accuracy: 0.9689
# Epoch [52/4000] - Train Loss: 0.1010, Train Accuracy: 0.9657, Validation Loss: 0.0916, Validation Accuracy: 0.9690
# Epoch [53/4000] - Train Loss: 0.1005, Train Accuracy: 0.9657, Validation Loss: 0.0916, Validation Accuracy: 0.9690
# Epoch [54/4000] - Train Loss: 0.0984, Train Accuracy: 0.9667, Validation Loss: 0.0931, Validation Accuracy: 0.9684
# Epoch [55/4000] - Train Loss: 0.0977, Train Accuracy: 0.9672, Validation Loss: 0.0917, Validation Accuracy: 0.9688
# Epoch [56/4000] - Train Loss: 0.0979, Train Accuracy: 0.9669, Validation Loss: 0.0932, Validation Accuracy: 0.9679
# Epoch [57/4000] - Train Loss: 0.1007, Train Accuracy: 0.9657, Validation Loss: 0.0905, Validation Accuracy: 0.9692
# Epoch [58/4000] - Train Loss: 0.0987, Train Accuracy: 0.9666, Validation Loss: 0.0906, Validation Accuracy: 0.9689
# Epoch [59/4000] - Train Loss: 0.0972, Train Accuracy: 0.9672, Validation Loss: 0.0918, Validation Accuracy: 0.9686
# Epoch [60/4000] - Train Loss: 0.0969, Train Accuracy: 0.9671, Validation Loss: 0.0932, Validation Accuracy: 0.9674
# Epoch [61/4000] - Train Loss: 0.0983, Train Accuracy: 0.9668, Validation Loss: 0.0909, Validation Accuracy: 0.9689
# Epoch [62/4000] - Train Loss: 0.0962, Train Accuracy: 0.9672, Validation Loss: 0.0898, Validation Accuracy: 0.9693
# Epoch [63/4000] - Train Loss: 0.0975, Train Accuracy: 0.9669, Validation Loss: 0.0906, Validation Accuracy: 0.9691
# Epoch [64/4000] - Train Loss: 0.0954, Train Accuracy: 0.9675, Validation Loss: 0.0949, Validation Accuracy: 0.9665
# Epoch [65/4000] - Train Loss: 0.0973, Train Accuracy: 0.9671, Validation Loss: 0.0903, Validation Accuracy: 0.9697
# Epoch [66/4000] - Train Loss: 0.0957, Train Accuracy: 0.9679, Validation Loss: 0.0894, Validation Accuracy: 0.9701
# Epoch [67/4000] - Train Loss: 0.0963, Train Accuracy: 0.9673, Validation Loss: 0.0887, Validation Accuracy: 0.9703
# Epoch [68/4000] - Train Loss: 0.0959, Train Accuracy: 0.9679, Validation Loss: 0.0882, Validation Accuracy: 0.9705
# Epoch [69/4000] - Train Loss: 0.0955, Train Accuracy: 0.9679, Validation Loss: 0.0878, Validation Accuracy: 0.9709
# Epoch [70/4000] - Train Loss: 0.0948, Train Accuracy: 0.9681, Validation Loss: 0.0881, Validation Accuracy: 0.9706
# Epoch [71/4000] - Train Loss: 0.0945, Train Accuracy: 0.9682, Validation Loss: 0.0888, Validation Accuracy: 0.9705
# Epoch [72/4000] - Train Loss: 0.0944, Train Accuracy: 0.9686, Validation Loss: 0.0876, Validation Accuracy: 0.9700
# Epoch [73/4000] - Train Loss: 0.0939, Train Accuracy: 0.9684, Validation Loss: 0.0875, Validation Accuracy: 0.9703
# Epoch [74/4000] - Train Loss: 0.0936, Train Accuracy: 0.9690, Validation Loss: 0.0872, Validation Accuracy: 0.9708
# Epoch [75/4000] - Train Loss: 0.0934, Train Accuracy: 0.9687, Validation Loss: 0.0878, Validation Accuracy: 0.9698
# Epoch [76/4000] - Train Loss: 0.0924, Train Accuracy: 0.9691, Validation Loss: 0.0878, Validation Accuracy: 0.9703
# Epoch [77/4000] - Train Loss: 0.0941, Train Accuracy: 0.9684, Validation Loss: 0.0879, Validation Accuracy: 0.9699
# Epoch [78/4000] - Train Loss: 0.0926, Train Accuracy: 0.9690, Validation Loss: 0.0887, Validation Accuracy: 0.9694
# Epoch [79/4000] - Train Loss: 0.0920, Train Accuracy: 0.9696, Validation Loss: 0.0858, Validation Accuracy: 0.9712
# Epoch [80/4000] - Train Loss: 0.0914, Train Accuracy: 0.9689, Validation Loss: 0.0884, Validation Accuracy: 0.9698
# Epoch [81/4000] - Train Loss: 0.0911, Train Accuracy: 0.9697, Validation Loss: 0.0879, Validation Accuracy: 0.9704
# Epoch [82/4000] - Train Loss: 0.0921, Train Accuracy: 0.9689, Validation Loss: 0.0855, Validation Accuracy: 0.9715
# Epoch [83/4000] - Train Loss: 0.0915, Train Accuracy: 0.9699, Validation Loss: 0.0862, Validation Accuracy: 0.9704
# Epoch [84/4000] - Train Loss: 0.0911, Train Accuracy: 0.9696, Validation Loss: 0.0849, Validation Accuracy: 0.9717
# Epoch [85/4000] - Train Loss: 0.0901, Train Accuracy: 0.9700, Validation Loss: 0.0858, Validation Accuracy: 0.9708
# Epoch [86/4000] - Train Loss: 0.0899, Train Accuracy: 0.9702, Validation Loss: 0.0905, Validation Accuracy: 0.9690
# Epoch [87/4000] - Train Loss: 0.0913, Train Accuracy: 0.9694, Validation Loss: 0.0865, Validation Accuracy: 0.9703
# Epoch [88/4000] - Train Loss: 0.0899, Train Accuracy: 0.9703, Validation Loss: 0.0852, Validation Accuracy: 0.9716
# Epoch [89/4000] - Train Loss: 0.0895, Train Accuracy: 0.9707, Validation Loss: 0.0910, Validation Accuracy: 0.9684
# Epoch [90/4000] - Train Loss: 0.0899, Train Accuracy: 0.9701, Validation Loss: 0.0855, Validation Accuracy: 0.9711
# Epoch [91/4000] - Train Loss: 0.0897, Train Accuracy: 0.9701, Validation Loss: 0.0842, Validation Accuracy: 0.9715
# Epoch [92/4000] - Train Loss: 0.0893, Train Accuracy: 0.9699, Validation Loss: 0.0836, Validation Accuracy: 0.9721
# Epoch [93/4000] - Train Loss: 0.0887, Train Accuracy: 0.9706, Validation Loss: 0.0892, Validation Accuracy: 0.9680
# Epoch [94/4000] - Train Loss: 0.0905, Train Accuracy: 0.9700, Validation Loss: 0.0848, Validation Accuracy: 0.9711
# Epoch [95/4000] - Train Loss: 0.0888, Train Accuracy: 0.9707, Validation Loss: 0.0848, Validation Accuracy: 0.9724
# Epoch [96/4000] - Train Loss: 0.0877, Train Accuracy: 0.9709, Validation Loss: 0.0843, Validation Accuracy: 0.9720
# Epoch [97/4000] - Train Loss: 0.0887, Train Accuracy: 0.9705, Validation Loss: 0.0842, Validation Accuracy: 0.9708
# Epoch [98/4000] - Train Loss: 0.0880, Train Accuracy: 0.9708, Validation Loss: 0.0848, Validation Accuracy: 0.9710
# Epoch [99/4000] - Train Loss: 0.0889, Train Accuracy: 0.9708, Validation Loss: 0.0859, Validation Accuracy: 0.9715
# Epoch [100/4000] - Train Loss: 0.0881, Train Accuracy: 0.9709, Validation Loss: 0.0827, Validation Accuracy: 0.9723
# Epoch [101/4000] - Train Loss: 0.0873, Train Accuracy: 0.9711, Validation Loss: 0.0847, Validation Accuracy: 0.9718
# Epoch [102/4000] - Train Loss: 0.0885, Train Accuracy: 0.9709, Validation Loss: 0.0847, Validation Accuracy: 0.9707
# Epoch [103/4000] - Train Loss: 0.0881, Train Accuracy: 0.9710, Validation Loss: 0.0831, Validation Accuracy: 0.9718
# Epoch [104/4000] - Train Loss: 0.0874, Train Accuracy: 0.9710, Validation Loss: 0.0829, Validation Accuracy: 0.9731
# Epoch [105/4000] - Train Loss: 0.0880, Train Accuracy: 0.9711, Validation Loss: 0.0901, Validation Accuracy: 0.9694
# Epoch [106/4000] - Train Loss: 0.0872, Train Accuracy: 0.9718, Validation Loss: 0.0823, Validation Accuracy: 0.9723
# Epoch [107/4000] - Train Loss: 0.0889, Train Accuracy: 0.9706, Validation Loss: 0.0852, Validation Accuracy: 0.9723
# Epoch [108/4000] - Train Loss: 0.0870, Train Accuracy: 0.9715, Validation Loss: 0.0825, Validation Accuracy: 0.9723
# Epoch [109/4000] - Train Loss: 0.0867, Train Accuracy: 0.9719, Validation Loss: 0.0821, Validation Accuracy: 0.9726
# Epoch [110/4000] - Train Loss: 0.0859, Train Accuracy: 0.9722, Validation Loss: 0.0815, Validation Accuracy: 0.9733
# Epoch [111/4000] - Train Loss: 0.0854, Train Accuracy: 0.9721, Validation Loss: 0.0826, Validation Accuracy: 0.9727
# Epoch [112/4000] - Train Loss: 0.0860, Train Accuracy: 0.9720, Validation Loss: 0.0843, Validation Accuracy: 0.9722
# Epoch [113/4000] - Train Loss: 0.0860, Train Accuracy: 0.9720, Validation Loss: 0.0822, Validation Accuracy: 0.9722
# Epoch [114/4000] - Train Loss: 0.0857, Train Accuracy: 0.9722, Validation Loss: 0.0812, Validation Accuracy: 0.9737
# Epoch [115/4000] - Train Loss: 0.0852, Train Accuracy: 0.9722, Validation Loss: 0.0810, Validation Accuracy: 0.9725
# Epoch [116/4000] - Train Loss: 0.0854, Train Accuracy: 0.9722, Validation Loss: 0.0830, Validation Accuracy: 0.9709
# Epoch [117/4000] - Train Loss: 0.0848, Train Accuracy: 0.9719, Validation Loss: 0.0845, Validation Accuracy: 0.9711
# Epoch [118/4000] - Train Loss: 0.0851, Train Accuracy: 0.9723, Validation Loss: 0.0810, Validation Accuracy: 0.9733
# Epoch [119/4000] - Train Loss: 0.0849, Train Accuracy: 0.9721, Validation Loss: 0.0829, Validation Accuracy: 0.9726
# Epoch [120/4000] - Train Loss: 0.0854, Train Accuracy: 0.9722, Validation Loss: 0.0806, Validation Accuracy: 0.9728
# Epoch [121/4000] - Train Loss: 0.0846, Train Accuracy: 0.9727, Validation Loss: 0.0797, Validation Accuracy: 0.9736
# Epoch [122/4000] - Train Loss: 0.0866, Train Accuracy: 0.9713, Validation Loss: 0.0812, Validation Accuracy: 0.9722
# Epoch [123/4000] - Train Loss: 0.0849, Train Accuracy: 0.9722, Validation Loss: 0.0798, Validation Accuracy: 0.9728
# Epoch [124/4000] - Train Loss: 0.0840, Train Accuracy: 0.9719, Validation Loss: 0.0804, Validation Accuracy: 0.9735
# Epoch [125/4000] - Train Loss: 0.0854, Train Accuracy: 0.9725, Validation Loss: 0.0805, Validation Accuracy: 0.9740
# Epoch [126/4000] - Train Loss: 0.0834, Train Accuracy: 0.9726, Validation Loss: 0.0796, Validation Accuracy: 0.9734
# Epoch [127/4000] - Train Loss: 0.0833, Train Accuracy: 0.9726, Validation Loss: 0.0808, Validation Accuracy: 0.9721
# Epoch [128/4000] - Train Loss: 0.0833, Train Accuracy: 0.9729, Validation Loss: 0.0801, Validation Accuracy: 0.9728
# Epoch [129/4000] - Train Loss: 0.0843, Train Accuracy: 0.9725, Validation Loss: 0.0813, Validation Accuracy: 0.9720
# Epoch [130/4000] - Train Loss: 0.0854, Train Accuracy: 0.9718, Validation Loss: 0.0847, Validation Accuracy: 0.9702
# Epoch [131/4000] - Train Loss: 0.0844, Train Accuracy: 0.9722, Validation Loss: 0.0804, Validation Accuracy: 0.9728
# Epoch [132/4000] - Train Loss: 0.0824, Train Accuracy: 0.9729, Validation Loss: 0.0788, Validation Accuracy: 0.9733
# Epoch [133/4000] - Train Loss: 0.0841, Train Accuracy: 0.9723, Validation Loss: 0.0792, Validation Accuracy: 0.9737
# Epoch [134/4000] - Train Loss: 0.0841, Train Accuracy: 0.9727, Validation Loss: 0.0795, Validation Accuracy: 0.9734
# Epoch [135/4000] - Train Loss: 0.0825, Train Accuracy: 0.9729, Validation Loss: 0.0797, Validation Accuracy: 0.9740
# Epoch [136/4000] - Train Loss: 0.0834, Train Accuracy: 0.9727, Validation Loss: 0.0798, Validation Accuracy: 0.9733
# Epoch [137/4000] - Train Loss: 0.0825, Train Accuracy: 0.9734, Validation Loss: 0.0782, Validation Accuracy: 0.9740
# Epoch [138/4000] - Train Loss: 0.0842, Train Accuracy: 0.9723, Validation Loss: 0.0784, Validation Accuracy: 0.9736
# Epoch [139/4000] - Train Loss: 0.0826, Train Accuracy: 0.9729, Validation Loss: 0.0814, Validation Accuracy: 0.9735
# Epoch [140/4000] - Train Loss: 0.0826, Train Accuracy: 0.9734, Validation Loss: 0.0784, Validation Accuracy: 0.9741
# Epoch [141/4000] - Train Loss: 0.0819, Train Accuracy: 0.9732, Validation Loss: 0.0809, Validation Accuracy: 0.9723
# Epoch [142/4000] - Train Loss: 0.0819, Train Accuracy: 0.9734, Validation Loss: 0.0804, Validation Accuracy: 0.9737
# Epoch [143/4000] - Train Loss: 0.0830, Train Accuracy: 0.9727, Validation Loss: 0.0788, Validation Accuracy: 0.9735
# Epoch [144/4000] - Train Loss: 0.0828, Train Accuracy: 0.9725, Validation Loss: 0.0809, Validation Accuracy: 0.9737
# Epoch [145/4000] - Train Loss: 0.0818, Train Accuracy: 0.9735, Validation Loss: 0.0780, Validation Accuracy: 0.9738
# Epoch [146/4000] - Train Loss: 0.0815, Train Accuracy: 0.9733, Validation Loss: 0.0810, Validation Accuracy: 0.9732
# Epoch [147/4000] - Train Loss: 0.0818, Train Accuracy: 0.9736, Validation Loss: 0.0784, Validation Accuracy: 0.9734
# Epoch [148/4000] - Train Loss: 0.0822, Train Accuracy: 0.9732, Validation Loss: 0.0777, Validation Accuracy: 0.9735
# Epoch [149/4000] - Train Loss: 0.0829, Train Accuracy: 0.9730, Validation Loss: 0.0812, Validation Accuracy: 0.9722
# Epoch [150/4000] - Train Loss: 0.0821, Train Accuracy: 0.9732, Validation Loss: 0.0785, Validation Accuracy: 0.9730
# Epoch [151/4000] - Train Loss: 0.0829, Train Accuracy: 0.9730, Validation Loss: 0.0776, Validation Accuracy: 0.9739
# Epoch [152/4000] - Train Loss: 0.0815, Train Accuracy: 0.9732, Validation Loss: 0.0782, Validation Accuracy: 0.9729
# Epoch [153/4000] - Train Loss: 0.0814, Train Accuracy: 0.9735, Validation Loss: 0.0777, Validation Accuracy: 0.9739
# Epoch [154/4000] - Train Loss: 0.0814, Train Accuracy: 0.9736, Validation Loss: 0.0772, Validation Accuracy: 0.9738
# Epoch [155/4000] - Train Loss: 0.0810, Train Accuracy: 0.9738, Validation Loss: 0.0820, Validation Accuracy: 0.9733
# Epoch [156/4000] - Train Loss: 0.0803, Train Accuracy: 0.9738, Validation Loss: 0.0766, Validation Accuracy: 0.9740
# Epoch [157/4000] - Train Loss: 0.0813, Train Accuracy: 0.9733, Validation Loss: 0.0779, Validation Accuracy: 0.9735
# Epoch [158/4000] - Train Loss: 0.0804, Train Accuracy: 0.9737, Validation Loss: 0.0769, Validation Accuracy: 0.9739
# Epoch [159/4000] - Train Loss: 0.0806, Train Accuracy: 0.9735, Validation Loss: 0.0786, Validation Accuracy: 0.9733
# Epoch [160/4000] - Train Loss: 0.0813, Train Accuracy: 0.9734, Validation Loss: 0.0773, Validation Accuracy: 0.9737
# Epoch [161/4000] - Train Loss: 0.0811, Train Accuracy: 0.9731, Validation Loss: 0.0768, Validation Accuracy: 0.9745
# Epoch [162/4000] - Train Loss: 0.0807, Train Accuracy: 0.9741, Validation Loss: 0.0785, Validation Accuracy: 0.9746
# Epoch [163/4000] - Train Loss: 0.0808, Train Accuracy: 0.9736, Validation Loss: 0.0763, Validation Accuracy: 0.9743
# Epoch [164/4000] - Train Loss: 0.0794, Train Accuracy: 0.9741, Validation Loss: 0.0769, Validation Accuracy: 0.9751
# Epoch [165/4000] - Train Loss: 0.0800, Train Accuracy: 0.9739, Validation Loss: 0.0787, Validation Accuracy: 0.9721
# Epoch [166/4000] - Train Loss: 0.0792, Train Accuracy: 0.9740, Validation Loss: 0.0758, Validation Accuracy: 0.9748
# Epoch [167/4000] - Train Loss: 0.0795, Train Accuracy: 0.9738, Validation Loss: 0.0781, Validation Accuracy: 0.9743
# Epoch [168/4000] - Train Loss: 0.0803, Train Accuracy: 0.9737, Validation Loss: 0.0761, Validation Accuracy: 0.9736
# Epoch [169/4000] - Train Loss: 0.0795, Train Accuracy: 0.9743, Validation Loss: 0.0762, Validation Accuracy: 0.9740
# Epoch [170/4000] - Train Loss: 0.0803, Train Accuracy: 0.9740, Validation Loss: 0.0771, Validation Accuracy: 0.9740
# Epoch [171/4000] - Train Loss: 0.0793, Train Accuracy: 0.9740, Validation Loss: 0.0770, Validation Accuracy: 0.9747
# Epoch [172/4000] - Train Loss: 0.0792, Train Accuracy: 0.9739, Validation Loss: 0.0772, Validation Accuracy: 0.9740
# Epoch [173/4000] - Train Loss: 0.0786, Train Accuracy: 0.9742, Validation Loss: 0.0756, Validation Accuracy: 0.9743
# Epoch [174/4000] - Train Loss: 0.0813, Train Accuracy: 0.9733, Validation Loss: 0.0748, Validation Accuracy: 0.9749
# Epoch [175/4000] - Train Loss: 0.0794, Train Accuracy: 0.9741, Validation Loss: 0.0758, Validation Accuracy: 0.9744
# Epoch [176/4000] - Train Loss: 0.0790, Train Accuracy: 0.9744, Validation Loss: 0.0745, Validation Accuracy: 0.9748
# Epoch [177/4000] - Train Loss: 0.0796, Train Accuracy: 0.9739, Validation Loss: 0.0747, Validation Accuracy: 0.9746
# Epoch [178/4000] - Train Loss: 0.0786, Train Accuracy: 0.9742, Validation Loss: 0.0751, Validation Accuracy: 0.9743
# Epoch [179/4000] - Train Loss: 0.0782, Train Accuracy: 0.9744, Validation Loss: 0.0747, Validation Accuracy: 0.9742
# Epoch [180/4000] - Train Loss: 0.0789, Train Accuracy: 0.9743, Validation Loss: 0.0762, Validation Accuracy: 0.9741
# Epoch [181/4000] - Train Loss: 0.0785, Train Accuracy: 0.9745, Validation Loss: 0.0749, Validation Accuracy: 0.9750
# Epoch [182/4000] - Train Loss: 0.0782, Train Accuracy: 0.9742, Validation Loss: 0.0742, Validation Accuracy: 0.9753
# Epoch [183/4000] - Train Loss: 0.0794, Train Accuracy: 0.9739, Validation Loss: 0.0770, Validation Accuracy: 0.9746
# Epoch [184/4000] - Train Loss: 0.0784, Train Accuracy: 0.9743, Validation Loss: 0.0753, Validation Accuracy: 0.9746
# Epoch [185/4000] - Train Loss: 0.0785, Train Accuracy: 0.9741, Validation Loss: 0.0737, Validation Accuracy: 0.9754
# Epoch [186/4000] - Train Loss: 0.0783, Train Accuracy: 0.9744, Validation Loss: 0.0752, Validation Accuracy: 0.9755
# Epoch [187/4000] - Train Loss: 0.0776, Train Accuracy: 0.9748, Validation Loss: 0.0744, Validation Accuracy: 0.9751
# Epoch [188/4000] - Train Loss: 0.0781, Train Accuracy: 0.9744, Validation Loss: 0.0741, Validation Accuracy: 0.9748
# Epoch [189/4000] - Train Loss: 0.0770, Train Accuracy: 0.9747, Validation Loss: 0.0734, Validation Accuracy: 0.9752
# Epoch [190/4000] - Train Loss: 0.0770, Train Accuracy: 0.9747, Validation Loss: 0.0781, Validation Accuracy: 0.9729
# Epoch [191/4000] - Train Loss: 0.0779, Train Accuracy: 0.9743, Validation Loss: 0.0743, Validation Accuracy: 0.9751
# Epoch [192/4000] - Train Loss: 0.0781, Train Accuracy: 0.9747, Validation Loss: 0.0734, Validation Accuracy: 0.9751
# Epoch [193/4000] - Train Loss: 0.0773, Train Accuracy: 0.9744, Validation Loss: 0.0741, Validation Accuracy: 0.9745
# Epoch [194/4000] - Train Loss: 0.0775, Train Accuracy: 0.9743, Validation Loss: 0.0771, Validation Accuracy: 0.9743
# Epoch [195/4000] - Train Loss: 0.0769, Train Accuracy: 0.9748, Validation Loss: 0.0747, Validation Accuracy: 0.9750
# Epoch [196/4000] - Train Loss: 0.0771, Train Accuracy: 0.9751, Validation Loss: 0.0735, Validation Accuracy: 0.9754
# Epoch [197/4000] - Train Loss: 0.0776, Train Accuracy: 0.9744, Validation Loss: 0.0762, Validation Accuracy: 0.9749
# Epoch [198/4000] - Train Loss: 0.0776, Train Accuracy: 0.9745, Validation Loss: 0.0738, Validation Accuracy: 0.9752
# Epoch [199/4000] - Train Loss: 0.0774, Train Accuracy: 0.9747, Validation Loss: 0.0726, Validation Accuracy: 0.9757
# Epoch [200/4000] - Train Loss: 0.0770, Train Accuracy: 0.9748, Validation Loss: 0.0729, Validation Accuracy: 0.9754
# Epoch [201/4000] - Train Loss: 0.0769, Train Accuracy: 0.9749, Validation Loss: 0.0724, Validation Accuracy: 0.9757
# Epoch [202/4000] - Train Loss: 0.0763, Train Accuracy: 0.9754, Validation Loss: 0.0724, Validation Accuracy: 0.9757
# Epoch [203/4000] - Train Loss: 0.0764, Train Accuracy: 0.9750, Validation Loss: 0.0744, Validation Accuracy: 0.9750
# Epoch [204/4000] - Train Loss: 0.0766, Train Accuracy: 0.9750, Validation Loss: 0.0723, Validation Accuracy: 0.9759
# Epoch [205/4000] - Train Loss: 0.0770, Train Accuracy: 0.9750, Validation Loss: 0.0739, Validation Accuracy: 0.9752
# Epoch [206/4000] - Train Loss: 0.0761, Train Accuracy: 0.9750, Validation Loss: 0.0731, Validation Accuracy: 0.9757
# Epoch [207/4000] - Train Loss: 0.0776, Train Accuracy: 0.9745, Validation Loss: 0.0718, Validation Accuracy: 0.9757
# Epoch [208/4000] - Train Loss: 0.0764, Train Accuracy: 0.9750, Validation Loss: 0.0756, Validation Accuracy: 0.9746
# Epoch [209/4000] - Train Loss: 0.0764, Train Accuracy: 0.9748, Validation Loss: 0.0748, Validation Accuracy: 0.9755
# Epoch [210/4000] - Train Loss: 0.0755, Train Accuracy: 0.9754, Validation Loss: 0.0719, Validation Accuracy: 0.9760
# Epoch [211/4000] - Train Loss: 0.0757, Train Accuracy: 0.9752, Validation Loss: 0.0725, Validation Accuracy: 0.9752
# Epoch [212/4000] - Train Loss: 0.0760, Train Accuracy: 0.9753, Validation Loss: 0.0734, Validation Accuracy: 0.9749
# Epoch [213/4000] - Train Loss: 0.0764, Train Accuracy: 0.9748, Validation Loss: 0.0723, Validation Accuracy: 0.9762
# Epoch [214/4000] - Train Loss: 0.0752, Train Accuracy: 0.9754, Validation Loss: 0.0742, Validation Accuracy: 0.9747
# Epoch [215/4000] - Train Loss: 0.0754, Train Accuracy: 0.9756, Validation Loss: 0.0717, Validation Accuracy: 0.9755
# Epoch [216/4000] - Train Loss: 0.0748, Train Accuracy: 0.9754, Validation Loss: 0.0722, Validation Accuracy: 0.9764
# Epoch [217/4000] - Train Loss: 0.0756, Train Accuracy: 0.9751, Validation Loss: 0.0713, Validation Accuracy: 0.9757
# Epoch [218/4000] - Train Loss: 0.0745, Train Accuracy: 0.9757, Validation Loss: 0.0724, Validation Accuracy: 0.9750
# Epoch [219/4000] - Train Loss: 0.0757, Train Accuracy: 0.9751, Validation Loss: 0.0723, Validation Accuracy: 0.9753
# Epoch [220/4000] - Train Loss: 0.0752, Train Accuracy: 0.9756, Validation Loss: 0.0725, Validation Accuracy: 0.9755
# Epoch [221/4000] - Train Loss: 0.0747, Train Accuracy: 0.9755, Validation Loss: 0.0717, Validation Accuracy: 0.9754
# Epoch [222/4000] - Train Loss: 0.0753, Train Accuracy: 0.9756, Validation Loss: 0.0717, Validation Accuracy: 0.9759
# Epoch [223/4000] - Train Loss: 0.0744, Train Accuracy: 0.9756, Validation Loss: 0.0714, Validation Accuracy: 0.9759
# Epoch [224/4000] - Train Loss: 0.0749, Train Accuracy: 0.9755, Validation Loss: 0.0744, Validation Accuracy: 0.9754
# Epoch [225/4000] - Train Loss: 0.0745, Train Accuracy: 0.9755, Validation Loss: 0.0712, Validation Accuracy: 0.9758
# Epoch [226/4000] - Train Loss: 0.0754, Train Accuracy: 0.9750, Validation Loss: 0.0746, Validation Accuracy: 0.9751
# Epoch [227/4000] - Train Loss: 0.0753, Train Accuracy: 0.9757, Validation Loss: 0.0720, Validation Accuracy: 0.9759
# Epoch [228/4000] - Train Loss: 0.0739, Train Accuracy: 0.9756, Validation Loss: 0.0709, Validation Accuracy: 0.9755
# Epoch [229/4000] - Train Loss: 0.0752, Train Accuracy: 0.9750, Validation Loss: 0.0706, Validation Accuracy: 0.9757
# Epoch [230/4000] - Train Loss: 0.0745, Train Accuracy: 0.9755, Validation Loss: 0.0708, Validation Accuracy: 0.9765
# Epoch [231/4000] - Train Loss: 0.0746, Train Accuracy: 0.9754, Validation Loss: 0.0710, Validation Accuracy: 0.9763
# Epoch [232/4000] - Train Loss: 0.0743, Train Accuracy: 0.9757, Validation Loss: 0.0709, Validation Accuracy: 0.9755
# Epoch [233/4000] - Train Loss: 0.0746, Train Accuracy: 0.9753, Validation Loss: 0.0709, Validation Accuracy: 0.9761
# Epoch [234/4000] - Train Loss: 0.0740, Train Accuracy: 0.9760, Validation Loss: 0.0725, Validation Accuracy: 0.9762
# Epoch [235/4000] - Train Loss: 0.0747, Train Accuracy: 0.9755, Validation Loss: 0.0709, Validation Accuracy: 0.9755
# Epoch [236/4000] - Train Loss: 0.0756, Train Accuracy: 0.9754, Validation Loss: 0.0716, Validation Accuracy: 0.9755
# Epoch [237/4000] - Train Loss: 0.0741, Train Accuracy: 0.9759, Validation Loss: 0.0702, Validation Accuracy: 0.9763
# Epoch [238/4000] - Train Loss: 0.0746, Train Accuracy: 0.9755, Validation Loss: 0.0797, Validation Accuracy: 0.9711
# Epoch [239/4000] - Train Loss: 0.0761, Train Accuracy: 0.9751, Validation Loss: 0.0716, Validation Accuracy: 0.9759
# Epoch [240/4000] - Train Loss: 0.0734, Train Accuracy: 0.9759, Validation Loss: 0.0713, Validation Accuracy: 0.9764
# Epoch [241/4000] - Train Loss: 0.0732, Train Accuracy: 0.9762, Validation Loss: 0.0704, Validation Accuracy: 0.9760
# Epoch [242/4000] - Train Loss: 0.0740, Train Accuracy: 0.9759, Validation Loss: 0.0716, Validation Accuracy: 0.9763
# Epoch [243/4000] - Train Loss: 0.0738, Train Accuracy: 0.9753, Validation Loss: 0.0701, Validation Accuracy: 0.9760
# Epoch [244/4000] - Train Loss: 0.0742, Train Accuracy: 0.9757, Validation Loss: 0.0712, Validation Accuracy: 0.9757
# Epoch [245/4000] - Train Loss: 0.0732, Train Accuracy: 0.9756, Validation Loss: 0.0710, Validation Accuracy: 0.9759
# Epoch [246/4000] - Train Loss: 0.0752, Train Accuracy: 0.9755, Validation Loss: 0.0700, Validation Accuracy: 0.9762
# Epoch [247/4000] - Train Loss: 0.0731, Train Accuracy: 0.9762, Validation Loss: 0.0701, Validation Accuracy: 0.9756
# Epoch [248/4000] - Train Loss: 0.0719, Train Accuracy: 0.9758, Validation Loss: 0.0705, Validation Accuracy: 0.9760
# Epoch [249/4000] - Train Loss: 0.0732, Train Accuracy: 0.9761, Validation Loss: 0.0707, Validation Accuracy: 0.9763
# Epoch [250/4000] - Train Loss: 0.0733, Train Accuracy: 0.9757, Validation Loss: 0.0707, Validation Accuracy: 0.9760
# Epoch [251/4000] - Train Loss: 0.0736, Train Accuracy: 0.9760, Validation Loss: 0.0704, Validation Accuracy: 0.9761
# Epoch [252/4000] - Train Loss: 0.0730, Train Accuracy: 0.9763, Validation Loss: 0.0703, Validation Accuracy: 0.9757
# Epoch [253/4000] - Train Loss: 0.0744, Train Accuracy: 0.9757, Validation Loss: 0.0733, Validation Accuracy: 0.9744
# Epoch [254/4000] - Train Loss: 0.0731, Train Accuracy: 0.9759, Validation Loss: 0.0696, Validation Accuracy: 0.9762
# Epoch [255/4000] - Train Loss: 0.0729, Train Accuracy: 0.9761, Validation Loss: 0.0717, Validation Accuracy: 0.9759
# Epoch [256/4000] - Train Loss: 0.0725, Train Accuracy: 0.9763, Validation Loss: 0.0707, Validation Accuracy: 0.9759
# Epoch [257/4000] - Train Loss: 0.0723, Train Accuracy: 0.9761, Validation Loss: 0.0695, Validation Accuracy: 0.9758
# Epoch [258/4000] - Train Loss: 0.0728, Train Accuracy: 0.9764, Validation Loss: 0.0697, Validation Accuracy: 0.9761
# Epoch [259/4000] - Train Loss: 0.0730, Train Accuracy: 0.9761, Validation Loss: 0.0708, Validation Accuracy: 0.9762
# Epoch [260/4000] - Train Loss: 0.0722, Train Accuracy: 0.9764, Validation Loss: 0.0710, Validation Accuracy: 0.9758
# Epoch [261/4000] - Train Loss: 0.0720, Train Accuracy: 0.9763, Validation Loss: 0.0708, Validation Accuracy: 0.9764
# Epoch [262/4000] - Train Loss: 0.0724, Train Accuracy: 0.9765, Validation Loss: 0.0700, Validation Accuracy: 0.9758
# Epoch [263/4000] - Train Loss: 0.0722, Train Accuracy: 0.9763, Validation Loss: 0.0728, Validation Accuracy: 0.9758
# Epoch [264/4000] - Train Loss: 0.0725, Train Accuracy: 0.9761, Validation Loss: 0.0716, Validation Accuracy: 0.9760
# Epoch [265/4000] - Train Loss: 0.0718, Train Accuracy: 0.9764, Validation Loss: 0.0704, Validation Accuracy: 0.9764
# Epoch [266/4000] - Train Loss: 0.0720, Train Accuracy: 0.9765, Validation Loss: 0.0699, Validation Accuracy: 0.9755
# Epoch [267/4000] - Train Loss: 0.0719, Train Accuracy: 0.9763, Validation Loss: 0.0712, Validation Accuracy: 0.9753
# Epoch [268/4000] - Train Loss: 0.0729, Train Accuracy: 0.9759, Validation Loss: 0.0689, Validation Accuracy: 0.9766
# Epoch [269/4000] - Train Loss: 0.0724, Train Accuracy: 0.9760, Validation Loss: 0.0709, Validation Accuracy: 0.9766
# Epoch [270/4000] - Train Loss: 0.0726, Train Accuracy: 0.9755, Validation Loss: 0.0698, Validation Accuracy: 0.9753
# Epoch [271/4000] - Train Loss: 0.0717, Train Accuracy: 0.9763, Validation Loss: 0.0711, Validation Accuracy: 0.9760
# Epoch [272/4000] - Train Loss: 0.0721, Train Accuracy: 0.9761, Validation Loss: 0.0686, Validation Accuracy: 0.9765
# Epoch [273/4000] - Train Loss: 0.0722, Train Accuracy: 0.9764, Validation Loss: 0.0727, Validation Accuracy: 0.9759
# Epoch [274/4000] - Train Loss: 0.0731, Train Accuracy: 0.9760, Validation Loss: 0.0695, Validation Accuracy: 0.9766
# Epoch [275/4000] - Train Loss: 0.0713, Train Accuracy: 0.9767, Validation Loss: 0.0686, Validation Accuracy: 0.9764
# Epoch [276/4000] - Train Loss: 0.0721, Train Accuracy: 0.9766, Validation Loss: 0.0691, Validation Accuracy: 0.9762
# Epoch [277/4000] - Train Loss: 0.0718, Train Accuracy: 0.9765, Validation Loss: 0.0689, Validation Accuracy: 0.9764
# Epoch [278/4000] - Train Loss: 0.0711, Train Accuracy: 0.9766, Validation Loss: 0.0685, Validation Accuracy: 0.9761
# Epoch [279/4000] - Train Loss: 0.0712, Train Accuracy: 0.9766, Validation Loss: 0.0696, Validation Accuracy: 0.9767
# Epoch [280/4000] - Train Loss: 0.0710, Train Accuracy: 0.9772, Validation Loss: 0.0692, Validation Accuracy: 0.9770
# Epoch [281/4000] - Train Loss: 0.0706, Train Accuracy: 0.9767, Validation Loss: 0.0688, Validation Accuracy: 0.9763
# Epoch [282/4000] - Train Loss: 0.0715, Train Accuracy: 0.9766, Validation Loss: 0.0692, Validation Accuracy: 0.9764
# Epoch [283/4000] - Train Loss: 0.0716, Train Accuracy: 0.9764, Validation Loss: 0.0728, Validation Accuracy: 0.9764
# Epoch [284/4000] - Train Loss: 0.0715, Train Accuracy: 0.9765, Validation Loss: 0.0722, Validation Accuracy: 0.9761
# Epoch [285/4000] - Train Loss: 0.0704, Train Accuracy: 0.9773, Validation Loss: 0.0682, Validation Accuracy: 0.9763
# Epoch [286/4000] - Train Loss: 0.0706, Train Accuracy: 0.9769, Validation Loss: 0.0727, Validation Accuracy: 0.9751
# Epoch [287/4000] - Train Loss: 0.0719, Train Accuracy: 0.9763, Validation Loss: 0.0707, Validation Accuracy: 0.9766
# Epoch [288/4000] - Train Loss: 0.0713, Train Accuracy: 0.9764, Validation Loss: 0.0705, Validation Accuracy: 0.9760
# Epoch [289/4000] - Train Loss: 0.0708, Train Accuracy: 0.9767, Validation Loss: 0.0692, Validation Accuracy: 0.9769
# Epoch [290/4000] - Train Loss: 0.0698, Train Accuracy: 0.9770, Validation Loss: 0.0728, Validation Accuracy: 0.9743
# Epoch [291/4000] - Train Loss: 0.0714, Train Accuracy: 0.9766, Validation Loss: 0.0702, Validation Accuracy: 0.9768
# Epoch [292/4000] - Train Loss: 0.0706, Train Accuracy: 0.9766, Validation Loss: 0.0698, Validation Accuracy: 0.9764
# Epoch [293/4000] - Train Loss: 0.0716, Train Accuracy: 0.9766, Validation Loss: 0.0683, Validation Accuracy: 0.9763
# Epoch [294/4000] - Train Loss: 0.0717, Train Accuracy: 0.9765, Validation Loss: 0.0685, Validation Accuracy: 0.9768
# Epoch [295/4000] - Train Loss: 0.0700, Train Accuracy: 0.9772, Validation Loss: 0.0699, Validation Accuracy: 0.9770
# Epoch [296/4000] - Train Loss: 0.0702, Train Accuracy: 0.9768, Validation Loss: 0.0698, Validation Accuracy: 0.9768
# Epoch [297/4000] - Train Loss: 0.0708, Train Accuracy: 0.9768, Validation Loss: 0.0690, Validation Accuracy: 0.9763
# Epoch [298/4000] - Train Loss: 0.0706, Train Accuracy: 0.9766, Validation Loss: 0.0690, Validation Accuracy: 0.9770
# Epoch [299/4000] - Train Loss: 0.0705, Train Accuracy: 0.9767, Validation Loss: 0.0691, Validation Accuracy: 0.9764
# Epoch [300/4000] - Train Loss: 0.0710, Train Accuracy: 0.9766, Validation Loss: 0.0689, Validation Accuracy: 0.9764
# Epoch [301/4000] - Train Loss: 0.0710, Train Accuracy: 0.9765, Validation Loss: 0.0682, Validation Accuracy: 0.9771
# Epoch [302/4000] - Train Loss: 0.0703, Train Accuracy: 0.9770, Validation Loss: 0.0698, Validation Accuracy: 0.9756
# Epoch [303/4000] - Train Loss: 0.0703, Train Accuracy: 0.9771, Validation Loss: 0.0691, Validation Accuracy: 0.9762
# Epoch [304/4000] - Train Loss: 0.0704, Train Accuracy: 0.9769, Validation Loss: 0.0707, Validation Accuracy: 0.9761
# Epoch [305/4000] - Train Loss: 0.0710, Train Accuracy: 0.9766, Validation Loss: 0.0712, Validation Accuracy: 0.9764
# Epoch [306/4000] - Train Loss: 0.0699, Train Accuracy: 0.9770, Validation Loss: 0.0699, Validation Accuracy: 0.9758
# Epoch [307/4000] - Train Loss: 0.0700, Train Accuracy: 0.9766, Validation Loss: 0.0693, Validation Accuracy: 0.9764
# Epoch [308/4000] - Train Loss: 0.0697, Train Accuracy: 0.9768, Validation Loss: 0.0680, Validation Accuracy: 0.9768
# Epoch [309/4000] - Train Loss: 0.0707, Train Accuracy: 0.9769, Validation Loss: 0.0704, Validation Accuracy: 0.9757
# Epoch [310/4000] - Train Loss: 0.0697, Train Accuracy: 0.9766, Validation Loss: 0.0686, Validation Accuracy: 0.9763
# Epoch [311/4000] - Train Loss: 0.0691, Train Accuracy: 0.9774, Validation Loss: 0.0680, Validation Accuracy: 0.9773
# Epoch [312/4000] - Train Loss: 0.0699, Train Accuracy: 0.9767, Validation Loss: 0.0683, Validation Accuracy: 0.9766
# Epoch [313/4000] - Train Loss: 0.0688, Train Accuracy: 0.9774, Validation Loss: 0.0690, Validation Accuracy: 0.9768
# Epoch [314/4000] - Train Loss: 0.0698, Train Accuracy: 0.9766, Validation Loss: 0.0681, Validation Accuracy: 0.9765
# Epoch [315/4000] - Train Loss: 0.0693, Train Accuracy: 0.9774, Validation Loss: 0.0692, Validation Accuracy: 0.9767
# Epoch [316/4000] - Train Loss: 0.0695, Train Accuracy: 0.9771, Validation Loss: 0.0678, Validation Accuracy: 0.9766
# Epoch [317/4000] - Train Loss: 0.0703, Train Accuracy: 0.9765, Validation Loss: 0.0700, Validation Accuracy: 0.9764
# Epoch [318/4000] - Train Loss: 0.0712, Train Accuracy: 0.9767, Validation Loss: 0.0678, Validation Accuracy: 0.9768
# Epoch [319/4000] - Train Loss: 0.0690, Train Accuracy: 0.9772, Validation Loss: 0.0685, Validation Accuracy: 0.9765
# Epoch [320/4000] - Train Loss: 0.0700, Train Accuracy: 0.9769, Validation Loss: 0.0675, Validation Accuracy: 0.9769
# Epoch [321/4000] - Train Loss: 0.0688, Train Accuracy: 0.9773, Validation Loss: 0.0674, Validation Accuracy: 0.9773
# Epoch [322/4000] - Train Loss: 0.0692, Train Accuracy: 0.9771, Validation Loss: 0.0684, Validation Accuracy: 0.9769
# Epoch [323/4000] - Train Loss: 0.0697, Train Accuracy: 0.9769, Validation Loss: 0.0690, Validation Accuracy: 0.9768
# Epoch [324/4000] - Train Loss: 0.0682, Train Accuracy: 0.9773, Validation Loss: 0.0689, Validation Accuracy: 0.9770
# Epoch [325/4000] - Train Loss: 0.0695, Train Accuracy: 0.9769, Validation Loss: 0.0708, Validation Accuracy: 0.9760
# Epoch [326/4000] - Train Loss: 0.0690, Train Accuracy: 0.9774, Validation Loss: 0.0677, Validation Accuracy: 0.9769
# Epoch [327/4000] - Train Loss: 0.0685, Train Accuracy: 0.9775, Validation Loss: 0.0674, Validation Accuracy: 0.9765
# Epoch [328/4000] - Train Loss: 0.0697, Train Accuracy: 0.9772, Validation Loss: 0.0712, Validation Accuracy: 0.9768
# Epoch [329/4000] - Train Loss: 0.0688, Train Accuracy: 0.9773, Validation Loss: 0.0690, Validation Accuracy: 0.9765
# Epoch [330/4000] - Train Loss: 0.0690, Train Accuracy: 0.9773, Validation Loss: 0.0675, Validation Accuracy: 0.9772
# Epoch [331/4000] - Train Loss: 0.0694, Train Accuracy: 0.9773, Validation Loss: 0.0680, Validation Accuracy: 0.9774
# Epoch [332/4000] - Train Loss: 0.0687, Train Accuracy: 0.9772, Validation Loss: 0.0681, Validation Accuracy: 0.9772
# Epoch [333/4000] - Train Loss: 0.0681, Train Accuracy: 0.9775, Validation Loss: 0.0679, Validation Accuracy: 0.9770
# Epoch [334/4000] - Train Loss: 0.0682, Train Accuracy: 0.9775, Validation Loss: 0.0671, Validation Accuracy: 0.9773
# Epoch [335/4000] - Train Loss: 0.0684, Train Accuracy: 0.9774, Validation Loss: 0.0671, Validation Accuracy: 0.9773
# Epoch [336/4000] - Train Loss: 0.0682, Train Accuracy: 0.9777, Validation Loss: 0.0674, Validation Accuracy: 0.9776
# Epoch [337/4000] - Train Loss: 0.0675, Train Accuracy: 0.9778, Validation Loss: 0.0692, Validation Accuracy: 0.9761
# Epoch [338/4000] - Train Loss: 0.0688, Train Accuracy: 0.9772, Validation Loss: 0.0681, Validation Accuracy: 0.9765
# Epoch [339/4000] - Train Loss: 0.0692, Train Accuracy: 0.9774, Validation Loss: 0.0676, Validation Accuracy: 0.9768
# Epoch [340/4000] - Train Loss: 0.0677, Train Accuracy: 0.9783, Validation Loss: 0.0678, Validation Accuracy: 0.9768
# Epoch [341/4000] - Train Loss: 0.0699, Train Accuracy: 0.9767, Validation Loss: 0.0671, Validation Accuracy: 0.9773
# Epoch [342/4000] - Train Loss: 0.0680, Train Accuracy: 0.9777, Validation Loss: 0.0685, Validation Accuracy: 0.9766
# Epoch [343/4000] - Train Loss: 0.0684, Train Accuracy: 0.9774, Validation Loss: 0.0681, Validation Accuracy: 0.9773
# Epoch [344/4000] - Train Loss: 0.0682, Train Accuracy: 0.9776, Validation Loss: 0.0673, Validation Accuracy: 0.9778
# Epoch [345/4000] - Train Loss: 0.0675, Train Accuracy: 0.9775, Validation Loss: 0.0680, Validation Accuracy: 0.9775
# Epoch [346/4000] - Train Loss: 0.0677, Train Accuracy: 0.9775, Validation Loss: 0.0702, Validation Accuracy: 0.9774
# Epoch [347/4000] - Train Loss: 0.0679, Train Accuracy: 0.9776, Validation Loss: 0.0676, Validation Accuracy: 0.9772
# Epoch [348/4000] - Train Loss: 0.0686, Train Accuracy: 0.9775, Validation Loss: 0.0668, Validation Accuracy: 0.9774
# Epoch [349/4000] - Train Loss: 0.0683, Train Accuracy: 0.9776, Validation Loss: 0.0690, Validation Accuracy: 0.9768
# Epoch [350/4000] - Train Loss: 0.0682, Train Accuracy: 0.9774, Validation Loss: 0.0680, Validation Accuracy: 0.9773
# Epoch [351/4000] - Train Loss: 0.0667, Train Accuracy: 0.9781, Validation Loss: 0.0676, Validation Accuracy: 0.9776
# Epoch [352/4000] - Train Loss: 0.0673, Train Accuracy: 0.9779, Validation Loss: 0.0672, Validation Accuracy: 0.9771
# Epoch [353/4000] - Train Loss: 0.0675, Train Accuracy: 0.9778, Validation Loss: 0.0672, Validation Accuracy: 0.9773
# Epoch [354/4000] - Train Loss: 0.0673, Train Accuracy: 0.9777, Validation Loss: 0.0690, Validation Accuracy: 0.9769
# Epoch [355/4000] - Train Loss: 0.0666, Train Accuracy: 0.9781, Validation Loss: 0.0684, Validation Accuracy: 0.9766
# Epoch [356/4000] - Train Loss: 0.0673, Train Accuracy: 0.9780, Validation Loss: 0.0708, Validation Accuracy: 0.9769
# Epoch [357/4000] - Train Loss: 0.0674, Train Accuracy: 0.9780, Validation Loss: 0.0688, Validation Accuracy: 0.9763
# Epoch [358/4000] - Train Loss: 0.0682, Train Accuracy: 0.9776, Validation Loss: 0.0668, Validation Accuracy: 0.9779
# Epoch [359/4000] - Train Loss: 0.0669, Train Accuracy: 0.9780, Validation Loss: 0.0719, Validation Accuracy: 0.9769
# Epoch [360/4000] - Train Loss: 0.0677, Train Accuracy: 0.9777, Validation Loss: 0.0693, Validation Accuracy: 0.9755
# Epoch [361/4000] - Train Loss: 0.0676, Train Accuracy: 0.9779, Validation Loss: 0.0677, Validation Accuracy: 0.9775
# Epoch [362/4000] - Train Loss: 0.0672, Train Accuracy: 0.9782, Validation Loss: 0.0680, Validation Accuracy: 0.9774
# Epoch [363/4000] - Train Loss: 0.0675, Train Accuracy: 0.9776, Validation Loss: 0.0670, Validation Accuracy: 0.9770
# Epoch [364/4000] - Train Loss: 0.0672, Train Accuracy: 0.9781, Validation Loss: 0.0667, Validation Accuracy: 0.9771
# Epoch [365/4000] - Train Loss: 0.0676, Train Accuracy: 0.9777, Validation Loss: 0.0681, Validation Accuracy: 0.9774
# Epoch [366/4000] - Train Loss: 0.0674, Train Accuracy: 0.9775, Validation Loss: 0.0665, Validation Accuracy: 0.9775
# Epoch [367/4000] - Train Loss: 0.0675, Train Accuracy: 0.9781, Validation Loss: 0.0688, Validation Accuracy: 0.9764
# Epoch [368/4000] - Train Loss: 0.0685, Train Accuracy: 0.9772, Validation Loss: 0.0692, Validation Accuracy: 0.9773
# Epoch [369/4000] - Train Loss: 0.0678, Train Accuracy: 0.9775, Validation Loss: 0.0680, Validation Accuracy: 0.9768
# Epoch [370/4000] - Train Loss: 0.0670, Train Accuracy: 0.9780, Validation Loss: 0.0674, Validation Accuracy: 0.9776
# Epoch [371/4000] - Train Loss: 0.0672, Train Accuracy: 0.9776, Validation Loss: 0.0677, Validation Accuracy: 0.9776
# Epoch [372/4000] - Train Loss: 0.0678, Train Accuracy: 0.9775, Validation Loss: 0.0666, Validation Accuracy: 0.9773
# Epoch [373/4000] - Train Loss: 0.0664, Train Accuracy: 0.9779, Validation Loss: 0.0665, Validation Accuracy: 0.9770
# Epoch [374/4000] - Train Loss: 0.0669, Train Accuracy: 0.9776, Validation Loss: 0.0668, Validation Accuracy: 0.9769
# Epoch [375/4000] - Train Loss: 0.0658, Train Accuracy: 0.9783, Validation Loss: 0.0665, Validation Accuracy: 0.9775
# Epoch [376/4000] - Train Loss: 0.0671, Train Accuracy: 0.9777, Validation Loss: 0.0674, Validation Accuracy: 0.9772
# Epoch [377/4000] - Train Loss: 0.0664, Train Accuracy: 0.9782, Validation Loss: 0.0667, Validation Accuracy: 0.9777
# Epoch [378/4000] - Train Loss: 0.0664, Train Accuracy: 0.9783, Validation Loss: 0.0678, Validation Accuracy: 0.9775
# Epoch [379/4000] - Train Loss: 0.0665, Train Accuracy: 0.9780, Validation Loss: 0.0668, Validation Accuracy: 0.9778
# Epoch [380/4000] - Train Loss: 0.0667, Train Accuracy: 0.9777, Validation Loss: 0.0674, Validation Accuracy: 0.9769
# Epoch [381/4000] - Train Loss: 0.0651, Train Accuracy: 0.9785, Validation Loss: 0.0676, Validation Accuracy: 0.9780
# Epoch [382/4000] - Train Loss: 0.0663, Train Accuracy: 0.9781, Validation Loss: 0.0678, Validation Accuracy: 0.9774
# Epoch [383/4000] - Train Loss: 0.0661, Train Accuracy: 0.9780, Validation Loss: 0.0674, Validation Accuracy: 0.9769
# Epoch [384/4000] - Train Loss: 0.0663, Train Accuracy: 0.9776, Validation Loss: 0.0676, Validation Accuracy: 0.9769
# Epoch [385/4000] - Train Loss: 0.0661, Train Accuracy: 0.9782, Validation Loss: 0.0682, Validation Accuracy: 0.9773
# Epoch [386/4000] - Train Loss: 0.0659, Train Accuracy: 0.9783, Validation Loss: 0.0679, Validation Accuracy: 0.9776
# Epoch [387/4000] - Train Loss: 0.0661, Train Accuracy: 0.9784, Validation Loss: 0.0672, Validation Accuracy: 0.9778
# Epoch [388/4000] - Train Loss: 0.0666, Train Accuracy: 0.9779, Validation Loss: 0.0683, Validation Accuracy: 0.9775
# Epoch [389/4000] - Train Loss: 0.0659, Train Accuracy: 0.9781, Validation Loss: 0.0672, Validation Accuracy: 0.9775
# Epoch [390/4000] - Train Loss: 0.0664, Train Accuracy: 0.9783, Validation Loss: 0.0694, Validation Accuracy: 0.9776
# Epoch [391/4000] - Train Loss: 0.0657, Train Accuracy: 0.9789, Validation Loss: 0.0674, Validation Accuracy: 0.9776
# Epoch [392/4000] - Train Loss: 0.0667, Train Accuracy: 0.9782, Validation Loss: 0.0708, Validation Accuracy: 0.9768
# Epoch [393/4000] - Train Loss: 0.0662, Train Accuracy: 0.9782, Validation Loss: 0.0715, Validation Accuracy: 0.9772
# Epoch [394/4000] - Train Loss: 0.0657, Train Accuracy: 0.9781, Validation Loss: 0.0668, Validation Accuracy: 0.9777
# Epoch [395/4000] - Train Loss: 0.0657, Train Accuracy: 0.9784, Validation Loss: 0.0665, Validation Accuracy: 0.9781
# Epoch [396/4000] - Train Loss: 0.0661, Train Accuracy: 0.9780, Validation Loss: 0.0675, Validation Accuracy: 0.9770
# Epoch [397/4000] - Train Loss: 0.0644, Train Accuracy: 0.9788, Validation Loss: 0.0665, Validation Accuracy: 0.9776
# Epoch [398/4000] - Train Loss: 0.0657, Train Accuracy: 0.9787, Validation Loss: 0.0666, Validation Accuracy: 0.9775
# Epoch [399/4000] - Train Loss: 0.0657, Train Accuracy: 0.9786, Validation Loss: 0.0668, Validation Accuracy: 0.9776
# Epoch [400/4000] - Train Loss: 0.0657, Train Accuracy: 0.9783, Validation Loss: 0.0692, Validation Accuracy: 0.9770
# Epoch [401/4000] - Train Loss: 0.0652, Train Accuracy: 0.9784, Validation Loss: 0.0668, Validation Accuracy: 0.9772
# Epoch [402/4000] - Train Loss: 0.0650, Train Accuracy: 0.9786, Validation Loss: 0.0665, Validation Accuracy: 0.9777
# Epoch [403/4000] - Train Loss: 0.0657, Train Accuracy: 0.9781, Validation Loss: 0.0664, Validation Accuracy: 0.9777
# Epoch [404/4000] - Train Loss: 0.0653, Train Accuracy: 0.9785, Validation Loss: 0.0695, Validation Accuracy: 0.9770
# Epoch [405/4000] - Train Loss: 0.0658, Train Accuracy: 0.9785, Validation Loss: 0.0663, Validation Accuracy: 0.9779
# Epoch [406/4000] - Train Loss: 0.0658, Train Accuracy: 0.9784, Validation Loss: 0.0687, Validation Accuracy: 0.9768
# Epoch [407/4000] - Train Loss: 0.0655, Train Accuracy: 0.9783, Validation Loss: 0.0674, Validation Accuracy: 0.9774
# Epoch [408/4000] - Train Loss: 0.0654, Train Accuracy: 0.9784, Validation Loss: 0.0693, Validation Accuracy: 0.9772
# Epoch [409/4000] - Train Loss: 0.0666, Train Accuracy: 0.9777, Validation Loss: 0.0685, Validation Accuracy: 0.9769
# Epoch [410/4000] - Train Loss: 0.0658, Train Accuracy: 0.9783, Validation Loss: 0.0663, Validation Accuracy: 0.9776
# Epoch [411/4000] - Train Loss: 0.0664, Train Accuracy: 0.9779, Validation Loss: 0.0673, Validation Accuracy: 0.9773
# Epoch [412/4000] - Train Loss: 0.0662, Train Accuracy: 0.9780, Validation Loss: 0.0668, Validation Accuracy: 0.9773
# Epoch [413/4000] - Train Loss: 0.0648, Train Accuracy: 0.9786, Validation Loss: 0.0668, Validation Accuracy: 0.9771
# Epoch [414/4000] - Train Loss: 0.0651, Train Accuracy: 0.9782, Validation Loss: 0.0662, Validation Accuracy: 0.9773
# ...
# Epoch [485/4000] - Train Loss: 0.0629, Train Accuracy: 0.9791, Validation Loss: 0.0671, Validation Accuracy: 0.9777
# Epoch [486/4000] - Train Loss: 0.0635, Train Accuracy: 0.9786, Validation Loss: 0.0665, Validation Accuracy: 0.9779
# Epoch [487/4000] - Train Loss: 0.0632, Train Accuracy: 0.9788, Validation Loss: 0.0685, Validation Accuracy: 0.9776
# Epoch [488/4000] - Train Loss: 0.0642, Train Accuracy: 0.9788, Validation Loss: 0.0762, Validation Accuracy: 0.9762
# Epoch [489/4000] - Train Loss: 0.0623, Train Accuracy: 0.9794, Validation Loss: 0.0676, Validation Accuracy: 0.9778
# Epoch [490/4000] - Train Loss: 0.0623, Train Accuracy: 0.9795, Validation Loss: 0.0664, Validation Accuracy: 0.9775
# Epoch [491/4000] - Train Loss: 0.0620, Train Accuracy: 0.9796, Validation Loss: 0.0666, Validation Accuracy: 0.9775
# Epoch [492/4000] - Train Loss: 0.0621, Train Accuracy: 0.9790, Validation Loss: 0.0677, Validation Accuracy: 0.9776
# Epoch [493/4000] - Train Loss: 0.0625, Train Accuracy: 0.9794, Validation Loss: 0.0653, Validation Accuracy: 0.9780
# Epoch [494/4000] - Train Loss: 0.0635, Train Accuracy: 0.9788, Validation Loss: 0.0666, Validation Accuracy: 0.9773
# Epoch [495/4000] - Train Loss: 0.0621, Train Accuracy: 0.9794, Validation Loss: 0.0655, Validation Accuracy: 0.9781
# Epoch [496/4000] - Train Loss: 0.0620, Train Accuracy: 0.9794, Validation Loss: 0.0668, Validation Accuracy: 0.9779
# Epoch [497/4000] - Train Loss: 0.0624, Train Accuracy: 0.9792, Validation Loss: 0.0652, Validation Accuracy: 0.9785
# Epoch [498/4000] - Train Loss: 0.0626, Train Accuracy: 0.9794, Validation Loss: 0.0659, Validation Accuracy: 0.9788
# Epoch [499/4000] - Train Loss: 0.0623, Train Accuracy: 0.9794, Validation Loss: 0.0662, Validation Accuracy: 0.9777
# Epoch [500/4000] - Train Loss: 0.0629, Train Accuracy: 0.9789, Validation Loss: 0.0659, Validation Accuracy: 0.9784
# Epoch [501/4000] - Train Loss: 0.0628, Train Accuracy: 0.9787, Validation Loss: 0.0651, Validation Accuracy: 0.9785
# Epoch [502/4000] - Train Loss: 0.0622, Train Accuracy: 0.9795, Validation Loss: 0.0680, Validation Accuracy: 0.9778
# Epoch [503/4000] - Train Loss: 0.0616, Train Accuracy: 0.9795, Validation Loss: 0.0660, Validation Accuracy: 0.9779
# Epoch [504/4000] - Train Loss: 0.0623, Train Accuracy: 0.9793, Validation Loss: 0.0650, Validation Accuracy: 0.9786
# Epoch [505/4000] - Train Loss: 0.0625, Train Accuracy: 0.9793, Validation Loss: 0.0671, Validation Accuracy: 0.9782
# Epoch [506/4000] - Train Loss: 0.0623, Train Accuracy: 0.9796, Validation Loss: 0.0651, Validation Accuracy: 0.9782
# Epoch [507/4000] - Train Loss: 0.0613, Train Accuracy: 0.9796, Validation Loss: 0.0659, Validation Accuracy: 0.9783
# Epoch [508/4000] - Train Loss: 0.0625, Train Accuracy: 0.9794, Validation Loss: 0.0650, Validation Accuracy: 0.9790
# Epoch [509/4000] - Train Loss: 0.0617, Train Accuracy: 0.9794, Validation Loss: 0.0663, Validation Accuracy: 0.9779
# Epoch [510/4000] - Train Loss: 0.0616, Train Accuracy: 0.9790, Validation Loss: 0.0654, Validation Accuracy: 0.9780
# Epoch [511/4000] - Train Loss: 0.0628, Train Accuracy: 0.9790, Validation Loss: 0.0647, Validation Accuracy: 0.9781
# Epoch [512/4000] - Train Loss: 0.0631, Train Accuracy: 0.9794, Validation Loss: 0.0658, Validation Accuracy: 0.9787
# Epoch [513/4000] - Train Loss: 0.0623, Train Accuracy: 0.9794, Validation Loss: 0.0649, Validation Accuracy: 0.9782
# Epoch [514/4000] - Train Loss: 0.0619, Train Accuracy: 0.9793, Validation Loss: 0.0663, Validation Accuracy: 0.9784
# Epoch [515/4000] - Train Loss: 0.0623, Train Accuracy: 0.9790, Validation Loss: 0.0653, Validation Accuracy: 0.9779
# Epoch [516/4000] - Train Loss: 0.0619, Train Accuracy: 0.9795, Validation Loss: 0.0664, Validation Accuracy: 0.9783
# Epoch [517/4000] - Train Loss: 0.0624, Train Accuracy: 0.9792, Validation Loss: 0.0663, Validation Accuracy: 0.9781
# Epoch [518/4000] - Train Loss: 0.0616, Train Accuracy: 0.9793, Validation Loss: 0.0667, Validation Accuracy: 0.9782
# Epoch [519/4000] - Train Loss: 0.0626, Train Accuracy: 0.9791, Validation Loss: 0.0674, Validation Accuracy: 0.9781
# Epoch [520/4000] - Train Loss: 0.0623, Train Accuracy: 0.9792, Validation Loss: 0.0662, Validation Accuracy: 0.9782
# Epoch [521/4000] - Train Loss: 0.0614, Train Accuracy: 0.9797, Validation Loss: 0.0657, Validation Accuracy: 0.9787
# Epoch [522/4000] - Train Loss: 0.0621, Train Accuracy: 0.9795, Validation Loss: 0.0646, Validation Accuracy: 0.9782
# Epoch [523/4000] - Train Loss: 0.0610, Train Accuracy: 0.9797, Validation Loss: 0.0650, Validation Accuracy: 0.9782
# Epoch [524/4000] - Train Loss: 0.0613, Train Accuracy: 0.9793, Validation Loss: 0.0653, Validation Accuracy: 0.9777
# Epoch [525/4000] - Train Loss: 0.0618, Train Accuracy: 0.9794, Validation Loss: 0.0654, Validation Accuracy: 0.9781
# Epoch [526/4000] - Train Loss: 0.0617, Train Accuracy: 0.9798, Validation Loss: 0.0669, Validation Accuracy: 0.9780
# Epoch [527/4000] - Train Loss: 0.0612, Train Accuracy: 0.9794, Validation Loss: 0.0654, Validation Accuracy: 0.9783
# Epoch [528/4000] - Train Loss: 0.0617, Train Accuracy: 0.9794, Validation Loss: 0.0649, Validation Accuracy: 0.9785
# Epoch [529/4000] - Train Loss: 0.0617, Train Accuracy: 0.9794, Validation Loss: 0.0688, Validation Accuracy: 0.9769
# Epoch [530/4000] - Train Loss: 0.0618, Train Accuracy: 0.9795, Validation Loss: 0.0661, Validation Accuracy: 0.9781
# Epoch [531/4000] - Train Loss: 0.0617, Train Accuracy: 0.9795, Validation Loss: 0.0655, Validation Accuracy: 0.9785
# Epoch [532/4000] - Train Loss: 0.0602, Train Accuracy: 0.9798, Validation Loss: 0.0656, Validation Accuracy: 0.9786
# Epoch [533/4000] - Train Loss: 0.0606, Train Accuracy: 0.9797, Validation Loss: 0.0656, Validation Accuracy: 0.9787
# Epoch [534/4000] - Train Loss: 0.0611, Train Accuracy: 0.9796, Validation Loss: 0.0655, Validation Accuracy: 0.9784
# Epoch [535/4000] - Train Loss: 0.0619, Train Accuracy: 0.9789, Validation Loss: 0.0649, Validation Accuracy: 0.9788
# Epoch [536/4000] - Train Loss: 0.0605, Train Accuracy: 0.9797, Validation Loss: 0.0662, Validation Accuracy: 0.9780
# Epoch [537/4000] - Train Loss: 0.0610, Train Accuracy: 0.9795, Validation Loss: 0.0659, Validation Accuracy: 0.9785
# Epoch [538/4000] - Train Loss: 0.0614, Train Accuracy: 0.9797, Validation Loss: 0.0668, Validation Accuracy: 0.9782
# Epoch [539/4000] - Train Loss: 0.0613, Train Accuracy: 0.9795, Validation Loss: 0.0658, Validation Accuracy: 0.9781
# Epoch [540/4000] - Train Loss: 0.0618, Train Accuracy: 0.9792, Validation Loss: 0.0662, Validation Accuracy: 0.9781
# Epoch [541/4000] - Train Loss: 0.0620, Train Accuracy: 0.9795, Validation Loss: 0.0672, Validation Accuracy: 0.9778
# Epoch [542/4000] - Train Loss: 0.0611, Train Accuracy: 0.9798, Validation Loss: 0.0654, Validation Accuracy: 0.9780
# Epoch [543/4000] - Train Loss: 0.0607, Train Accuracy: 0.9797, Validation Loss: 0.0670, Validation Accuracy: 0.9781
# Epoch [544/4000] - Train Loss: 0.0604, Train Accuracy: 0.9796, Validation Loss: 0.0652, Validation Accuracy: 0.9784
# Epoch [545/4000] - Train Loss: 0.0609, Train Accuracy: 0.9800, Validation Loss: 0.0650, Validation Accuracy: 0.9783
# Epoch [546/4000] - Train Loss: 0.0597, Train Accuracy: 0.9799, Validation Loss: 0.0652, Validation Accuracy: 0.9783
# Epoch [547/4000] - Train Loss: 0.0605, Train Accuracy: 0.9794, Validation Loss: 0.0650, Validation Accuracy: 0.9788
# Epoch [548/4000] - Train Loss: 0.0600, Train Accuracy: 0.9801, Validation Loss: 0.0675, Validation Accuracy: 0.9776
# Epoch [549/4000] - Train Loss: 0.0610, Train Accuracy: 0.9796, Validation Loss: 0.0655, Validation Accuracy: 0.9785
# Epoch [550/4000] - Train Loss: 0.0606, Train Accuracy: 0.9800, Validation Loss: 0.0690, Validation Accuracy: 0.9776
# Epoch [551/4000] - Train Loss: 0.0609, Train Accuracy: 0.9794, Validation Loss: 0.0655, Validation Accuracy: 0.9783
# Epoch [552/4000] - Train Loss: 0.0601, Train Accuracy: 0.9801, Validation Loss: 0.0702, Validation Accuracy: 0.9780
# Epoch [553/4000] - Train Loss: 0.0606, Train Accuracy: 0.9802, Validation Loss: 0.0657, Validation Accuracy: 0.9782
# Epoch [554/4000] - Train Loss: 0.0608, Train Accuracy: 0.9804, Validation Loss: 0.0660, Validation Accuracy: 0.9778
# Epoch [555/4000] - Train Loss: 0.0610, Train Accuracy: 0.9798, Validation Loss: 0.0656, Validation Accuracy: 0.9780
# Epoch [556/4000] - Train Loss: 0.0603, Train Accuracy: 0.9802, Validation Loss: 0.0654, Validation Accuracy: 0.9781
# Epoch [557/4000] - Train Loss: 0.0614, Train Accuracy: 0.9793, Validation Loss: 0.0656, Validation Accuracy: 0.9789
# Epoch [558/4000] - Train Loss: 0.0608, Train Accuracy: 0.9799, Validation Loss: 0.0657, Validation Accuracy: 0.9782
# Epoch [559/4000] - Train Loss: 0.0610, Train Accuracy: 0.9795, Validation Loss: 0.0649, Validation Accuracy: 0.9783
# Epoch [560/4000] - Train Loss: 0.0606, Train Accuracy: 0.9796, Validation Loss: 0.0658, Validation Accuracy: 0.9782
# Epoch [561/4000] - Train Loss: 0.0597, Train Accuracy: 0.9802, Validation Loss: 0.0663, Validation Accuracy: 0.9782
# Epoch [562/4000] - Train Loss: 0.0606, Train Accuracy: 0.9793, Validation Loss: 0.0671, Validation Accuracy: 0.9780
# Epoch [563/4000] - Train Loss: 0.0614, Train Accuracy: 0.9796, Validation Loss: 0.0651, Validation Accuracy: 0.9779
# Epoch [564/4000] - Train Loss: 0.0598, Train Accuracy: 0.9802, Validation Loss: 0.0652, Validation Accuracy: 0.9784
# Epoch [565/4000] - Train Loss: 0.0606, Train Accuracy: 0.9796, Validation Loss: 0.0666, Validation Accuracy: 0.9777
# Epoch [566/4000] - Train Loss: 0.0610, Train Accuracy: 0.9796, Validation Loss: 0.0656, Validation Accuracy: 0.9784
# Epoch [567/4000] - Train Loss: 0.0604, Train Accuracy: 0.9799, Validation Loss: 0.0656, Validation Accuracy: 0.9780
# Epoch [568/4000] - Train Loss: 0.0600, Train Accuracy: 0.9800, Validation Loss: 0.0657, Validation Accuracy: 0.9783
# Epoch [569/4000] - Train Loss: 0.0611, Train Accuracy: 0.9799, Validation Loss: 0.0676, Validation Accuracy: 0.9773
# Epoch [570/4000] - Train Loss: 0.0603, Train Accuracy: 0.9796, Validation Loss: 0.0659, Validation Accuracy: 0.9783
# Epoch [571/4000] - Train Loss: 0.0598, Train Accuracy: 0.9798, Validation Loss: 0.0649, Validation Accuracy: 0.9784
# Epoch [572/4000] - Train Loss: 0.0592, Train Accuracy: 0.9801, Validation Loss: 0.0665, Validation Accuracy: 0.9785
# Epoch [573/4000] - Train Loss: 0.0606, Train Accuracy: 0.9803, Validation Loss: 0.0655, Validation Accuracy: 0.9786
# Epoch [574/4000] - Train Loss: 0.0600, Train Accuracy: 0.9803, Validation Loss: 0.0651, Validation Accuracy: 0.9781
# Epoch [575/4000] - Train Loss: 0.0598, Train Accuracy: 0.9800, Validation Loss: 0.0664, Validation Accuracy: 0.9785
# Epoch [576/4000] - Train Loss: 0.0601, Train Accuracy: 0.9799, Validation Loss: 0.0682, Validation Accuracy: 0.9776
# Epoch [577/4000] - Train Loss: 0.0603, Train Accuracy: 0.9800, Validation Loss: 0.0663, Validation Accuracy: 0.9779
# Epoch [578/4000] - Train Loss: 0.0597, Train Accuracy: 0.9799, Validation Loss: 0.0669, Validation Accuracy: 0.9783
# Epoch [579/4000] - Train Loss: 0.0594, Train Accuracy: 0.9800, Validation Loss: 0.0660, Validation Accuracy: 0.9779
# Epoch [580/4000] - Train Loss: 0.0604, Train Accuracy: 0.9798, Validation Loss: 0.0658, Validation Accuracy: 0.9782
# Epoch [581/4000] - Train Loss: 0.0604, Train Accuracy: 0.9797, Validation Loss: 0.0658, Validation Accuracy: 0.9779
# Epoch [582/4000] - Train Loss: 0.0602, Train Accuracy: 0.9801, Validation Loss: 0.0671, Validation Accuracy: 0.9781
# Epoch [583/4000] - Train Loss: 0.0591, Train Accuracy: 0.9803, Validation Loss: 0.0659, Validation Accuracy: 0.9785
# Epoch [584/4000] - Train Loss: 0.0591, Train Accuracy: 0.9798, Validation Loss: 0.0678, Validation Accuracy: 0.9784
# Epoch [585/4000] - Train Loss: 0.0608, Train Accuracy: 0.9794, Validation Loss: 0.0652, Validation Accuracy: 0.9786
# Epoch [586/4000] - Train Loss: 0.0597, Train Accuracy: 0.9801, Validation Loss: 0.0657, Validation Accuracy: 0.9785
# Epoch [587/4000] - Train Loss: 0.0609, Train Accuracy: 0.9792, Validation Loss: 0.0671, Validation Accuracy: 0.9775
# Epoch [588/4000] - Train Loss: 0.0595, Train Accuracy: 0.9801, Validation Loss: 0.0662, Validation Accuracy: 0.9787
# Epoch [589/4000] - Train Loss: 0.0600, Train Accuracy: 0.9799, Validation Loss: 0.0648, Validation Accuracy: 0.9779
# Epoch [590/4000] - Train Loss: 0.0602, Train Accuracy: 0.9799, Validation Loss: 0.0659, Validation Accuracy: 0.9785
# Epoch [591/4000] - Train Loss: 0.0596, Train Accuracy: 0.9798, Validation Loss: 0.0667, Validation Accuracy: 0.9779
# Epoch [592/4000] - Train Loss: 0.0598, Train Accuracy: 0.9801, Validation Loss: 0.0658, Validation Accuracy: 0.9781
# Epoch [593/4000] - Train Loss: 0.0588, Train Accuracy: 0.9806, Validation Loss: 0.0647, Validation Accuracy: 0.9787
# Epoch [594/4000] - Train Loss: 0.0596, Train Accuracy: 0.9801, Validation Loss: 0.0657, Validation Accuracy: 0.9785
# Epoch [595/4000] - Train Loss: 0.0602, Train Accuracy: 0.9800, Validation Loss: 0.0659, Validation Accuracy: 0.9777
# Epoch [596/4000] - Train Loss: 0.0600, Train Accuracy: 0.9797, Validation Loss: 0.0650, Validation Accuracy: 0.9789
# Epoch [597/4000] - Train Loss: 0.0605, Train Accuracy: 0.9797, Validation Loss: 0.0652, Validation Accuracy: 0.9783
# Epoch [598/4000] - Train Loss: 0.0590, Train Accuracy: 0.9802, Validation Loss: 0.0652, Validation Accuracy: 0.9786
# Epoch [599/4000] - Train Loss: 0.0594, Train Accuracy: 0.9800, Validation Loss: 0.0655, Validation Accuracy: 0.9788
# Epoch [600/4000] - Train Loss: 0.0588, Train Accuracy: 0.9798, Validation Loss: 0.0671, Validation Accuracy: 0.9777
# Epoch [601/4000] - Train Loss: 0.0602, Train Accuracy: 0.9796, Validation Loss: 0.0685, Validation Accuracy: 0.9776
# Epoch [602/4000] - Train Loss: 0.0593, Train Accuracy: 0.9805, Validation Loss: 0.0654, Validation Accuracy: 0.9787
# Epoch [603/4000] - Train Loss: 0.0588, Train Accuracy: 0.9803, Validation Loss: 0.0657, Validation Accuracy: 0.9785
# Epoch [604/4000] - Train Loss: 0.0587, Train Accuracy: 0.9807, Validation Loss: 0.0679, Validation Accuracy: 0.9776
# Epoch [605/4000] - Train Loss: 0.0601, Train Accuracy: 0.9799, Validation Loss: 0.0652, Validation Accuracy: 0.9792
# Epoch [606/4000] - Train Loss: 0.0597, Train Accuracy: 0.9799, Validation Loss: 0.0656, Validation Accuracy: 0.9783
# Epoch [607/4000] - Train Loss: 0.0588, Train Accuracy: 0.9806, Validation Loss: 0.0656, Validation Accuracy: 0.9787
# Epoch [608/4000] - Train Loss: 0.0595, Train Accuracy: 0.9800, Validation Loss: 0.0653, Validation Accuracy: 0.9788
# Epoch [609/4000] - Train Loss: 0.0580, Train Accuracy: 0.9807, Validation Loss: 0.0652, Validation Accuracy: 0.9784
# Epoch [610/4000] - Train Loss: 0.0595, Train Accuracy: 0.9804, Validation Loss: 0.0658, Validation Accuracy: 0.9783
# Epoch [611/4000] - Train Loss: 0.0595, Train Accuracy: 0.9804, Validation Loss: 0.0663, Validation Accuracy: 0.9780
# Epoch [612/4000] - Train Loss: 0.0585, Train Accuracy: 0.9800, Validation Loss: 0.0657, Validation Accuracy: 0.9780
# Epoch [613/4000] - Train Loss: 0.0596, Train Accuracy: 0.9798, Validation Loss: 0.0653, Validation Accuracy: 0.9786
# Epoch [614/4000] - Train Loss: 0.0583, Train Accuracy: 0.9804, Validation Loss: 0.0651, Validation Accuracy: 0.9786
# Epoch [615/4000] - Train Loss: 0.0595, Train Accuracy: 0.9803, Validation Loss: 0.0651, Validation Accuracy: 0.9783
# Epoch [616/4000] - Train Loss: 0.0592, Train Accuracy: 0.9805, Validation Loss: 0.0653, Validation Accuracy: 0.9775
# Epoch [617/4000] - Train Loss: 0.0594, Train Accuracy: 0.9800, Validation Loss: 0.0693, Validation Accuracy: 0.9771
# Epoch [618/4000] - Train Loss: 0.0596, Train Accuracy: 0.9800, Validation Loss: 0.0650, Validation Accuracy: 0.9784
# Epoch [619/4000] - Train Loss: 0.0591, Train Accuracy: 0.9802, Validation Loss: 0.0656, Validation Accuracy: 0.9791
# Epoch [620/4000] - Train Loss: 0.0587, Train Accuracy: 0.9801, Validation Loss: 0.0660, Validation Accuracy: 0.9784
# Epoch [621/4000] - Train Loss: 0.0591, Train Accuracy: 0.9803, Validation Loss: 0.0666, Validation Accuracy: 0.9781
# Early stopping at epoch 622

# %% [markdown]
# #### Testing the Model

# %%
# Set the model to evaluation mode

pf_model.load_state_dict(torch.load(os.path.join(out_dir, "EX1_SG_MargNet_DNN_Model.pth"), map_location=device))
pf_model.eval()
y_test_pred = torch.empty(0).to(device)

# Generate predictions
with torch.no_grad():
    for feats, labels in pf_test_loader:
        feats = feats.to(device)
        labels = labels.to(device)
        pred = pf_model(feats)

        y_test_pred = torch.cat((y_test_pred, pred), dim=0)

y_test_pred = y_test_pred.cpu().numpy()
y_test_pred = y_test_pred.argmax(axis=1)
print(get_metrics(y_test_pred, y_test, label_strings))

# https://www.stackvidhya.com/plot-confusion-matrix-in-python-and-why/#google_vignette
# fig = plt.figure()
cf_matrix = metrics.confusion_matrix(y_test, y_test_pred)
cf_matrix_percentage = metrics.confusion_matrix(y_test, y_test_pred, normalize='true')
group_counts = ["{0:0.0f}".format(value) for value in cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_matrix_percentage.flatten()]
labels = [f"{v1}\n({v2})\n" for v1, v2 in
          zip(group_percentages,group_counts)]
labels = np.asarray(labels).reshape(2,2)
fig, ax = plt.subplots(figsize=(8, 6))  # Adjust the size as needed

ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
ax.set_xlabel('\nPredicted', fontsize=14, weight='bold')
ax.set_ylabel('Actual', fontsize=14, weight='bold');
ax.xaxis.set_ticklabels(['GALAXY', 'STAR'], fontsize=14, weight='bold')
ax.yaxis.set_ticklabels(['GALAXY', 'STAR'], fontsize=14, weight='bold')
plt.tight_layout()
plt.savefig(os.path.join(out_dir, "EX1_SG_MargNet_DNN_CM.png"))
plt.show()
plt.close()
# Out:
# Identified 19570 correct labels out of 20000 labels
# Accuracy: 0.9785
# Precision: 0.97849949913998
# Recall: 0.9785124189758091
# F1 Score: 0.9784998432638574
# Labels are: ['GALAXY' 'STAR']
# Confusion Matrix:
#  [[9758  190]
#  [ 240 9812]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      9948
#            1       0.98      0.98      0.98     10052
#
#     accuracy                           0.98     20000
#    macro avg       0.98      0.98      0.98     20000
# weighted avg       0.98      0.98      0.98     20000
#
# (array([    0,     1,     2, ..., 19997, 19998, 19999]), 0.9785, 0.97849949913998, 0.9785124189758091, array([[9758,  190],
#        [ 240, 9812]]), '              precision    recall  f1-score   support\n\n           0       0.98      0.98      0.98      9948\n           1       0.98      0.98      0.98     10052\n\n    accuracy                           0.98     20000\n   macro avg       0.98      0.98      0.98     20000\nweighted avg       0.98      0.98      0.98     20000\n')

# %% [markdown]
# ### 2. CNN Model using Images

# %% [markdown]
# ##### Create dataset and dataloader for pytorch training

# %%
class SGData_image(Dataset):
    def __init__(self, x, y, transform=None):
        self.n_samples = x.shape[0]
        self.x = torch.tensor(x, dtype=torch.float32)
        self.y = torch.tensor(y)
        self.transform = transform

    def __len__(self):
        return self.n_samples

    def __getitem__(self, i):
        inputs, targets = self.x[i], self.y[i]
        
        if self.transform:
            inputs = self.transform(inputs)

        return inputs, targets

# Define your data augmentation transformations
image_transform = transforms.Compose([    
    transforms.RandomRotation(180),
    transforms.RandomAffine(degrees = 0, translate = (0.1, 0.1)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
])

# Create DataLoader for training and validation data
image_train_dataset = SGData_image(X_train, y_train, transform=image_transform)
image_train_loader = DataLoader(image_train_dataset, batch_size=512, shuffle=True, num_workers=8)
image_val_dataset = SGData_image(X_val, y_val, transform=image_transform)
image_val_loader = DataLoader(image_val_dataset, batch_size=512, shuffle=False, num_workers=4)
image_test_dataset = SGData_image(X_test, y_test, transform=None)
image_test_loader = DataLoader(image_test_dataset, batch_size=512, shuffle=False, num_workers=4)

# %% [markdown]
# #### Initialize or Define the Model

# %%
# Initialize the PyTorch model
in_channels = X_train.shape[1]
image_ht = X_train.shape[2]
image_wt = X_train.shape[3]

class InceptionLikeNet(nn.Module):
    def __init__(self, in_channels, img_height, img_width, num_classes=2):
        super().__init__()
        self.relu = nn.ReLU(inplace=True)

        # First conv
        self.conv0 = nn.Conv2d(in_channels, 64, kernel_size=5, padding=2)

        # --- Block 1 ---
        self.b1_c1_1x1 = nn.Conv2d(64, 48, kernel_size=1)
        self.b1_c2_1x1 = nn.Conv2d(64, 48, kernel_size=1)
        self.b1_c3_1x1 = nn.Conv2d(64, 48, kernel_size=1)
        self.b1_c4_1x1 = nn.Conv2d(48, 64, kernel_size=1)
        self.b1_c5_3x3 = nn.Conv2d(48, 64, kernel_size=3, padding=1)
        self.b1_c6_5x5 = nn.Conv2d(48, 64, kernel_size=5, padding=2)

        # shared pools
        self.pool1x1 = nn.AvgPool2d(kernel_size=1, stride=1)  # like AveragePooling2D((1,1))
        self.pool2x2 = nn.AvgPool2d(kernel_size=2, stride=2)

        # --- Block 2 ---
        # input channels after block1 concat: 64+64+64+48 = 240
        self.b2_c7_1x1  = nn.Conv2d(240, 64, kernel_size=1)
        self.b2_c8_1x1  = nn.Conv2d(240, 64, kernel_size=1)
        self.b2_c9_1x1  = nn.Conv2d(240, 64, kernel_size=1)
        self.b2_c10_1x1 = nn.Conv2d(64, 92, kernel_size=1)
        self.b2_c11_3x3 = nn.Conv2d(64, 92, kernel_size=3, padding=1)
        self.b2_c12_5x5 = nn.Conv2d(64, 92, kernel_size=5, padding=2)
        # after concat: 92+92+92+64 = 340, then 2x2 avg pool

        # --- Block 3 ---
        self.b3_c13_1x1 = nn.Conv2d(340, 92, kernel_size=1)
        self.b3_c14_1x1 = nn.Conv2d(340, 92, kernel_size=1)
        self.b3_c15_1x1 = nn.Conv2d(340, 92, kernel_size=1)
        self.b3_c16_1x1 = nn.Conv2d(92, 128, kernel_size=1)
        self.b3_c17_3x3 = nn.Conv2d(92, 128, kernel_size=3, padding=1)
        self.b3_c18_5x5 = nn.Conv2d(92, 128, kernel_size=5, padding=2)
        # concat: 128+128+128+92 = 476

        # --- Block 4 ---
        self.b4_c19_1x1 = nn.Conv2d(476, 92, kernel_size=1)
        self.b4_c20_1x1 = nn.Conv2d(476, 92, kernel_size=1)
        self.b4_c21_1x1 = nn.Conv2d(476, 92, kernel_size=1)
        self.b4_c22_1x1 = nn.Conv2d(92, 128, kernel_size=1)
        self.b4_c23_3x3 = nn.Conv2d(92, 128, kernel_size=3, padding=1)
        self.b4_c24_5x5 = nn.Conv2d(92, 128, kernel_size=5, padding=2)
        # concat: 128+128+128+92 = 476, then 2x2 avg pool

        # --- Block 5 ---
        self.b5_c25_1x1 = nn.Conv2d(476, 92, kernel_size=1)
        self.b5_c26_1x1 = nn.Conv2d(476, 92, kernel_size=1)
        self.b5_c27_1x1 = nn.Conv2d(476, 128, kernel_size=1)
        self.b5_c28_3x3 = nn.Conv2d(92, 128, kernel_size=3, padding=1)
        # concat: 128+128+92 = 348

        # Dense part we need to know flattened size, so we build dynamically
        self._build_fc(in_channels, img_height, img_width, num_classes)

    # run only the conv part (up to Flatten in your Keras model)
    def _forward_features(self, x):
        x = self.relu(self.conv0(x))

        # Block 1
        c1 = self.relu(self.b1_c1_1x1(x))
        c2 = self.relu(self.b1_c2_1x1(x))
        c3 = self.relu(self.b1_c3_1x1(x))
        c4 = self.relu(self.b1_c4_1x1(c1))
        c5 = self.relu(self.b1_c5_3x3(c1))
        c6 = self.relu(self.b1_c6_5x5(c2))
        p1 = self.pool1x1(c3)
        x  = torch.cat([c4, c5, c6, p1], dim=1)      # 240 ch

        # Block 2
        c7  = self.relu(self.b2_c7_1x1(x))
        c8  = self.relu(self.b2_c8_1x1(x))
        c9  = self.relu(self.b2_c9_1x1(x))
        c10 = self.relu(self.b2_c10_1x1(c7))
        c11 = self.relu(self.b2_c11_3x3(c7))
        c12 = self.relu(self.b2_c12_5x5(c8))
        p2  = self.pool1x1(c9)
        x   = torch.cat([c10, c11, c12, p2], dim=1)  # 340 ch
        x   = self.pool2x2(x)

        # Block 3
        c13 = self.relu(self.b3_c13_1x1(x))
        c14 = self.relu(self.b3_c14_1x1(x))
        c15 = self.relu(self.b3_c15_1x1(x))
        c16 = self.relu(self.b3_c16_1x1(c13))
        c17 = self.relu(self.b3_c17_3x3(c13))
        c18 = self.relu(self.b3_c18_5x5(c14))
        p3  = self.pool1x1(c15)
        x   = torch.cat([c16, c17, c18, p3], dim=1)  # 476 ch

        # Block 4
        c19 = self.relu(self.b4_c19_1x1(x))
        c20 = self.relu(self.b4_c20_1x1(x))
        c21 = self.relu(self.b4_c21_1x1(x))
        c22 = self.relu(self.b4_c22_1x1(c19))
        c23 = self.relu(self.b4_c23_3x3(c19))
        c24 = self.relu(self.b4_c24_5x5(c20))
        p4  = self.pool1x1(c21)
        x   = torch.cat([c22, c23, c24, p4], dim=1)  # 476 ch
        x   = self.pool2x2(x)

        # Block 5
        c25 = self.relu(self.b5_c25_1x1(x))
        c26 = self.relu(self.b5_c26_1x1(x))
        c27 = self.relu(self.b5_c27_1x1(x))
        c28 = self.relu(self.b5_c28_3x3(c25))
        p5  = self.pool1x1(c26)
        x   = torch.cat([c27, c28, p5], dim=1)       # 348 ch

        return x

    def _build_fc(self, in_channels, img_height, img_width, num_classes):
        # run a dummy tensor through conv part to figure out Flatten size
        with torch.no_grad():
            dummy = torch.zeros(1, in_channels, img_height, img_width)
            feats = self._forward_features(dummy)
            flatten_dim = feats.view(1, -1).shape[1]

        self.flatten = nn.Flatten()
        # Keras: Flatten -> Dense(1024) -> Dense(1024) -> Dense(2, softmax)
        # (no activations between Dense in your code; keeping that)
        self.fc1 = nn.Linear(flatten_dim, 1024)
        self.fc2 = nn.Linear(1024, 1024)
        self.fc3 = nn.Linear(1024, num_classes)

    def forward(self, x):
        x = self._forward_features(x)
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.fc2(x)
        logits = self.fc3(x)   # raw scores; use CrossEntropyLoss (includes softmax)
        return logits

image_model = InceptionLikeNet(in_channels=in_channels, img_height=image_ht, img_width=image_wt, num_classes=n_classes).to(device)

# %% [markdown]
# #### Training the Model

# %%
train_loss_arr = []
train_accuracy_arr = []
val_loss_arr = []
val_accuracy_arr = []

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(image_model.parameters())

# Early stopping parameters
patience = 30
best_val_loss = float('inf')
best_model_state = None  # Initialize a variable to store the best model state
counter = 0

# Training loop
epochs = 300
epoch1 =0
print('\n')
for epoch in range(epochs):
    epoch1+=1
    image_model.train()
    train_loss = 0.0
    correct_train = 0
    total_train = 0
    for batch_x, batch_y in image_train_loader:
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)
        optimizer.zero_grad()
        output = image_model(batch_x)
        loss = criterion(output, batch_y)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = output.max(1)
        total_train += batch_y.size(0)
        correct_train += predicted.eq(batch_y).sum().item()

    train_loss /= len(image_train_loader)
    train_accuracy = correct_train / total_train
    train_loss_arr.append(train_loss)
    train_accuracy_arr.append(train_accuracy)
    
    image_model.eval()
    
    val_loss = 0.0
    correct_val = 0
    total_val = 0
    with torch.no_grad():
        for batch_x, batch_y in image_val_loader:
            batch_x = batch_x.to(device)
            batch_y = batch_y.to(device)
            output = image_model(batch_x)
            val_loss += criterion(output, batch_y).item()
            _, predicted = output.max(1)
            total_val += batch_y.size(0)
            correct_val += predicted.eq(batch_y).sum().item()

    val_loss /= len(image_val_loader)
    val_accuracy = correct_val / total_val
    val_loss_arr.append(val_loss)
    val_accuracy_arr.append(val_accuracy)
    
    image_model.train()
        
    #Check for early stopping and save best model state
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        counter = 0
        best_model_state = image_model.state_dict()  # Store the current best model state        
        torch.save(best_model_state, os.path.join(out_dir, 'EX1_SG_MargNet_CNN_Model.pth'))
        
    else:
        counter += 1

    if counter >= patience:
        print(f'Early stopping at epoch {epoch+1}')
        if best_model_state is not None:
            image_model.load_state_dict(best_model_state)  # Restore best model state
        counter = 0  # Reset the counter    
        break

    print(f'Epoch [{epoch+1}/{epochs}] - '
      f'Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, '
      f'Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}')

# Create the range of epochs
epoch_range = range(1, epoch1+1)

# Plot training accuracy in blue
plt.figsize=(8, 6)  # Adjust the size as needed
plt.plot(epoch_range, train_accuracy_arr, label='Train Accuracy', color='blue')

# Plot validation accuracy in red
plt.plot(epoch_range, val_accuracy_arr, label='Validation Accuracy', color='red')

# Add labels and title
plt.xlabel('Epoch', fontsize=14, weight='bold')
plt.ylabel('Accuracy', fontsize=14, weight='bold')
plt.title('Model Accuracy', fontsize=14, weight='bold')

# Add a legend
plt.legend(fontsize=14, title_fontproperties={'weight':'bold'})
plt.savefig(os.path.join(out_dir, "EX1_SG_MargNet_CNN_Accuracy.png"))

# Show the plot
plt.show()
plt.close()

# Plot training accuracy in blue
plt.figsize=(8, 6)  # Adjust the size as needed
plt.plot(epoch_range, train_loss_arr, label='Train Loss', color='blue')

# Plot validation accuracy in red
plt.plot(epoch_range, val_loss_arr, label='Validation Loss', color='red')

# Add labels and title
plt.xlabel('Epoch', fontsize=14, weight='bold')
plt.ylabel('Loss', fontsize=14, weight='bold')
plt.title('Model Loss', fontsize=14, weight='bold')

# Add a legend
plt.legend(fontsize=14, title_fontproperties={'weight':'bold'})
plt.savefig(os.path.join(out_dir, "EX1_SG_MargNet_CNN_Loss.png"))

# Show the plot
plt.show()
plt.close()
# Out:
# Epoch [1/300] - Train Loss: 0.2737, Train Accuracy: 0.8948, Validation Loss: 0.1884, Validation Accuracy: 0.9320
# Epoch [2/300] - Train Loss: 0.1444, Train Accuracy: 0.9508, Validation Loss: 0.1552, Validation Accuracy: 0.9465
# Epoch [3/300] - Train Loss: 0.1285, Train Accuracy: 0.9556, Validation Loss: 0.1363, Validation Accuracy: 0.9546
# Epoch [4/300] - Train Loss: 0.1251, Train Accuracy: 0.9571, Validation Loss: 0.1332, Validation Accuracy: 0.9576
# Epoch [5/300] - Train Loss: 0.1195, Train Accuracy: 0.9584, Validation Loss: 0.1298, Validation Accuracy: 0.9587
# Epoch [6/300] - Train Loss: 0.1160, Train Accuracy: 0.9598, Validation Loss: 0.1248, Validation Accuracy: 0.9583
# Epoch [7/300] - Train Loss: 0.1130, Train Accuracy: 0.9612, Validation Loss: 0.1179, Validation Accuracy: 0.9606
# Epoch [8/300] - Train Loss: 0.1078, Train Accuracy: 0.9625, Validation Loss: 0.1200, Validation Accuracy: 0.9593
# Epoch [9/300] - Train Loss: 0.1045, Train Accuracy: 0.9640, Validation Loss: 0.1126, Validation Accuracy: 0.9631
# Epoch [10/300] - Train Loss: 0.1038, Train Accuracy: 0.9642, Validation Loss: 0.1240, Validation Accuracy: 0.9578
# Epoch [11/300] - Train Loss: 0.1034, Train Accuracy: 0.9643, Validation Loss: 0.1060, Validation Accuracy: 0.9625
# Epoch [12/300] - Train Loss: 0.1030, Train Accuracy: 0.9644, Validation Loss: 0.1097, Validation Accuracy: 0.9629
# Epoch [13/300] - Train Loss: 0.1002, Train Accuracy: 0.9647, Validation Loss: 0.1055, Validation Accuracy: 0.9647
# Epoch [14/300] - Train Loss: 0.0971, Train Accuracy: 0.9662, Validation Loss: 0.1083, Validation Accuracy: 0.9635
# Epoch [15/300] - Train Loss: 0.0967, Train Accuracy: 0.9662, Validation Loss: 0.1038, Validation Accuracy: 0.9664
# Epoch [16/300] - Train Loss: 0.0946, Train Accuracy: 0.9667, Validation Loss: 0.0999, Validation Accuracy: 0.9668
# Epoch [17/300] - Train Loss: 0.0958, Train Accuracy: 0.9670, Validation Loss: 0.0979, Validation Accuracy: 0.9671
# Epoch [18/300] - Train Loss: 0.0926, Train Accuracy: 0.9676, Validation Loss: 0.0982, Validation Accuracy: 0.9660
# Epoch [19/300] - Train Loss: 0.0923, Train Accuracy: 0.9674, Validation Loss: 0.1030, Validation Accuracy: 0.9661
# Epoch [20/300] - Train Loss: 0.0915, Train Accuracy: 0.9677, Validation Loss: 0.0941, Validation Accuracy: 0.9687
# Epoch [21/300] - Train Loss: 0.0892, Train Accuracy: 0.9690, Validation Loss: 0.0953, Validation Accuracy: 0.9670
# Epoch [22/300] - Train Loss: 0.0881, Train Accuracy: 0.9695, Validation Loss: 0.1134, Validation Accuracy: 0.9621
# Epoch [23/300] - Train Loss: 0.0896, Train Accuracy: 0.9683, Validation Loss: 0.0968, Validation Accuracy: 0.9672
# Epoch [24/300] - Train Loss: 0.0880, Train Accuracy: 0.9692, Validation Loss: 0.0962, Validation Accuracy: 0.9673
# Epoch [25/300] - Train Loss: 0.0868, Train Accuracy: 0.9692, Validation Loss: 0.0911, Validation Accuracy: 0.9682
# Epoch [26/300] - Train Loss: 0.0864, Train Accuracy: 0.9694, Validation Loss: 0.1015, Validation Accuracy: 0.9650
# Epoch [27/300] - Train Loss: 0.0873, Train Accuracy: 0.9696, Validation Loss: 0.0906, Validation Accuracy: 0.9698
# Epoch [28/300] - Train Loss: 0.0875, Train Accuracy: 0.9693, Validation Loss: 0.1004, Validation Accuracy: 0.9683
# Epoch [29/300] - Train Loss: 0.0857, Train Accuracy: 0.9698, Validation Loss: 0.0959, Validation Accuracy: 0.9678
# Epoch [30/300] - Train Loss: 0.0851, Train Accuracy: 0.9702, Validation Loss: 0.0923, Validation Accuracy: 0.9691
# Epoch [31/300] - Train Loss: 0.0840, Train Accuracy: 0.9709, Validation Loss: 0.0907, Validation Accuracy: 0.9694
# Epoch [32/300] - Train Loss: 0.0823, Train Accuracy: 0.9708, Validation Loss: 0.0923, Validation Accuracy: 0.9689
# Epoch [33/300] - Train Loss: 0.0840, Train Accuracy: 0.9706, Validation Loss: 0.0906, Validation Accuracy: 0.9689
# Epoch [34/300] - Train Loss: 0.0842, Train Accuracy: 0.9705, Validation Loss: 0.0910, Validation Accuracy: 0.9696
# Epoch [35/300] - Train Loss: 0.0816, Train Accuracy: 0.9714, Validation Loss: 0.0931, Validation Accuracy: 0.9673
# Epoch [36/300] - Train Loss: 0.0813, Train Accuracy: 0.9710, Validation Loss: 0.0932, Validation Accuracy: 0.9683
# Epoch [37/300] - Train Loss: 0.0802, Train Accuracy: 0.9720, Validation Loss: 0.0917, Validation Accuracy: 0.9688
# Epoch [38/300] - Train Loss: 0.0815, Train Accuracy: 0.9713, Validation Loss: 0.0968, Validation Accuracy: 0.9679
# Epoch [39/300] - Train Loss: 0.0810, Train Accuracy: 0.9715, Validation Loss: 0.0934, Validation Accuracy: 0.9681
# Epoch [40/300] - Train Loss: 0.0800, Train Accuracy: 0.9716, Validation Loss: 0.0859, Validation Accuracy: 0.9690
# Epoch [41/300] - Train Loss: 0.0795, Train Accuracy: 0.9718, Validation Loss: 0.0909, Validation Accuracy: 0.9699
# Epoch [42/300] - Train Loss: 0.0807, Train Accuracy: 0.9717, Validation Loss: 0.0917, Validation Accuracy: 0.9694
# Epoch [43/300] - Train Loss: 0.0785, Train Accuracy: 0.9723, Validation Loss: 0.0878, Validation Accuracy: 0.9695
# Epoch [44/300] - Train Loss: 0.0786, Train Accuracy: 0.9719, Validation Loss: 0.1038, Validation Accuracy: 0.9659
# Epoch [45/300] - Train Loss: 0.0787, Train Accuracy: 0.9718, Validation Loss: 0.0926, Validation Accuracy: 0.9688
# Epoch [46/300] - Train Loss: 0.0781, Train Accuracy: 0.9725, Validation Loss: 0.0921, Validation Accuracy: 0.9703
# Epoch [47/300] - Train Loss: 0.0773, Train Accuracy: 0.9730, Validation Loss: 0.0909, Validation Accuracy: 0.9700
# Epoch [48/300] - Train Loss: 0.0774, Train Accuracy: 0.9724, Validation Loss: 0.0954, Validation Accuracy: 0.9679
# Epoch [49/300] - Train Loss: 0.0763, Train Accuracy: 0.9729, Validation Loss: 0.0922, Validation Accuracy: 0.9700
# Epoch [50/300] - Train Loss: 0.0770, Train Accuracy: 0.9728, Validation Loss: 0.0884, Validation Accuracy: 0.9693
# Epoch [51/300] - Train Loss: 0.0763, Train Accuracy: 0.9730, Validation Loss: 0.0871, Validation Accuracy: 0.9707
# Epoch [52/300] - Train Loss: 0.0785, Train Accuracy: 0.9724, Validation Loss: 0.0875, Validation Accuracy: 0.9703
# Epoch [53/300] - Train Loss: 0.0757, Train Accuracy: 0.9731, Validation Loss: 0.0897, Validation Accuracy: 0.9700
# Epoch [54/300] - Train Loss: 0.0754, Train Accuracy: 0.9734, Validation Loss: 0.0858, Validation Accuracy: 0.9709
# Epoch [55/300] - Train Loss: 0.0755, Train Accuracy: 0.9730, Validation Loss: 0.0982, Validation Accuracy: 0.9678
# Epoch [56/300] - Train Loss: 0.0746, Train Accuracy: 0.9732, Validation Loss: 0.0879, Validation Accuracy: 0.9695
# Epoch [57/300] - Train Loss: 0.0735, Train Accuracy: 0.9738, Validation Loss: 0.0922, Validation Accuracy: 0.9691
# Epoch [58/300] - Train Loss: 0.0741, Train Accuracy: 0.9736, Validation Loss: 0.0844, Validation Accuracy: 0.9722
# Epoch [59/300] - Train Loss: 0.0749, Train Accuracy: 0.9736, Validation Loss: 0.0854, Validation Accuracy: 0.9713
# Epoch [60/300] - Train Loss: 0.0738, Train Accuracy: 0.9737, Validation Loss: 0.0917, Validation Accuracy: 0.9690
# Epoch [61/300] - Train Loss: 0.0745, Train Accuracy: 0.9736, Validation Loss: 0.0876, Validation Accuracy: 0.9692
# Epoch [62/300] - Train Loss: 0.0739, Train Accuracy: 0.9737, Validation Loss: 0.0910, Validation Accuracy: 0.9698
# Epoch [63/300] - Train Loss: 0.0742, Train Accuracy: 0.9738, Validation Loss: 0.0926, Validation Accuracy: 0.9692
# Epoch [64/300] - Train Loss: 0.0759, Train Accuracy: 0.9735, Validation Loss: 0.0937, Validation Accuracy: 0.9705
# Epoch [65/300] - Train Loss: 0.0734, Train Accuracy: 0.9742, Validation Loss: 0.0899, Validation Accuracy: 0.9688
# Epoch [66/300] - Train Loss: 0.0721, Train Accuracy: 0.9747, Validation Loss: 0.0888, Validation Accuracy: 0.9700
# Epoch [67/300] - Train Loss: 0.0718, Train Accuracy: 0.9735, Validation Loss: 0.0869, Validation Accuracy: 0.9701
# Epoch [68/300] - Train Loss: 0.0717, Train Accuracy: 0.9744, Validation Loss: 0.0899, Validation Accuracy: 0.9714
# Epoch [69/300] - Train Loss: 0.0718, Train Accuracy: 0.9746, Validation Loss: 0.0868, Validation Accuracy: 0.9710
# Epoch [70/300] - Train Loss: 0.0709, Train Accuracy: 0.9746, Validation Loss: 0.0937, Validation Accuracy: 0.9709
# Epoch [71/300] - Train Loss: 0.0717, Train Accuracy: 0.9747, Validation Loss: 0.0867, Validation Accuracy: 0.9710
# Epoch [72/300] - Train Loss: 0.0708, Train Accuracy: 0.9746, Validation Loss: 0.0831, Validation Accuracy: 0.9691
# Epoch [73/300] - Train Loss: 0.0810, Train Accuracy: 0.9726, Validation Loss: 0.0896, Validation Accuracy: 0.9702
# Epoch [74/300] - Train Loss: 0.0761, Train Accuracy: 0.9732, Validation Loss: 0.0891, Validation Accuracy: 0.9713
# Epoch [75/300] - Train Loss: 0.0722, Train Accuracy: 0.9738, Validation Loss: 0.0888, Validation Accuracy: 0.9716
# Epoch [76/300] - Train Loss: 0.0714, Train Accuracy: 0.9746, Validation Loss: 0.0835, Validation Accuracy: 0.9719
# Epoch [77/300] - Train Loss: 0.0702, Train Accuracy: 0.9748, Validation Loss: 0.0901, Validation Accuracy: 0.9720
# Epoch [78/300] - Train Loss: 0.0705, Train Accuracy: 0.9747, Validation Loss: 0.0870, Validation Accuracy: 0.9722
# Epoch [79/300] - Train Loss: 0.0693, Train Accuracy: 0.9749, Validation Loss: 0.0923, Validation Accuracy: 0.9695
# Epoch [80/300] - Train Loss: 0.0697, Train Accuracy: 0.9746, Validation Loss: 0.0861, Validation Accuracy: 0.9712
# Epoch [81/300] - Train Loss: 0.0742, Train Accuracy: 0.9745, Validation Loss: 0.1006, Validation Accuracy: 0.9663
# Epoch [82/300] - Train Loss: 0.0760, Train Accuracy: 0.9732, Validation Loss: 0.0855, Validation Accuracy: 0.9714
# Epoch [83/300] - Train Loss: 0.0703, Train Accuracy: 0.9749, Validation Loss: 0.0863, Validation Accuracy: 0.9712
# Epoch [84/300] - Train Loss: 0.0691, Train Accuracy: 0.9753, Validation Loss: 0.0839, Validation Accuracy: 0.9713
# Epoch [85/300] - Train Loss: 0.0705, Train Accuracy: 0.9746, Validation Loss: 0.0885, Validation Accuracy: 0.9705
# Epoch [86/300] - Train Loss: 0.0688, Train Accuracy: 0.9757, Validation Loss: 0.0889, Validation Accuracy: 0.9702
# Epoch [87/300] - Train Loss: 0.0679, Train Accuracy: 0.9755, Validation Loss: 0.0873, Validation Accuracy: 0.9715
# Epoch [88/300] - Train Loss: 0.0681, Train Accuracy: 0.9756, Validation Loss: 0.0917, Validation Accuracy: 0.9697
# Epoch [89/300] - Train Loss: 0.0679, Train Accuracy: 0.9756, Validation Loss: 0.0831, Validation Accuracy: 0.9725
# Epoch [90/300] - Train Loss: 0.0674, Train Accuracy: 0.9757, Validation Loss: 0.1086, Validation Accuracy: 0.9680
# Epoch [91/300] - Train Loss: 0.0682, Train Accuracy: 0.9755, Validation Loss: 0.0928, Validation Accuracy: 0.9702
# Epoch [92/300] - Train Loss: 0.0666, Train Accuracy: 0.9762, Validation Loss: 0.0941, Validation Accuracy: 0.9703
# Epoch [93/300] - Train Loss: 0.0699, Train Accuracy: 0.9749, Validation Loss: 0.0867, Validation Accuracy: 0.9718
# Epoch [94/300] - Train Loss: 0.0708, Train Accuracy: 0.9749, Validation Loss: 0.0953, Validation Accuracy: 0.9714
# Epoch [95/300] - Train Loss: 0.0679, Train Accuracy: 0.9757, Validation Loss: 0.0839, Validation Accuracy: 0.9723
# Epoch [96/300] - Train Loss: 0.0688, Train Accuracy: 0.9755, Validation Loss: 0.0898, Validation Accuracy: 0.9708
# Epoch [97/300] - Train Loss: 0.0681, Train Accuracy: 0.9756, Validation Loss: 0.0872, Validation Accuracy: 0.9712
# Epoch [98/300] - Train Loss: 0.0663, Train Accuracy: 0.9764, Validation Loss: 0.0948, Validation Accuracy: 0.9709
# Epoch [99/300] - Train Loss: 0.0801, Train Accuracy: 0.9737, Validation Loss: 0.0887, Validation Accuracy: 0.9709
# Epoch [100/300] - Train Loss: 0.0704, Train Accuracy: 0.9749, Validation Loss: 0.0865, Validation Accuracy: 0.9722
# Epoch [101/300] - Train Loss: 0.0671, Train Accuracy: 0.9761, Validation Loss: 0.0938, Validation Accuracy: 0.9702
# Epoch [102/300] - Train Loss: 0.0693, Train Accuracy: 0.9756, Validation Loss: 0.0862, Validation Accuracy: 0.9719
# Epoch [103/300] - Train Loss: 0.0672, Train Accuracy: 0.9759, Validation Loss: 0.0855, Validation Accuracy: 0.9721
# Epoch [104/300] - Train Loss: 0.0691, Train Accuracy: 0.9753, Validation Loss: 0.0930, Validation Accuracy: 0.9695
# Epoch [105/300] - Train Loss: 0.0671, Train Accuracy: 0.9761, Validation Loss: 0.0883, Validation Accuracy: 0.9706
# Epoch [106/300] - Train Loss: 0.0660, Train Accuracy: 0.9760, Validation Loss: 0.0900, Validation Accuracy: 0.9705
# Epoch [107/300] - Train Loss: 0.0647, Train Accuracy: 0.9766, Validation Loss: 0.0894, Validation Accuracy: 0.9711
# Epoch [108/300] - Train Loss: 0.0653, Train Accuracy: 0.9767, Validation Loss: 0.0857, Validation Accuracy: 0.9714
# Epoch [109/300] - Train Loss: 0.0645, Train Accuracy: 0.9768, Validation Loss: 0.0892, Validation Accuracy: 0.9718
# Epoch [110/300] - Train Loss: 0.0646, Train Accuracy: 0.9763, Validation Loss: 0.0875, Validation Accuracy: 0.9728
# Epoch [111/300] - Train Loss: 0.0651, Train Accuracy: 0.9768, Validation Loss: 0.0846, Validation Accuracy: 0.9703
# Epoch [112/300] - Train Loss: 0.0661, Train Accuracy: 0.9762, Validation Loss: 0.0906, Validation Accuracy: 0.9693
# Epoch [113/300] - Train Loss: 0.0656, Train Accuracy: 0.9765, Validation Loss: 0.0825, Validation Accuracy: 0.9721
# Epoch [114/300] - Train Loss: 0.0649, Train Accuracy: 0.9768, Validation Loss: 0.0835, Validation Accuracy: 0.9719
# Epoch [115/300] - Train Loss: 0.0659, Train Accuracy: 0.9764, Validation Loss: 0.0827, Validation Accuracy: 0.9712
# Epoch [116/300] - Train Loss: 0.0641, Train Accuracy: 0.9767, Validation Loss: 0.0870, Validation Accuracy: 0.9711
# Epoch [117/300] - Train Loss: 0.0647, Train Accuracy: 0.9765, Validation Loss: 0.0842, Validation Accuracy: 0.9727
# Epoch [118/300] - Train Loss: 0.0640, Train Accuracy: 0.9769, Validation Loss: 0.0856, Validation Accuracy: 0.9714
# Epoch [119/300] - Train Loss: 0.0633, Train Accuracy: 0.9776, Validation Loss: 0.0872, Validation Accuracy: 0.9715
# Epoch [120/300] - Train Loss: 0.0647, Train Accuracy: 0.9762, Validation Loss: 0.0954, Validation Accuracy: 0.9718
# Epoch [121/300] - Train Loss: 0.0658, Train Accuracy: 0.9765, Validation Loss: 0.0878, Validation Accuracy: 0.9703
# Epoch [122/300] - Train Loss: 0.0659, Train Accuracy: 0.9767, Validation Loss: 0.0902, Validation Accuracy: 0.9725
# Epoch [123/300] - Train Loss: 0.0636, Train Accuracy: 0.9769, Validation Loss: 0.0882, Validation Accuracy: 0.9722
# Epoch [124/300] - Train Loss: 0.0658, Train Accuracy: 0.9767, Validation Loss: 0.0882, Validation Accuracy: 0.9710
# Epoch [125/300] - Train Loss: 0.0643, Train Accuracy: 0.9766, Validation Loss: 0.0917, Validation Accuracy: 0.9692
# Epoch [126/300] - Train Loss: 0.0630, Train Accuracy: 0.9778, Validation Loss: 0.0925, Validation Accuracy: 0.9715
# Epoch [127/300] - Train Loss: 0.0619, Train Accuracy: 0.9777, Validation Loss: 0.0854, Validation Accuracy: 0.9713
# Epoch [128/300] - Train Loss: 0.0635, Train Accuracy: 0.9771, Validation Loss: 0.0861, Validation Accuracy: 0.9708
# Epoch [129/300] - Train Loss: 0.0621, Train Accuracy: 0.9775, Validation Loss: 0.0882, Validation Accuracy: 0.9720
# Epoch [130/300] - Train Loss: 0.0623, Train Accuracy: 0.9779, Validation Loss: 0.0884, Validation Accuracy: 0.9710
# Epoch [131/300] - Train Loss: 0.0625, Train Accuracy: 0.9772, Validation Loss: 0.0917, Validation Accuracy: 0.9713
# Epoch [132/300] - Train Loss: 0.0637, Train Accuracy: 0.9767, Validation Loss: 0.0872, Validation Accuracy: 0.9704
# Epoch [133/300] - Train Loss: 0.0643, Train Accuracy: 0.9770, Validation Loss: 0.0897, Validation Accuracy: 0.9721
# Epoch [134/300] - Train Loss: 0.0625, Train Accuracy: 0.9774, Validation Loss: 0.0858, Validation Accuracy: 0.9714
# Epoch [135/300] - Train Loss: 0.0631, Train Accuracy: 0.9774, Validation Loss: 0.0935, Validation Accuracy: 0.9708
# Epoch [136/300] - Train Loss: 0.0624, Train Accuracy: 0.9773, Validation Loss: 0.0930, Validation Accuracy: 0.9716
# Epoch [137/300] - Train Loss: 0.0620, Train Accuracy: 0.9777, Validation Loss: 0.0860, Validation Accuracy: 0.9727
# Epoch [138/300] - Train Loss: 0.0622, Train Accuracy: 0.9780, Validation Loss: 0.0869, Validation Accuracy: 0.9707
# Epoch [139/300] - Train Loss: 0.0607, Train Accuracy: 0.9782, Validation Loss: 0.0889, Validation Accuracy: 0.9700
# Epoch [140/300] - Train Loss: 0.0606, Train Accuracy: 0.9782, Validation Loss: 0.0928, Validation Accuracy: 0.9719
# Epoch [141/300] - Train Loss: 0.0599, Train Accuracy: 0.9786, Validation Loss: 0.0889, Validation Accuracy: 0.9718
# Epoch [142/300] - Train Loss: 0.0619, Train Accuracy: 0.9780, Validation Loss: 0.0921, Validation Accuracy: 0.9705
# Early stopping at epoch 143

# %% [markdown]
# #### Testing the Model

# %%
torch.cuda.empty_cache()

# Set the model to evaluation mode

image_model.load_state_dict(torch.load(os.path.join(out_dir, 'EX1_SG_MargNet_CNN_Model.pth'), map_location=device))
image_model.eval()

y_test_pred = torch.empty(0).to(device)
print('\n')
# Generate predictions
with torch.no_grad():
    for images, labels in image_test_loader:
        images = images.to(device)
        labels = labels.to(device)
        pred = image_model(images)

        y_test_pred = torch.cat((y_test_pred, pred), dim=0)

y_test_pred = y_test_pred.cpu().numpy()
y_test_pred = y_test_pred.argmax(axis=1)
print(get_metrics(y_test_pred, y_test, label_strings))

# https://www.stackvidhya.com/plot-confusion-matrix-in-python-and-why/#google_vignette
# fig = plt.figure()
cf_matrix = metrics.confusion_matrix(y_test, y_test_pred)
cf_matrix_percentage = metrics.confusion_matrix(y_test, y_test_pred, normalize='true')
group_counts = ["{0:0.0f}".format(value) for value in cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_matrix_percentage.flatten()]
labels = [f"{v1}\n({v2})\n" for v1, v2 in
          zip(group_percentages,group_counts)]
labels = np.asarray(labels).reshape(2,2)
fig, ax = plt.subplots(figsize=(8, 6))  # Adjust the size as needed

ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
ax.set_xlabel('\nPredicted', fontsize=14, weight='bold')
ax.set_ylabel('Actual', fontsize=14, weight='bold');
ax.xaxis.set_ticklabels(['GALAXY', 'STAR'], fontsize=14, weight='bold')
ax.yaxis.set_ticklabels(['GALAXY', 'STAR'], fontsize=14, weight='bold')
plt.tight_layout()
plt.savefig(os.path.join(out_dir, "EX1_SG_MargNet_CNN_CM.png"))
plt.show()
plt.close()
# Out:
# Identified 19429 correct labels out of 20000 labels
# Accuracy: 0.97145
# Precision: 0.9715049594732198
# Recall: 0.9714266073754634
# F1 Score: 0.9714473959311274
# Labels are: ['GALAXY' 'STAR']
# Confusion Matrix:
#  [[9619  329]
#  [ 242 9810]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97      9948
#            1       0.97      0.98      0.97     10052
#
#     accuracy                           0.97     20000
#    macro avg       0.97      0.97      0.97     20000
# weighted avg       0.97      0.97      0.97     20000
#
# (array([    0,     1,     2, ..., 19997, 19998, 19999]), 0.97145, 0.9715049594732198, 0.9714266073754634, array([[9619,  329],
#        [ 242, 9810]]), '              precision    recall  f1-score   support\n\n           0       0.98      0.97      0.97      9948\n           1       0.97      0.98      0.97     10052\n\n    accuracy                           0.97     20000\n   macro avg       0.97      0.97      0.97     20000\nweighted avg       0.97      0.97      0.97     20000\n')

# %% [markdown]
# ### 3. Ensemble Model (ANN+CNN) using photometric features and Images

# %%
cnnclassifier = image_model
dnnclassifier = pf_model

# %%
checkpoint_image = torch.load(os.path.join(out_dir, 'EX1_SG_MargNet_CNN_Model.pth'))
checkpoint_pf = torch.load(os.path.join(out_dir, 'EX1_SG_MargNet_DNN_Model.pth'))

# %%
cnnclassifier.load_state_dict(checkpoint_image)
dnnclassifier.load_state_dict(checkpoint_pf)
# Out:
# <All keys matched successfully>

# %%
class StackedModel(nn.Module):
    def __init__(self, members):
        super(StackedModel, self).__init__()
        self.members = nn.ModuleList(members)

        # Create a dictionary to store renamed parameters
        renamed_params = {}

        # Freeze the layers and rename them
        for i, model in enumerate(self.members):
            for name, param in model.named_parameters():
                param.requires_grad = False
                new_name = f'ensemble_{i+1}_{name.replace(".", "_")}'  # Replace '.' with '_'
                renamed_params[new_name] = param

        # Apply the changes to the model outside the loop
        for i, model in enumerate(self.members):
            for new_name, param in renamed_params.items():
                setattr(model, new_name, param)

        # Define multi-headed input
        self.ensemble_visible = [model for model in self.members]

        # Concatenate the outputs from each model
        self.hidden = nn.Linear(len(members) * 2, 10)
        self.output = nn.Linear(10, 2)

    def forward(self, inputs):
        outputs = [model(inputs[i]) for i, model in enumerate(self.members)]
        merge = torch.cat(outputs, dim=1)
        hidden = torch.relu(self.hidden(merge))
        output = self.output(hidden)
        return output

# %%
# Create the ensemble model
members = [cnnclassifier, dnnclassifier]
model = StackedModel(members).to(device)

# %%
# Convert data to PyTorch tensors and create DataLoader
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
dnnx_val_tensor = torch.tensor(dnnx_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)

dataset = TensorDataset(X_val_tensor, dnnx_val_tensor, y_val_tensor)
dataloader = DataLoader(dataset, batch_size=512, shuffle=False)

# %% [markdown]
# #### Training the Model

# %%
# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())

# Training loop
num_epochs = 100
pf_image_best_loss = float('inf')
pf_image_best_model_state = None  # Initialize a variable to store the best model state

# filepath = "output/EnsembleClassifier.pth"

for epoch in range(num_epochs):
    train_loss = 0.0  # Initialize total loss for the epoch
    correct_train = 0
    total_train = 0    

    for X_batch, dnnx_batch, y_batch in dataloader:
        model.train()
        X_batch = X_batch.to(device)
        dnnx_batch = dnnx_batch.to(device)
        y_batch = y_batch.to(device)
        optimizer.zero_grad()
        outputs = model([X_batch, dnnx_batch])
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()

        # Accumulate the batch loss to the total loss
        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total_train += y_batch.size(0)
        correct_train += predicted.eq(y_batch).sum().item()

    # Calculate the average loss for the epoch
    train_loss /= len(dataloader)
    train_accuracy = correct_train / total_train

    #Check for early stopping and save best model state
    if train_loss < pf_image_best_loss:
        pf_image_best_loss = train_loss  # Update with the current train_loss
        pf_image_best_model_state = model.state_dict()
        torch.save(pf_image_best_model_state, os.path.join(out_dir, 'EX1_SG_MargNet_Model.pth'))

    # Print the average loss for the epoch
    print(f'Epoch [{epoch+1}/{num_epochs}] - 'f'Loss: {train_loss:.4f}, Accuracy: {train_accuracy:.4f} ')
# Out:
# Epoch [1/100] - Loss: 0.5123, Accuracy: 0.8887
# Epoch [2/100] - Loss: 0.2656, Accuracy: 0.9798
# Epoch [3/100] - Loss: 0.1636, Accuracy: 0.9805
# Epoch [4/100] - Loss: 0.1166, Accuracy: 0.9803
# Epoch [5/100] - Loss: 0.0940, Accuracy: 0.9806
# Epoch [6/100] - Loss: 0.0806, Accuracy: 0.9806
# Epoch [7/100] - Loss: 0.0727, Accuracy: 0.9806
# Epoch [8/100] - Loss: 0.0679, Accuracy: 0.9803
# Epoch [9/100] - Loss: 0.0650, Accuracy: 0.9811
# Epoch [10/100] - Loss: 0.0615, Accuracy: 0.9805
# Epoch [11/100] - Loss: 0.0611, Accuracy: 0.9807
# Epoch [12/100] - Loss: 0.0600, Accuracy: 0.9809
# Epoch [13/100] - Loss: 0.0589, Accuracy: 0.9805
# Epoch [14/100] - Loss: 0.0575, Accuracy: 0.9814
# Epoch [15/100] - Loss: 0.0576, Accuracy: 0.9809
# Epoch [16/100] - Loss: 0.0586, Accuracy: 0.9802
# Epoch [17/100] - Loss: 0.0583, Accuracy: 0.9804
# Epoch [18/100] - Loss: 0.0581, Accuracy: 0.9807
# Epoch [19/100] - Loss: 0.0590, Accuracy: 0.9806
# Epoch [20/100] - Loss: 0.0570, Accuracy: 0.9803
# Epoch [21/100] - Loss: 0.0566, Accuracy: 0.9813
# Epoch [22/100] - Loss: 0.0565, Accuracy: 0.9809
# Epoch [23/100] - Loss: 0.0574, Accuracy: 0.9809
# Epoch [24/100] - Loss: 0.0589, Accuracy: 0.9808
# Epoch [25/100] - Loss: 0.0578, Accuracy: 0.9812
# Epoch [26/100] - Loss: 0.0569, Accuracy: 0.9804
# Epoch [27/100] - Loss: 0.0582, Accuracy: 0.9806
# Epoch [28/100] - Loss: 0.0574, Accuracy: 0.9809
# Epoch [29/100] - Loss: 0.0576, Accuracy: 0.9810
# Epoch [30/100] - Loss: 0.0569, Accuracy: 0.9802
# Epoch [31/100] - Loss: 0.0566, Accuracy: 0.9803
# Epoch [32/100] - Loss: 0.0589, Accuracy: 0.9804
# Epoch [33/100] - Loss: 0.0564, Accuracy: 0.9806
# Epoch [34/100] - Loss: 0.0574, Accuracy: 0.9807
# Epoch [35/100] - Loss: 0.0552, Accuracy: 0.9808
# Epoch [36/100] - Loss: 0.0590, Accuracy: 0.9817
# Epoch [37/100] - Loss: 0.0557, Accuracy: 0.9807
# Epoch [38/100] - Loss: 0.0560, Accuracy: 0.9808
# Epoch [39/100] - Loss: 0.0582, Accuracy: 0.9805
# Epoch [40/100] - Loss: 0.0556, Accuracy: 0.9815
# Epoch [41/100] - Loss: 0.0558, Accuracy: 0.9810
# Epoch [42/100] - Loss: 0.0565, Accuracy: 0.9807
# Epoch [43/100] - Loss: 0.0553, Accuracy: 0.9811
# Epoch [44/100] - Loss: 0.0549, Accuracy: 0.9806
# Epoch [45/100] - Loss: 0.0575, Accuracy: 0.9810
# Epoch [46/100] - Loss: 0.0561, Accuracy: 0.9807
# Epoch [47/100] - Loss: 0.0557, Accuracy: 0.9805
# Epoch [48/100] - Loss: 0.0562, Accuracy: 0.9813
# Epoch [49/100] - Loss: 0.0571, Accuracy: 0.9808
# Epoch [50/100] - Loss: 0.0582, Accuracy: 0.9804
# Epoch [51/100] - Loss: 0.0566, Accuracy: 0.9813
# Epoch [52/100] - Loss: 0.0577, Accuracy: 0.9810
# Epoch [53/100] - Loss: 0.0554, Accuracy: 0.9808
# Epoch [54/100] - Loss: 0.0566, Accuracy: 0.9815
# Epoch [55/100] - Loss: 0.0545, Accuracy: 0.9810
# Epoch [56/100] - Loss: 0.0555, Accuracy: 0.9811
# Epoch [57/100] - Loss: 0.0557, Accuracy: 0.9806
# Epoch [58/100] - Loss: 0.0549, Accuracy: 0.9810
# Epoch [59/100] - Loss: 0.0562, Accuracy: 0.9809
# Epoch [60/100] - Loss: 0.0557, Accuracy: 0.9803
# Epoch [61/100] - Loss: 0.0558, Accuracy: 0.9807
# Epoch [62/100] - Loss: 0.0553, Accuracy: 0.9817
# Epoch [63/100] - Loss: 0.0565, Accuracy: 0.9808
# Epoch [64/100] - Loss: 0.0563, Accuracy: 0.9806
# Epoch [65/100] - Loss: 0.0568, Accuracy: 0.9809
# Epoch [66/100] - Loss: 0.0566, Accuracy: 0.9811
# Epoch [67/100] - Loss: 0.0575, Accuracy: 0.9807
# Epoch [68/100] - Loss: 0.0569, Accuracy: 0.9803
# Epoch [69/100] - Loss: 0.0555, Accuracy: 0.9812
# Epoch [70/100] - Loss: 0.0569, Accuracy: 0.9810
# Epoch [71/100] - Loss: 0.0570, Accuracy: 0.9808
# Epoch [72/100] - Loss: 0.0567, Accuracy: 0.9811
# Epoch [73/100] - Loss: 0.0558, Accuracy: 0.9808
# Epoch [74/100] - Loss: 0.0569, Accuracy: 0.9808
# Epoch [75/100] - Loss: 0.0565, Accuracy: 0.9808
# Epoch [76/100] - Loss: 0.0558, Accuracy: 0.9810
# Epoch [77/100] - Loss: 0.0563, Accuracy: 0.9804
# Epoch [78/100] - Loss: 0.0573, Accuracy: 0.9815
# Epoch [79/100] - Loss: 0.0554, Accuracy: 0.9809
# Epoch [80/100] - Loss: 0.0557, Accuracy: 0.9811
# Epoch [81/100] - Loss: 0.0554, Accuracy: 0.9815
# Epoch [82/100] - Loss: 0.0565, Accuracy: 0.9805
# Epoch [83/100] - Loss: 0.0565, Accuracy: 0.9806
# Epoch [84/100] - Loss: 0.0561, Accuracy: 0.9811
# Epoch [85/100] - Loss: 0.0560, Accuracy: 0.9812
# Epoch [86/100] - Loss: 0.0579, Accuracy: 0.9807
# Epoch [87/100] - Loss: 0.0566, Accuracy: 0.9814
# Epoch [88/100] - Loss: 0.0567, Accuracy: 0.9811
# Epoch [89/100] - Loss: 0.0552, Accuracy: 0.9812
# Epoch [90/100] - Loss: 0.0547, Accuracy: 0.9815
# Epoch [91/100] - Loss: 0.0554, Accuracy: 0.9801
# Epoch [92/100] - Loss: 0.0558, Accuracy: 0.9814
# Epoch [93/100] - Loss: 0.0558, Accuracy: 0.9806
# Epoch [94/100] - Loss: 0.0561, Accuracy: 0.9809
# Epoch [95/100] - Loss: 0.0557, Accuracy: 0.9811
# Epoch [96/100] - Loss: 0.0572, Accuracy: 0.9807
# Epoch [97/100] - Loss: 0.0551, Accuracy: 0.9809
# Epoch [98/100] - Loss: 0.0559, Accuracy: 0.9811
# Epoch [99/100] - Loss: 0.0561, Accuracy: 0.9809
# Epoch [100/100] - Loss: 0.0560, Accuracy: 0.9815

# %%
model.load_state_dict(pf_image_best_model_state)  # Restore best model state
# Out:
# <All keys matched successfully>

# %%
# Convert data to PyTorch tensors and create DataLoader
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
dnnx_test_tensor = torch.tensor(dnnx_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

dataset1 = TensorDataset(X_test_tensor, dnnx_test_tensor, y_test_tensor)
dataloader1 = DataLoader(dataset1, batch_size=512, shuffle=False)

# %% [markdown]
# #### Testing the Model

# %%
# Set the model to evaluation mode
        
model.load_state_dict(torch.load(os.path.join(out_dir, 'EX1_SG_MargNet_Model.pth'), map_location=device))
model.eval()

model.eval()
y_test_pred = torch.empty(0).to(device)

# Generate predictions
with torch.no_grad():
    for images, pfs, labels in dataloader1:
        images = images.to(device)
        pfs = pfs.to(device)
        labels = labels.to(device)
        pred = model([images, pfs])

        y_test_pred = torch.cat((y_test_pred, pred), dim=0)

y_test_pred = y_test_pred.cpu().numpy()
y_test_pred = y_test_pred.argmax(axis=1)
print(get_metrics(y_test_pred, y_test, label_strings))

# https://www.stackvidhya.com/plot-confusion-matrix-in-python-and-why/#google_vignette
# fig = plt.figure()
cf_matrix = metrics.confusion_matrix(y_test_pred, y_test)
cf_matrix_percentage = metrics.confusion_matrix(y_test_pred, y_test, normalize='true')
group_counts = ["{0:0.0f}".format(value) for value in cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_matrix_percentage.flatten()]
labels = [f"{v1}\n({v2})\n" for v1, v2 in
          zip(group_percentages,group_counts)]
labels = np.asarray(labels).reshape(2,2)
fig, ax = plt.subplots(figsize=(8, 6))  # Adjust the size as needed

ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
ax.set_xlabel('\nPredicted', fontsize=14, weight='bold')
ax.set_ylabel('Actual', fontsize=14, weight='bold');
ax.xaxis.set_ticklabels(['GALAXY', 'STAR'], fontsize=14, weight='bold')
ax.yaxis.set_ticklabels(['GALAXY', 'STAR'], fontsize=14, weight='bold')
plt.tight_layout()
plt.savefig(os.path.join(out_dir, "EX1_SG_MargNet_CM.png"))

plt.show()
plt.close()
# Out:
# Identified 19634 correct labels out of 20000 labels
# Accuracy: 0.9817
# Precision: 0.9817045940204275
# Recall: 0.98169534504213
# F1 Score: 0.9816993411762824
# Labels are: ['GALAXY' 'STAR']
# Confusion Matrix:
#  [[9757  191]
#  [ 175 9877]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      9948
#            1       0.98      0.98      0.98     10052
#
#     accuracy                           0.98     20000
#    macro avg       0.98      0.98      0.98     20000
# weighted avg       0.98      0.98      0.98     20000
#
# (array([    0,     1,     2, ..., 19997, 19998, 19999]), 0.9817, 0.9817045940204275, 0.98169534504213, array([[9757,  191],
#        [ 175, 9877]]), '              precision    recall  f1-score   support\n\n           0       0.98      0.98      0.98      9948\n           1       0.98      0.98      0.98     10052\n\n    accuracy                           0.98     20000\n   macro avg       0.98      0.98      0.98     20000\nweighted avg       0.98      0.98      0.98     20000\n')

# %%
sum(p.numel() for p in model.parameters())
# Out:
# 25874128

# %% [markdown]
# ## Result Analysis

# %%
del(dnnx_train, dnnx_val, dnnx_test, X_train, X_val, X_test)

# %%
X = np.load("/scratch/srinadb/Foundation/Dataset/Experiment1/X_exp1.npy")
dnnx = np.load("/scratch/srinadb/Foundation/Dataset/Experiment1/dnnx_exp1.npy")
objlist = np.load("/scratch/srinadb/Foundation/Dataset/Experiment1/objlist_exp1.npy")
y = np.load("/scratch/srinadb/Foundation/Dataset/Experiment1/y_exp1.npy", allow_pickle=True)

idx_drop = np.where(y=="QSO")[0]
X = np.delete(X,idx_drop,axis=0)
dnnx = np.delete(dnnx,idx_drop,axis=0)
y = np.delete(y,idx_drop,axis=0)
objlist = np.delete(objlist,idx_drop,axis=0)
y, label_strings = pd.factorize(y,sort=True)
# y = to_categorical(y)
print('\n')
print(label_strings)

zipX = list(zip(X, dnnx))
zipy = list(zip(y, objlist))

zipX_train, zipX_test, zipy_train, zipy_test = train_test_split(zipX, zipy, test_size = 0.125,random_state=42)
zipX_train, zipX_val, zipy_train, zipy_val = train_test_split(zipX_train, zipy_train, test_size = 0.1428, random_state=42)

X_train, dnnx_train = zip(*zipX_train)
X_val, dnnx_val = zip(*zipX_val)
X_test, dnnx_test = zip(*zipX_test)

y_train, objlist_train = zip(*zipy_train)
y_val, objlist_val = zip(*zipy_val)
y_test, objlist_test = zip(*zipy_test)

X_train = np.array(X_train)
X_val = np.array(X_val)
X_test = np.array(X_test)

dnnx_train = np.array(dnnx_train)
dnnx_val = np.array(dnnx_val)
dnnx_test = np.array(dnnx_test)

y_train = np.array(y_train)
objlist_train = np.array(objlist_train)
y_val = np.array(y_val)
objlist_val = np.array(objlist_val)
y_test = np.array(y_test)
objlist_test = np.array(objlist_test)

del(zipX,zipX_test,zipX_train,zipX_val, X, zipy, zipy_test, zipy_train, zipy_val, objlist)

X_train = X_train.transpose((0, 3, 1, 2))
X_val = X_val.transpose((0, 3, 1, 2))
X_test = X_test.transpose((0, 3, 1, 2))

print('\n')
print('The shape of the Train data is:', X_train.shape)
print('The shape of the Validation data is:', X_val.shape)
print('The shape of the Test data is:', X_test.shape)

# Convert data to PyTorch tensors and create DataLoader
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
dnnx_train_tensor = torch.tensor(dnnx_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)

X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
dnnx_val_tensor = torch.tensor(dnnx_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)

X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
dnnx_test_tensor = torch.tensor(dnnx_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)


train_dataset = TensorDataset(X_train_tensor, dnnx_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=512, shuffle=False)

val_dataset = TensorDataset(X_val_tensor, dnnx_val_tensor, y_val_tensor)
val_loader = DataLoader(val_dataset, batch_size=512, shuffle=False)

test_dataset = TensorDataset(X_test_tensor, dnnx_test_tensor, y_test_tensor)
test_loader = DataLoader(test_dataset, batch_size=512, shuffle=False)
# Out:
# ['GALAXY' 'STAR']
#
#
# The shape of the Train data is: (120007, 5, 32, 32)
# The shape of the Validation data is: (19992, 5, 32, 32)
# The shape of the Test data is: (20000, 5, 32, 32)

# %%
def get_preds(loader):
    model.eval()
    all_logits = []

    with torch.no_grad():
        for images, pf, labels in loader:
            pf = pf.to(device)
            images = images.to(device)
            logits = model([images, pf])      # [batch, 3]
            all_logits.append(logits.cpu())

    all_logits = torch.cat(all_logits, dim=0)   # [N, 3]
    all_probs  = F.softmax(all_logits, dim=1)   # probabilities, rows sum to 1
    all_probs  = all_probs.numpy()

    pred_labels = all_probs.argmax(axis=1)
    return all_probs, pred_labels

preds_train, y_train_pred = get_preds(train_loader)
print(get_metrics(y_train_pred, y_train, label_strings))
print('\n')

preds_val, y_val_pred = get_preds(val_loader)
print(get_metrics(y_val_pred, y_val, label_strings))
print('\n')

preds_test, y_test_pred = get_preds(test_loader)
print(get_metrics(y_test_pred, y_test, label_strings))
# Out:
# Identified 118387 correct labels out of 120007 labels
# Accuracy: 0.9865007874540652
# Precision: 0.9865068219264876
# Recall: 0.9865038586286666
# F1 Score: 0.9865007806818095
# Labels are: ['GALAXY' 'STAR']
# Confusion Matrix:
#  [[59151   939]
#  [  681 59236]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99     60090
#            1       0.98      0.99      0.99     59917
#
#     accuracy                           0.99    120007
#    macro avg       0.99      0.99      0.99    120007
# weighted avg       0.99      0.99      0.99    120007
#
# (array([     0,      1,      2, ..., 120004, 120005, 120006]), 0.9865007874540652, 0.9865068219264876, 0.9865038586286666, array([[59151,   939],
#        [  681, 59236]]), '              precision    recall  f1-score   support\n\n           0       0.99      0.98      0.99     60090\n           1       0.98      0.99      0.99     59917\n\n    accuracy                           0.99    120007\n   macro avg       0.99      0.99      0.99    120007\nweighted avg       0.99      0.99      0.99    120007\n')
#
#
# Identified 19624 correct labels out of 19992 labels
# Accuracy: 0.9815926370548219
# Precision: 0.9816055371318934
# Recall: 0.981585755976571
# F1 Score: 0.9815920998507763
# Labels are: ['GALAXY' 'STAR']
# Confusion Matrix:
#  [[9758  203]
#  [ 165 9866]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      9961
#            1       0.98      0.98      0.98     10031
#
#     accuracy                           0.98     19992
#    macro avg       0.98      0.98      0.98     19992
# weighted avg       0.98      0.98      0.98     19992
#
# (array([    0,     1,     2, ..., 19989, 19990, 19991]), 0.9815926370548219, 0.9816055371318934, 0.981585755976571, array([[9758,  203],
#        [ 165, 9866]]), '              precision    recall  f1-score   support\n\n           0       0.98      0.98      0.98      9961\n           1       0.98      0.98      0.98     10031\n\n    accuracy                           0.98     19992\n   macro avg       0.98      0.98      0.98     19992\nweighted avg       0.98      0.98      0.98     19992\n')
#
#
# Identified 19634 correct labels out of 20000 labels
# Accuracy: 0.9817
# Precision: 0.9817045940204275
# Recall: 0.98169534504213
# F1 Score: 0.9816993411762824
# Labels are: ['GALAXY' 'STAR']
# Confusion Matrix:
#  [[9757  191]
#  [ 175 9877]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      9948
#            1       0.98      0.98      0.98     10052
#
#     accuracy                           0.98     20000
#    macro avg       0.98      0.98      0.98     20000
# weighted avg       0.98      0.98      0.98     20000
#
# (array([    0,     1,     2, ..., 19997, 19998, 19999]), 0.9817, 0.9817045940204275, 0.98169534504213, array([[9757,  191],
#        [ 175, 9877]]), '              precision    recall  f1-score   support\n\n           0       0.98      0.98      0.98      9948\n           1       0.98      0.98      0.98     10052\n\n    accuracy                           0.98     20000\n   macro avg       0.98      0.98      0.98     20000\nweighted avg       0.98      0.98      0.98     20000\n')

# %%
df = pd.read_csv("/scratch/srinadb/Foundation/Dataset/Experiment1/photofeatures_exp1.csv",index_col=0)
df = df[df["class"]!="QSO"].reset_index()
df = df.set_index(["objid"])

df.loc[objlist_train, ["set"]] = "TRAIN"
df.loc[objlist_val, ["set"]] = "VALIDATION"
df.loc[objlist_test, ["set"]] = "TEST"

df.loc[objlist_train, ["pred_class"]] = label_strings[preds_train.argmax(axis=1)]
df.loc[objlist_val, ["pred_class"]] = label_strings[preds_val.argmax(axis=1)]
df.loc[objlist_test, ["pred_class"]] = label_strings[preds_test.argmax(axis=1)]

pgal_train = preds_train[:,np.where(label_strings=="GALAXY")[0][0]]
pstar_train = preds_train[:,np.where(label_strings=="STAR")[0][0]]

pgal_val = preds_val[:,np.where(label_strings=="GALAXY")[0][0]]
pstar_val = preds_val[:,np.where(label_strings=="STAR")[0][0]]

pgal_test = preds_test[:,np.where(label_strings=="GALAXY")[0][0]]
pstar_test = preds_test[:,np.where(label_strings=="STAR")[0][0]]


df.to_csv(os.path.join(out_dir, "EX1_SG_MargNet_results.csv"))

# %%
sns.set_palette("tab10")

df = pd.read_csv(os.path.join(out_dir, "EX1_SG_MargNet_results.csv"))

subdflist = []

bin_size = 0.1
lower_bin_list = np.arange(20,23,bin_size)
bad_lower_bin=[]
acclist = []
f1list = []
reportlist = []
num_samplelist = []
starmaglist = []
galmaglist = []

for lower_bin in lower_bin_list:
#     print(f"******************** {lower_bin} < r <= {lower_bin+bin_size} ********************")
    subdf = df[(
        ((df["dered_r"]+df["extinction_r"]) > lower_bin) & 
        ((df["dered_r"]+df["extinction_r"]) <= lower_bin+bin_size)
    )]
    # Choose equal number of stars and galaxies
    min_num = subdf["class"].value_counts().min()
    if min_num < 50:
        bad_lower_bin.append(lower_bin)
        continue
    s1 = subdf[subdf["class"]=="GALAXY"].sample(n=min_num)
    galmaglist.append((s1["dered_r"]+s1["extinction_r"]).to_numpy())
    s2 = subdf[subdf["class"]=="STAR"].sample(n=min_num)
    starmaglist.append((s2["dered_r"]+s2["extinction_r"]).to_numpy())
    num_samplelist.append(min_num)
    subdf = pd.concat([s1,s2])
    subdflist.append(subdf)
    
    accuracy = metrics.accuracy_score(subdf["class"], subdf["pred_class"])
    f1score = metrics.f1_score(subdf["class"], subdf["pred_class"],average='macro')
    report = metrics.classification_report(subdf["class"], subdf["pred_class"],output_dict=True)
    reportlist.append(report)
    acclist.append(accuracy)
    f1list.append(f1score)

bad_lower_bin = np.array(bad_lower_bin)
lower_bin_list = lower_bin_list[~np.in1d(lower_bin_list,bad_lower_bin)]
# elems in lower_bin_list not in bad_lower_bin

galmaglist = np.concatenate(galmaglist)

starmaglist = np.concatenate(starmaglist)

plt.errorbar(lower_bin_list+bin_size/2, np.array(acclist)*100, xerr=bin_size/2, fmt=" ",color="black",label="Bin")
plt.errorbar(lower_bin_list+bin_size/2, np.array(acclist)*100, yerr=0.01*100,fmt=".",color="red",label="Accuracy")
# plt.errorbar(lower_bin_list+bin_size/2, f1list, yerr=0.01,label="F1 Score")
plt.legend()
plt.title("Star-Galaxy")
plt.xlabel("r magnitude bins")
plt.ylabel("Accuracy Score (%)")
# plt.ylim(93, 100)
# os.path.join(out_dir, "EX1_SG_MargNet_results.csv")
plt.savefig(os.path.join(out_dir, "EX1_SG_MargNet_v2.png"))

# %%
subdfs = pd.concat(subdflist)
subdfs["r"]=subdfs["dered_r"]+subdfs["extinction_r"]

gal_recall_list = []
gal_precision_list = []
star_recall_list = []
star_precision_list = []
for r in reportlist:
    gal_recall_list.append(r["GALAXY"]["recall"])
    gal_precision_list.append(r["GALAXY"]["precision"])
    star_recall_list.append(r["STAR"]["recall"])
    star_precision_list.append(r["STAR"]["precision"])
    
    
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1,sharex=True, figsize=(8,18))

galcolor = sns.color_palette("tab10")[1]
starcolor = sns.color_palette("tab10")[2]
acccolor = sns.color_palette("tab10")[3]
f1color = sns.color_palette("tab10")[4]

dyfit = 0.01
x_ax = lower_bin_list+bin_size/2


d1 = subdfs[subdfs["class"]=="GALAXY"]["r"]
d2 = subdfs[subdfs["class"]=="STAR"]["r"]

ax1.hist([d1, d2], color=[galcolor,starcolor],
         alpha=0.8, label=["GALAXY","STAR"],bins=len(lower_bin_list))
ax1.set_ylabel("Count")

ax1.legend()


y_ax1 = np.array(gal_precision_list)
y_ax2 = np.array(star_precision_list)

ax2.errorbar(x_ax, y_ax1*100,fmt="-o", ms=4, label="Galaxy Precision",color=galcolor)
ax2.fill_between(x_ax, y_ax1*100 - dyfit*100, y_ax1*100 + dyfit*100,
             color=sns.color_palette("pastel")[1], alpha=0.3)
ax2.errorbar(x_ax, y_ax2*100,fmt="-o", ms=4, label="Star Precision",color=starcolor)
ax2.fill_between(x_ax, y_ax2*100 - dyfit*100, y_ax2*100 + dyfit*100,
                 color=sns.color_palette("pastel")[2], alpha=0.3)
ax2.set_ylabel("Precision (%)")
ax2.legend()



y_ax1 = np.array(gal_recall_list)
y_ax2 = np.array(star_recall_list)

ax3.errorbar(x_ax, y_ax1*100,fmt="-o", ms=4, label="Galaxy Recall",color=galcolor)
ax3.fill_between(x_ax, y_ax1*100 - dyfit*100, y_ax1*100 + dyfit*100,
             color=sns.color_palette("pastel")[1], alpha=0.3)
ax3.errorbar(x_ax, y_ax2*100,fmt="-o", ms=4, label="Star Recall",color=starcolor)
ax3.fill_between(x_ax, y_ax2*100 - dyfit*100, y_ax2*100 + dyfit*100,
             color=sns.color_palette("pastel")[2], alpha=0.3)
ax3.set_ylabel("Recall (%)")
ax3.legend()



y_ax1 = np.array(acclist)
y_ax2 = np.array(f1list)
ax4.errorbar(x_ax, y_ax1*100,fmt="-o", ms=4, label="Accuracy",color=acccolor)
# ax4.errorbar(x_ax, y_ax2*100,fmt="-o", ms=4, label="F1 Score",color=f1color)
ax4.fill_between(x_ax, y_ax1*100 - dyfit*100, y_ax1*100 + dyfit*100,
             color=sns.color_palette("pastel")[3], alpha=0.3)
ax4.set_ylabel("Accuracy Score (%)")
ax4.legend()

plt.xlabel("r magnitude bins")


# plt.suptitle("Star-Galaxy")
plt.savefig(os.path.join(out_dir, "EX1_SG_MargNet_v2Set.png")) 
plt.show()
