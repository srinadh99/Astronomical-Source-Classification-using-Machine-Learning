# %% [markdown]
# ## MargNet - Experiment2 - Star-Galaxy Classification
#
# ## Star-Galaxy Classification (Experiment 2) using MargNet. Stacked ensemble of ANN (for Photometric features), and CNN (for images).

# %% [markdown]
# #### Import libraries

# %%
import warnings
warnings.filterwarnings("ignore")

import os
import numpy as np
np.random.seed(69)
import pandas as pd
import random
import matplotlib.pyplot as plt
import matplotlib.image as img
import seaborn as sns
sns.set()
# from tqdm.notebook 
import tqdm
from sklearn import metrics
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import time
import pickle

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader

# %%
out_dir = "/scratch/srinadb/Foundation/Trained_Models/MargNet/Experiment2/SG/"
os.makedirs(out_dir, exist_ok=True)

# %% [markdown]
# #### 1. Load and extract the dataset

# %%
X = np.load("/scratch/srinadb/Foundation/Dataset/Experiment2/X_exp2.npy")
dnnx = np.load("/scratch/srinadb/Foundation//Dataset/Experiment2/dnnx_exp2.npy")
objlist = np.load("/scratch/srinadb/Foundation//Dataset/Experiment2/objlist_exp2.npy")
y = np.load("/scratch/srinadb/Foundation//Dataset/Experiment2/y_exp2.npy", allow_pickle=True)

idx_drop = np.where(y=="QSO")[0]
X = np.delete(X,idx_drop,axis=0)
dnnx = np.delete(dnnx,idx_drop,axis=0)
y = np.delete(y,idx_drop,axis=0)
objlist = np.delete(objlist,idx_drop,axis=0)
y, label_strings = pd.factorize(y,sort=True)
# y = to_categorical(y)
print('\n')
print(label_strings)
# Out:
# ['GALAXY' 'STAR']

# %%
zipX = list(zip(X, dnnx))
zipy = list(zip(y, objlist))

zipX_train, zipX_test, zipy_train, zipy_test = train_test_split(zipX, zipy, test_size = 0.1,random_state=42)
zipX_train, zipX_val, zipy_train, zipy_val = train_test_split(zipX_train, zipy_train, test_size = 0.111111, random_state=42)

X_train, dnnx_train = zip(*zipX_train)
X_val, dnnx_val = zip(*zipX_val)
X_test, dnnx_test = zip(*zipX_test)

y_train, objlist_train = zip(*zipy_train)
y_val, objlist_val = zip(*zipy_val)
y_test, objlist_test = zip(*zipy_test)

X_train = np.array(X_train)
X_val = np.array(X_val)
X_test = np.array(X_test)

dnnx_train = np.array(dnnx_train)
dnnx_val = np.array(dnnx_val)
dnnx_test = np.array(dnnx_test)

y_train = np.array(y_train)
objlist_train = np.array(objlist_train)
y_val = np.array(y_val)
objlist_val = np.array(objlist_val)
y_test = np.array(y_test)
objlist_test = np.array(objlist_test)

del(zipX,zipX_test,zipX_train,zipX_val, X, zipy, zipy_test, zipy_train, zipy_val, objlist)

X_train = X_train.transpose((0, 3, 1, 2))
X_val = X_val.transpose((0, 3, 1, 2))
X_test = X_test.transpose((0, 3, 1, 2))


print('The shape of the Train data is:', dnnx_train.shape)
print('The shape of the Validation data is:', dnnx_val.shape)
print('The shape of the Test data is:', dnnx_test.shape)
print('\n')
print('The shape of the Train data is:', X_train.shape)
print('The shape of the Validation data is:', X_val.shape)
print('The shape of the Test data is:', X_test.shape)
# Out:
# The shape of the Train data is: (79996, 24)
# The shape of the Validation data is: (10000, 24)
# The shape of the Test data is: (10000, 24)
#
#
# The shape of the Train data is: (79996, 5, 32, 32)
# The shape of the Validation data is: (10000, 5, 32, 32)
# The shape of the Test data is: (10000, 5, 32, 32)

# %%
def get_metrics(y_pred, y_test, labels, to_print=True):
    correct_labels = np.where(y_pred==y_test)[0]
    accuracy = metrics.accuracy_score(y_test, y_pred)
    precision = metrics.precision_score(y_test, y_pred,average='macro')
    recall = metrics.recall_score(y_test, y_pred,average='macro')
    f1score = metrics.f1_score(y_test, y_pred,average='macro')
    # rocscore = metrics.roc_auc_score(y_test, y_pred,average='micro',multi_class="ovo")
    confusion_matrix = metrics.confusion_matrix(y_test, y_pred)  
    classification_report = metrics.classification_report(y_test, y_pred)

    if to_print:
        print("Identified {} correct labels out of {} labels".format(len(correct_labels), y_test.shape[0]))
        print("Accuracy:",accuracy)
        print("Precision:",precision)
        print("Recall:",recall)
        print("F1 Score:",f1score)
        # print("ROC AUC Score:",rocscore)
        print(f"Labels are: {labels}")
        print("Confusion Matrix:\n", confusion_matrix)
        print("Classification_Report:\n", classification_report)

    return (correct_labels, accuracy, precision, recall, confusion_matrix, classification_report)

# %% [markdown]
# ### 1. ANN Model using Photometric Features

# %% [markdown]
# ##### Create dataset and dataloader for pytorch training

# %%
class SGData_pf(Dataset):
    def __init__(self, x, y, transform=None):
        self.n_samples = x.shape[0]
        self.x = torch.tensor(x, dtype=torch.float32)
        self.y = torch.tensor(y)
        self.transform = transform

    def __len__(self):
        return self.n_samples

    def __getitem__(self, i):
        inputs, targets = self.x[i], self.y[i]

        if self.transform:
            inputs = self.transform(inputs)

        return inputs, targets

# Create DataLoader for training and validation data
pf_train_dataset = SGData_pf(dnnx_train, y_train, transform=None)
pf_train_loader = DataLoader(pf_train_dataset, batch_size=2048, shuffle=True, num_workers=8)
pf_val_dataset = SGData_pf(dnnx_val, y_val, transform=None)
pf_val_loader = DataLoader(pf_val_dataset, batch_size=2048, shuffle=False, num_workers=4)
pf_test_dataset = SGData_pf(dnnx_test, y_test)
pf_test_loader = DataLoader(pf_test_dataset, batch_size=2048, shuffle=False)

# %% [markdown]
# #### Initialize or Define the Model

# %%
# Define the custom PyTorch model

class DNNModel(nn.Module):
    def __init__(self, input_dim, n_classes):
        super(DNNModel, self).__init__()
        self.fc1 = nn.Linear(input_dim, 1024)
        self.dropout1 = nn.Dropout(0.25)
        # self.activation = torch.nn.sigmoid()
        self.fc2 = nn.Linear(1024, 256)
        self.dropout2 = nn.Dropout(0.25)
        self.fc3 = nn.Linear(256, 128)
        self.dropout3 = nn.Dropout(0.25)
        self.fc4 = nn.Linear(128, 64)
        self.dropout4 = nn.Dropout(0.25)
        self.fc5 = nn.Linear(64, 32)
        self.dropout5 = nn.Dropout(0.25)
        self.fc6 = nn.Linear(32, n_classes)        

    def forward(self, x):
        x = torch.sigmoid(self.fc1(x))
        x = self.dropout1(x)
        x = torch.sigmoid(self.fc2(x))
        x = self.dropout2(x)
        x = torch.sigmoid(self.fc3(x))
        x = self.dropout3(x)
        x = torch.sigmoid(self.fc4(x))
        x = self.dropout4(x)
        x = torch.sigmoid(self.fc5(x))
        x = self.dropout5(x)
        x = self.fc6(x)
        return x

# Initialize the PyTorch model
pf_input_dim = dnnx_train.shape[1]
n_classes = 2
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
pf_model = DNNModel(pf_input_dim, n_classes).to(device)
# Out:
# cuda:0

# %% [markdown]
# #### Training the model

# %%
train_loss_arr = []
train_accuracy_arr = []
val_loss_arr = []
val_accuracy_arr = []

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(pf_model.parameters())

# Early stopping parameters
patience = 100
best_val_loss = float('inf')
best_model_state = None  # Initialize a variable to store the best model state
counter = 0

# Training loop
epochs = 4000
epoch1 =0

for epoch in range(epochs):
    epoch1+=1
    pf_model.train()
    train_loss = 0.0
    correct_train = 0
    total_train = 0
    for batch_x, batch_y in pf_train_loader:
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)
        optimizer.zero_grad()
        output = pf_model(batch_x)
        loss = criterion(output, batch_y)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = output.max(1)
        total_train += batch_y.size(0)
        correct_train += predicted.eq(batch_y).sum().item()

    train_loss /= len(pf_train_loader)
    train_accuracy = correct_train / total_train
    train_loss_arr.append(train_loss)
    train_accuracy_arr.append(train_accuracy)
    
    pf_model.eval()
    
    val_loss = 0.0
    correct_val = 0
    total_val = 0
    with torch.no_grad():
        for batch_x, batch_y in pf_val_loader:
            batch_x = batch_x.to(device)
            batch_y = batch_y.to(device)
            output = pf_model(batch_x)
            val_loss += criterion(output, batch_y).item()
            _, predicted = output.max(1)
            total_val += batch_y.size(0)
            correct_val += predicted.eq(batch_y).sum().item()

    val_loss /= len(pf_val_loader)
    val_accuracy = correct_val / total_val
    val_loss_arr.append(val_loss)
    val_accuracy_arr.append(val_accuracy)
    
    pf_model.train()
        
    #Check for early stopping and save best model state
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        counter = 0
        best_model_state = pf_model.state_dict()  # Store the current best model state 
        torch.save(best_model_state, os.path.join(out_dir, 'EX2_SG_MargNet_DNN_Model.pth'))
    else:
        counter += 1

    if counter >= patience:
        print(f'Early stopping at epoch {epoch+1}')
        if best_model_state is not None:
            pf_model.load_state_dict(best_model_state)  # Restore best model state
        counter = 0  # Reset the counter    
        break

    print(f'Epoch [{epoch+1}/{epochs}] - '
      f'Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, '
      f'Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}')

# Create the range of epochs
epoch_range = range(1, epoch1+1)
    
# Plot training accuracy in blue
plt.figsize=(8, 6)  # Adjust the size as needed
plt.plot(epoch_range, train_accuracy_arr, label='Train Accuracy', color='blue')

# Plot validation accuracy in red
plt.plot(epoch_range, val_accuracy_arr, label='Validation Accuracy', color='red')

# Add labels and title
plt.xlabel('Epoch', fontsize=14, weight='bold')
plt.ylabel('Accuracy', fontsize=14, weight='bold')
plt.title('Model Accuracy', fontsize=14, weight='bold')

# Add a legend
plt.legend(fontsize=14, title_fontproperties={'weight':'bold'})
plt.savefig(os.path.join(out_dir, "EX2_SG_MargNet_DNN_Accuracy.png"))
# Show the plot
plt.show()
plt.close()

# Plot training accuracy in blue
plt.figsize=(8, 6)  # Adjust the size as needed
plt.plot(epoch_range, train_loss_arr, label='Train Loss', color='blue')

# Plot validation accuracy in red
plt.plot(epoch_range, val_loss_arr, label='Validation Loss', color='red')

# Add labels and title
plt.xlabel('Epoch', fontsize=14, weight='bold')
plt.ylabel('Loss', fontsize=14, weight='bold')
plt.title('Model Loss', fontsize=14, weight='bold')

# Add a legend
plt.legend(fontsize=14, title_fontproperties={'weight':'bold'})
plt.savefig(os.path.join(out_dir, "EX2_SG_MargNet_DNN_Loss.png"))

# Show the plot
plt.show()
plt.close()
# Out:
# Epoch [1/4000] - Train Loss: 0.7023, Train Accuracy: 0.5024, Validation Loss: 0.6938, Validation Accuracy: 0.4934
# Epoch [2/4000] - Train Loss: 0.6969, Train Accuracy: 0.4995, Validation Loss: 0.6915, Validation Accuracy: 0.7018
# Epoch [3/4000] - Train Loss: 0.6567, Train Accuracy: 0.6206, Validation Loss: 0.5440, Validation Accuracy: 0.7925
# Epoch [4/4000] - Train Loss: 0.4215, Train Accuracy: 0.8405, Validation Loss: 0.3227, Validation Accuracy: 0.8826
# Epoch [5/4000] - Train Loss: 0.3291, Train Accuracy: 0.8761, Validation Loss: 0.3039, Validation Accuracy: 0.8857
# Epoch [6/4000] - Train Loss: 0.3011, Train Accuracy: 0.8895, Validation Loss: 0.2427, Validation Accuracy: 0.9145
# Epoch [7/4000] - Train Loss: 0.2633, Train Accuracy: 0.9057, Validation Loss: 0.2181, Validation Accuracy: 0.9232
# Epoch [8/4000] - Train Loss: 0.2431, Train Accuracy: 0.9135, Validation Loss: 0.2048, Validation Accuracy: 0.9310
# Epoch [9/4000] - Train Loss: 0.2261, Train Accuracy: 0.9226, Validation Loss: 0.1911, Validation Accuracy: 0.9361
# Epoch [10/4000] - Train Loss: 0.2220, Train Accuracy: 0.9226, Validation Loss: 0.1843, Validation Accuracy: 0.9372
# Epoch [11/4000] - Train Loss: 0.2169, Train Accuracy: 0.9261, Validation Loss: 0.1813, Validation Accuracy: 0.9385
# Epoch [12/4000] - Train Loss: 0.2070, Train Accuracy: 0.9291, Validation Loss: 0.1790, Validation Accuracy: 0.9396
# Epoch [13/4000] - Train Loss: 0.2049, Train Accuracy: 0.9302, Validation Loss: 0.1849, Validation Accuracy: 0.9396
# Epoch [14/4000] - Train Loss: 0.2039, Train Accuracy: 0.9319, Validation Loss: 0.1745, Validation Accuracy: 0.9412
# Epoch [15/4000] - Train Loss: 0.1969, Train Accuracy: 0.9326, Validation Loss: 0.1761, Validation Accuracy: 0.9409
# Epoch [16/4000] - Train Loss: 0.2001, Train Accuracy: 0.9325, Validation Loss: 0.1827, Validation Accuracy: 0.9381
# Epoch [17/4000] - Train Loss: 0.1991, Train Accuracy: 0.9331, Validation Loss: 0.1714, Validation Accuracy: 0.9418
# Epoch [18/4000] - Train Loss: 0.1934, Train Accuracy: 0.9342, Validation Loss: 0.1715, Validation Accuracy: 0.9421
# Epoch [19/4000] - Train Loss: 0.1920, Train Accuracy: 0.9345, Validation Loss: 0.1714, Validation Accuracy: 0.9420
# Epoch [20/4000] - Train Loss: 0.1915, Train Accuracy: 0.9350, Validation Loss: 0.1692, Validation Accuracy: 0.9425
# Epoch [21/4000] - Train Loss: 0.1894, Train Accuracy: 0.9353, Validation Loss: 0.1702, Validation Accuracy: 0.9424
# Epoch [22/4000] - Train Loss: 0.1880, Train Accuracy: 0.9355, Validation Loss: 0.1717, Validation Accuracy: 0.9413
# Epoch [23/4000] - Train Loss: 0.1894, Train Accuracy: 0.9355, Validation Loss: 0.1653, Validation Accuracy: 0.9445
# Epoch [24/4000] - Train Loss: 0.1844, Train Accuracy: 0.9371, Validation Loss: 0.1651, Validation Accuracy: 0.9435
# Epoch [25/4000] - Train Loss: 0.1814, Train Accuracy: 0.9369, Validation Loss: 0.1665, Validation Accuracy: 0.9428
# Epoch [26/4000] - Train Loss: 0.1812, Train Accuracy: 0.9368, Validation Loss: 0.1704, Validation Accuracy: 0.9417
# Epoch [27/4000] - Train Loss: 0.1821, Train Accuracy: 0.9371, Validation Loss: 0.1661, Validation Accuracy: 0.9433
# Epoch [28/4000] - Train Loss: 0.1813, Train Accuracy: 0.9371, Validation Loss: 0.1627, Validation Accuracy: 0.9440
# Epoch [29/4000] - Train Loss: 0.1768, Train Accuracy: 0.9392, Validation Loss: 0.1843, Validation Accuracy: 0.9351
# Epoch [30/4000] - Train Loss: 0.1839, Train Accuracy: 0.9358, Validation Loss: 0.1790, Validation Accuracy: 0.9355
# Epoch [31/4000] - Train Loss: 0.1790, Train Accuracy: 0.9382, Validation Loss: 0.1613, Validation Accuracy: 0.9444
# Epoch [32/4000] - Train Loss: 0.1773, Train Accuracy: 0.9399, Validation Loss: 0.1570, Validation Accuracy: 0.9455
# Epoch [33/4000] - Train Loss: 0.1754, Train Accuracy: 0.9387, Validation Loss: 0.1662, Validation Accuracy: 0.9425
# Epoch [34/4000] - Train Loss: 0.1790, Train Accuracy: 0.9389, Validation Loss: 0.1594, Validation Accuracy: 0.9440
# Epoch [35/4000] - Train Loss: 0.1733, Train Accuracy: 0.9401, Validation Loss: 0.1610, Validation Accuracy: 0.9436
# Epoch [36/4000] - Train Loss: 0.1712, Train Accuracy: 0.9405, Validation Loss: 0.1569, Validation Accuracy: 0.9461
# Epoch [37/4000] - Train Loss: 0.1722, Train Accuracy: 0.9411, Validation Loss: 0.1558, Validation Accuracy: 0.9474
# Epoch [38/4000] - Train Loss: 0.1725, Train Accuracy: 0.9404, Validation Loss: 0.1551, Validation Accuracy: 0.9472
# Epoch [39/4000] - Train Loss: 0.1717, Train Accuracy: 0.9411, Validation Loss: 0.1573, Validation Accuracy: 0.9447
# Epoch [40/4000] - Train Loss: 0.1709, Train Accuracy: 0.9413, Validation Loss: 0.1626, Validation Accuracy: 0.9442
# Epoch [41/4000] - Train Loss: 0.1723, Train Accuracy: 0.9391, Validation Loss: 0.1552, Validation Accuracy: 0.9461
# Epoch [42/4000] - Train Loss: 0.1690, Train Accuracy: 0.9414, Validation Loss: 0.1548, Validation Accuracy: 0.9457
# Epoch [43/4000] - Train Loss: 0.1696, Train Accuracy: 0.9413, Validation Loss: 0.1597, Validation Accuracy: 0.9445
# Epoch [44/4000] - Train Loss: 0.1721, Train Accuracy: 0.9408, Validation Loss: 0.1600, Validation Accuracy: 0.9442
# Epoch [45/4000] - Train Loss: 0.1697, Train Accuracy: 0.9413, Validation Loss: 0.1527, Validation Accuracy: 0.9478
# Epoch [46/4000] - Train Loss: 0.1695, Train Accuracy: 0.9420, Validation Loss: 0.1532, Validation Accuracy: 0.9473
# Epoch [47/4000] - Train Loss: 0.1661, Train Accuracy: 0.9426, Validation Loss: 0.1554, Validation Accuracy: 0.9463
# Epoch [48/4000] - Train Loss: 0.1669, Train Accuracy: 0.9422, Validation Loss: 0.1517, Validation Accuracy: 0.9477
# Epoch [49/4000] - Train Loss: 0.1662, Train Accuracy: 0.9428, Validation Loss: 0.1517, Validation Accuracy: 0.9487
# Epoch [50/4000] - Train Loss: 0.1670, Train Accuracy: 0.9428, Validation Loss: 0.1509, Validation Accuracy: 0.9472
# Epoch [51/4000] - Train Loss: 0.1645, Train Accuracy: 0.9427, Validation Loss: 0.1555, Validation Accuracy: 0.9450
# Epoch [52/4000] - Train Loss: 0.1634, Train Accuracy: 0.9428, Validation Loss: 0.1606, Validation Accuracy: 0.9439
# Epoch [53/4000] - Train Loss: 0.1676, Train Accuracy: 0.9418, Validation Loss: 0.1495, Validation Accuracy: 0.9480
# Epoch [54/4000] - Train Loss: 0.1632, Train Accuracy: 0.9438, Validation Loss: 0.1547, Validation Accuracy: 0.9473
# Epoch [55/4000] - Train Loss: 0.1668, Train Accuracy: 0.9428, Validation Loss: 0.1507, Validation Accuracy: 0.9479
# Epoch [56/4000] - Train Loss: 0.1633, Train Accuracy: 0.9435, Validation Loss: 0.1493, Validation Accuracy: 0.9489
# Epoch [57/4000] - Train Loss: 0.1617, Train Accuracy: 0.9447, Validation Loss: 0.1480, Validation Accuracy: 0.9487
# Epoch [58/4000] - Train Loss: 0.1627, Train Accuracy: 0.9432, Validation Loss: 0.1509, Validation Accuracy: 0.9486
# Epoch [59/4000] - Train Loss: 0.1637, Train Accuracy: 0.9434, Validation Loss: 0.1472, Validation Accuracy: 0.9491
# Epoch [60/4000] - Train Loss: 0.1629, Train Accuracy: 0.9435, Validation Loss: 0.1470, Validation Accuracy: 0.9498
# Epoch [61/4000] - Train Loss: 0.1604, Train Accuracy: 0.9444, Validation Loss: 0.1815, Validation Accuracy: 0.9350
# Epoch [62/4000] - Train Loss: 0.1650, Train Accuracy: 0.9423, Validation Loss: 0.1541, Validation Accuracy: 0.9465
# Epoch [63/4000] - Train Loss: 0.1600, Train Accuracy: 0.9445, Validation Loss: 0.1455, Validation Accuracy: 0.9498
# Epoch [64/4000] - Train Loss: 0.1595, Train Accuracy: 0.9447, Validation Loss: 0.1476, Validation Accuracy: 0.9490
# Epoch [65/4000] - Train Loss: 0.1592, Train Accuracy: 0.9444, Validation Loss: 0.1463, Validation Accuracy: 0.9497
# Epoch [66/4000] - Train Loss: 0.1598, Train Accuracy: 0.9449, Validation Loss: 0.1455, Validation Accuracy: 0.9491
# Epoch [67/4000] - Train Loss: 0.1596, Train Accuracy: 0.9453, Validation Loss: 0.1490, Validation Accuracy: 0.9483
# Epoch [68/4000] - Train Loss: 0.1609, Train Accuracy: 0.9438, Validation Loss: 0.1458, Validation Accuracy: 0.9495
# Epoch [69/4000] - Train Loss: 0.1596, Train Accuracy: 0.9449, Validation Loss: 0.1462, Validation Accuracy: 0.9498
# Epoch [70/4000] - Train Loss: 0.1566, Train Accuracy: 0.9457, Validation Loss: 0.1466, Validation Accuracy: 0.9495
# Epoch [71/4000] - Train Loss: 0.1584, Train Accuracy: 0.9456, Validation Loss: 0.1482, Validation Accuracy: 0.9473
# Epoch [72/4000] - Train Loss: 0.1585, Train Accuracy: 0.9467, Validation Loss: 0.1475, Validation Accuracy: 0.9480
# Epoch [73/4000] - Train Loss: 0.1594, Train Accuracy: 0.9455, Validation Loss: 0.1496, Validation Accuracy: 0.9491
# Epoch [74/4000] - Train Loss: 0.1574, Train Accuracy: 0.9454, Validation Loss: 0.1425, Validation Accuracy: 0.9507
# Epoch [75/4000] - Train Loss: 0.1584, Train Accuracy: 0.9448, Validation Loss: 0.1458, Validation Accuracy: 0.9495
# Epoch [76/4000] - Train Loss: 0.1548, Train Accuracy: 0.9466, Validation Loss: 0.1471, Validation Accuracy: 0.9490
# Epoch [77/4000] - Train Loss: 0.1552, Train Accuracy: 0.9465, Validation Loss: 0.1443, Validation Accuracy: 0.9499
# Epoch [78/4000] - Train Loss: 0.1586, Train Accuracy: 0.9462, Validation Loss: 0.1473, Validation Accuracy: 0.9481
# Epoch [79/4000] - Train Loss: 0.1559, Train Accuracy: 0.9470, Validation Loss: 0.1420, Validation Accuracy: 0.9508
# Epoch [80/4000] - Train Loss: 0.1561, Train Accuracy: 0.9467, Validation Loss: 0.1412, Validation Accuracy: 0.9516
# Epoch [81/4000] - Train Loss: 0.1544, Train Accuracy: 0.9467, Validation Loss: 0.1450, Validation Accuracy: 0.9496
# Epoch [82/4000] - Train Loss: 0.1545, Train Accuracy: 0.9472, Validation Loss: 0.1415, Validation Accuracy: 0.9517
# Epoch [83/4000] - Train Loss: 0.1539, Train Accuracy: 0.9466, Validation Loss: 0.1448, Validation Accuracy: 0.9504
# Epoch [84/4000] - Train Loss: 0.1529, Train Accuracy: 0.9467, Validation Loss: 0.1539, Validation Accuracy: 0.9479
# Epoch [85/4000] - Train Loss: 0.1555, Train Accuracy: 0.9457, Validation Loss: 0.1399, Validation Accuracy: 0.9521
# Epoch [86/4000] - Train Loss: 0.1570, Train Accuracy: 0.9467, Validation Loss: 0.1417, Validation Accuracy: 0.9493
# Epoch [87/4000] - Train Loss: 0.1547, Train Accuracy: 0.9469, Validation Loss: 0.1426, Validation Accuracy: 0.9504
# Epoch [88/4000] - Train Loss: 0.1539, Train Accuracy: 0.9471, Validation Loss: 0.1439, Validation Accuracy: 0.9510
# Epoch [89/4000] - Train Loss: 0.1546, Train Accuracy: 0.9474, Validation Loss: 0.1514, Validation Accuracy: 0.9452
# Epoch [90/4000] - Train Loss: 0.1564, Train Accuracy: 0.9466, Validation Loss: 0.1397, Validation Accuracy: 0.9501
# Epoch [91/4000] - Train Loss: 0.1530, Train Accuracy: 0.9483, Validation Loss: 0.1515, Validation Accuracy: 0.9451
# Epoch [92/4000] - Train Loss: 0.1548, Train Accuracy: 0.9459, Validation Loss: 0.1413, Validation Accuracy: 0.9518
# Epoch [93/4000] - Train Loss: 0.1519, Train Accuracy: 0.9483, Validation Loss: 0.1418, Validation Accuracy: 0.9521
# Epoch [94/4000] - Train Loss: 0.1528, Train Accuracy: 0.9482, Validation Loss: 0.1385, Validation Accuracy: 0.9513
# Epoch [95/4000] - Train Loss: 0.1511, Train Accuracy: 0.9488, Validation Loss: 0.1389, Validation Accuracy: 0.9513
# Epoch [96/4000] - Train Loss: 0.1521, Train Accuracy: 0.9476, Validation Loss: 0.1422, Validation Accuracy: 0.9513
# Epoch [97/4000] - Train Loss: 0.1504, Train Accuracy: 0.9489, Validation Loss: 0.1386, Validation Accuracy: 0.9525
# Epoch [98/4000] - Train Loss: 0.1532, Train Accuracy: 0.9476, Validation Loss: 0.1377, Validation Accuracy: 0.9521
# Epoch [99/4000] - Train Loss: 0.1545, Train Accuracy: 0.9485, Validation Loss: 0.1480, Validation Accuracy: 0.9454
# Epoch [100/4000] - Train Loss: 0.1515, Train Accuracy: 0.9475, Validation Loss: 0.1379, Validation Accuracy: 0.9523
# Epoch [101/4000] - Train Loss: 0.1498, Train Accuracy: 0.9486, Validation Loss: 0.1376, Validation Accuracy: 0.9523
# Epoch [102/4000] - Train Loss: 0.1479, Train Accuracy: 0.9487, Validation Loss: 0.1416, Validation Accuracy: 0.9535
# Epoch [103/4000] - Train Loss: 0.1528, Train Accuracy: 0.9484, Validation Loss: 0.1377, Validation Accuracy: 0.9528
# Epoch [104/4000] - Train Loss: 0.1499, Train Accuracy: 0.9490, Validation Loss: 0.1359, Validation Accuracy: 0.9535
# Epoch [105/4000] - Train Loss: 0.1496, Train Accuracy: 0.9495, Validation Loss: 0.1387, Validation Accuracy: 0.9535
# Epoch [106/4000] - Train Loss: 0.1472, Train Accuracy: 0.9497, Validation Loss: 0.1439, Validation Accuracy: 0.9482
# Epoch [107/4000] - Train Loss: 0.1508, Train Accuracy: 0.9485, Validation Loss: 0.1359, Validation Accuracy: 0.9523
# Epoch [108/4000] - Train Loss: 0.1502, Train Accuracy: 0.9490, Validation Loss: 0.1359, Validation Accuracy: 0.9534
# Epoch [109/4000] - Train Loss: 0.1460, Train Accuracy: 0.9496, Validation Loss: 0.1378, Validation Accuracy: 0.9532
# Epoch [110/4000] - Train Loss: 0.1460, Train Accuracy: 0.9503, Validation Loss: 0.1391, Validation Accuracy: 0.9494
# Epoch [111/4000] - Train Loss: 0.1461, Train Accuracy: 0.9496, Validation Loss: 0.1353, Validation Accuracy: 0.9529
# Epoch [112/4000] - Train Loss: 0.1480, Train Accuracy: 0.9497, Validation Loss: 0.1357, Validation Accuracy: 0.9540
# Epoch [113/4000] - Train Loss: 0.1448, Train Accuracy: 0.9498, Validation Loss: 0.1418, Validation Accuracy: 0.9487
# Epoch [114/4000] - Train Loss: 0.1487, Train Accuracy: 0.9496, Validation Loss: 0.1400, Validation Accuracy: 0.9524
# Epoch [115/4000] - Train Loss: 0.1482, Train Accuracy: 0.9498, Validation Loss: 0.1553, Validation Accuracy: 0.9432
# Epoch [116/4000] - Train Loss: 0.1519, Train Accuracy: 0.9494, Validation Loss: 0.1358, Validation Accuracy: 0.9525
# Epoch [117/4000] - Train Loss: 0.1458, Train Accuracy: 0.9501, Validation Loss: 0.1343, Validation Accuracy: 0.9535
# Epoch [118/4000] - Train Loss: 0.1463, Train Accuracy: 0.9502, Validation Loss: 0.1335, Validation Accuracy: 0.9545
# Epoch [119/4000] - Train Loss: 0.1459, Train Accuracy: 0.9501, Validation Loss: 0.1356, Validation Accuracy: 0.9540
# Epoch [120/4000] - Train Loss: 0.1452, Train Accuracy: 0.9496, Validation Loss: 0.1352, Validation Accuracy: 0.9538
# Epoch [121/4000] - Train Loss: 0.1440, Train Accuracy: 0.9509, Validation Loss: 0.1342, Validation Accuracy: 0.9520
# Epoch [122/4000] - Train Loss: 0.1426, Train Accuracy: 0.9511, Validation Loss: 0.1388, Validation Accuracy: 0.9545
# Epoch [123/4000] - Train Loss: 0.1440, Train Accuracy: 0.9509, Validation Loss: 0.1323, Validation Accuracy: 0.9532
# Epoch [124/4000] - Train Loss: 0.1423, Train Accuracy: 0.9503, Validation Loss: 0.1340, Validation Accuracy: 0.9544
# Epoch [125/4000] - Train Loss: 0.1446, Train Accuracy: 0.9507, Validation Loss: 0.1323, Validation Accuracy: 0.9552
# Epoch [126/4000] - Train Loss: 0.1470, Train Accuracy: 0.9506, Validation Loss: 0.1331, Validation Accuracy: 0.9540
# Epoch [127/4000] - Train Loss: 0.1449, Train Accuracy: 0.9505, Validation Loss: 0.1315, Validation Accuracy: 0.9552
# Epoch [128/4000] - Train Loss: 0.1436, Train Accuracy: 0.9515, Validation Loss: 0.1321, Validation Accuracy: 0.9550
# Epoch [129/4000] - Train Loss: 0.1421, Train Accuracy: 0.9510, Validation Loss: 0.1399, Validation Accuracy: 0.9505
# Epoch [130/4000] - Train Loss: 0.1460, Train Accuracy: 0.9498, Validation Loss: 0.1374, Validation Accuracy: 0.9515
# Epoch [131/4000] - Train Loss: 0.1447, Train Accuracy: 0.9505, Validation Loss: 0.1316, Validation Accuracy: 0.9545
# Epoch [132/4000] - Train Loss: 0.1420, Train Accuracy: 0.9516, Validation Loss: 0.1304, Validation Accuracy: 0.9551
# Epoch [133/4000] - Train Loss: 0.1432, Train Accuracy: 0.9520, Validation Loss: 0.1423, Validation Accuracy: 0.9529
# Epoch [134/4000] - Train Loss: 0.1455, Train Accuracy: 0.9509, Validation Loss: 0.1321, Validation Accuracy: 0.9547
# Epoch [135/4000] - Train Loss: 0.1417, Train Accuracy: 0.9518, Validation Loss: 0.1365, Validation Accuracy: 0.9508
# Epoch [136/4000] - Train Loss: 0.1447, Train Accuracy: 0.9505, Validation Loss: 0.1331, Validation Accuracy: 0.9531
# Epoch [137/4000] - Train Loss: 0.1432, Train Accuracy: 0.9515, Validation Loss: 0.1366, Validation Accuracy: 0.9514
# Epoch [138/4000] - Train Loss: 0.1412, Train Accuracy: 0.9513, Validation Loss: 0.1307, Validation Accuracy: 0.9554
# Epoch [139/4000] - Train Loss: 0.1417, Train Accuracy: 0.9517, Validation Loss: 0.1384, Validation Accuracy: 0.9510
# Epoch [140/4000] - Train Loss: 0.1439, Train Accuracy: 0.9509, Validation Loss: 0.1294, Validation Accuracy: 0.9552
# Epoch [141/4000] - Train Loss: 0.1380, Train Accuracy: 0.9523, Validation Loss: 0.1367, Validation Accuracy: 0.9509
# Epoch [142/4000] - Train Loss: 0.1418, Train Accuracy: 0.9517, Validation Loss: 0.1325, Validation Accuracy: 0.9551
# Epoch [143/4000] - Train Loss: 0.1400, Train Accuracy: 0.9521, Validation Loss: 0.1315, Validation Accuracy: 0.9556
# Epoch [144/4000] - Train Loss: 0.1428, Train Accuracy: 0.9509, Validation Loss: 0.1293, Validation Accuracy: 0.9560
# Epoch [145/4000] - Train Loss: 0.1402, Train Accuracy: 0.9520, Validation Loss: 0.1286, Validation Accuracy: 0.9555
# Epoch [146/4000] - Train Loss: 0.1403, Train Accuracy: 0.9520, Validation Loss: 0.1320, Validation Accuracy: 0.9551
# Epoch [147/4000] - Train Loss: 0.1409, Train Accuracy: 0.9519, Validation Loss: 0.1318, Validation Accuracy: 0.9533
# Epoch [148/4000] - Train Loss: 0.1400, Train Accuracy: 0.9516, Validation Loss: 0.1295, Validation Accuracy: 0.9542
# Epoch [149/4000] - Train Loss: 0.1394, Train Accuracy: 0.9521, Validation Loss: 0.1299, Validation Accuracy: 0.9544
# Epoch [150/4000] - Train Loss: 0.1380, Train Accuracy: 0.9529, Validation Loss: 0.1288, Validation Accuracy: 0.9553
# Epoch [151/4000] - Train Loss: 0.1385, Train Accuracy: 0.9518, Validation Loss: 0.1305, Validation Accuracy: 0.9537
# Epoch [152/4000] - Train Loss: 0.1392, Train Accuracy: 0.9521, Validation Loss: 0.1293, Validation Accuracy: 0.9568
# Epoch [153/4000] - Train Loss: 0.1380, Train Accuracy: 0.9526, Validation Loss: 0.1373, Validation Accuracy: 0.9545
# Epoch [154/4000] - Train Loss: 0.1417, Train Accuracy: 0.9514, Validation Loss: 0.1300, Validation Accuracy: 0.9543
# Epoch [155/4000] - Train Loss: 0.1398, Train Accuracy: 0.9522, Validation Loss: 0.1301, Validation Accuracy: 0.9554
# Epoch [156/4000] - Train Loss: 0.1401, Train Accuracy: 0.9524, Validation Loss: 0.1291, Validation Accuracy: 0.9558
# Epoch [157/4000] - Train Loss: 0.1372, Train Accuracy: 0.9533, Validation Loss: 0.1288, Validation Accuracy: 0.9565
# Epoch [158/4000] - Train Loss: 0.1409, Train Accuracy: 0.9522, Validation Loss: 0.1281, Validation Accuracy: 0.9554
# Epoch [159/4000] - Train Loss: 0.1386, Train Accuracy: 0.9526, Validation Loss: 0.1285, Validation Accuracy: 0.9543
# Epoch [160/4000] - Train Loss: 0.1382, Train Accuracy: 0.9520, Validation Loss: 0.1304, Validation Accuracy: 0.9563
# Epoch [161/4000] - Train Loss: 0.1390, Train Accuracy: 0.9525, Validation Loss: 0.1285, Validation Accuracy: 0.9554
# Epoch [162/4000] - Train Loss: 0.1397, Train Accuracy: 0.9521, Validation Loss: 0.1281, Validation Accuracy: 0.9559
# Epoch [163/4000] - Train Loss: 0.1375, Train Accuracy: 0.9525, Validation Loss: 0.1312, Validation Accuracy: 0.9555
# Epoch [164/4000] - Train Loss: 0.1387, Train Accuracy: 0.9532, Validation Loss: 0.1289, Validation Accuracy: 0.9550
# Epoch [165/4000] - Train Loss: 0.1375, Train Accuracy: 0.9523, Validation Loss: 0.1358, Validation Accuracy: 0.9504
# Epoch [166/4000] - Train Loss: 0.1402, Train Accuracy: 0.9521, Validation Loss: 0.1275, Validation Accuracy: 0.9555
# Epoch [167/4000] - Train Loss: 0.1368, Train Accuracy: 0.9525, Validation Loss: 0.1383, Validation Accuracy: 0.9530
# Epoch [168/4000] - Train Loss: 0.1388, Train Accuracy: 0.9523, Validation Loss: 0.1269, Validation Accuracy: 0.9565
# Epoch [169/4000] - Train Loss: 0.1393, Train Accuracy: 0.9524, Validation Loss: 0.1339, Validation Accuracy: 0.9508
# Epoch [170/4000] - Train Loss: 0.1390, Train Accuracy: 0.9511, Validation Loss: 0.1279, Validation Accuracy: 0.9572
# Epoch [171/4000] - Train Loss: 0.1352, Train Accuracy: 0.9529, Validation Loss: 0.1324, Validation Accuracy: 0.9562
# Epoch [172/4000] - Train Loss: 0.1426, Train Accuracy: 0.9513, Validation Loss: 0.1281, Validation Accuracy: 0.9546
# Epoch [173/4000] - Train Loss: 0.1359, Train Accuracy: 0.9529, Validation Loss: 0.1265, Validation Accuracy: 0.9554
# Epoch [174/4000] - Train Loss: 0.1349, Train Accuracy: 0.9537, Validation Loss: 0.1287, Validation Accuracy: 0.9560
# Epoch [175/4000] - Train Loss: 0.1342, Train Accuracy: 0.9530, Validation Loss: 0.1275, Validation Accuracy: 0.9569
# Epoch [176/4000] - Train Loss: 0.1358, Train Accuracy: 0.9532, Validation Loss: 0.1284, Validation Accuracy: 0.9532
# Epoch [177/4000] - Train Loss: 0.1348, Train Accuracy: 0.9531, Validation Loss: 0.1289, Validation Accuracy: 0.9543
# Epoch [178/4000] - Train Loss: 0.1354, Train Accuracy: 0.9531, Validation Loss: 0.1268, Validation Accuracy: 0.9566
# Epoch [179/4000] - Train Loss: 0.1391, Train Accuracy: 0.9533, Validation Loss: 0.1302, Validation Accuracy: 0.9536
# Epoch [180/4000] - Train Loss: 0.1392, Train Accuracy: 0.9526, Validation Loss: 0.1264, Validation Accuracy: 0.9557
# Epoch [181/4000] - Train Loss: 0.1349, Train Accuracy: 0.9539, Validation Loss: 0.1260, Validation Accuracy: 0.9555
# Epoch [182/4000] - Train Loss: 0.1355, Train Accuracy: 0.9528, Validation Loss: 0.1281, Validation Accuracy: 0.9542
# Epoch [183/4000] - Train Loss: 0.1358, Train Accuracy: 0.9536, Validation Loss: 0.1276, Validation Accuracy: 0.9550
# Epoch [184/4000] - Train Loss: 0.1359, Train Accuracy: 0.9539, Validation Loss: 0.1276, Validation Accuracy: 0.9567
# Epoch [185/4000] - Train Loss: 0.1357, Train Accuracy: 0.9535, Validation Loss: 0.1281, Validation Accuracy: 0.9536
# Epoch [186/4000] - Train Loss: 0.1341, Train Accuracy: 0.9542, Validation Loss: 0.1279, Validation Accuracy: 0.9542
# Epoch [187/4000] - Train Loss: 0.1365, Train Accuracy: 0.9534, Validation Loss: 0.1297, Validation Accuracy: 0.9569
# Epoch [188/4000] - Train Loss: 0.1337, Train Accuracy: 0.9531, Validation Loss: 0.1263, Validation Accuracy: 0.9538
# Epoch [189/4000] - Train Loss: 0.1346, Train Accuracy: 0.9536, Validation Loss: 0.1271, Validation Accuracy: 0.9540
# Epoch [190/4000] - Train Loss: 0.1358, Train Accuracy: 0.9532, Validation Loss: 0.1258, Validation Accuracy: 0.9550
# Epoch [191/4000] - Train Loss: 0.1360, Train Accuracy: 0.9532, Validation Loss: 0.1313, Validation Accuracy: 0.9513
# Epoch [192/4000] - Train Loss: 0.1364, Train Accuracy: 0.9535, Validation Loss: 0.1252, Validation Accuracy: 0.9563
# Epoch [193/4000] - Train Loss: 0.1342, Train Accuracy: 0.9539, Validation Loss: 0.1248, Validation Accuracy: 0.9562
# Epoch [194/4000] - Train Loss: 0.1338, Train Accuracy: 0.9537, Validation Loss: 0.1247, Validation Accuracy: 0.9551
# Epoch [195/4000] - Train Loss: 0.1347, Train Accuracy: 0.9537, Validation Loss: 0.1257, Validation Accuracy: 0.9553
# Epoch [196/4000] - Train Loss: 0.1330, Train Accuracy: 0.9542, Validation Loss: 0.1249, Validation Accuracy: 0.9570
# Epoch [197/4000] - Train Loss: 0.1339, Train Accuracy: 0.9542, Validation Loss: 0.1267, Validation Accuracy: 0.9559
# Epoch [198/4000] - Train Loss: 0.1322, Train Accuracy: 0.9541, Validation Loss: 0.1294, Validation Accuracy: 0.9566
# Epoch [199/4000] - Train Loss: 0.1330, Train Accuracy: 0.9536, Validation Loss: 0.1279, Validation Accuracy: 0.9534
# Epoch [200/4000] - Train Loss: 0.1353, Train Accuracy: 0.9535, Validation Loss: 0.1253, Validation Accuracy: 0.9576
# Epoch [201/4000] - Train Loss: 0.1320, Train Accuracy: 0.9540, Validation Loss: 0.1255, Validation Accuracy: 0.9566
# Epoch [202/4000] - Train Loss: 0.1316, Train Accuracy: 0.9537, Validation Loss: 0.1235, Validation Accuracy: 0.9561
# Epoch [203/4000] - Train Loss: 0.1329, Train Accuracy: 0.9543, Validation Loss: 0.1250, Validation Accuracy: 0.9554
# Epoch [204/4000] - Train Loss: 0.1353, Train Accuracy: 0.9530, Validation Loss: 0.1242, Validation Accuracy: 0.9563
# Epoch [205/4000] - Train Loss: 0.1364, Train Accuracy: 0.9547, Validation Loss: 0.1299, Validation Accuracy: 0.9522
# Epoch [206/4000] - Train Loss: 0.1339, Train Accuracy: 0.9539, Validation Loss: 0.1251, Validation Accuracy: 0.9575
# Epoch [207/4000] - Train Loss: 0.1331, Train Accuracy: 0.9548, Validation Loss: 0.1324, Validation Accuracy: 0.9524
# Epoch [208/4000] - Train Loss: 0.1341, Train Accuracy: 0.9538, Validation Loss: 0.1254, Validation Accuracy: 0.9558
# Epoch [209/4000] - Train Loss: 0.1326, Train Accuracy: 0.9543, Validation Loss: 0.1271, Validation Accuracy: 0.9563
# Epoch [210/4000] - Train Loss: 0.1309, Train Accuracy: 0.9555, Validation Loss: 0.1317, Validation Accuracy: 0.9519
# Epoch [211/4000] - Train Loss: 0.1340, Train Accuracy: 0.9532, Validation Loss: 0.1241, Validation Accuracy: 0.9568
# Epoch [212/4000] - Train Loss: 0.1318, Train Accuracy: 0.9547, Validation Loss: 0.1226, Validation Accuracy: 0.9565
# Epoch [213/4000] - Train Loss: 0.1308, Train Accuracy: 0.9540, Validation Loss: 0.1253, Validation Accuracy: 0.9577
# Epoch [214/4000] - Train Loss: 0.1348, Train Accuracy: 0.9543, Validation Loss: 0.1293, Validation Accuracy: 0.9531
# Epoch [215/4000] - Train Loss: 0.1332, Train Accuracy: 0.9534, Validation Loss: 0.1281, Validation Accuracy: 0.9532
# Epoch [216/4000] - Train Loss: 0.1325, Train Accuracy: 0.9537, Validation Loss: 0.1290, Validation Accuracy: 0.9571
# Epoch [217/4000] - Train Loss: 0.1333, Train Accuracy: 0.9541, Validation Loss: 0.1253, Validation Accuracy: 0.9541
# Epoch [218/4000] - Train Loss: 0.1331, Train Accuracy: 0.9557, Validation Loss: 0.1298, Validation Accuracy: 0.9540
# Epoch [219/4000] - Train Loss: 0.1340, Train Accuracy: 0.9536, Validation Loss: 0.1240, Validation Accuracy: 0.9561
# Epoch [220/4000] - Train Loss: 0.1317, Train Accuracy: 0.9542, Validation Loss: 0.1225, Validation Accuracy: 0.9573
# Epoch [221/4000] - Train Loss: 0.1316, Train Accuracy: 0.9551, Validation Loss: 0.1265, Validation Accuracy: 0.9538
# Epoch [222/4000] - Train Loss: 0.1325, Train Accuracy: 0.9543, Validation Loss: 0.1261, Validation Accuracy: 0.9544
# Epoch [223/4000] - Train Loss: 0.1322, Train Accuracy: 0.9547, Validation Loss: 0.1228, Validation Accuracy: 0.9570
# Epoch [224/4000] - Train Loss: 0.1322, Train Accuracy: 0.9542, Validation Loss: 0.1252, Validation Accuracy: 0.9550
# Epoch [225/4000] - Train Loss: 0.1327, Train Accuracy: 0.9539, Validation Loss: 0.1362, Validation Accuracy: 0.9504
# Epoch [226/4000] - Train Loss: 0.1345, Train Accuracy: 0.9535, Validation Loss: 0.1293, Validation Accuracy: 0.9535
# Epoch [227/4000] - Train Loss: 0.1322, Train Accuracy: 0.9541, Validation Loss: 0.1223, Validation Accuracy: 0.9574
# Epoch [228/4000] - Train Loss: 0.1321, Train Accuracy: 0.9545, Validation Loss: 0.1230, Validation Accuracy: 0.9573
# Epoch [229/4000] - Train Loss: 0.1301, Train Accuracy: 0.9550, Validation Loss: 0.1221, Validation Accuracy: 0.9573
# Epoch [230/4000] - Train Loss: 0.1300, Train Accuracy: 0.9549, Validation Loss: 0.1249, Validation Accuracy: 0.9578
# Epoch [231/4000] - Train Loss: 0.1313, Train Accuracy: 0.9549, Validation Loss: 0.1235, Validation Accuracy: 0.9560
# Epoch [232/4000] - Train Loss: 0.1314, Train Accuracy: 0.9556, Validation Loss: 0.1228, Validation Accuracy: 0.9576
# Epoch [233/4000] - Train Loss: 0.1313, Train Accuracy: 0.9551, Validation Loss: 0.1245, Validation Accuracy: 0.9551
# Epoch [234/4000] - Train Loss: 0.1323, Train Accuracy: 0.9542, Validation Loss: 0.1223, Validation Accuracy: 0.9566
# Epoch [235/4000] - Train Loss: 0.1300, Train Accuracy: 0.9543, Validation Loss: 0.1247, Validation Accuracy: 0.9555
# Epoch [236/4000] - Train Loss: 0.1296, Train Accuracy: 0.9547, Validation Loss: 0.1224, Validation Accuracy: 0.9557
# Epoch [237/4000] - Train Loss: 0.1304, Train Accuracy: 0.9544, Validation Loss: 0.1252, Validation Accuracy: 0.9546
# Epoch [238/4000] - Train Loss: 0.1315, Train Accuracy: 0.9547, Validation Loss: 0.1246, Validation Accuracy: 0.9576
# Epoch [239/4000] - Train Loss: 0.1314, Train Accuracy: 0.9552, Validation Loss: 0.1225, Validation Accuracy: 0.9580
# Epoch [240/4000] - Train Loss: 0.1325, Train Accuracy: 0.9546, Validation Loss: 0.1234, Validation Accuracy: 0.9556
# Epoch [241/4000] - Train Loss: 0.1308, Train Accuracy: 0.9549, Validation Loss: 0.1229, Validation Accuracy: 0.9582
# Epoch [242/4000] - Train Loss: 0.1292, Train Accuracy: 0.9553, Validation Loss: 0.1233, Validation Accuracy: 0.9549
# Epoch [243/4000] - Train Loss: 0.1296, Train Accuracy: 0.9551, Validation Loss: 0.1254, Validation Accuracy: 0.9541
# Epoch [244/4000] - Train Loss: 0.1298, Train Accuracy: 0.9552, Validation Loss: 0.1256, Validation Accuracy: 0.9568
# Epoch [245/4000] - Train Loss: 0.1323, Train Accuracy: 0.9550, Validation Loss: 0.1289, Validation Accuracy: 0.9533
# Epoch [246/4000] - Train Loss: 0.1304, Train Accuracy: 0.9550, Validation Loss: 0.1222, Validation Accuracy: 0.9571
# Epoch [247/4000] - Train Loss: 0.1298, Train Accuracy: 0.9549, Validation Loss: 0.1217, Validation Accuracy: 0.9587
# Epoch [248/4000] - Train Loss: 0.1302, Train Accuracy: 0.9559, Validation Loss: 0.1247, Validation Accuracy: 0.9554
# Epoch [249/4000] - Train Loss: 0.1301, Train Accuracy: 0.9547, Validation Loss: 0.1229, Validation Accuracy: 0.9571
# Epoch [250/4000] - Train Loss: 0.1269, Train Accuracy: 0.9555, Validation Loss: 0.1236, Validation Accuracy: 0.9561
# Epoch [251/4000] - Train Loss: 0.1304, Train Accuracy: 0.9551, Validation Loss: 0.1219, Validation Accuracy: 0.9570
# Epoch [252/4000] - Train Loss: 0.1274, Train Accuracy: 0.9557, Validation Loss: 0.1215, Validation Accuracy: 0.9577
# Epoch [253/4000] - Train Loss: 0.1313, Train Accuracy: 0.9555, Validation Loss: 0.1256, Validation Accuracy: 0.9546
# Epoch [254/4000] - Train Loss: 0.1322, Train Accuracy: 0.9548, Validation Loss: 0.1245, Validation Accuracy: 0.9551
# Epoch [255/4000] - Train Loss: 0.1308, Train Accuracy: 0.9554, Validation Loss: 0.1222, Validation Accuracy: 0.9551
# Epoch [256/4000] - Train Loss: 0.1309, Train Accuracy: 0.9555, Validation Loss: 0.1212, Validation Accuracy: 0.9562
# Epoch [257/4000] - Train Loss: 0.1310, Train Accuracy: 0.9556, Validation Loss: 0.1207, Validation Accuracy: 0.9568
# Epoch [258/4000] - Train Loss: 0.1299, Train Accuracy: 0.9557, Validation Loss: 0.1216, Validation Accuracy: 0.9568
# Epoch [259/4000] - Train Loss: 0.1295, Train Accuracy: 0.9557, Validation Loss: 0.1209, Validation Accuracy: 0.9574
# Epoch [260/4000] - Train Loss: 0.1305, Train Accuracy: 0.9546, Validation Loss: 0.1218, Validation Accuracy: 0.9558
# Epoch [261/4000] - Train Loss: 0.1306, Train Accuracy: 0.9556, Validation Loss: 0.1239, Validation Accuracy: 0.9566
# Epoch [262/4000] - Train Loss: 0.1319, Train Accuracy: 0.9548, Validation Loss: 0.1220, Validation Accuracy: 0.9576
# Epoch [263/4000] - Train Loss: 0.1331, Train Accuracy: 0.9555, Validation Loss: 0.1224, Validation Accuracy: 0.9560
# Epoch [264/4000] - Train Loss: 0.1300, Train Accuracy: 0.9554, Validation Loss: 0.1228, Validation Accuracy: 0.9573
# Epoch [265/4000] - Train Loss: 0.1301, Train Accuracy: 0.9551, Validation Loss: 0.1208, Validation Accuracy: 0.9584
# Epoch [266/4000] - Train Loss: 0.1298, Train Accuracy: 0.9552, Validation Loss: 0.1225, Validation Accuracy: 0.9570
# Epoch [267/4000] - Train Loss: 0.1297, Train Accuracy: 0.9554, Validation Loss: 0.1243, Validation Accuracy: 0.9561
# Epoch [268/4000] - Train Loss: 0.1298, Train Accuracy: 0.9554, Validation Loss: 0.1229, Validation Accuracy: 0.9564
# Epoch [269/4000] - Train Loss: 0.1273, Train Accuracy: 0.9551, Validation Loss: 0.1214, Validation Accuracy: 0.9577
# Epoch [270/4000] - Train Loss: 0.1288, Train Accuracy: 0.9556, Validation Loss: 0.1220, Validation Accuracy: 0.9567
# Epoch [271/4000] - Train Loss: 0.1274, Train Accuracy: 0.9552, Validation Loss: 0.1226, Validation Accuracy: 0.9572
# Epoch [272/4000] - Train Loss: 0.1283, Train Accuracy: 0.9559, Validation Loss: 0.1239, Validation Accuracy: 0.9566
# Epoch [273/4000] - Train Loss: 0.1281, Train Accuracy: 0.9559, Validation Loss: 0.1294, Validation Accuracy: 0.9543
# Epoch [274/4000] - Train Loss: 0.1312, Train Accuracy: 0.9550, Validation Loss: 0.1278, Validation Accuracy: 0.9543
# Epoch [275/4000] - Train Loss: 0.1286, Train Accuracy: 0.9557, Validation Loss: 0.1262, Validation Accuracy: 0.9572
# Epoch [276/4000] - Train Loss: 0.1275, Train Accuracy: 0.9555, Validation Loss: 0.1213, Validation Accuracy: 0.9574
# Epoch [277/4000] - Train Loss: 0.1262, Train Accuracy: 0.9566, Validation Loss: 0.1206, Validation Accuracy: 0.9575
# Epoch [278/4000] - Train Loss: 0.1288, Train Accuracy: 0.9562, Validation Loss: 0.1201, Validation Accuracy: 0.9581
# Epoch [279/4000] - Train Loss: 0.1281, Train Accuracy: 0.9559, Validation Loss: 0.1213, Validation Accuracy: 0.9581
# Epoch [280/4000] - Train Loss: 0.1275, Train Accuracy: 0.9566, Validation Loss: 0.1225, Validation Accuracy: 0.9566
# Epoch [281/4000] - Train Loss: 0.1287, Train Accuracy: 0.9568, Validation Loss: 0.1233, Validation Accuracy: 0.9573
# Epoch [282/4000] - Train Loss: 0.1264, Train Accuracy: 0.9561, Validation Loss: 0.1218, Validation Accuracy: 0.9586
# Epoch [283/4000] - Train Loss: 0.1265, Train Accuracy: 0.9567, Validation Loss: 0.1193, Validation Accuracy: 0.9574
# Epoch [284/4000] - Train Loss: 0.1250, Train Accuracy: 0.9562, Validation Loss: 0.1236, Validation Accuracy: 0.9572
# Epoch [285/4000] - Train Loss: 0.1285, Train Accuracy: 0.9560, Validation Loss: 0.1204, Validation Accuracy: 0.9581
# Epoch [286/4000] - Train Loss: 0.1283, Train Accuracy: 0.9565, Validation Loss: 0.1202, Validation Accuracy: 0.9576
# Epoch [287/4000] - Train Loss: 0.1277, Train Accuracy: 0.9561, Validation Loss: 0.1196, Validation Accuracy: 0.9575
# Epoch [288/4000] - Train Loss: 0.1267, Train Accuracy: 0.9566, Validation Loss: 0.1197, Validation Accuracy: 0.9579
# Epoch [289/4000] - Train Loss: 0.1276, Train Accuracy: 0.9564, Validation Loss: 0.1189, Validation Accuracy: 0.9575
# Epoch [290/4000] - Train Loss: 0.1264, Train Accuracy: 0.9561, Validation Loss: 0.1202, Validation Accuracy: 0.9577
# Epoch [291/4000] - Train Loss: 0.1288, Train Accuracy: 0.9558, Validation Loss: 0.1183, Validation Accuracy: 0.9573
# Epoch [292/4000] - Train Loss: 0.1249, Train Accuracy: 0.9570, Validation Loss: 0.1204, Validation Accuracy: 0.9572
# Epoch [293/4000] - Train Loss: 0.1267, Train Accuracy: 0.9560, Validation Loss: 0.1202, Validation Accuracy: 0.9583
# Epoch [294/4000] - Train Loss: 0.1272, Train Accuracy: 0.9567, Validation Loss: 0.1213, Validation Accuracy: 0.9575
# Epoch [295/4000] - Train Loss: 0.1248, Train Accuracy: 0.9568, Validation Loss: 0.1206, Validation Accuracy: 0.9574
# Epoch [296/4000] - Train Loss: 0.1257, Train Accuracy: 0.9564, Validation Loss: 0.1188, Validation Accuracy: 0.9578
# Epoch [297/4000] - Train Loss: 0.1253, Train Accuracy: 0.9567, Validation Loss: 0.1218, Validation Accuracy: 0.9562
# Epoch [298/4000] - Train Loss: 0.1271, Train Accuracy: 0.9559, Validation Loss: 0.1209, Validation Accuracy: 0.9567
# Epoch [299/4000] - Train Loss: 0.1283, Train Accuracy: 0.9564, Validation Loss: 0.1191, Validation Accuracy: 0.9578
# Epoch [300/4000] - Train Loss: 0.1257, Train Accuracy: 0.9570, Validation Loss: 0.1404, Validation Accuracy: 0.9481
# Epoch [301/4000] - Train Loss: 0.1311, Train Accuracy: 0.9546, Validation Loss: 0.1260, Validation Accuracy: 0.9558
# Epoch [302/4000] - Train Loss: 0.1262, Train Accuracy: 0.9556, Validation Loss: 0.1210, Validation Accuracy: 0.9582
# Epoch [303/4000] - Train Loss: 0.1255, Train Accuracy: 0.9572, Validation Loss: 0.1220, Validation Accuracy: 0.9576
# Epoch [304/4000] - Train Loss: 0.1256, Train Accuracy: 0.9558, Validation Loss: 0.1256, Validation Accuracy: 0.9572
# Epoch [305/4000] - Train Loss: 0.1236, Train Accuracy: 0.9564, Validation Loss: 0.1197, Validation Accuracy: 0.9582
# Epoch [306/4000] - Train Loss: 0.1241, Train Accuracy: 0.9571, Validation Loss: 0.1179, Validation Accuracy: 0.9574
# Epoch [307/4000] - Train Loss: 0.1247, Train Accuracy: 0.9564, Validation Loss: 0.1219, Validation Accuracy: 0.9578
# Epoch [308/4000] - Train Loss: 0.1261, Train Accuracy: 0.9564, Validation Loss: 0.1216, Validation Accuracy: 0.9564
# Epoch [309/4000] - Train Loss: 0.1255, Train Accuracy: 0.9571, Validation Loss: 0.1180, Validation Accuracy: 0.9582
# Epoch [310/4000] - Train Loss: 0.1248, Train Accuracy: 0.9574, Validation Loss: 0.1219, Validation Accuracy: 0.9572
# Epoch [311/4000] - Train Loss: 0.1279, Train Accuracy: 0.9563, Validation Loss: 0.1190, Validation Accuracy: 0.9575
# Epoch [312/4000] - Train Loss: 0.1237, Train Accuracy: 0.9568, Validation Loss: 0.1188, Validation Accuracy: 0.9584
# Epoch [313/4000] - Train Loss: 0.1256, Train Accuracy: 0.9569, Validation Loss: 0.1195, Validation Accuracy: 0.9582
# Epoch [314/4000] - Train Loss: 0.1260, Train Accuracy: 0.9560, Validation Loss: 0.1181, Validation Accuracy: 0.9584
# Epoch [315/4000] - Train Loss: 0.1248, Train Accuracy: 0.9567, Validation Loss: 0.1194, Validation Accuracy: 0.9579
# Epoch [316/4000] - Train Loss: 0.1260, Train Accuracy: 0.9561, Validation Loss: 0.1184, Validation Accuracy: 0.9577
# Epoch [317/4000] - Train Loss: 0.1241, Train Accuracy: 0.9569, Validation Loss: 0.1188, Validation Accuracy: 0.9584
# Epoch [318/4000] - Train Loss: 0.1253, Train Accuracy: 0.9576, Validation Loss: 0.1176, Validation Accuracy: 0.9580
# Epoch [319/4000] - Train Loss: 0.1245, Train Accuracy: 0.9568, Validation Loss: 0.1215, Validation Accuracy: 0.9564
# Epoch [320/4000] - Train Loss: 0.1237, Train Accuracy: 0.9572, Validation Loss: 0.1174, Validation Accuracy: 0.9581
# Epoch [321/4000] - Train Loss: 0.1225, Train Accuracy: 0.9579, Validation Loss: 0.1200, Validation Accuracy: 0.9576
# Epoch [322/4000] - Train Loss: 0.1264, Train Accuracy: 0.9576, Validation Loss: 0.1203, Validation Accuracy: 0.9580
# Epoch [323/4000] - Train Loss: 0.1281, Train Accuracy: 0.9566, Validation Loss: 0.1198, Validation Accuracy: 0.9581
# Epoch [324/4000] - Train Loss: 0.1252, Train Accuracy: 0.9566, Validation Loss: 0.1172, Validation Accuracy: 0.9582
# Epoch [325/4000] - Train Loss: 0.1236, Train Accuracy: 0.9575, Validation Loss: 0.1195, Validation Accuracy: 0.9581
# Epoch [326/4000] - Train Loss: 0.1244, Train Accuracy: 0.9572, Validation Loss: 0.1179, Validation Accuracy: 0.9582
# Epoch [327/4000] - Train Loss: 0.1258, Train Accuracy: 0.9567, Validation Loss: 0.1181, Validation Accuracy: 0.9593
# Epoch [328/4000] - Train Loss: 0.1238, Train Accuracy: 0.9573, Validation Loss: 0.1190, Validation Accuracy: 0.9587
# Epoch [329/4000] - Train Loss: 0.1290, Train Accuracy: 0.9569, Validation Loss: 0.1176, Validation Accuracy: 0.9585
# Epoch [330/4000] - Train Loss: 0.1218, Train Accuracy: 0.9580, Validation Loss: 0.1201, Validation Accuracy: 0.9589
# Epoch [331/4000] - Train Loss: 0.1256, Train Accuracy: 0.9567, Validation Loss: 0.1191, Validation Accuracy: 0.9577
# Epoch [332/4000] - Train Loss: 0.1266, Train Accuracy: 0.9572, Validation Loss: 0.1182, Validation Accuracy: 0.9575
# Epoch [333/4000] - Train Loss: 0.1241, Train Accuracy: 0.9571, Validation Loss: 0.1222, Validation Accuracy: 0.9574
# Epoch [334/4000] - Train Loss: 0.1233, Train Accuracy: 0.9571, Validation Loss: 0.1203, Validation Accuracy: 0.9576
# Epoch [335/4000] - Train Loss: 0.1238, Train Accuracy: 0.9569, Validation Loss: 0.1178, Validation Accuracy: 0.9591
# Epoch [336/4000] - Train Loss: 0.1245, Train Accuracy: 0.9573, Validation Loss: 0.1196, Validation Accuracy: 0.9575
# Epoch [337/4000] - Train Loss: 0.1213, Train Accuracy: 0.9568, Validation Loss: 0.1171, Validation Accuracy: 0.9586
# Epoch [338/4000] - Train Loss: 0.1244, Train Accuracy: 0.9578, Validation Loss: 0.1172, Validation Accuracy: 0.9578
# Epoch [339/4000] - Train Loss: 0.1227, Train Accuracy: 0.9574, Validation Loss: 0.1164, Validation Accuracy: 0.9588
# Epoch [340/4000] - Train Loss: 0.1221, Train Accuracy: 0.9580, Validation Loss: 0.1189, Validation Accuracy: 0.9591
# Epoch [341/4000] - Train Loss: 0.1244, Train Accuracy: 0.9568, Validation Loss: 0.1279, Validation Accuracy: 0.9536
# Epoch [342/4000] - Train Loss: 0.1243, Train Accuracy: 0.9570, Validation Loss: 0.1188, Validation Accuracy: 0.9586
# Epoch [343/4000] - Train Loss: 0.1244, Train Accuracy: 0.9566, Validation Loss: 0.1165, Validation Accuracy: 0.9578
# Epoch [344/4000] - Train Loss: 0.1232, Train Accuracy: 0.9571, Validation Loss: 0.1168, Validation Accuracy: 0.9582
# Epoch [345/4000] - Train Loss: 0.1232, Train Accuracy: 0.9574, Validation Loss: 0.1163, Validation Accuracy: 0.9577
# Epoch [346/4000] - Train Loss: 0.1230, Train Accuracy: 0.9576, Validation Loss: 0.1172, Validation Accuracy: 0.9582
# Epoch [347/4000] - Train Loss: 0.1213, Train Accuracy: 0.9578, Validation Loss: 0.1193, Validation Accuracy: 0.9579
# Epoch [348/4000] - Train Loss: 0.1239, Train Accuracy: 0.9577, Validation Loss: 0.1209, Validation Accuracy: 0.9576
# Epoch [349/4000] - Train Loss: 0.1239, Train Accuracy: 0.9572, Validation Loss: 0.1181, Validation Accuracy: 0.9597
# Epoch [350/4000] - Train Loss: 0.1241, Train Accuracy: 0.9580, Validation Loss: 0.1195, Validation Accuracy: 0.9567
# Epoch [351/4000] - Train Loss: 0.1240, Train Accuracy: 0.9576, Validation Loss: 0.1222, Validation Accuracy: 0.9565
# Epoch [352/4000] - Train Loss: 0.1239, Train Accuracy: 0.9569, Validation Loss: 0.1198, Validation Accuracy: 0.9574
# Epoch [353/4000] - Train Loss: 0.1224, Train Accuracy: 0.9579, Validation Loss: 0.1177, Validation Accuracy: 0.9588
# Epoch [354/4000] - Train Loss: 0.1241, Train Accuracy: 0.9576, Validation Loss: 0.1176, Validation Accuracy: 0.9579
# Epoch [355/4000] - Train Loss: 0.1227, Train Accuracy: 0.9576, Validation Loss: 0.1182, Validation Accuracy: 0.9582
# Epoch [356/4000] - Train Loss: 0.1217, Train Accuracy: 0.9576, Validation Loss: 0.1161, Validation Accuracy: 0.9592
# Epoch [357/4000] - Train Loss: 0.1209, Train Accuracy: 0.9585, Validation Loss: 0.1173, Validation Accuracy: 0.9578
# Epoch [358/4000] - Train Loss: 0.1207, Train Accuracy: 0.9582, Validation Loss: 0.1213, Validation Accuracy: 0.9565
# Epoch [359/4000] - Train Loss: 0.1235, Train Accuracy: 0.9575, Validation Loss: 0.1193, Validation Accuracy: 0.9589
# Epoch [360/4000] - Train Loss: 0.1231, Train Accuracy: 0.9573, Validation Loss: 0.1163, Validation Accuracy: 0.9581
# Epoch [361/4000] - Train Loss: 0.1213, Train Accuracy: 0.9579, Validation Loss: 0.1168, Validation Accuracy: 0.9589
# Epoch [362/4000] - Train Loss: 0.1242, Train Accuracy: 0.9569, Validation Loss: 0.1184, Validation Accuracy: 0.9581
# Epoch [363/4000] - Train Loss: 0.1223, Train Accuracy: 0.9574, Validation Loss: 0.1176, Validation Accuracy: 0.9575
# Epoch [364/4000] - Train Loss: 0.1223, Train Accuracy: 0.9574, Validation Loss: 0.1173, Validation Accuracy: 0.9577
# Epoch [365/4000] - Train Loss: 0.1205, Train Accuracy: 0.9579, Validation Loss: 0.1171, Validation Accuracy: 0.9589
# Epoch [366/4000] - Train Loss: 0.1212, Train Accuracy: 0.9578, Validation Loss: 0.1192, Validation Accuracy: 0.9580
# Epoch [367/4000] - Train Loss: 0.1200, Train Accuracy: 0.9582, Validation Loss: 0.1199, Validation Accuracy: 0.9584
# Epoch [368/4000] - Train Loss: 0.1234, Train Accuracy: 0.9583, Validation Loss: 0.1170, Validation Accuracy: 0.9593
# Epoch [369/4000] - Train Loss: 0.1225, Train Accuracy: 0.9575, Validation Loss: 0.1263, Validation Accuracy: 0.9563
# Epoch [370/4000] - Train Loss: 0.1223, Train Accuracy: 0.9577, Validation Loss: 0.1177, Validation Accuracy: 0.9581
# Epoch [371/4000] - Train Loss: 0.1202, Train Accuracy: 0.9584, Validation Loss: 0.1155, Validation Accuracy: 0.9595
# Epoch [372/4000] - Train Loss: 0.1208, Train Accuracy: 0.9585, Validation Loss: 0.1155, Validation Accuracy: 0.9584
# Epoch [373/4000] - Train Loss: 0.1214, Train Accuracy: 0.9585, Validation Loss: 0.1200, Validation Accuracy: 0.9573
# Epoch [374/4000] - Train Loss: 0.1207, Train Accuracy: 0.9583, Validation Loss: 0.1228, Validation Accuracy: 0.9573
# Epoch [375/4000] - Train Loss: 0.1226, Train Accuracy: 0.9573, Validation Loss: 0.1170, Validation Accuracy: 0.9590
# Epoch [376/4000] - Train Loss: 0.1226, Train Accuracy: 0.9581, Validation Loss: 0.1158, Validation Accuracy: 0.9587
# Epoch [377/4000] - Train Loss: 0.1228, Train Accuracy: 0.9580, Validation Loss: 0.1169, Validation Accuracy: 0.9585
# Epoch [378/4000] - Train Loss: 0.1217, Train Accuracy: 0.9577, Validation Loss: 0.1149, Validation Accuracy: 0.9583
# Epoch [379/4000] - Train Loss: 0.1206, Train Accuracy: 0.9581, Validation Loss: 0.1150, Validation Accuracy: 0.9592
# Epoch [380/4000] - Train Loss: 0.1190, Train Accuracy: 0.9584, Validation Loss: 0.1152, Validation Accuracy: 0.9582
# Epoch [381/4000] - Train Loss: 0.1194, Train Accuracy: 0.9581, Validation Loss: 0.1169, Validation Accuracy: 0.9580
# Epoch [382/4000] - Train Loss: 0.1201, Train Accuracy: 0.9584, Validation Loss: 0.1174, Validation Accuracy: 0.9591
# Epoch [383/4000] - Train Loss: 0.1199, Train Accuracy: 0.9586, Validation Loss: 0.1167, Validation Accuracy: 0.9592
# Epoch [384/4000] - Train Loss: 0.1189, Train Accuracy: 0.9589, Validation Loss: 0.1184, Validation Accuracy: 0.9581
# Epoch [385/4000] - Train Loss: 0.1206, Train Accuracy: 0.9581, Validation Loss: 0.1156, Validation Accuracy: 0.9589
# Epoch [386/4000] - Train Loss: 0.1211, Train Accuracy: 0.9588, Validation Loss: 0.1172, Validation Accuracy: 0.9582
# Epoch [387/4000] - Train Loss: 0.1238, Train Accuracy: 0.9575, Validation Loss: 0.1157, Validation Accuracy: 0.9581
# Epoch [388/4000] - Train Loss: 0.1212, Train Accuracy: 0.9588, Validation Loss: 0.1173, Validation Accuracy: 0.9582
# Epoch [389/4000] - Train Loss: 0.1201, Train Accuracy: 0.9584, Validation Loss: 0.1168, Validation Accuracy: 0.9592
# Epoch [390/4000] - Train Loss: 0.1182, Train Accuracy: 0.9586, Validation Loss: 0.1168, Validation Accuracy: 0.9592
# Epoch [391/4000] - Train Loss: 0.1226, Train Accuracy: 0.9579, Validation Loss: 0.1168, Validation Accuracy: 0.9590
# Epoch [392/4000] - Train Loss: 0.1235, Train Accuracy: 0.9583, Validation Loss: 0.1191, Validation Accuracy: 0.9574
# Epoch [393/4000] - Train Loss: 0.1202, Train Accuracy: 0.9580, Validation Loss: 0.1144, Validation Accuracy: 0.9581
# Epoch [394/4000] - Train Loss: 0.1205, Train Accuracy: 0.9579, Validation Loss: 0.1202, Validation Accuracy: 0.9577
# Epoch [395/4000] - Train Loss: 0.1222, Train Accuracy: 0.9584, Validation Loss: 0.1155, Validation Accuracy: 0.9599
# Epoch [396/4000] - Train Loss: 0.1197, Train Accuracy: 0.9585, Validation Loss: 0.1145, Validation Accuracy: 0.9589
# Epoch [397/4000] - Train Loss: 0.1211, Train Accuracy: 0.9579, Validation Loss: 0.1259, Validation Accuracy: 0.9542
# Epoch [398/4000] - Train Loss: 0.1240, Train Accuracy: 0.9565, Validation Loss: 0.1157, Validation Accuracy: 0.9587
# Epoch [399/4000] - Train Loss: 0.1194, Train Accuracy: 0.9578, Validation Loss: 0.1145, Validation Accuracy: 0.9592
# Epoch [400/4000] - Train Loss: 0.1204, Train Accuracy: 0.9583, Validation Loss: 0.1155, Validation Accuracy: 0.9599
# Epoch [401/4000] - Train Loss: 0.1184, Train Accuracy: 0.9585, Validation Loss: 0.1193, Validation Accuracy: 0.9583
# Epoch [402/4000] - Train Loss: 0.1210, Train Accuracy: 0.9580, Validation Loss: 0.1165, Validation Accuracy: 0.9594
# Epoch [403/4000] - Train Loss: 0.1207, Train Accuracy: 0.9583, Validation Loss: 0.1164, Validation Accuracy: 0.9588
# Epoch [404/4000] - Train Loss: 0.1191, Train Accuracy: 0.9586, Validation Loss: 0.1150, Validation Accuracy: 0.9582
# Epoch [405/4000] - Train Loss: 0.1199, Train Accuracy: 0.9585, Validation Loss: 0.1149, Validation Accuracy: 0.9585
# Epoch [406/4000] - Train Loss: 0.1203, Train Accuracy: 0.9585, Validation Loss: 0.1153, Validation Accuracy: 0.9595
# Epoch [407/4000] - Train Loss: 0.1220, Train Accuracy: 0.9585, Validation Loss: 0.1251, Validation Accuracy: 0.9561
# Epoch [408/4000] - Train Loss: 0.1226, Train Accuracy: 0.9580, Validation Loss: 0.1177, Validation Accuracy: 0.9582
# Epoch [409/4000] - Train Loss: 0.1190, Train Accuracy: 0.9587, Validation Loss: 0.1152, Validation Accuracy: 0.9593
# Epoch [410/4000] - Train Loss: 0.1190, Train Accuracy: 0.9593, Validation Loss: 0.1136, Validation Accuracy: 0.9592
# Epoch [411/4000] - Train Loss: 0.1233, Train Accuracy: 0.9593, Validation Loss: 0.1145, Validation Accuracy: 0.9591
# Epoch [412/4000] - Train Loss: 0.1192, Train Accuracy: 0.9587, Validation Loss: 0.1155, Validation Accuracy: 0.9599
# Epoch [413/4000] - Train Loss: 0.1223, Train Accuracy: 0.9582, Validation Loss: 0.1156, Validation Accuracy: 0.9604
# Epoch [414/4000] - Train Loss: 0.1236, Train Accuracy: 0.9586, Validation Loss: 0.1134, Validation Accuracy: 0.9596
# ...
# Epoch [552/4000] - Train Loss: 0.1134, Train Accuracy: 0.9620, Validation Loss: 0.1125, Validation Accuracy: 0.9600
# Epoch [553/4000] - Train Loss: 0.1131, Train Accuracy: 0.9610, Validation Loss: 0.1125, Validation Accuracy: 0.9602
# Epoch [554/4000] - Train Loss: 0.1116, Train Accuracy: 0.9614, Validation Loss: 0.1135, Validation Accuracy: 0.9601
# Epoch [555/4000] - Train Loss: 0.1145, Train Accuracy: 0.9608, Validation Loss: 0.1128, Validation Accuracy: 0.9599
# Epoch [556/4000] - Train Loss: 0.1124, Train Accuracy: 0.9607, Validation Loss: 0.1174, Validation Accuracy: 0.9596
# Epoch [557/4000] - Train Loss: 0.1115, Train Accuracy: 0.9623, Validation Loss: 0.1130, Validation Accuracy: 0.9599
# Epoch [558/4000] - Train Loss: 0.1126, Train Accuracy: 0.9608, Validation Loss: 0.1130, Validation Accuracy: 0.9601
# Epoch [559/4000] - Train Loss: 0.1117, Train Accuracy: 0.9608, Validation Loss: 0.1128, Validation Accuracy: 0.9608
# Epoch [560/4000] - Train Loss: 0.1121, Train Accuracy: 0.9614, Validation Loss: 0.1160, Validation Accuracy: 0.9604
# Epoch [561/4000] - Train Loss: 0.1130, Train Accuracy: 0.9610, Validation Loss: 0.1139, Validation Accuracy: 0.9598
# Epoch [562/4000] - Train Loss: 0.1141, Train Accuracy: 0.9601, Validation Loss: 0.1170, Validation Accuracy: 0.9580
# Epoch [563/4000] - Train Loss: 0.1135, Train Accuracy: 0.9606, Validation Loss: 0.1144, Validation Accuracy: 0.9595
# Epoch [564/4000] - Train Loss: 0.1118, Train Accuracy: 0.9611, Validation Loss: 0.1130, Validation Accuracy: 0.9607
# Epoch [565/4000] - Train Loss: 0.1123, Train Accuracy: 0.9612, Validation Loss: 0.1140, Validation Accuracy: 0.9601
# Epoch [566/4000] - Train Loss: 0.1131, Train Accuracy: 0.9619, Validation Loss: 0.1146, Validation Accuracy: 0.9605
# Epoch [567/4000] - Train Loss: 0.1136, Train Accuracy: 0.9614, Validation Loss: 0.1121, Validation Accuracy: 0.9605
# Epoch [568/4000] - Train Loss: 0.1120, Train Accuracy: 0.9616, Validation Loss: 0.1129, Validation Accuracy: 0.9611
# Epoch [569/4000] - Train Loss: 0.1140, Train Accuracy: 0.9621, Validation Loss: 0.1170, Validation Accuracy: 0.9580
# Epoch [570/4000] - Train Loss: 0.1162, Train Accuracy: 0.9597, Validation Loss: 0.1126, Validation Accuracy: 0.9604
# Epoch [571/4000] - Train Loss: 0.1113, Train Accuracy: 0.9618, Validation Loss: 0.1133, Validation Accuracy: 0.9608
# Epoch [572/4000] - Train Loss: 0.1124, Train Accuracy: 0.9612, Validation Loss: 0.1193, Validation Accuracy: 0.9575
# Epoch [573/4000] - Train Loss: 0.1133, Train Accuracy: 0.9609, Validation Loss: 0.1162, Validation Accuracy: 0.9600
# Epoch [574/4000] - Train Loss: 0.1142, Train Accuracy: 0.9616, Validation Loss: 0.1225, Validation Accuracy: 0.9578
# Epoch [575/4000] - Train Loss: 0.1172, Train Accuracy: 0.9593, Validation Loss: 0.1160, Validation Accuracy: 0.9595
# Epoch [576/4000] - Train Loss: 0.1107, Train Accuracy: 0.9623, Validation Loss: 0.1154, Validation Accuracy: 0.9597
# Epoch [577/4000] - Train Loss: 0.1120, Train Accuracy: 0.9615, Validation Loss: 0.1118, Validation Accuracy: 0.9607
# Epoch [578/4000] - Train Loss: 0.1118, Train Accuracy: 0.9616, Validation Loss: 0.1152, Validation Accuracy: 0.9602
# Epoch [579/4000] - Train Loss: 0.1132, Train Accuracy: 0.9620, Validation Loss: 0.1135, Validation Accuracy: 0.9599
# Epoch [580/4000] - Train Loss: 0.1143, Train Accuracy: 0.9614, Validation Loss: 0.1127, Validation Accuracy: 0.9604
# Epoch [581/4000] - Train Loss: 0.1122, Train Accuracy: 0.9619, Validation Loss: 0.1128, Validation Accuracy: 0.9611
# Epoch [582/4000] - Train Loss: 0.1126, Train Accuracy: 0.9613, Validation Loss: 0.1143, Validation Accuracy: 0.9602
# Epoch [583/4000] - Train Loss: 0.1136, Train Accuracy: 0.9613, Validation Loss: 0.1136, Validation Accuracy: 0.9610
# Epoch [584/4000] - Train Loss: 0.1118, Train Accuracy: 0.9617, Validation Loss: 0.1130, Validation Accuracy: 0.9610
# Epoch [585/4000] - Train Loss: 0.1131, Train Accuracy: 0.9620, Validation Loss: 0.1130, Validation Accuracy: 0.9595
# Epoch [586/4000] - Train Loss: 0.1114, Train Accuracy: 0.9608, Validation Loss: 0.1137, Validation Accuracy: 0.9611
# Epoch [587/4000] - Train Loss: 0.1130, Train Accuracy: 0.9621, Validation Loss: 0.1142, Validation Accuracy: 0.9599
# Epoch [588/4000] - Train Loss: 0.1116, Train Accuracy: 0.9618, Validation Loss: 0.1122, Validation Accuracy: 0.9612
# Epoch [589/4000] - Train Loss: 0.1111, Train Accuracy: 0.9621, Validation Loss: 0.1111, Validation Accuracy: 0.9614
# Epoch [590/4000] - Train Loss: 0.1099, Train Accuracy: 0.9620, Validation Loss: 0.1143, Validation Accuracy: 0.9601
# Epoch [591/4000] - Train Loss: 0.1110, Train Accuracy: 0.9620, Validation Loss: 0.1191, Validation Accuracy: 0.9581
# Epoch [592/4000] - Train Loss: 0.1121, Train Accuracy: 0.9613, Validation Loss: 0.1116, Validation Accuracy: 0.9612
# Epoch [593/4000] - Train Loss: 0.1146, Train Accuracy: 0.9617, Validation Loss: 0.1125, Validation Accuracy: 0.9604
# Epoch [594/4000] - Train Loss: 0.1105, Train Accuracy: 0.9621, Validation Loss: 0.1127, Validation Accuracy: 0.9611
# Epoch [595/4000] - Train Loss: 0.1117, Train Accuracy: 0.9610, Validation Loss: 0.1187, Validation Accuracy: 0.9583
# Epoch [596/4000] - Train Loss: 0.1115, Train Accuracy: 0.9614, Validation Loss: 0.1139, Validation Accuracy: 0.9607
# Epoch [597/4000] - Train Loss: 0.1122, Train Accuracy: 0.9615, Validation Loss: 0.1141, Validation Accuracy: 0.9596
# Epoch [598/4000] - Train Loss: 0.1115, Train Accuracy: 0.9619, Validation Loss: 0.1152, Validation Accuracy: 0.9604
# Epoch [599/4000] - Train Loss: 0.1113, Train Accuracy: 0.9613, Validation Loss: 0.1117, Validation Accuracy: 0.9603
# Epoch [600/4000] - Train Loss: 0.1115, Train Accuracy: 0.9619, Validation Loss: 0.1159, Validation Accuracy: 0.9594
# Epoch [601/4000] - Train Loss: 0.1114, Train Accuracy: 0.9615, Validation Loss: 0.1154, Validation Accuracy: 0.9598
# Epoch [602/4000] - Train Loss: 0.1123, Train Accuracy: 0.9608, Validation Loss: 0.1126, Validation Accuracy: 0.9613
# Epoch [603/4000] - Train Loss: 0.1133, Train Accuracy: 0.9611, Validation Loss: 0.1140, Validation Accuracy: 0.9607
# Epoch [604/4000] - Train Loss: 0.1136, Train Accuracy: 0.9606, Validation Loss: 0.1140, Validation Accuracy: 0.9606
# Epoch [605/4000] - Train Loss: 0.1116, Train Accuracy: 0.9616, Validation Loss: 0.1136, Validation Accuracy: 0.9607
# Epoch [606/4000] - Train Loss: 0.1125, Train Accuracy: 0.9623, Validation Loss: 0.1137, Validation Accuracy: 0.9601
# Epoch [607/4000] - Train Loss: 0.1101, Train Accuracy: 0.9625, Validation Loss: 0.1142, Validation Accuracy: 0.9609
# Epoch [608/4000] - Train Loss: 0.1129, Train Accuracy: 0.9618, Validation Loss: 0.1177, Validation Accuracy: 0.9597
# Epoch [609/4000] - Train Loss: 0.1105, Train Accuracy: 0.9618, Validation Loss: 0.1120, Validation Accuracy: 0.9611
# Epoch [610/4000] - Train Loss: 0.1127, Train Accuracy: 0.9619, Validation Loss: 0.1124, Validation Accuracy: 0.9608
# Epoch [611/4000] - Train Loss: 0.1115, Train Accuracy: 0.9620, Validation Loss: 0.1118, Validation Accuracy: 0.9601
# Epoch [612/4000] - Train Loss: 0.1086, Train Accuracy: 0.9625, Validation Loss: 0.1137, Validation Accuracy: 0.9609
# Epoch [613/4000] - Train Loss: 0.1126, Train Accuracy: 0.9606, Validation Loss: 0.1120, Validation Accuracy: 0.9607
# Epoch [614/4000] - Train Loss: 0.1121, Train Accuracy: 0.9612, Validation Loss: 0.1143, Validation Accuracy: 0.9611
# Epoch [615/4000] - Train Loss: 0.1110, Train Accuracy: 0.9619, Validation Loss: 0.1129, Validation Accuracy: 0.9604
# Epoch [616/4000] - Train Loss: 0.1091, Train Accuracy: 0.9624, Validation Loss: 0.1156, Validation Accuracy: 0.9605
# Epoch [617/4000] - Train Loss: 0.1109, Train Accuracy: 0.9612, Validation Loss: 0.1125, Validation Accuracy: 0.9610
# Epoch [618/4000] - Train Loss: 0.1106, Train Accuracy: 0.9620, Validation Loss: 0.1142, Validation Accuracy: 0.9604
# Epoch [619/4000] - Train Loss: 0.1094, Train Accuracy: 0.9618, Validation Loss: 0.1150, Validation Accuracy: 0.9599
# Epoch [620/4000] - Train Loss: 0.1107, Train Accuracy: 0.9625, Validation Loss: 0.1127, Validation Accuracy: 0.9603
# Epoch [621/4000] - Train Loss: 0.1138, Train Accuracy: 0.9620, Validation Loss: 0.1114, Validation Accuracy: 0.9611
# Epoch [622/4000] - Train Loss: 0.1113, Train Accuracy: 0.9625, Validation Loss: 0.1171, Validation Accuracy: 0.9580
# Epoch [623/4000] - Train Loss: 0.1139, Train Accuracy: 0.9614, Validation Loss: 0.1126, Validation Accuracy: 0.9603
# Epoch [624/4000] - Train Loss: 0.1093, Train Accuracy: 0.9625, Validation Loss: 0.1129, Validation Accuracy: 0.9601
# Epoch [625/4000] - Train Loss: 0.1098, Train Accuracy: 0.9623, Validation Loss: 0.1121, Validation Accuracy: 0.9615
# Epoch [626/4000] - Train Loss: 0.1118, Train Accuracy: 0.9624, Validation Loss: 0.1205, Validation Accuracy: 0.9590
# Epoch [627/4000] - Train Loss: 0.1092, Train Accuracy: 0.9615, Validation Loss: 0.1172, Validation Accuracy: 0.9595
# Epoch [628/4000] - Train Loss: 0.1104, Train Accuracy: 0.9618, Validation Loss: 0.1147, Validation Accuracy: 0.9596
# Epoch [629/4000] - Train Loss: 0.1098, Train Accuracy: 0.9615, Validation Loss: 0.1141, Validation Accuracy: 0.9610
# Epoch [630/4000] - Train Loss: 0.1113, Train Accuracy: 0.9620, Validation Loss: 0.1114, Validation Accuracy: 0.9614
# Epoch [631/4000] - Train Loss: 0.1098, Train Accuracy: 0.9619, Validation Loss: 0.1121, Validation Accuracy: 0.9603
# Epoch [632/4000] - Train Loss: 0.1101, Train Accuracy: 0.9621, Validation Loss: 0.1138, Validation Accuracy: 0.9601
# Epoch [633/4000] - Train Loss: 0.1093, Train Accuracy: 0.9624, Validation Loss: 0.1172, Validation Accuracy: 0.9588
# Epoch [634/4000] - Train Loss: 0.1096, Train Accuracy: 0.9624, Validation Loss: 0.1131, Validation Accuracy: 0.9613
# Epoch [635/4000] - Train Loss: 0.1094, Train Accuracy: 0.9623, Validation Loss: 0.1129, Validation Accuracy: 0.9611
# Epoch [636/4000] - Train Loss: 0.1111, Train Accuracy: 0.9618, Validation Loss: 0.1141, Validation Accuracy: 0.9594
# Epoch [637/4000] - Train Loss: 0.1096, Train Accuracy: 0.9623, Validation Loss: 0.1136, Validation Accuracy: 0.9604
# Epoch [638/4000] - Train Loss: 0.1093, Train Accuracy: 0.9616, Validation Loss: 0.1135, Validation Accuracy: 0.9614
# Epoch [639/4000] - Train Loss: 0.1116, Train Accuracy: 0.9620, Validation Loss: 0.1114, Validation Accuracy: 0.9613
# Epoch [640/4000] - Train Loss: 0.1104, Train Accuracy: 0.9620, Validation Loss: 0.1158, Validation Accuracy: 0.9600
# Epoch [641/4000] - Train Loss: 0.1105, Train Accuracy: 0.9623, Validation Loss: 0.1132, Validation Accuracy: 0.9608
# Epoch [642/4000] - Train Loss: 0.1102, Train Accuracy: 0.9619, Validation Loss: 0.1140, Validation Accuracy: 0.9614
# Epoch [643/4000] - Train Loss: 0.1117, Train Accuracy: 0.9620, Validation Loss: 0.1142, Validation Accuracy: 0.9616
# Epoch [644/4000] - Train Loss: 0.1076, Train Accuracy: 0.9629, Validation Loss: 0.1170, Validation Accuracy: 0.9605
# Epoch [645/4000] - Train Loss: 0.1096, Train Accuracy: 0.9624, Validation Loss: 0.1128, Validation Accuracy: 0.9614
# Epoch [646/4000] - Train Loss: 0.1092, Train Accuracy: 0.9623, Validation Loss: 0.1129, Validation Accuracy: 0.9615
# Epoch [647/4000] - Train Loss: 0.1067, Train Accuracy: 0.9632, Validation Loss: 0.1136, Validation Accuracy: 0.9609
# Epoch [648/4000] - Train Loss: 0.1076, Train Accuracy: 0.9628, Validation Loss: 0.1134, Validation Accuracy: 0.9608
# Epoch [649/4000] - Train Loss: 0.1101, Train Accuracy: 0.9624, Validation Loss: 0.1129, Validation Accuracy: 0.9605
# Epoch [650/4000] - Train Loss: 0.1093, Train Accuracy: 0.9624, Validation Loss: 0.1202, Validation Accuracy: 0.9589
# Epoch [651/4000] - Train Loss: 0.1143, Train Accuracy: 0.9613, Validation Loss: 0.1134, Validation Accuracy: 0.9604
# Epoch [652/4000] - Train Loss: 0.1101, Train Accuracy: 0.9618, Validation Loss: 0.1128, Validation Accuracy: 0.9607
# Epoch [653/4000] - Train Loss: 0.1113, Train Accuracy: 0.9619, Validation Loss: 0.1148, Validation Accuracy: 0.9602
# Epoch [654/4000] - Train Loss: 0.1114, Train Accuracy: 0.9622, Validation Loss: 0.1158, Validation Accuracy: 0.9593
# Epoch [655/4000] - Train Loss: 0.1098, Train Accuracy: 0.9616, Validation Loss: 0.1130, Validation Accuracy: 0.9607
# Epoch [656/4000] - Train Loss: 0.1092, Train Accuracy: 0.9621, Validation Loss: 0.1122, Validation Accuracy: 0.9615
# Epoch [657/4000] - Train Loss: 0.1093, Train Accuracy: 0.9620, Validation Loss: 0.1137, Validation Accuracy: 0.9611
# Epoch [658/4000] - Train Loss: 0.1089, Train Accuracy: 0.9631, Validation Loss: 0.1137, Validation Accuracy: 0.9605
# Epoch [659/4000] - Train Loss: 0.1080, Train Accuracy: 0.9628, Validation Loss: 0.1124, Validation Accuracy: 0.9611
# Epoch [660/4000] - Train Loss: 0.1075, Train Accuracy: 0.9626, Validation Loss: 0.1138, Validation Accuracy: 0.9605
# Epoch [661/4000] - Train Loss: 0.1074, Train Accuracy: 0.9627, Validation Loss: 0.1135, Validation Accuracy: 0.9614
# Epoch [662/4000] - Train Loss: 0.1083, Train Accuracy: 0.9631, Validation Loss: 0.1134, Validation Accuracy: 0.9611
# Epoch [663/4000] - Train Loss: 0.1098, Train Accuracy: 0.9628, Validation Loss: 0.1124, Validation Accuracy: 0.9605
# Epoch [664/4000] - Train Loss: 0.1098, Train Accuracy: 0.9624, Validation Loss: 0.1142, Validation Accuracy: 0.9599
# Epoch [665/4000] - Train Loss: 0.1088, Train Accuracy: 0.9628, Validation Loss: 0.1120, Validation Accuracy: 0.9606
# Epoch [666/4000] - Train Loss: 0.1095, Train Accuracy: 0.9624, Validation Loss: 0.1135, Validation Accuracy: 0.9600
# Epoch [667/4000] - Train Loss: 0.1097, Train Accuracy: 0.9626, Validation Loss: 0.1159, Validation Accuracy: 0.9597
# Epoch [668/4000] - Train Loss: 0.1105, Train Accuracy: 0.9622, Validation Loss: 0.1149, Validation Accuracy: 0.9611
# Epoch [669/4000] - Train Loss: 0.1104, Train Accuracy: 0.9621, Validation Loss: 0.1119, Validation Accuracy: 0.9599
# Epoch [670/4000] - Train Loss: 0.1083, Train Accuracy: 0.9629, Validation Loss: 0.1127, Validation Accuracy: 0.9617
# Epoch [671/4000] - Train Loss: 0.1093, Train Accuracy: 0.9630, Validation Loss: 0.1131, Validation Accuracy: 0.9605
# Epoch [672/4000] - Train Loss: 0.1078, Train Accuracy: 0.9627, Validation Loss: 0.1131, Validation Accuracy: 0.9611
# Epoch [673/4000] - Train Loss: 0.1082, Train Accuracy: 0.9631, Validation Loss: 0.1147, Validation Accuracy: 0.9605
# Epoch [674/4000] - Train Loss: 0.1084, Train Accuracy: 0.9625, Validation Loss: 0.1143, Validation Accuracy: 0.9602
# Epoch [675/4000] - Train Loss: 0.1076, Train Accuracy: 0.9635, Validation Loss: 0.1122, Validation Accuracy: 0.9612
# Epoch [676/4000] - Train Loss: 0.1089, Train Accuracy: 0.9625, Validation Loss: 0.1133, Validation Accuracy: 0.9613
# Epoch [677/4000] - Train Loss: 0.1069, Train Accuracy: 0.9631, Validation Loss: 0.1131, Validation Accuracy: 0.9612
# Epoch [678/4000] - Train Loss: 0.1079, Train Accuracy: 0.9625, Validation Loss: 0.1136, Validation Accuracy: 0.9608
# Epoch [679/4000] - Train Loss: 0.1087, Train Accuracy: 0.9631, Validation Loss: 0.1125, Validation Accuracy: 0.9609
# Epoch [680/4000] - Train Loss: 0.1095, Train Accuracy: 0.9620, Validation Loss: 0.1135, Validation Accuracy: 0.9608
# Epoch [681/4000] - Train Loss: 0.1091, Train Accuracy: 0.9631, Validation Loss: 0.1123, Validation Accuracy: 0.9612
# Epoch [682/4000] - Train Loss: 0.1098, Train Accuracy: 0.9618, Validation Loss: 0.1148, Validation Accuracy: 0.9605
# Epoch [683/4000] - Train Loss: 0.1072, Train Accuracy: 0.9626, Validation Loss: 0.1115, Validation Accuracy: 0.9612
# Epoch [684/4000] - Train Loss: 0.1097, Train Accuracy: 0.9629, Validation Loss: 0.1155, Validation Accuracy: 0.9595
# Epoch [685/4000] - Train Loss: 0.1097, Train Accuracy: 0.9621, Validation Loss: 0.1150, Validation Accuracy: 0.9603
# Epoch [686/4000] - Train Loss: 0.1076, Train Accuracy: 0.9624, Validation Loss: 0.1141, Validation Accuracy: 0.9610
# Epoch [687/4000] - Train Loss: 0.1083, Train Accuracy: 0.9623, Validation Loss: 0.1139, Validation Accuracy: 0.9606
# Epoch [688/4000] - Train Loss: 0.1110, Train Accuracy: 0.9630, Validation Loss: 0.1124, Validation Accuracy: 0.9615
# Early stopping at epoch 689

# %% [markdown]
# #### Testing the Model

# %%
# Set the model to evaluation mode

pf_model.load_state_dict(torch.load(os.path.join(out_dir, "EX2_SG_MargNet_DNN_Model.pth"), map_location=device))
pf_model.eval()
y_test_pred = torch.empty(0).to(device)

# Generate predictions
with torch.no_grad():
    for feats, labels in pf_test_loader:
        feats = feats.to(device)
        labels = labels.to(device)
        pred = pf_model(feats)

        y_test_pred = torch.cat((y_test_pred, pred), dim=0)

y_test_pred = y_test_pred.cpu().numpy()
y_test_pred = y_test_pred.argmax(axis=1)
print(get_metrics(y_test_pred, y_test, label_strings))

# https://www.stackvidhya.com/plot-confusion-matrix-in-python-and-why/#google_vignette
# fig = plt.figure()
cf_matrix = metrics.confusion_matrix(y_test, y_test_pred)
cf_matrix_percentage = metrics.confusion_matrix(y_test, y_test_pred, normalize='true')
group_counts = ["{0:0.0f}".format(value) for value in cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_matrix_percentage.flatten()]
labels = [f"{v1}\n({v2})\n" for v1, v2 in
          zip(group_percentages,group_counts)]
labels = np.asarray(labels).reshape(2,2)
fig, ax = plt.subplots(figsize=(8, 6))  # Adjust the size as needed

ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
ax.set_xlabel('\nPredicted', fontsize=14, weight='bold')
ax.set_ylabel('Actual', fontsize=14, weight='bold');
ax.xaxis.set_ticklabels(['GALAXY', 'STAR'], fontsize=14, weight='bold')
ax.yaxis.set_ticklabels(['GALAXY', 'STAR'], fontsize=14, weight='bold')
plt.tight_layout()
plt.savefig(os.path.join(out_dir, "EX2_SG_MargNet_DNN_CM.png"))
plt.show()
plt.close()
# Out:
# Identified 9607 correct labels out of 10000 labels
# Accuracy: 0.9607
# Precision: 0.9607214301317744
# Recall: 0.9607043834143121
# F1 Score: 0.9606997543734648
# Labels are: ['GALAXY' 'STAR']
# Confusion Matrix:
#  [[4816  178]
#  [ 215 4791]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      4994
#            1       0.96      0.96      0.96      5006
#
#     accuracy                           0.96     10000
#    macro avg       0.96      0.96      0.96     10000
# weighted avg       0.96      0.96      0.96     10000
#
# (array([   0,    1,    2, ..., 9997, 9998, 9999]), 0.9607, 0.9607214301317744, 0.9607043834143121, array([[4816,  178],
#        [ 215, 4791]]), '              precision    recall  f1-score   support\n\n           0       0.96      0.96      0.96      4994\n           1       0.96      0.96      0.96      5006\n\n    accuracy                           0.96     10000\n   macro avg       0.96      0.96      0.96     10000\nweighted avg       0.96      0.96      0.96     10000\n')

# %% [markdown]
# ### 2. CNN Model using Images

# %% [markdown]
# ##### Create dataset and dataloader for pytorch training

# %%
class SGData_image(Dataset):
    def __init__(self, x, y, transform=None):
        self.n_samples = x.shape[0]
        self.x = torch.tensor(x, dtype=torch.float32)
        self.y = torch.tensor(y)
        self.transform = transform

    def __len__(self):
        return self.n_samples

    def __getitem__(self, i):
        inputs, targets = self.x[i], self.y[i]
        
        if self.transform:
            inputs = self.transform(inputs)

        return inputs, targets

# Define your data augmentation transformations
image_transform = transforms.Compose([    
    transforms.RandomRotation(180),
    transforms.RandomAffine(degrees = 0, translate = (0.1, 0.1)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
])

# Create DataLoader for training and validation data
image_train_dataset = SGData_image(X_train, y_train, transform=image_transform)
image_train_loader = DataLoader(image_train_dataset, batch_size=512, shuffle=True, num_workers=8)
image_val_dataset = SGData_image(X_val, y_val, transform=image_transform)
image_val_loader = DataLoader(image_val_dataset, batch_size=512, shuffle=False, num_workers=4)
image_test_dataset = SGData_image(X_test, y_test, transform=None)
image_test_loader = DataLoader(image_test_dataset, batch_size=512, shuffle=False, num_workers=4)

# %% [markdown]
# #### Initialize or Define the Model

# %%
# Initialize the PyTorch model
in_channels = X_train.shape[1]
image_ht = X_train.shape[2]
image_wt = X_train.shape[3]

class InceptionLikeNet(nn.Module):
    def __init__(self, in_channels, img_height, img_width, num_classes=2):
        super().__init__()
        self.relu = nn.ReLU(inplace=True)

        # First conv
        self.conv0 = nn.Conv2d(in_channels, 64, kernel_size=5, padding=2)

        # --- Block 1 ---
        self.b1_c1_1x1 = nn.Conv2d(64, 48, kernel_size=1)
        self.b1_c2_1x1 = nn.Conv2d(64, 48, kernel_size=1)
        self.b1_c3_1x1 = nn.Conv2d(64, 48, kernel_size=1)
        self.b1_c4_1x1 = nn.Conv2d(48, 64, kernel_size=1)
        self.b1_c5_3x3 = nn.Conv2d(48, 64, kernel_size=3, padding=1)
        self.b1_c6_5x5 = nn.Conv2d(48, 64, kernel_size=5, padding=2)

        # shared pools
        self.pool1x1 = nn.AvgPool2d(kernel_size=1, stride=1)  # like AveragePooling2D((1,1))
        self.pool2x2 = nn.AvgPool2d(kernel_size=2, stride=2)

        # --- Block 2 ---
        # input channels after block1 concat: 64+64+64+48 = 240
        self.b2_c7_1x1  = nn.Conv2d(240, 64, kernel_size=1)
        self.b2_c8_1x1  = nn.Conv2d(240, 64, kernel_size=1)
        self.b2_c9_1x1  = nn.Conv2d(240, 64, kernel_size=1)
        self.b2_c10_1x1 = nn.Conv2d(64, 92, kernel_size=1)
        self.b2_c11_3x3 = nn.Conv2d(64, 92, kernel_size=3, padding=1)
        self.b2_c12_5x5 = nn.Conv2d(64, 92, kernel_size=5, padding=2)
        # after concat: 92+92+92+64 = 340, then 2x2 avg pool

        # --- Block 3 ---
        self.b3_c13_1x1 = nn.Conv2d(340, 92, kernel_size=1)
        self.b3_c14_1x1 = nn.Conv2d(340, 92, kernel_size=1)
        self.b3_c15_1x1 = nn.Conv2d(340, 92, kernel_size=1)
        self.b3_c16_1x1 = nn.Conv2d(92, 128, kernel_size=1)
        self.b3_c17_3x3 = nn.Conv2d(92, 128, kernel_size=3, padding=1)
        self.b3_c18_5x5 = nn.Conv2d(92, 128, kernel_size=5, padding=2)
        # concat: 128+128+128+92 = 476

        # --- Block 4 ---
        self.b4_c19_1x1 = nn.Conv2d(476, 92, kernel_size=1)
        self.b4_c20_1x1 = nn.Conv2d(476, 92, kernel_size=1)
        self.b4_c21_1x1 = nn.Conv2d(476, 92, kernel_size=1)
        self.b4_c22_1x1 = nn.Conv2d(92, 128, kernel_size=1)
        self.b4_c23_3x3 = nn.Conv2d(92, 128, kernel_size=3, padding=1)
        self.b4_c24_5x5 = nn.Conv2d(92, 128, kernel_size=5, padding=2)
        # concat: 128+128+128+92 = 476, then 2x2 avg pool

        # --- Block 5 ---
        self.b5_c25_1x1 = nn.Conv2d(476, 92, kernel_size=1)
        self.b5_c26_1x1 = nn.Conv2d(476, 92, kernel_size=1)
        self.b5_c27_1x1 = nn.Conv2d(476, 128, kernel_size=1)
        self.b5_c28_3x3 = nn.Conv2d(92, 128, kernel_size=3, padding=1)
        # concat: 128+128+92 = 348

        # Dense part we need to know flattened size, so we build dynamically
        self._build_fc(in_channels, img_height, img_width, num_classes)

    # run only the conv part (up to Flatten in your Keras model)
    def _forward_features(self, x):
        x = self.relu(self.conv0(x))

        # Block 1
        c1 = self.relu(self.b1_c1_1x1(x))
        c2 = self.relu(self.b1_c2_1x1(x))
        c3 = self.relu(self.b1_c3_1x1(x))
        c4 = self.relu(self.b1_c4_1x1(c1))
        c5 = self.relu(self.b1_c5_3x3(c1))
        c6 = self.relu(self.b1_c6_5x5(c2))
        p1 = self.pool1x1(c3)
        x  = torch.cat([c4, c5, c6, p1], dim=1)      # 240 ch

        # Block 2
        c7  = self.relu(self.b2_c7_1x1(x))
        c8  = self.relu(self.b2_c8_1x1(x))
        c9  = self.relu(self.b2_c9_1x1(x))
        c10 = self.relu(self.b2_c10_1x1(c7))
        c11 = self.relu(self.b2_c11_3x3(c7))
        c12 = self.relu(self.b2_c12_5x5(c8))
        p2  = self.pool1x1(c9)
        x   = torch.cat([c10, c11, c12, p2], dim=1)  # 340 ch
        x   = self.pool2x2(x)

        # Block 3
        c13 = self.relu(self.b3_c13_1x1(x))
        c14 = self.relu(self.b3_c14_1x1(x))
        c15 = self.relu(self.b3_c15_1x1(x))
        c16 = self.relu(self.b3_c16_1x1(c13))
        c17 = self.relu(self.b3_c17_3x3(c13))
        c18 = self.relu(self.b3_c18_5x5(c14))
        p3  = self.pool1x1(c15)
        x   = torch.cat([c16, c17, c18, p3], dim=1)  # 476 ch

        # Block 4
        c19 = self.relu(self.b4_c19_1x1(x))
        c20 = self.relu(self.b4_c20_1x1(x))
        c21 = self.relu(self.b4_c21_1x1(x))
        c22 = self.relu(self.b4_c22_1x1(c19))
        c23 = self.relu(self.b4_c23_3x3(c19))
        c24 = self.relu(self.b4_c24_5x5(c20))
        p4  = self.pool1x1(c21)
        x   = torch.cat([c22, c23, c24, p4], dim=1)  # 476 ch
        x   = self.pool2x2(x)

        # Block 5
        c25 = self.relu(self.b5_c25_1x1(x))
        c26 = self.relu(self.b5_c26_1x1(x))
        c27 = self.relu(self.b5_c27_1x1(x))
        c28 = self.relu(self.b5_c28_3x3(c25))
        p5  = self.pool1x1(c26)
        x   = torch.cat([c27, c28, p5], dim=1)       # 348 ch

        return x

    def _build_fc(self, in_channels, img_height, img_width, num_classes):
        # run a dummy tensor through conv part to figure out Flatten size
        with torch.no_grad():
            dummy = torch.zeros(1, in_channels, img_height, img_width)
            feats = self._forward_features(dummy)
            flatten_dim = feats.view(1, -1).shape[1]

        self.flatten = nn.Flatten()
        # Keras: Flatten -> Dense(1024) -> Dense(1024) -> Dense(2, softmax)
        # (no activations between Dense in your code; keeping that)
        self.fc1 = nn.Linear(flatten_dim, 1024)
        self.fc2 = nn.Linear(1024, 1024)
        self.fc3 = nn.Linear(1024, num_classes)

    def forward(self, x):
        x = self._forward_features(x)
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.fc2(x)
        logits = self.fc3(x)   # raw scores; use CrossEntropyLoss (includes softmax)
        return logits

image_model = InceptionLikeNet(in_channels=in_channels, img_height=image_ht, img_width=image_wt, num_classes=n_classes).to(device)

# %% [markdown]
# #### Training the Model

# %%
train_loss_arr = []
train_accuracy_arr = []
val_loss_arr = []
val_accuracy_arr = []

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(image_model.parameters())

# Early stopping parameters
patience = 30
best_val_loss = float('inf')
best_model_state = None  # Initialize a variable to store the best model state
counter = 0

# Training loop
epochs = 300
epoch1 =0
print('\n')
for epoch in range(epochs):
    epoch1+=1
    image_model.train()
    train_loss = 0.0
    correct_train = 0
    total_train = 0
    for batch_x, batch_y in image_train_loader:
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)
        optimizer.zero_grad()
        output = image_model(batch_x)
        loss = criterion(output, batch_y)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = output.max(1)
        total_train += batch_y.size(0)
        correct_train += predicted.eq(batch_y).sum().item()

    train_loss /= len(image_train_loader)
    train_accuracy = correct_train / total_train
    train_loss_arr.append(train_loss)
    train_accuracy_arr.append(train_accuracy)
    
    image_model.eval()
    
    val_loss = 0.0
    correct_val = 0
    total_val = 0
    with torch.no_grad():
        for batch_x, batch_y in image_val_loader:
            batch_x = batch_x.to(device)
            batch_y = batch_y.to(device)
            output = image_model(batch_x)
            val_loss += criterion(output, batch_y).item()
            _, predicted = output.max(1)
            total_val += batch_y.size(0)
            correct_val += predicted.eq(batch_y).sum().item()

    val_loss /= len(image_val_loader)
    val_accuracy = correct_val / total_val
    val_loss_arr.append(val_loss)
    val_accuracy_arr.append(val_accuracy)
    
    image_model.train()
        
    #Check for early stopping and save best model state
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        counter = 0
        best_model_state = image_model.state_dict()  # Store the current best model state        
        torch.save(best_model_state, os.path.join(out_dir, 'EX2_SG_MargNet_CNN_Model.pth'))
        
    else:
        counter += 1

    if counter >= patience:
        print(f'Early stopping at epoch {epoch+1}')
        if best_model_state is not None:
            image_model.load_state_dict(best_model_state)  # Restore best model state
        counter = 0  # Reset the counter    
        break

    print(f'Epoch [{epoch+1}/{epochs}] - '
      f'Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, '
      f'Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}')

# Create the range of epochs
epoch_range = range(1, epoch1+1)

# Plot training accuracy in blue
plt.figsize=(8, 6)  # Adjust the size as needed
plt.plot(epoch_range, train_accuracy_arr, label='Train Accuracy', color='blue')

# Plot validation accuracy in red
plt.plot(epoch_range, val_accuracy_arr, label='Validation Accuracy', color='red')

# Add labels and title
plt.xlabel('Epoch', fontsize=14, weight='bold')
plt.ylabel('Accuracy', fontsize=14, weight='bold')
plt.title('Model Accuracy', fontsize=14, weight='bold')

# Add a legend
plt.legend(fontsize=14, title_fontproperties={'weight':'bold'})
plt.savefig(os.path.join(out_dir, "EX2_SG_MargNet_CNN_Accuracy.png"))

# Show the plot
plt.show()
plt.close()

# Plot training accuracy in blue
plt.figsize=(8, 6)  # Adjust the size as needed
plt.plot(epoch_range, train_loss_arr, label='Train Loss', color='blue')

# Plot validation accuracy in red
plt.plot(epoch_range, val_loss_arr, label='Validation Loss', color='red')

# Add labels and title
plt.xlabel('Epoch', fontsize=14, weight='bold')
plt.ylabel('Loss', fontsize=14, weight='bold')
plt.title('Model Loss', fontsize=14, weight='bold')

# Add a legend
plt.legend(fontsize=14, title_fontproperties={'weight':'bold'})
plt.savefig(os.path.join(out_dir, "EX2_SG_MargNet_CNN_Loss.png"))

# Show the plot
plt.show()
plt.close()
# Out:
# Epoch [1/300] - Train Loss: 0.7091, Train Accuracy: 0.4982, Validation Loss: 0.6936, Validation Accuracy: 0.4934
# Epoch [2/300] - Train Loss: 0.6932, Train Accuracy: 0.5035, Validation Loss: 0.6934, Validation Accuracy: 0.4934
# Epoch [3/300] - Train Loss: 0.6932, Train Accuracy: 0.4999, Validation Loss: 0.6931, Validation Accuracy: 0.5066
# Epoch [4/300] - Train Loss: 0.6933, Train Accuracy: 0.4984, Validation Loss: 0.6931, Validation Accuracy: 0.5066
# Epoch [5/300] - Train Loss: 0.6932, Train Accuracy: 0.4998, Validation Loss: 0.6931, Validation Accuracy: 0.5066
# Epoch [6/300] - Train Loss: 0.6932, Train Accuracy: 0.5005, Validation Loss: 0.6933, Validation Accuracy: 0.4934
# Epoch [7/300] - Train Loss: 0.6932, Train Accuracy: 0.4976, Validation Loss: 0.6933, Validation Accuracy: 0.4934
# Epoch [8/300] - Train Loss: 0.6460, Train Accuracy: 0.5736, Validation Loss: 0.3617, Validation Accuracy: 0.8691
# Epoch [9/300] - Train Loss: 0.2516, Train Accuracy: 0.9062, Validation Loss: 0.2363, Validation Accuracy: 0.9093
# Epoch [10/300] - Train Loss: 0.2070, Train Accuracy: 0.9219, Validation Loss: 0.1973, Validation Accuracy: 0.9258
# Epoch [11/300] - Train Loss: 0.1964, Train Accuracy: 0.9252, Validation Loss: 0.1925, Validation Accuracy: 0.9257
# Epoch [12/300] - Train Loss: 0.1918, Train Accuracy: 0.9283, Validation Loss: 0.1860, Validation Accuracy: 0.9310
# Epoch [13/300] - Train Loss: 0.1845, Train Accuracy: 0.9296, Validation Loss: 0.1966, Validation Accuracy: 0.9255
# Epoch [14/300] - Train Loss: 0.1796, Train Accuracy: 0.9319, Validation Loss: 0.1762, Validation Accuracy: 0.9343
# Epoch [15/300] - Train Loss: 0.1790, Train Accuracy: 0.9322, Validation Loss: 0.1799, Validation Accuracy: 0.9288
# Epoch [16/300] - Train Loss: 0.1728, Train Accuracy: 0.9335, Validation Loss: 0.1714, Validation Accuracy: 0.9340
# Epoch [17/300] - Train Loss: 0.1697, Train Accuracy: 0.9356, Validation Loss: 0.1724, Validation Accuracy: 0.9331
# Epoch [18/300] - Train Loss: 0.1645, Train Accuracy: 0.9374, Validation Loss: 0.1634, Validation Accuracy: 0.9382
# Epoch [19/300] - Train Loss: 0.1623, Train Accuracy: 0.9391, Validation Loss: 0.1621, Validation Accuracy: 0.9366
# Epoch [20/300] - Train Loss: 0.1643, Train Accuracy: 0.9375, Validation Loss: 0.1713, Validation Accuracy: 0.9337
# Epoch [21/300] - Train Loss: 0.1623, Train Accuracy: 0.9384, Validation Loss: 0.1674, Validation Accuracy: 0.9354
# Epoch [22/300] - Train Loss: 0.1589, Train Accuracy: 0.9401, Validation Loss: 0.1833, Validation Accuracy: 0.9316
# Epoch [23/300] - Train Loss: 0.1557, Train Accuracy: 0.9412, Validation Loss: 0.1580, Validation Accuracy: 0.9387
# Epoch [24/300] - Train Loss: 0.1562, Train Accuracy: 0.9412, Validation Loss: 0.1598, Validation Accuracy: 0.9411
# Epoch [25/300] - Train Loss: 0.1520, Train Accuracy: 0.9426, Validation Loss: 0.1527, Validation Accuracy: 0.9405
# Epoch [26/300] - Train Loss: 0.1514, Train Accuracy: 0.9428, Validation Loss: 0.1512, Validation Accuracy: 0.9428
# Epoch [27/300] - Train Loss: 0.1524, Train Accuracy: 0.9423, Validation Loss: 0.1561, Validation Accuracy: 0.9401
# Epoch [28/300] - Train Loss: 0.1506, Train Accuracy: 0.9420, Validation Loss: 0.1538, Validation Accuracy: 0.9385
# Epoch [29/300] - Train Loss: 0.1504, Train Accuracy: 0.9432, Validation Loss: 0.1581, Validation Accuracy: 0.9372
# Epoch [30/300] - Train Loss: 0.1487, Train Accuracy: 0.9434, Validation Loss: 0.1514, Validation Accuracy: 0.9431
# Epoch [31/300] - Train Loss: 0.1499, Train Accuracy: 0.9438, Validation Loss: 0.1675, Validation Accuracy: 0.9379
# Epoch [32/300] - Train Loss: 0.1482, Train Accuracy: 0.9432, Validation Loss: 0.1513, Validation Accuracy: 0.9407
# Epoch [33/300] - Train Loss: 0.1451, Train Accuracy: 0.9447, Validation Loss: 0.1465, Validation Accuracy: 0.9447
# Epoch [34/300] - Train Loss: 0.1458, Train Accuracy: 0.9444, Validation Loss: 0.1469, Validation Accuracy: 0.9442
# Epoch [35/300] - Train Loss: 0.1453, Train Accuracy: 0.9446, Validation Loss: 0.1471, Validation Accuracy: 0.9429
# Epoch [36/300] - Train Loss: 0.1454, Train Accuracy: 0.9447, Validation Loss: 0.1529, Validation Accuracy: 0.9408
# Epoch [37/300] - Train Loss: 0.1452, Train Accuracy: 0.9452, Validation Loss: 0.1501, Validation Accuracy: 0.9422
# Epoch [38/300] - Train Loss: 0.1423, Train Accuracy: 0.9463, Validation Loss: 0.1440, Validation Accuracy: 0.9445
# Epoch [39/300] - Train Loss: 0.1418, Train Accuracy: 0.9456, Validation Loss: 0.1528, Validation Accuracy: 0.9411
# Epoch [40/300] - Train Loss: 0.1432, Train Accuracy: 0.9451, Validation Loss: 0.1470, Validation Accuracy: 0.9395
# Epoch [41/300] - Train Loss: 0.1414, Train Accuracy: 0.9456, Validation Loss: 0.1451, Validation Accuracy: 0.9420
# Epoch [42/300] - Train Loss: 0.1414, Train Accuracy: 0.9463, Validation Loss: 0.1473, Validation Accuracy: 0.9441
# Epoch [43/300] - Train Loss: 0.1388, Train Accuracy: 0.9475, Validation Loss: 0.1464, Validation Accuracy: 0.9439
# Epoch [44/300] - Train Loss: 0.1401, Train Accuracy: 0.9464, Validation Loss: 0.1419, Validation Accuracy: 0.9439
# Epoch [45/300] - Train Loss: 0.1399, Train Accuracy: 0.9466, Validation Loss: 0.1519, Validation Accuracy: 0.9411
# Epoch [46/300] - Train Loss: 0.1401, Train Accuracy: 0.9471, Validation Loss: 0.1455, Validation Accuracy: 0.9434
# Epoch [47/300] - Train Loss: 0.1399, Train Accuracy: 0.9470, Validation Loss: 0.1496, Validation Accuracy: 0.9425
# Epoch [48/300] - Train Loss: 0.1400, Train Accuracy: 0.9470, Validation Loss: 0.1407, Validation Accuracy: 0.9453
# Epoch [49/300] - Train Loss: 0.1369, Train Accuracy: 0.9479, Validation Loss: 0.1445, Validation Accuracy: 0.9449
# Epoch [50/300] - Train Loss: 0.1388, Train Accuracy: 0.9473, Validation Loss: 0.1454, Validation Accuracy: 0.9436
# Epoch [51/300] - Train Loss: 0.1366, Train Accuracy: 0.9478, Validation Loss: 0.1478, Validation Accuracy: 0.9420
# Epoch [52/300] - Train Loss: 0.1360, Train Accuracy: 0.9482, Validation Loss: 0.1452, Validation Accuracy: 0.9441
# Epoch [53/300] - Train Loss: 0.1366, Train Accuracy: 0.9478, Validation Loss: 0.1459, Validation Accuracy: 0.9429
# Epoch [54/300] - Train Loss: 0.1369, Train Accuracy: 0.9479, Validation Loss: 0.1425, Validation Accuracy: 0.9437
# Epoch [55/300] - Train Loss: 0.1364, Train Accuracy: 0.9480, Validation Loss: 0.1397, Validation Accuracy: 0.9455
# Epoch [56/300] - Train Loss: 0.1355, Train Accuracy: 0.9483, Validation Loss: 0.1385, Validation Accuracy: 0.9476
# Epoch [57/300] - Train Loss: 0.1335, Train Accuracy: 0.9487, Validation Loss: 0.1430, Validation Accuracy: 0.9460
# Epoch [58/300] - Train Loss: 0.1350, Train Accuracy: 0.9481, Validation Loss: 0.1401, Validation Accuracy: 0.9460
# Epoch [59/300] - Train Loss: 0.1333, Train Accuracy: 0.9489, Validation Loss: 0.1373, Validation Accuracy: 0.9444
# Epoch [60/300] - Train Loss: 0.1344, Train Accuracy: 0.9490, Validation Loss: 0.1425, Validation Accuracy: 0.9446
# Epoch [61/300] - Train Loss: 0.1328, Train Accuracy: 0.9495, Validation Loss: 0.1365, Validation Accuracy: 0.9475
# Epoch [62/300] - Train Loss: 0.1325, Train Accuracy: 0.9496, Validation Loss: 0.1424, Validation Accuracy: 0.9456
# Epoch [63/300] - Train Loss: 0.1334, Train Accuracy: 0.9488, Validation Loss: 0.1641, Validation Accuracy: 0.9384
# Epoch [64/300] - Train Loss: 0.1341, Train Accuracy: 0.9490, Validation Loss: 0.1370, Validation Accuracy: 0.9450
# Epoch [65/300] - Train Loss: 0.1302, Train Accuracy: 0.9501, Validation Loss: 0.1381, Validation Accuracy: 0.9465
# Epoch [66/300] - Train Loss: 0.1316, Train Accuracy: 0.9504, Validation Loss: 0.1444, Validation Accuracy: 0.9459
# Epoch [67/300] - Train Loss: 0.1295, Train Accuracy: 0.9508, Validation Loss: 0.1352, Validation Accuracy: 0.9483
# Epoch [68/300] - Train Loss: 0.1309, Train Accuracy: 0.9497, Validation Loss: 0.1340, Validation Accuracy: 0.9466
# Epoch [69/300] - Train Loss: 0.1312, Train Accuracy: 0.9501, Validation Loss: 0.1412, Validation Accuracy: 0.9476
# Epoch [70/300] - Train Loss: 0.1285, Train Accuracy: 0.9514, Validation Loss: 0.1429, Validation Accuracy: 0.9468
# Epoch [71/300] - Train Loss: 0.1288, Train Accuracy: 0.9514, Validation Loss: 0.1378, Validation Accuracy: 0.9471
# Epoch [72/300] - Train Loss: 0.1287, Train Accuracy: 0.9507, Validation Loss: 0.1324, Validation Accuracy: 0.9494
# Epoch [73/300] - Train Loss: 0.1296, Train Accuracy: 0.9509, Validation Loss: 0.1367, Validation Accuracy: 0.9481
# Epoch [74/300] - Train Loss: 0.1279, Train Accuracy: 0.9515, Validation Loss: 0.1374, Validation Accuracy: 0.9451
# Epoch [75/300] - Train Loss: 0.1292, Train Accuracy: 0.9507, Validation Loss: 0.1392, Validation Accuracy: 0.9471
# Epoch [76/300] - Train Loss: 0.1267, Train Accuracy: 0.9520, Validation Loss: 0.1614, Validation Accuracy: 0.9409
# Epoch [77/300] - Train Loss: 0.1259, Train Accuracy: 0.9521, Validation Loss: 0.1398, Validation Accuracy: 0.9469
# Epoch [78/300] - Train Loss: 0.1291, Train Accuracy: 0.9512, Validation Loss: 0.1388, Validation Accuracy: 0.9462
# Epoch [79/300] - Train Loss: 0.1280, Train Accuracy: 0.9507, Validation Loss: 0.1346, Validation Accuracy: 0.9485
# Epoch [80/300] - Train Loss: 0.1269, Train Accuracy: 0.9514, Validation Loss: 0.1349, Validation Accuracy: 0.9486
# Epoch [81/300] - Train Loss: 0.1268, Train Accuracy: 0.9507, Validation Loss: 0.1361, Validation Accuracy: 0.9488
# Epoch [82/300] - Train Loss: 0.1269, Train Accuracy: 0.9517, Validation Loss: 0.1343, Validation Accuracy: 0.9488
# Epoch [83/300] - Train Loss: 0.1266, Train Accuracy: 0.9524, Validation Loss: 0.1403, Validation Accuracy: 0.9473
# Epoch [84/300] - Train Loss: 0.1270, Train Accuracy: 0.9515, Validation Loss: 0.1296, Validation Accuracy: 0.9485
# Epoch [85/300] - Train Loss: 0.1276, Train Accuracy: 0.9529, Validation Loss: 0.1343, Validation Accuracy: 0.9480
# Epoch [86/300] - Train Loss: 0.1250, Train Accuracy: 0.9520, Validation Loss: 0.1323, Validation Accuracy: 0.9487
# Epoch [87/300] - Train Loss: 0.1254, Train Accuracy: 0.9520, Validation Loss: 0.1322, Validation Accuracy: 0.9471
# Epoch [88/300] - Train Loss: 0.1248, Train Accuracy: 0.9526, Validation Loss: 0.1354, Validation Accuracy: 0.9469
# Epoch [89/300] - Train Loss: 0.1242, Train Accuracy: 0.9541, Validation Loss: 0.1350, Validation Accuracy: 0.9493
# Epoch [90/300] - Train Loss: 0.1247, Train Accuracy: 0.9527, Validation Loss: 0.1418, Validation Accuracy: 0.9462
# Epoch [91/300] - Train Loss: 0.1258, Train Accuracy: 0.9516, Validation Loss: 0.1327, Validation Accuracy: 0.9497
# Epoch [92/300] - Train Loss: 0.1245, Train Accuracy: 0.9525, Validation Loss: 0.1347, Validation Accuracy: 0.9486
# Epoch [93/300] - Train Loss: 0.1223, Train Accuracy: 0.9542, Validation Loss: 0.1323, Validation Accuracy: 0.9491
# Epoch [94/300] - Train Loss: 0.1228, Train Accuracy: 0.9533, Validation Loss: 0.1350, Validation Accuracy: 0.9495
# Epoch [95/300] - Train Loss: 0.1244, Train Accuracy: 0.9527, Validation Loss: 0.1363, Validation Accuracy: 0.9461
# Epoch [96/300] - Train Loss: 0.1232, Train Accuracy: 0.9536, Validation Loss: 0.1389, Validation Accuracy: 0.9481
# Epoch [97/300] - Train Loss: 0.1235, Train Accuracy: 0.9534, Validation Loss: 0.1319, Validation Accuracy: 0.9499
# Epoch [98/300] - Train Loss: 0.1225, Train Accuracy: 0.9533, Validation Loss: 0.1344, Validation Accuracy: 0.9489
# Epoch [99/300] - Train Loss: 0.1234, Train Accuracy: 0.9529, Validation Loss: 0.1359, Validation Accuracy: 0.9473
# Epoch [100/300] - Train Loss: 0.1228, Train Accuracy: 0.9532, Validation Loss: 0.1340, Validation Accuracy: 0.9498
# Epoch [101/300] - Train Loss: 0.1254, Train Accuracy: 0.9525, Validation Loss: 0.1417, Validation Accuracy: 0.9450
# Epoch [102/300] - Train Loss: 0.1224, Train Accuracy: 0.9536, Validation Loss: 0.1363, Validation Accuracy: 0.9486
# Epoch [103/300] - Train Loss: 0.1224, Train Accuracy: 0.9532, Validation Loss: 0.1292, Validation Accuracy: 0.9508
# Epoch [104/300] - Train Loss: 0.1208, Train Accuracy: 0.9542, Validation Loss: 0.1397, Validation Accuracy: 0.9473
# Epoch [105/300] - Train Loss: 0.1223, Train Accuracy: 0.9543, Validation Loss: 0.1348, Validation Accuracy: 0.9488
# Epoch [106/300] - Train Loss: 0.1211, Train Accuracy: 0.9541, Validation Loss: 0.1359, Validation Accuracy: 0.9469
# Epoch [107/300] - Train Loss: 0.1205, Train Accuracy: 0.9543, Validation Loss: 0.1349, Validation Accuracy: 0.9475
# Epoch [108/300] - Train Loss: 0.1194, Train Accuracy: 0.9546, Validation Loss: 0.1374, Validation Accuracy: 0.9467
# Epoch [109/300] - Train Loss: 0.1194, Train Accuracy: 0.9547, Validation Loss: 0.1388, Validation Accuracy: 0.9465
# Epoch [110/300] - Train Loss: 0.1206, Train Accuracy: 0.9543, Validation Loss: 0.1346, Validation Accuracy: 0.9476
# Epoch [111/300] - Train Loss: 0.1213, Train Accuracy: 0.9544, Validation Loss: 0.1330, Validation Accuracy: 0.9467
# Epoch [112/300] - Train Loss: 0.1221, Train Accuracy: 0.9534, Validation Loss: 0.1323, Validation Accuracy: 0.9499
# Epoch [113/300] - Train Loss: 0.1204, Train Accuracy: 0.9542, Validation Loss: 0.1317, Validation Accuracy: 0.9493
# Epoch [114/300] - Train Loss: 0.1203, Train Accuracy: 0.9541, Validation Loss: 0.1414, Validation Accuracy: 0.9459
# Epoch [115/300] - Train Loss: 0.1195, Train Accuracy: 0.9543, Validation Loss: 0.1336, Validation Accuracy: 0.9477
# Epoch [116/300] - Train Loss: 0.1188, Train Accuracy: 0.9547, Validation Loss: 0.1294, Validation Accuracy: 0.9497
# Epoch [117/300] - Train Loss: 0.1190, Train Accuracy: 0.9545, Validation Loss: 0.1346, Validation Accuracy: 0.9468
# Epoch [118/300] - Train Loss: 0.1182, Train Accuracy: 0.9552, Validation Loss: 0.1334, Validation Accuracy: 0.9471
# Epoch [119/300] - Train Loss: 0.1182, Train Accuracy: 0.9550, Validation Loss: 0.1294, Validation Accuracy: 0.9514
# Epoch [120/300] - Train Loss: 0.1183, Train Accuracy: 0.9553, Validation Loss: 0.1315, Validation Accuracy: 0.9496
# Epoch [121/300] - Train Loss: 0.1203, Train Accuracy: 0.9544, Validation Loss: 0.1384, Validation Accuracy: 0.9471
# Epoch [122/300] - Train Loss: 0.1195, Train Accuracy: 0.9545, Validation Loss: 0.1354, Validation Accuracy: 0.9500
# Epoch [123/300] - Train Loss: 0.1206, Train Accuracy: 0.9547, Validation Loss: 0.1524, Validation Accuracy: 0.9404
# Epoch [124/300] - Train Loss: 0.1365, Train Accuracy: 0.9499, Validation Loss: 0.1417, Validation Accuracy: 0.9441
# Epoch [125/300] - Train Loss: 0.1224, Train Accuracy: 0.9537, Validation Loss: 0.1342, Validation Accuracy: 0.9495
# Epoch [126/300] - Train Loss: 0.1191, Train Accuracy: 0.9552, Validation Loss: 0.1373, Validation Accuracy: 0.9479
# Epoch [127/300] - Train Loss: 0.1187, Train Accuracy: 0.9549, Validation Loss: 0.1377, Validation Accuracy: 0.9482
# Epoch [128/300] - Train Loss: 0.1182, Train Accuracy: 0.9548, Validation Loss: 0.1325, Validation Accuracy: 0.9483
# Epoch [129/300] - Train Loss: 0.1155, Train Accuracy: 0.9565, Validation Loss: 0.1377, Validation Accuracy: 0.9482
# Epoch [130/300] - Train Loss: 0.1173, Train Accuracy: 0.9556, Validation Loss: 0.1331, Validation Accuracy: 0.9506
# Epoch [131/300] - Train Loss: 0.1151, Train Accuracy: 0.9569, Validation Loss: 0.1349, Validation Accuracy: 0.9494
# Epoch [132/300] - Train Loss: 0.1175, Train Accuracy: 0.9546, Validation Loss: 0.1393, Validation Accuracy: 0.9488
# Early stopping at epoch 133

# %% [markdown]
# #### Testing the Model

# %%
torch.cuda.empty_cache()

# Set the model to evaluation mode

image_model.load_state_dict(torch.load(os.path.join(out_dir, 'EX2_SG_MargNet_CNN_Model.pth'), map_location=device))
image_model.eval()

y_test_pred = torch.empty(0).to(device)
print('\n')
# Generate predictions
with torch.no_grad():
    for images, labels in image_test_loader:
        images = images.to(device)
        labels = labels.to(device)
        pred = image_model(images)

        y_test_pred = torch.cat((y_test_pred, pred), dim=0)

y_test_pred = y_test_pred.cpu().numpy()
y_test_pred = y_test_pred.argmax(axis=1)
print(get_metrics(y_test_pred, y_test, label_strings))

# https://www.stackvidhya.com/plot-confusion-matrix-in-python-and-why/#google_vignette
# fig = plt.figure()
cf_matrix = metrics.confusion_matrix(y_test, y_test_pred)
cf_matrix_percentage = metrics.confusion_matrix(y_test, y_test_pred, normalize='true')
group_counts = ["{0:0.0f}".format(value) for value in cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_matrix_percentage.flatten()]
labels = [f"{v1}\n({v2})\n" for v1, v2 in
          zip(group_percentages,group_counts)]
labels = np.asarray(labels).reshape(2,2)
fig, ax = plt.subplots(figsize=(8, 6))  # Adjust the size as needed

ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
ax.set_xlabel('\nPredicted', fontsize=14, weight='bold')
ax.set_ylabel('Actual', fontsize=14, weight='bold');
ax.xaxis.set_ticklabels(['GALAXY', 'STAR'], fontsize=14, weight='bold')
ax.yaxis.set_ticklabels(['GALAXY', 'STAR'], fontsize=14, weight='bold')
plt.tight_layout()
plt.savefig(os.path.join(out_dir, "EX2_SG_MargNet_CNN_CM.png"))
plt.show()
plt.close()
# Out:
# Identified 9517 correct labels out of 10000 labels
# Accuracy: 0.9517
# Precision: 0.9517117155821122
# Recall: 0.9516971704439254
# F1 Score: 0.9516994083177519
# Labels are: ['GALAXY' 'STAR']
# Confusion Matrix:
#  [[4741  253]
#  [ 230 4776]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95      4994
#            1       0.95      0.95      0.95      5006
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000
#
# (array([   0,    1,    2, ..., 9997, 9998, 9999]), 0.9517, 0.9517117155821122, 0.9516971704439254, array([[4741,  253],
#        [ 230, 4776]]), '              precision    recall  f1-score   support\n\n           0       0.95      0.95      0.95      4994\n           1       0.95      0.95      0.95      5006\n\n    accuracy                           0.95     10000\n   macro avg       0.95      0.95      0.95     10000\nweighted avg       0.95      0.95      0.95     10000\n')

# %% [markdown]
# ### 3. Ensemble Model (ANN+CNN) using photometric features and Images

# %%
cnnclassifier = image_model
dnnclassifier = pf_model

# %%
checkpoint_image = torch.load(os.path.join(out_dir, 'EX2_SG_MargNet_CNN_Model.pth'))
checkpoint_pf = torch.load(os.path.join(out_dir, 'EX2_SG_MargNet_DNN_Model.pth'))

# %%
cnnclassifier.load_state_dict(checkpoint_image)
dnnclassifier.load_state_dict(checkpoint_pf)
# Out:
# <All keys matched successfully>

# %%
class StackedModel(nn.Module):
    def __init__(self, members):
        super(StackedModel, self).__init__()
        self.members = nn.ModuleList(members)

        # Create a dictionary to store renamed parameters
        renamed_params = {}

        # Freeze the layers and rename them
        for i, model in enumerate(self.members):
            for name, param in model.named_parameters():
                param.requires_grad = False
                new_name = f'ensemble_{i+1}_{name.replace(".", "_")}'  # Replace '.' with '_'
                renamed_params[new_name] = param

        # Apply the changes to the model outside the loop
        for i, model in enumerate(self.members):
            for new_name, param in renamed_params.items():
                setattr(model, new_name, param)

        # Define multi-headed input
        self.ensemble_visible = [model for model in self.members]

        # Concatenate the outputs from each model
        self.hidden = nn.Linear(len(members) * 2, 10)
        self.output = nn.Linear(10, 2)

    def forward(self, inputs):
        outputs = [model(inputs[i]) for i, model in enumerate(self.members)]
        merge = torch.cat(outputs, dim=1)
        hidden = torch.relu(self.hidden(merge))
        output = self.output(hidden)
        return output

# %%
# Create the ensemble model
members = [cnnclassifier, dnnclassifier]
model = StackedModel(members).to(device)

# %%
# Convert data to PyTorch tensors and create DataLoader
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
dnnx_val_tensor = torch.tensor(dnnx_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)

dataset = TensorDataset(X_val_tensor, dnnx_val_tensor, y_val_tensor)
dataloader = DataLoader(dataset, batch_size=512, shuffle=False)

# %% [markdown]
# #### Training the Model

# %%
# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())

# Training loop
num_epochs = 100
pf_image_best_loss = float('inf')
pf_image_best_model_state = None  # Initialize a variable to store the best model state

# filepath = "output/EnsembleClassifier.pth"

for epoch in range(num_epochs):
    train_loss = 0.0  # Initialize total loss for the epoch
    correct_train = 0
    total_train = 0    

    for X_batch, dnnx_batch, y_batch in dataloader:
        model.train()
        X_batch = X_batch.to(device)
        dnnx_batch = dnnx_batch.to(device)
        y_batch = y_batch.to(device)
        optimizer.zero_grad()
        outputs = model([X_batch, dnnx_batch])
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()

        # Accumulate the batch loss to the total loss
        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total_train += y_batch.size(0)
        correct_train += predicted.eq(y_batch).sum().item()

    # Calculate the average loss for the epoch
    train_loss /= len(dataloader)
    train_accuracy = correct_train / total_train

    #Check for early stopping and save best model state
    if train_loss < pf_image_best_loss:
        pf_image_best_loss = train_loss  # Update with the current train_loss
        pf_image_best_model_state = model.state_dict()
        torch.save(pf_image_best_model_state, os.path.join(out_dir, 'EX2_SG_MargNet_Model.pth'))

    # Print the average loss for the epoch
    print(f'Epoch [{epoch+1}/{num_epochs}] - 'f'Loss: {train_loss:.4f}, Accuracy: {train_accuracy:.4f} ')
# Out:
# Epoch [1/100] - Loss: 1.1356, Accuracy: 0.2061
# Epoch [2/100] - Loss: 0.7926, Accuracy: 0.4925
# Epoch [3/100] - Loss: 0.5554, Accuracy: 0.8688
# Epoch [4/100] - Loss: 0.4081, Accuracy: 0.9555
# Epoch [5/100] - Loss: 0.3150, Accuracy: 0.9615
# Epoch [6/100] - Loss: 0.2537, Accuracy: 0.9632
# Epoch [7/100] - Loss: 0.2107, Accuracy: 0.9642
# Epoch [8/100] - Loss: 0.1815, Accuracy: 0.9668
# Epoch [9/100] - Loss: 0.1603, Accuracy: 0.9668
# Epoch [10/100] - Loss: 0.1439, Accuracy: 0.9674
# Epoch [11/100] - Loss: 0.1325, Accuracy: 0.9694
# Epoch [12/100] - Loss: 0.1252, Accuracy: 0.9664
# Epoch [13/100] - Loss: 0.1190, Accuracy: 0.9672
# Epoch [14/100] - Loss: 0.1130, Accuracy: 0.9668
# Epoch [15/100] - Loss: 0.1093, Accuracy: 0.9665
# Epoch [16/100] - Loss: 0.1061, Accuracy: 0.9665
# Epoch [17/100] - Loss: 0.1033, Accuracy: 0.9675
# Epoch [18/100] - Loss: 0.1013, Accuracy: 0.9676
# Epoch [19/100] - Loss: 0.1006, Accuracy: 0.9670
# Epoch [20/100] - Loss: 0.0984, Accuracy: 0.9678
# Epoch [21/100] - Loss: 0.0966, Accuracy: 0.9675
# Epoch [22/100] - Loss: 0.0955, Accuracy: 0.9669
# Epoch [23/100] - Loss: 0.0942, Accuracy: 0.9685
# Epoch [24/100] - Loss: 0.0945, Accuracy: 0.9681
# Epoch [25/100] - Loss: 0.0930, Accuracy: 0.9680
# Epoch [26/100] - Loss: 0.0937, Accuracy: 0.9672
# Epoch [27/100] - Loss: 0.0920, Accuracy: 0.9675
# Epoch [28/100] - Loss: 0.0921, Accuracy: 0.9676
# Epoch [29/100] - Loss: 0.0903, Accuracy: 0.9685
# Epoch [30/100] - Loss: 0.0918, Accuracy: 0.9684
# Epoch [31/100] - Loss: 0.0924, Accuracy: 0.9683
# Epoch [32/100] - Loss: 0.0909, Accuracy: 0.9678
# Epoch [33/100] - Loss: 0.0919, Accuracy: 0.9667
# Epoch [34/100] - Loss: 0.0915, Accuracy: 0.9667
# Epoch [35/100] - Loss: 0.0903, Accuracy: 0.9679
# Epoch [36/100] - Loss: 0.0903, Accuracy: 0.9669
# Epoch [37/100] - Loss: 0.0913, Accuracy: 0.9685
# Epoch [38/100] - Loss: 0.0892, Accuracy: 0.9677
# Epoch [39/100] - Loss: 0.0898, Accuracy: 0.9690
# Epoch [40/100] - Loss: 0.0886, Accuracy: 0.9682
# Epoch [41/100] - Loss: 0.0909, Accuracy: 0.9666
# Epoch [42/100] - Loss: 0.0894, Accuracy: 0.9683
# Epoch [43/100] - Loss: 0.0913, Accuracy: 0.9673
# Epoch [44/100] - Loss: 0.0879, Accuracy: 0.9681
# Epoch [45/100] - Loss: 0.0901, Accuracy: 0.9687
# Epoch [46/100] - Loss: 0.0890, Accuracy: 0.9693
# Epoch [47/100] - Loss: 0.0883, Accuracy: 0.9681
# Epoch [48/100] - Loss: 0.0898, Accuracy: 0.9680
# Epoch [49/100] - Loss: 0.0887, Accuracy: 0.9684
# Epoch [50/100] - Loss: 0.0892, Accuracy: 0.9679
# Epoch [51/100] - Loss: 0.0904, Accuracy: 0.9674
# Epoch [52/100] - Loss: 0.0879, Accuracy: 0.9683
# Epoch [53/100] - Loss: 0.0888, Accuracy: 0.9682
# Epoch [54/100] - Loss: 0.0894, Accuracy: 0.9680
# Epoch [55/100] - Loss: 0.0887, Accuracy: 0.9688
# Epoch [56/100] - Loss: 0.0893, Accuracy: 0.9692
# Epoch [57/100] - Loss: 0.0901, Accuracy: 0.9685
# Epoch [58/100] - Loss: 0.0889, Accuracy: 0.9690
# Epoch [59/100] - Loss: 0.0893, Accuracy: 0.9678
# Epoch [60/100] - Loss: 0.0907, Accuracy: 0.9680
# Epoch [61/100] - Loss: 0.0888, Accuracy: 0.9688
# Epoch [62/100] - Loss: 0.0886, Accuracy: 0.9687
# Epoch [63/100] - Loss: 0.0890, Accuracy: 0.9674
# Epoch [64/100] - Loss: 0.0882, Accuracy: 0.9686
# Epoch [65/100] - Loss: 0.0898, Accuracy: 0.9680
# Epoch [66/100] - Loss: 0.0887, Accuracy: 0.9682
# Epoch [67/100] - Loss: 0.0874, Accuracy: 0.9689
# Epoch [68/100] - Loss: 0.0888, Accuracy: 0.9681
# Epoch [69/100] - Loss: 0.0888, Accuracy: 0.9672
# Epoch [70/100] - Loss: 0.0884, Accuracy: 0.9692
# Epoch [71/100] - Loss: 0.0879, Accuracy: 0.9691
# Epoch [72/100] - Loss: 0.0879, Accuracy: 0.9679
# Epoch [73/100] - Loss: 0.0887, Accuracy: 0.9677
# Epoch [74/100] - Loss: 0.0887, Accuracy: 0.9676
# Epoch [75/100] - Loss: 0.0902, Accuracy: 0.9679
# Epoch [76/100] - Loss: 0.0888, Accuracy: 0.9676
# Epoch [77/100] - Loss: 0.0868, Accuracy: 0.9684
# Epoch [78/100] - Loss: 0.0881, Accuracy: 0.9679
# Epoch [79/100] - Loss: 0.0879, Accuracy: 0.9686
# Epoch [80/100] - Loss: 0.0879, Accuracy: 0.9684
# Epoch [81/100] - Loss: 0.0877, Accuracy: 0.9690
# Epoch [82/100] - Loss: 0.0882, Accuracy: 0.9682
# Epoch [83/100] - Loss: 0.0873, Accuracy: 0.9698
# Epoch [84/100] - Loss: 0.0878, Accuracy: 0.9685
# Epoch [85/100] - Loss: 0.0890, Accuracy: 0.9691
# Epoch [86/100] - Loss: 0.0876, Accuracy: 0.9693
# Epoch [87/100] - Loss: 0.0874, Accuracy: 0.9683
# Epoch [88/100] - Loss: 0.0876, Accuracy: 0.9683
# Epoch [89/100] - Loss: 0.0873, Accuracy: 0.9680
# Epoch [90/100] - Loss: 0.0875, Accuracy: 0.9686
# Epoch [91/100] - Loss: 0.0883, Accuracy: 0.9689
# Epoch [92/100] - Loss: 0.0874, Accuracy: 0.9687
# Epoch [93/100] - Loss: 0.0897, Accuracy: 0.9674
# Epoch [94/100] - Loss: 0.0887, Accuracy: 0.9680
# Epoch [95/100] - Loss: 0.0873, Accuracy: 0.9690
# Epoch [96/100] - Loss: 0.0889, Accuracy: 0.9686
# Epoch [97/100] - Loss: 0.0871, Accuracy: 0.9691
# Epoch [98/100] - Loss: 0.0894, Accuracy: 0.9693
# Epoch [99/100] - Loss: 0.0887, Accuracy: 0.9682
# Epoch [100/100] - Loss: 0.0872, Accuracy: 0.9694

# %%
model.load_state_dict(pf_image_best_model_state)  # Restore best model state
# Out:
# <All keys matched successfully>

# %%
# Convert data to PyTorch tensors and create DataLoader
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
dnnx_test_tensor = torch.tensor(dnnx_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

dataset1 = TensorDataset(X_test_tensor, dnnx_test_tensor, y_test_tensor)
dataloader1 = DataLoader(dataset1, batch_size=512, shuffle=False)

# %% [markdown]
# #### Testing the Model

# %%
# Set the model to evaluation mode
        
model.load_state_dict(torch.load(os.path.join(out_dir, 'EX2_SG_MargNet_Model.pth'), map_location=device))
model.eval()

model.eval()
y_test_pred = torch.empty(0).to(device)

# Generate predictions
with torch.no_grad():
    for images, pfs, labels in dataloader1:
        images = images.to(device)
        pfs = pfs.to(device)
        labels = labels.to(device)
        pred = model([images, pfs])

        y_test_pred = torch.cat((y_test_pred, pred), dim=0)

y_test_pred = y_test_pred.cpu().numpy()
y_test_pred = y_test_pred.argmax(axis=1)
print(get_metrics(y_test_pred, y_test, label_strings))

# https://www.stackvidhya.com/plot-confusion-matrix-in-python-and-why/#google_vignette
# fig = plt.figure()
cf_matrix = metrics.confusion_matrix(y_test_pred, y_test)
cf_matrix_percentage = metrics.confusion_matrix(y_test_pred, y_test, normalize='true')
group_counts = ["{0:0.0f}".format(value) for value in cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_matrix_percentage.flatten()]
labels = [f"{v1}\n({v2})\n" for v1, v2 in
          zip(group_percentages,group_counts)]
labels = np.asarray(labels).reshape(2,2)
fig, ax = plt.subplots(figsize=(8, 6))  # Adjust the size as needed

ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
ax.set_xlabel('\nPredicted', fontsize=14, weight='bold')
ax.set_ylabel('Actual', fontsize=14, weight='bold');
ax.xaxis.set_ticklabels(['GALAXY', 'STAR'], fontsize=14, weight='bold')
ax.yaxis.set_ticklabels(['GALAXY', 'STAR'], fontsize=14, weight='bold')
plt.tight_layout()
plt.savefig(os.path.join(out_dir, "EX2_SG_MargNet_CM.png"))

plt.show()
plt.close()
# Out:
# Identified 9669 correct labels out of 10000 labels
# Accuracy: 0.9669
# Precision: 0.966902402121619
# Recall: 0.9668988723343761
# F1 Score: 0.9668998540283562
# Labels are: ['GALAXY' 'STAR']
# Confusion Matrix:
#  [[4824  170]
#  [ 161 4845]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      4994
#            1       0.97      0.97      0.97      5006
#
#     accuracy                           0.97     10000
#    macro avg       0.97      0.97      0.97     10000
# weighted avg       0.97      0.97      0.97     10000
#
# (array([   0,    1,    2, ..., 9997, 9998, 9999]), 0.9669, 0.966902402121619, 0.9668988723343761, array([[4824,  170],
#        [ 161, 4845]]), '              precision    recall  f1-score   support\n\n           0       0.97      0.97      0.97      4994\n           1       0.97      0.97      0.97      5006\n\n    accuracy                           0.97     10000\n   macro avg       0.97      0.97      0.97     10000\nweighted avg       0.97      0.97      0.97     10000\n')

# %%
sum(p.numel() for p in model.parameters())
# Out:
# 25874128

# %% [markdown]
# ## Result Analysis

# %%
del(dnnx_train, dnnx_val, dnnx_test, X_train, X_val, X_test)

# %%
X = np.load("/scratch/srinadb/Foundation/Dataset/Experiment2/X_exp2.npy")
dnnx = np.load("/scratch/srinadb/Foundation/Dataset/Experiment2/dnnx_exp2.npy")
objlist = np.load("/scratch/srinadb/Foundation/Dataset/Experiment2/objlist_exp2.npy")
y = np.load("/scratch/srinadb/Foundation/Dataset/Experiment2/y_exp2.npy", allow_pickle=True)

idx_drop = np.where(y=="QSO")[0]
X = np.delete(X,idx_drop,axis=0)
dnnx = np.delete(dnnx,idx_drop,axis=0)
y = np.delete(y,idx_drop,axis=0)
objlist = np.delete(objlist,idx_drop,axis=0)
y, label_strings = pd.factorize(y,sort=True)
# y = to_categorical(y)
print('\n')
print(label_strings)

zipX = list(zip(X, dnnx))
zipy = list(zip(y, objlist))

zipX_train, zipX_test, zipy_train, zipy_test = train_test_split(zipX, zipy, test_size = 0.125,random_state=42)
zipX_train, zipX_val, zipy_train, zipy_val = train_test_split(zipX_train, zipy_train, test_size = 0.1428, random_state=42)

X_train, dnnx_train = zip(*zipX_train)
X_val, dnnx_val = zip(*zipX_val)
X_test, dnnx_test = zip(*zipX_test)

y_train, objlist_train = zip(*zipy_train)
y_val, objlist_val = zip(*zipy_val)
y_test, objlist_test = zip(*zipy_test)

X_train = np.array(X_train)
X_val = np.array(X_val)
X_test = np.array(X_test)

dnnx_train = np.array(dnnx_train)
dnnx_val = np.array(dnnx_val)
dnnx_test = np.array(dnnx_test)

y_train = np.array(y_train)
objlist_train = np.array(objlist_train)
y_val = np.array(y_val)
objlist_val = np.array(objlist_val)
y_test = np.array(y_test)
objlist_test = np.array(objlist_test)

del(zipX,zipX_test,zipX_train,zipX_val, X, zipy, zipy_test, zipy_train, zipy_val, objlist)

X_train = X_train.transpose((0, 3, 1, 2))
X_val = X_val.transpose((0, 3, 1, 2))
X_test = X_test.transpose((0, 3, 1, 2))

print('\n')
print('The shape of the Train data is:', X_train.shape)
print('The shape of the Validation data is:', X_val.shape)
print('The shape of the Test data is:', X_test.shape)

# Convert data to PyTorch tensors and create DataLoader
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
dnnx_train_tensor = torch.tensor(dnnx_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)

X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
dnnx_val_tensor = torch.tensor(dnnx_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)

X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
dnnx_test_tensor = torch.tensor(dnnx_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)


train_dataset = TensorDataset(X_train_tensor, dnnx_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=512, shuffle=False)

val_dataset = TensorDataset(X_val_tensor, dnnx_val_tensor, y_val_tensor)
val_loader = DataLoader(val_dataset, batch_size=512, shuffle=False)

test_dataset = TensorDataset(X_test_tensor, dnnx_test_tensor, y_test_tensor)
test_loader = DataLoader(test_dataset, batch_size=512, shuffle=False)
# Out:
# ['GALAXY' 'STAR']
#
#
# The shape of the Train data is: (75001, 5, 32, 32)
# The shape of the Validation data is: (12495, 5, 32, 32)
# The shape of the Test data is: (12500, 5, 32, 32)

# %%
def get_preds(loader):
    model.eval()
    all_logits = []

    with torch.no_grad():
        for images, pf, labels in loader:
            pf = pf.to(device)
            images = images.to(device)
            logits = model([images, pf])      # [batch, 3]
            all_logits.append(logits.cpu())

    all_logits = torch.cat(all_logits, dim=0)   # [N, 3]
    all_probs  = F.softmax(all_logits, dim=1)   # probabilities, rows sum to 1
    all_probs  = all_probs.numpy()

    pred_labels = all_probs.argmax(axis=1)
    return all_probs, pred_labels

preds_train, y_train_pred = get_preds(train_loader)
print(get_metrics(y_train_pred, y_train, label_strings))
print('\n')

preds_val, y_val_pred = get_preds(val_loader)
print(get_metrics(y_val_pred, y_val, label_strings))
print('\n')

preds_test, y_test_pred = get_preds(test_loader)
print(get_metrics(y_test_pred, y_test, label_strings))
# Out:
# Identified 72934 correct labels out of 75001 labels
# Accuracy: 0.9724403674617672
# Precision: 0.9724603470458257
# Recall: 0.9724475078418184
# F1 Score: 0.9724402768429145
# Labels are: ['GALAXY' 'STAR']
# Confusion Matrix:
#  [[36399  1174]
#  [  893 36535]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97     37573
#            1       0.97      0.98      0.97     37428
#
#     accuracy                           0.97     75001
#    macro avg       0.97      0.97      0.97     75001
# weighted avg       0.97      0.97      0.97     75001
#
# (array([    0,     1,     2, ..., 74998, 74999, 75000]), 0.9724403674617672, 0.9724603470458257, 0.9724475078418184, array([[36399,  1174],
#        [  893, 36535]]), '              precision    recall  f1-score   support\n\n           0       0.98      0.97      0.97     37573\n           1       0.97      0.98      0.97     37428\n\n    accuracy                           0.97     75001\n   macro avg       0.97      0.97      0.97     75001\nweighted avg       0.97      0.97      0.97     75001\n')
#
#
# Identified 12125 correct labels out of 12495 labels
# Accuracy: 0.9703881552621049
# Precision: 0.9704378925523707
# Recall: 0.9703637649922148
# F1 Score: 0.9703852855042578
# Labels are: ['GALAXY' 'STAR']
# Confusion Matrix:
#  [[6001  210]
#  [ 160 6124]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      6211
#            1       0.97      0.97      0.97      6284
#
#     accuracy                           0.97     12495
#    macro avg       0.97      0.97      0.97     12495
# weighted avg       0.97      0.97      0.97     12495
#
# (array([    0,     1,     2, ..., 12492, 12493, 12494]), 0.9703881552621049, 0.9704378925523707, 0.9703637649922148, array([[6001,  210],
#        [ 160, 6124]]), '              precision    recall  f1-score   support\n\n           0       0.97      0.97      0.97      6211\n           1       0.97      0.97      0.97      6284\n\n    accuracy                           0.97     12495\n   macro avg       0.97      0.97      0.97     12495\nweighted avg       0.97      0.97      0.97     12495\n')
#
#
# Identified 12114 correct labels out of 12500 labels
# Accuracy: 0.96912
# Precision: 0.969121807229224
# Recall: 0.96911647484531
# F1 Score: 0.9691189177292383
# Labels are: ['GALAXY' 'STAR']
# Confusion Matrix:
#  [[6020  196]
#  [ 190 6094]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      6216
#            1       0.97      0.97      0.97      6284
#
#     accuracy                           0.97     12500
#    macro avg       0.97      0.97      0.97     12500
# weighted avg       0.97      0.97      0.97     12500
#
# (array([    0,     1,     2, ..., 12497, 12498, 12499]), 0.96912, 0.969121807229224, 0.96911647484531, array([[6020,  196],
#        [ 190, 6094]]), '              precision    recall  f1-score   support\n\n           0       0.97      0.97      0.97      6216\n           1       0.97      0.97      0.97      6284\n\n    accuracy                           0.97     12500\n   macro avg       0.97      0.97      0.97     12500\nweighted avg       0.97      0.97      0.97     12500\n')

# %%
df = pd.read_csv("/scratch/srinadb/Foundation/Dataset/Experiment2/photofeatures_exp2.csv",index_col=0)
df = df[df["class"]!="QSO"].reset_index()
df = df.set_index(["objid"])

df.loc[objlist_train, ["set"]] = "TRAIN"
df.loc[objlist_val, ["set"]] = "VALIDATION"
df.loc[objlist_test, ["set"]] = "TEST"

df.loc[objlist_train, ["pred_class"]] = label_strings[preds_train.argmax(axis=1)]
df.loc[objlist_val, ["pred_class"]] = label_strings[preds_val.argmax(axis=1)]
df.loc[objlist_test, ["pred_class"]] = label_strings[preds_test.argmax(axis=1)]

pgal_train = preds_train[:,np.where(label_strings=="GALAXY")[0][0]]
pstar_train = preds_train[:,np.where(label_strings=="STAR")[0][0]]

pgal_val = preds_val[:,np.where(label_strings=="GALAXY")[0][0]]
pstar_val = preds_val[:,np.where(label_strings=="STAR")[0][0]]

pgal_test = preds_test[:,np.where(label_strings=="GALAXY")[0][0]]
pstar_test = preds_test[:,np.where(label_strings=="STAR")[0][0]]


df.to_csv(os.path.join(out_dir, "EX2_SG_MargNet_results.csv"))

# %%
sns.set_palette("tab10")

df = pd.read_csv(os.path.join(out_dir, "EX2_SG_MargNet_results.csv"))

subdflist = []

bin_size = 0.1
lower_bin_list = np.arange(20,23,bin_size)
bad_lower_bin=[]
acclist = []
f1list = []
reportlist = []
num_samplelist = []
starmaglist = []
galmaglist = []

for lower_bin in lower_bin_list:
#     print(f"******************** {lower_bin} < r <= {lower_bin+bin_size} ********************")
    subdf = df[(
        ((df["dered_r"]+df["extinction_r"]) > lower_bin) & 
        ((df["dered_r"]+df["extinction_r"]) <= lower_bin+bin_size)
    )]
    # Choose equal number of stars and galaxies
    min_num = subdf["class"].value_counts().min()
    if min_num < 50:
        bad_lower_bin.append(lower_bin)
        continue
    s1 = subdf[subdf["class"]=="GALAXY"].sample(n=min_num)
    galmaglist.append((s1["dered_r"]+s1["extinction_r"]).to_numpy())
    s2 = subdf[subdf["class"]=="STAR"].sample(n=min_num)
    starmaglist.append((s2["dered_r"]+s2["extinction_r"]).to_numpy())
    num_samplelist.append(min_num)
    subdf = pd.concat([s1,s2])
    subdflist.append(subdf)
    
    accuracy = metrics.accuracy_score(subdf["class"], subdf["pred_class"])
    f1score = metrics.f1_score(subdf["class"], subdf["pred_class"],average='macro')
    report = metrics.classification_report(subdf["class"], subdf["pred_class"],output_dict=True)
    reportlist.append(report)
    acclist.append(accuracy)
    f1list.append(f1score)

bad_lower_bin = np.array(bad_lower_bin)
lower_bin_list = lower_bin_list[~np.in1d(lower_bin_list,bad_lower_bin)]
# elems in lower_bin_list not in bad_lower_bin

galmaglist = np.concatenate(galmaglist)

starmaglist = np.concatenate(starmaglist)

plt.errorbar(lower_bin_list+bin_size/2, np.array(acclist)*100, xerr=bin_size/2, fmt=" ",color="black",label="Bin")
plt.errorbar(lower_bin_list+bin_size/2, np.array(acclist)*100, yerr=0.01*100,fmt=".",color="red",label="Accuracy")
# plt.errorbar(lower_bin_list+bin_size/2, f1list, yerr=0.01,label="F1 Score")
plt.legend()
plt.title("Star-Galaxy")
plt.xlabel("r magnitude bins")
plt.ylabel("Accuracy Score (%)")
# plt.ylim(93, 100)
# os.path.join(out_dir, "EX1_SG_MargNet_results.csv")
plt.savefig(os.path.join(out_dir, "EX2_SG_MargNet_v2.png"))

# %%
subdfs = pd.concat(subdflist)
subdfs["r"]=subdfs["dered_r"]+subdfs["extinction_r"]

gal_recall_list = []
gal_precision_list = []
star_recall_list = []
star_precision_list = []
for r in reportlist:
    gal_recall_list.append(r["GALAXY"]["recall"])
    gal_precision_list.append(r["GALAXY"]["precision"])
    star_recall_list.append(r["STAR"]["recall"])
    star_precision_list.append(r["STAR"]["precision"])
    
    
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1,sharex=True, figsize=(8,18))

galcolor = sns.color_palette("tab10")[1]
starcolor = sns.color_palette("tab10")[2]
acccolor = sns.color_palette("tab10")[3]
f1color = sns.color_palette("tab10")[4]

dyfit = 0.01
x_ax = lower_bin_list+bin_size/2


d1 = subdfs[subdfs["class"]=="GALAXY"]["r"]
d2 = subdfs[subdfs["class"]=="STAR"]["r"]

ax1.hist([d1, d2], color=[galcolor,starcolor],
         alpha=0.8, label=["GALAXY","STAR"],bins=len(lower_bin_list))
ax1.set_ylabel("Count")

ax1.legend()


y_ax1 = np.array(gal_precision_list)
y_ax2 = np.array(star_precision_list)

ax2.errorbar(x_ax, y_ax1*100,fmt="-o", ms=4, label="Galaxy Precision",color=galcolor)
ax2.fill_between(x_ax, y_ax1*100 - dyfit*100, y_ax1*100 + dyfit*100,
             color=sns.color_palette("pastel")[1], alpha=0.3)
ax2.errorbar(x_ax, y_ax2*100,fmt="-o", ms=4, label="Star Precision",color=starcolor)
ax2.fill_between(x_ax, y_ax2*100 - dyfit*100, y_ax2*100 + dyfit*100,
                 color=sns.color_palette("pastel")[2], alpha=0.3)
ax2.set_ylabel("Precision (%)")
ax2.legend()



y_ax1 = np.array(gal_recall_list)
y_ax2 = np.array(star_recall_list)

ax3.errorbar(x_ax, y_ax1*100,fmt="-o", ms=4, label="Galaxy Recall",color=galcolor)
ax3.fill_between(x_ax, y_ax1*100 - dyfit*100, y_ax1*100 + dyfit*100,
             color=sns.color_palette("pastel")[1], alpha=0.3)
ax3.errorbar(x_ax, y_ax2*100,fmt="-o", ms=4, label="Star Recall",color=starcolor)
ax3.fill_between(x_ax, y_ax2*100 - dyfit*100, y_ax2*100 + dyfit*100,
             color=sns.color_palette("pastel")[2], alpha=0.3)
ax3.set_ylabel("Recall (%)")
ax3.legend()



y_ax1 = np.array(acclist)
y_ax2 = np.array(f1list)
ax4.errorbar(x_ax, y_ax1*100,fmt="-o", ms=4, label="Accuracy",color=acccolor)
# ax4.errorbar(x_ax, y_ax2*100,fmt="-o", ms=4, label="F1 Score",color=f1color)
ax4.fill_between(x_ax, y_ax1*100 - dyfit*100, y_ax1*100 + dyfit*100,
             color=sns.color_palette("pastel")[3], alpha=0.3)
ax4.set_ylabel("Accuracy Score (%)")
ax4.legend()

plt.xlabel("r magnitude bins")


# plt.suptitle("Star-Galaxy")
plt.savefig(os.path.join(out_dir, "EX2_SG_MargNet_v2Set.png")) 
plt.show()
