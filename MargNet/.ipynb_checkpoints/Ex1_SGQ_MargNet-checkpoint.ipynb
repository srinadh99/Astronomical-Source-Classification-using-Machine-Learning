# %% [markdown]
# ## MargNet - Experiment1 - Star-Galaxy-Quasar Classification
#
# ## Star-Galaxy-Quasar Classification (Experiment 1) using MargNet. Stacked ensemble of ANN (for Photometric features), and CNN (for images).

# %% [markdown]
# #### Import libraries

# %%
import warnings
warnings.filterwarnings("ignore")

import os
import numpy as np
np.random.seed(69)
import pandas as pd
import random
import matplotlib.pyplot as plt
import matplotlib.image as img
import seaborn as sns
sns.set()
# from tqdm.notebook 
import tqdm
from sklearn import metrics
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import time
import pickle

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader

# %%
out_dir = "/scratch/srinadb/Foundation/Trained_Models/MargNet/Experiment1/SGQ/"
os.makedirs(out_dir, exist_ok=True)

# %% [markdown]
# #### 1. Load and extract the dataset

# %%
X = np.load("/scratch/srinadb/Foundation/Dataset/Experiment1/X_exp1.npy")
dnnx = np.load("/scratch/srinadb/Foundation//Dataset/Experiment1/dnnx_exp1.npy")
objlist = np.load("/scratch/srinadb/Foundation//Dataset/Experiment1/objlist_exp1.npy")
y = np.load("/scratch/srinadb/Foundation//Dataset/Experiment1/y_exp1.npy", allow_pickle=True)

# idx_drop = np.where(y=="QSO")[0]
# X = np.delete(X,idx_drop,axis=0)
# dnnx = np.delete(dnnx,idx_drop,axis=0)
# y = np.delete(y,idx_drop,axis=0)
# objlist = np.delete(objlist,idx_drop,axis=0)
y, label_strings = pd.factorize(y,sort=True)
# y = to_categorical(y)
print('\n')
print(label_strings)
# Out:
# ['GALAXY' 'QSO' 'STAR']

# %%
zipX = list(zip(X, dnnx))
zipy = list(zip(y, objlist))

zipX_train, zipX_test, zipy_train, zipy_test = train_test_split(zipX, zipy, test_size = 0.125,random_state=42)
zipX_train, zipX_val, zipy_train, zipy_val = train_test_split(zipX_train, zipy_train, test_size = 0.1428, random_state=42)

X_train, dnnx_train = zip(*zipX_train)
X_val, dnnx_val = zip(*zipX_val)
X_test, dnnx_test = zip(*zipX_test)

y_train, objlist_train = zip(*zipy_train)
y_val, objlist_val = zip(*zipy_val)
y_test, objlist_test = zip(*zipy_test)

X_train = np.array(X_train)
X_val = np.array(X_val)
X_test = np.array(X_test)

dnnx_train = np.array(dnnx_train)
dnnx_val = np.array(dnnx_val)
dnnx_test = np.array(dnnx_test)

y_train = np.array(y_train)
objlist_train = np.array(objlist_train)
y_val = np.array(y_val)
objlist_val = np.array(objlist_val)
y_test = np.array(y_test)
objlist_test = np.array(objlist_test)

del(zipX,zipX_test,zipX_train,zipX_val, X, zipy, zipy_test, zipy_train, zipy_val, objlist)

X_train = X_train.transpose((0, 3, 1, 2))
X_val = X_val.transpose((0, 3, 1, 2))
X_test = X_test.transpose((0, 3, 1, 2))


print('The shape of the Train data is:', dnnx_train.shape)
print('The shape of the Validation data is:', dnnx_val.shape)
print('The shape of the Test data is:', dnnx_test.shape)
print('\n')
print('The shape of the Train data is:', X_train.shape)
print('The shape of the Validation data is:', X_val.shape)
print('The shape of the Test data is:', X_test.shape)
# Out:
# The shape of the Train data is: (180011, 24)
# The shape of the Validation data is: (29988, 24)
# The shape of the Test data is: (30000, 24)
#
#
# The shape of the Train data is: (180011, 5, 32, 32)
# The shape of the Validation data is: (29988, 5, 32, 32)
# The shape of the Test data is: (30000, 5, 32, 32)

# %%
def get_metrics(y_pred, y_test, labels, to_print=True):
    correct_labels = np.where(y_pred==y_test)[0]
    accuracy = metrics.accuracy_score(y_test, y_pred)
    precision = metrics.precision_score(y_test, y_pred,average='macro')
    recall = metrics.recall_score(y_test, y_pred,average='macro')
    f1score = metrics.f1_score(y_test, y_pred,average='macro')
    # rocscore = metrics.roc_auc_score(y_test, y_pred,average='micro',multi_class="ovo")
    confusion_matrix = metrics.confusion_matrix(y_test, y_pred)  
    classification_report = metrics.classification_report(y_test, y_pred)

    if to_print:
        print("Identified {} correct labels out of {} labels".format(len(correct_labels), y_test.shape[0]))
        print("Accuracy:",accuracy)
        print("Precision:",precision)
        print("Recall:",recall)
        print("F1 Score:",f1score)
        # print("ROC AUC Score:",rocscore)
        print(f"Labels are: {labels}")
        print("Confusion Matrix:\n", confusion_matrix)
        print("Classification_Report:\n", classification_report)

    return (correct_labels, accuracy, precision, recall, confusion_matrix, classification_report)

# %% [markdown]
# ### 1. ANN Model using Photometric Features

# %% [markdown]
# ##### Create dataset and dataloader for pytorch training

# %%
class SGQData_pf(Dataset):
    def __init__(self, x, y, transform=None):
        self.n_samples = x.shape[0]
        self.x = torch.tensor(x, dtype=torch.float32)
        self.y = torch.tensor(y)
        self.transform = transform

    def __len__(self):
        return self.n_samples

    def __getitem__(self, i):
        inputs, targets = self.x[i], self.y[i]

        if self.transform:
            inputs = self.transform(inputs)

        return inputs, targets

# Create DataLoader for training and validation data
pf_train_dataset = SGQData_pf(dnnx_train, y_train, transform=None)
pf_train_loader = DataLoader(pf_train_dataset, batch_size=2048, shuffle=True, num_workers=8)
pf_val_dataset = SGQData_pf(dnnx_val, y_val, transform=None)
pf_val_loader = DataLoader(pf_val_dataset, batch_size=2048, shuffle=False, num_workers=4)
pf_test_dataset = SGQData_pf(dnnx_test, y_test)
pf_test_loader = DataLoader(pf_test_dataset, batch_size=2048, shuffle=False)

# %% [markdown]
# #### Initialize or Define the Model

# %%
# Define the custom PyTorch model

class DNNModel(nn.Module):
    def __init__(self, input_dim, n_classes):
        super(DNNModel, self).__init__()
        self.fc1 = nn.Linear(input_dim, 1024)
        self.dropout1 = nn.Dropout(0.25)
        # self.activation = torch.nn.sigmoid()
        self.fc2 = nn.Linear(1024, 256)
        self.dropout2 = nn.Dropout(0.25)
        self.fc3 = nn.Linear(256, 128)
        self.dropout3 = nn.Dropout(0.25)
        self.fc4 = nn.Linear(128, 64)
        self.dropout4 = nn.Dropout(0.25)
        self.fc5 = nn.Linear(64, 32)
        self.dropout5 = nn.Dropout(0.25)
        self.fc6 = nn.Linear(32, n_classes)        

    def forward(self, x):
        x = torch.sigmoid(self.fc1(x))
        x = self.dropout1(x)
        x = torch.sigmoid(self.fc2(x))
        x = self.dropout2(x)
        x = torch.sigmoid(self.fc3(x))
        x = self.dropout3(x)
        x = torch.sigmoid(self.fc4(x))
        x = self.dropout4(x)
        x = torch.sigmoid(self.fc5(x))
        x = self.dropout5(x)
        x = self.fc6(x)
        return x

# Initialize the PyTorch model
pf_input_dim = dnnx_train.shape[1]
n_classes = 3
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
pf_model = DNNModel(pf_input_dim, n_classes).to(device)
# Out:
# cuda:0

# %% [markdown]
# #### Training the model

# %%
train_loss_arr = []
train_accuracy_arr = []
val_loss_arr = []
val_accuracy_arr = []

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(pf_model.parameters())

# Early stopping parameters
patience = 100
best_val_loss = float('inf')
best_model_state = None  # Initialize a variable to store the best model state
counter = 0

# Training loop
epochs = 4000
epoch1 =0

for epoch in range(epochs):
    epoch1+=1
    pf_model.train()
    train_loss = 0.0
    correct_train = 0
    total_train = 0
    for batch_x, batch_y in pf_train_loader:
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)
        optimizer.zero_grad()
        output = pf_model(batch_x)
        loss = criterion(output, batch_y)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = output.max(1)
        total_train += batch_y.size(0)
        correct_train += predicted.eq(batch_y).sum().item()

    train_loss /= len(pf_train_loader)
    train_accuracy = correct_train / total_train
    train_loss_arr.append(train_loss)
    train_accuracy_arr.append(train_accuracy)
    
    pf_model.eval()
    
    val_loss = 0.0
    correct_val = 0
    total_val = 0
    with torch.no_grad():
        for batch_x, batch_y in pf_val_loader:
            batch_x = batch_x.to(device)
            batch_y = batch_y.to(device)
            output = pf_model(batch_x)
            val_loss += criterion(output, batch_y).item()
            _, predicted = output.max(1)
            total_val += batch_y.size(0)
            correct_val += predicted.eq(batch_y).sum().item()

    val_loss /= len(pf_val_loader)
    val_accuracy = correct_val / total_val
    val_loss_arr.append(val_loss)
    val_accuracy_arr.append(val_accuracy)
    
    pf_model.train()
        
    #Check for early stopping and save best model state
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        counter = 0
        best_model_state = pf_model.state_dict()  # Store the current best model state
        torch.save(best_model_state, os.path.join(out_dir, 'EX1_SGQ_MargNet_DNN_Model.pth'))
    else:
        counter += 1

    if counter >= patience:
        print(f'Early stopping at epoch {epoch+1}')
        if best_model_state is not None:
            pf_model.load_state_dict(best_model_state)  # Restore best model state
        counter = 0  # Reset the counter    
        break

    print(f'Epoch [{epoch+1}/{epochs}] - '
      f'Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, '
      f'Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}')

# Create the range of epochs
epoch_range = range(1, epoch1+1)
    
# Plot training accuracy in blue
plt.figsize=(8, 6)  # Adjust the size as needed
plt.plot(epoch_range, train_accuracy_arr, label='Train Accuracy', color='blue')

# Plot validation accuracy in red
plt.plot(epoch_range, val_accuracy_arr, label='Validation Accuracy', color='red')

# Add labels and title
plt.xlabel('Epoch', fontsize=14, weight='bold')
plt.ylabel('Accuracy', fontsize=14, weight='bold')
plt.title('Model Accuracy', fontsize=14, weight='bold')

# Add a legend
plt.legend(fontsize=14, title_fontproperties={'weight':'bold'})
plt.savefig(os.path.join(out_dir, "EX1_SGQ_MargNet_DNN_Accuracy.png"))

# Show the plot
plt.show()
plt.close()

# Plot training accuracy in blue
plt.figsize=(8, 6)  # Adjust the size as needed
plt.plot(epoch_range, train_loss_arr, label='Train Loss', color='blue')

# Plot validation accuracy in red
plt.plot(epoch_range, val_loss_arr, label='Validation Loss', color='red')

# Add labels and title
plt.xlabel('Epoch', fontsize=14, weight='bold')
plt.ylabel('Loss', fontsize=14, weight='bold')
plt.title('Model Loss', fontsize=14, weight='bold')

# Add a legend
plt.legend(fontsize=14, title_fontproperties={'weight':'bold'})
plt.savefig(os.path.join(out_dir, "EX1_SGQ_MargNet_DNN_Loss.png"))

# Show the plot
plt.show()
plt.close()
# Out:
# Epoch [1/4000] - Train Loss: 1.0549, Train Accuracy: 0.4171, Validation Loss: 0.8815, Validation Accuracy: 0.5865
# Epoch [2/4000] - Train Loss: 0.7986, Train Accuracy: 0.5897, Validation Loss: 0.6760, Validation Accuracy: 0.5962
# Epoch [3/4000] - Train Loss: 0.6782, Train Accuracy: 0.6436, Validation Loss: 0.6130, Validation Accuracy: 0.7344
# Epoch [4/4000] - Train Loss: 0.6017, Train Accuracy: 0.7508, Validation Loss: 0.5103, Validation Accuracy: 0.8163
# Epoch [5/4000] - Train Loss: 0.5402, Train Accuracy: 0.7932, Validation Loss: 0.4859, Validation Accuracy: 0.8202
# Epoch [6/4000] - Train Loss: 0.5060, Train Accuracy: 0.8143, Validation Loss: 0.4383, Validation Accuracy: 0.8460
# Epoch [7/4000] - Train Loss: 0.4765, Train Accuracy: 0.8323, Validation Loss: 0.4087, Validation Accuracy: 0.8615
# Epoch [8/4000] - Train Loss: 0.4507, Train Accuracy: 0.8446, Validation Loss: 0.3885, Validation Accuracy: 0.8654
# Epoch [9/4000] - Train Loss: 0.4324, Train Accuracy: 0.8505, Validation Loss: 0.3770, Validation Accuracy: 0.8659
# Epoch [10/4000] - Train Loss: 0.4120, Train Accuracy: 0.8562, Validation Loss: 0.3534, Validation Accuracy: 0.8743
# Epoch [11/4000] - Train Loss: 0.3991, Train Accuracy: 0.8583, Validation Loss: 0.3457, Validation Accuracy: 0.8761
# Epoch [12/4000] - Train Loss: 0.3901, Train Accuracy: 0.8594, Validation Loss: 0.3399, Validation Accuracy: 0.8752
# Epoch [13/4000] - Train Loss: 0.3807, Train Accuracy: 0.8613, Validation Loss: 0.3344, Validation Accuracy: 0.8776
# Epoch [14/4000] - Train Loss: 0.3738, Train Accuracy: 0.8626, Validation Loss: 0.3271, Validation Accuracy: 0.8780
# Epoch [15/4000] - Train Loss: 0.3661, Train Accuracy: 0.8655, Validation Loss: 0.3228, Validation Accuracy: 0.8800
# Epoch [16/4000] - Train Loss: 0.3613, Train Accuracy: 0.8663, Validation Loss: 0.3146, Validation Accuracy: 0.8809
# Epoch [17/4000] - Train Loss: 0.3549, Train Accuracy: 0.8685, Validation Loss: 0.3108, Validation Accuracy: 0.8823
# Epoch [18/4000] - Train Loss: 0.3501, Train Accuracy: 0.8706, Validation Loss: 0.3098, Validation Accuracy: 0.8840
# Epoch [19/4000] - Train Loss: 0.3476, Train Accuracy: 0.8695, Validation Loss: 0.3097, Validation Accuracy: 0.8823
# Epoch [20/4000] - Train Loss: 0.3439, Train Accuracy: 0.8718, Validation Loss: 0.3011, Validation Accuracy: 0.8859
# Epoch [21/4000] - Train Loss: 0.3357, Train Accuracy: 0.8739, Validation Loss: 0.2964, Validation Accuracy: 0.8877
# Epoch [22/4000] - Train Loss: 0.3330, Train Accuracy: 0.8752, Validation Loss: 0.2920, Validation Accuracy: 0.8867
# Epoch [23/4000] - Train Loss: 0.3306, Train Accuracy: 0.8763, Validation Loss: 0.2955, Validation Accuracy: 0.8863
# Epoch [24/4000] - Train Loss: 0.3293, Train Accuracy: 0.8761, Validation Loss: 0.2892, Validation Accuracy: 0.8891
# Epoch [25/4000] - Train Loss: 0.3250, Train Accuracy: 0.8781, Validation Loss: 0.2847, Validation Accuracy: 0.8892
# Epoch [26/4000] - Train Loss: 0.3215, Train Accuracy: 0.8785, Validation Loss: 0.2838, Validation Accuracy: 0.8891
# Epoch [27/4000] - Train Loss: 0.3193, Train Accuracy: 0.8804, Validation Loss: 0.2848, Validation Accuracy: 0.8891
# Epoch [28/4000] - Train Loss: 0.3185, Train Accuracy: 0.8801, Validation Loss: 0.2810, Validation Accuracy: 0.8913
# Epoch [29/4000] - Train Loss: 0.3151, Train Accuracy: 0.8815, Validation Loss: 0.2772, Validation Accuracy: 0.8912
# Epoch [30/4000] - Train Loss: 0.3133, Train Accuracy: 0.8812, Validation Loss: 0.2772, Validation Accuracy: 0.8924
# Epoch [31/4000] - Train Loss: 0.3105, Train Accuracy: 0.8827, Validation Loss: 0.2718, Validation Accuracy: 0.8937
# Epoch [32/4000] - Train Loss: 0.3083, Train Accuracy: 0.8833, Validation Loss: 0.2710, Validation Accuracy: 0.8940
# Epoch [33/4000] - Train Loss: 0.3072, Train Accuracy: 0.8836, Validation Loss: 0.2701, Validation Accuracy: 0.8941
# Epoch [34/4000] - Train Loss: 0.3046, Train Accuracy: 0.8844, Validation Loss: 0.2677, Validation Accuracy: 0.8954
# Epoch [35/4000] - Train Loss: 0.3036, Train Accuracy: 0.8851, Validation Loss: 0.2652, Validation Accuracy: 0.8956
# Epoch [36/4000] - Train Loss: 0.3007, Train Accuracy: 0.8853, Validation Loss: 0.2632, Validation Accuracy: 0.8955
# Epoch [37/4000] - Train Loss: 0.2984, Train Accuracy: 0.8864, Validation Loss: 0.2659, Validation Accuracy: 0.8949
# Epoch [38/4000] - Train Loss: 0.2981, Train Accuracy: 0.8872, Validation Loss: 0.2621, Validation Accuracy: 0.8959
# Epoch [39/4000] - Train Loss: 0.2967, Train Accuracy: 0.8867, Validation Loss: 0.2621, Validation Accuracy: 0.8964
# Epoch [40/4000] - Train Loss: 0.2939, Train Accuracy: 0.8877, Validation Loss: 0.2601, Validation Accuracy: 0.8981
# Epoch [41/4000] - Train Loss: 0.2944, Train Accuracy: 0.8878, Validation Loss: 0.2707, Validation Accuracy: 0.8917
# Epoch [42/4000] - Train Loss: 0.2931, Train Accuracy: 0.8879, Validation Loss: 0.2595, Validation Accuracy: 0.8991
# Epoch [43/4000] - Train Loss: 0.2901, Train Accuracy: 0.8887, Validation Loss: 0.2562, Validation Accuracy: 0.8989
# Epoch [44/4000] - Train Loss: 0.2898, Train Accuracy: 0.8885, Validation Loss: 0.2569, Validation Accuracy: 0.8976
# Epoch [45/4000] - Train Loss: 0.2881, Train Accuracy: 0.8894, Validation Loss: 0.2522, Validation Accuracy: 0.8994
# Epoch [46/4000] - Train Loss: 0.2860, Train Accuracy: 0.8904, Validation Loss: 0.2488, Validation Accuracy: 0.9002
# Epoch [47/4000] - Train Loss: 0.2837, Train Accuracy: 0.8905, Validation Loss: 0.2500, Validation Accuracy: 0.9002
# Epoch [48/4000] - Train Loss: 0.2834, Train Accuracy: 0.8907, Validation Loss: 0.2479, Validation Accuracy: 0.9001
# Epoch [49/4000] - Train Loss: 0.2815, Train Accuracy: 0.8913, Validation Loss: 0.2497, Validation Accuracy: 0.9002
# Epoch [50/4000] - Train Loss: 0.2802, Train Accuracy: 0.8925, Validation Loss: 0.2457, Validation Accuracy: 0.9012
# Epoch [51/4000] - Train Loss: 0.2796, Train Accuracy: 0.8926, Validation Loss: 0.2445, Validation Accuracy: 0.9021
# Epoch [52/4000] - Train Loss: 0.2788, Train Accuracy: 0.8926, Validation Loss: 0.2445, Validation Accuracy: 0.9012
# Epoch [53/4000] - Train Loss: 0.2772, Train Accuracy: 0.8931, Validation Loss: 0.2431, Validation Accuracy: 0.9020
# Epoch [54/4000] - Train Loss: 0.2752, Train Accuracy: 0.8943, Validation Loss: 0.2427, Validation Accuracy: 0.9025
# Epoch [55/4000] - Train Loss: 0.2738, Train Accuracy: 0.8946, Validation Loss: 0.2410, Validation Accuracy: 0.9027
# Epoch [56/4000] - Train Loss: 0.2736, Train Accuracy: 0.8952, Validation Loss: 0.2413, Validation Accuracy: 0.9027
# Epoch [57/4000] - Train Loss: 0.2733, Train Accuracy: 0.8947, Validation Loss: 0.2424, Validation Accuracy: 0.9020
# Epoch [58/4000] - Train Loss: 0.2725, Train Accuracy: 0.8948, Validation Loss: 0.2383, Validation Accuracy: 0.9045
# Epoch [59/4000] - Train Loss: 0.2707, Train Accuracy: 0.8965, Validation Loss: 0.2379, Validation Accuracy: 0.9043
# Epoch [60/4000] - Train Loss: 0.2699, Train Accuracy: 0.8958, Validation Loss: 0.2409, Validation Accuracy: 0.9025
# Epoch [61/4000] - Train Loss: 0.2705, Train Accuracy: 0.8959, Validation Loss: 0.2360, Validation Accuracy: 0.9054
# Epoch [62/4000] - Train Loss: 0.2680, Train Accuracy: 0.8970, Validation Loss: 0.2338, Validation Accuracy: 0.9069
# Epoch [63/4000] - Train Loss: 0.2680, Train Accuracy: 0.8967, Validation Loss: 0.2424, Validation Accuracy: 0.9028
# Epoch [64/4000] - Train Loss: 0.2682, Train Accuracy: 0.8974, Validation Loss: 0.2335, Validation Accuracy: 0.9071
# Epoch [65/4000] - Train Loss: 0.2649, Train Accuracy: 0.8979, Validation Loss: 0.2344, Validation Accuracy: 0.9072
# Epoch [66/4000] - Train Loss: 0.2646, Train Accuracy: 0.8982, Validation Loss: 0.2342, Validation Accuracy: 0.9066
# Epoch [67/4000] - Train Loss: 0.2640, Train Accuracy: 0.8989, Validation Loss: 0.2332, Validation Accuracy: 0.9068
# Epoch [68/4000] - Train Loss: 0.2645, Train Accuracy: 0.8979, Validation Loss: 0.2325, Validation Accuracy: 0.9081
# Epoch [69/4000] - Train Loss: 0.2610, Train Accuracy: 0.9004, Validation Loss: 0.2363, Validation Accuracy: 0.9050
# Epoch [70/4000] - Train Loss: 0.2624, Train Accuracy: 0.8993, Validation Loss: 0.2311, Validation Accuracy: 0.9087
# Epoch [71/4000] - Train Loss: 0.2590, Train Accuracy: 0.9005, Validation Loss: 0.2311, Validation Accuracy: 0.9077
# Epoch [72/4000] - Train Loss: 0.2600, Train Accuracy: 0.9005, Validation Loss: 0.2278, Validation Accuracy: 0.9097
# Epoch [73/4000] - Train Loss: 0.2587, Train Accuracy: 0.9003, Validation Loss: 0.2290, Validation Accuracy: 0.9102
# Epoch [74/4000] - Train Loss: 0.2580, Train Accuracy: 0.9010, Validation Loss: 0.2277, Validation Accuracy: 0.9099
# Epoch [75/4000] - Train Loss: 0.2571, Train Accuracy: 0.9013, Validation Loss: 0.2276, Validation Accuracy: 0.9103
# Epoch [76/4000] - Train Loss: 0.2549, Train Accuracy: 0.9019, Validation Loss: 0.2247, Validation Accuracy: 0.9107
# Epoch [77/4000] - Train Loss: 0.2554, Train Accuracy: 0.9023, Validation Loss: 0.2250, Validation Accuracy: 0.9111
# Epoch [78/4000] - Train Loss: 0.2540, Train Accuracy: 0.9025, Validation Loss: 0.2257, Validation Accuracy: 0.9106
# Epoch [79/4000] - Train Loss: 0.2556, Train Accuracy: 0.9017, Validation Loss: 0.2271, Validation Accuracy: 0.9080
# Epoch [80/4000] - Train Loss: 0.2526, Train Accuracy: 0.9027, Validation Loss: 0.2242, Validation Accuracy: 0.9119
# Epoch [81/4000] - Train Loss: 0.2539, Train Accuracy: 0.9028, Validation Loss: 0.2236, Validation Accuracy: 0.9120
# Epoch [82/4000] - Train Loss: 0.2533, Train Accuracy: 0.9028, Validation Loss: 0.2250, Validation Accuracy: 0.9117
# Epoch [83/4000] - Train Loss: 0.2535, Train Accuracy: 0.9026, Validation Loss: 0.2222, Validation Accuracy: 0.9114
# Epoch [84/4000] - Train Loss: 0.2516, Train Accuracy: 0.9035, Validation Loss: 0.2235, Validation Accuracy: 0.9113
# Epoch [85/4000] - Train Loss: 0.2520, Train Accuracy: 0.9038, Validation Loss: 0.2230, Validation Accuracy: 0.9126
# Epoch [86/4000] - Train Loss: 0.2512, Train Accuracy: 0.9037, Validation Loss: 0.2226, Validation Accuracy: 0.9124
# Epoch [87/4000] - Train Loss: 0.2495, Train Accuracy: 0.9042, Validation Loss: 0.2223, Validation Accuracy: 0.9117
# Epoch [88/4000] - Train Loss: 0.2496, Train Accuracy: 0.9038, Validation Loss: 0.2207, Validation Accuracy: 0.9129
# Epoch [89/4000] - Train Loss: 0.2501, Train Accuracy: 0.9038, Validation Loss: 0.2254, Validation Accuracy: 0.9106
# Epoch [90/4000] - Train Loss: 0.2484, Train Accuracy: 0.9044, Validation Loss: 0.2204, Validation Accuracy: 0.9131
# Epoch [91/4000] - Train Loss: 0.2492, Train Accuracy: 0.9050, Validation Loss: 0.2215, Validation Accuracy: 0.9117
# Epoch [92/4000] - Train Loss: 0.2470, Train Accuracy: 0.9052, Validation Loss: 0.2187, Validation Accuracy: 0.9134
# Epoch [93/4000] - Train Loss: 0.2460, Train Accuracy: 0.9051, Validation Loss: 0.2183, Validation Accuracy: 0.9142
# Epoch [94/4000] - Train Loss: 0.2464, Train Accuracy: 0.9050, Validation Loss: 0.2195, Validation Accuracy: 0.9143
# Epoch [95/4000] - Train Loss: 0.2464, Train Accuracy: 0.9061, Validation Loss: 0.2190, Validation Accuracy: 0.9121
# Epoch [96/4000] - Train Loss: 0.2438, Train Accuracy: 0.9063, Validation Loss: 0.2214, Validation Accuracy: 0.9120
# Epoch [97/4000] - Train Loss: 0.2457, Train Accuracy: 0.9056, Validation Loss: 0.2182, Validation Accuracy: 0.9143
# Epoch [98/4000] - Train Loss: 0.2452, Train Accuracy: 0.9052, Validation Loss: 0.2174, Validation Accuracy: 0.9141
# Epoch [99/4000] - Train Loss: 0.2454, Train Accuracy: 0.9066, Validation Loss: 0.2177, Validation Accuracy: 0.9144
# Epoch [100/4000] - Train Loss: 0.2424, Train Accuracy: 0.9069, Validation Loss: 0.2148, Validation Accuracy: 0.9154
# Epoch [101/4000] - Train Loss: 0.2445, Train Accuracy: 0.9065, Validation Loss: 0.2155, Validation Accuracy: 0.9149
# Epoch [102/4000] - Train Loss: 0.2428, Train Accuracy: 0.9072, Validation Loss: 0.2144, Validation Accuracy: 0.9144
# Epoch [103/4000] - Train Loss: 0.2418, Train Accuracy: 0.9071, Validation Loss: 0.2161, Validation Accuracy: 0.9158
# Epoch [104/4000] - Train Loss: 0.2433, Train Accuracy: 0.9074, Validation Loss: 0.2137, Validation Accuracy: 0.9153
# Epoch [105/4000] - Train Loss: 0.2410, Train Accuracy: 0.9075, Validation Loss: 0.2144, Validation Accuracy: 0.9155
# Epoch [106/4000] - Train Loss: 0.2410, Train Accuracy: 0.9079, Validation Loss: 0.2136, Validation Accuracy: 0.9158
# Epoch [107/4000] - Train Loss: 0.2398, Train Accuracy: 0.9078, Validation Loss: 0.2141, Validation Accuracy: 0.9149
# Epoch [108/4000] - Train Loss: 0.2409, Train Accuracy: 0.9076, Validation Loss: 0.2137, Validation Accuracy: 0.9151
# Epoch [109/4000] - Train Loss: 0.2393, Train Accuracy: 0.9085, Validation Loss: 0.2128, Validation Accuracy: 0.9149
# Epoch [110/4000] - Train Loss: 0.2393, Train Accuracy: 0.9090, Validation Loss: 0.2124, Validation Accuracy: 0.9167
# Epoch [111/4000] - Train Loss: 0.2398, Train Accuracy: 0.9084, Validation Loss: 0.2117, Validation Accuracy: 0.9162
# Epoch [112/4000] - Train Loss: 0.2394, Train Accuracy: 0.9083, Validation Loss: 0.2111, Validation Accuracy: 0.9162
# Epoch [113/4000] - Train Loss: 0.2381, Train Accuracy: 0.9091, Validation Loss: 0.2124, Validation Accuracy: 0.9170
# Epoch [114/4000] - Train Loss: 0.2378, Train Accuracy: 0.9085, Validation Loss: 0.2134, Validation Accuracy: 0.9167
# Epoch [115/4000] - Train Loss: 0.2386, Train Accuracy: 0.9086, Validation Loss: 0.2096, Validation Accuracy: 0.9175
# Epoch [116/4000] - Train Loss: 0.2371, Train Accuracy: 0.9094, Validation Loss: 0.2104, Validation Accuracy: 0.9168
# Epoch [117/4000] - Train Loss: 0.2363, Train Accuracy: 0.9098, Validation Loss: 0.2106, Validation Accuracy: 0.9162
# Epoch [118/4000] - Train Loss: 0.2370, Train Accuracy: 0.9093, Validation Loss: 0.2105, Validation Accuracy: 0.9166
# Epoch [119/4000] - Train Loss: 0.2394, Train Accuracy: 0.9087, Validation Loss: 0.2107, Validation Accuracy: 0.9161
# Epoch [120/4000] - Train Loss: 0.2353, Train Accuracy: 0.9098, Validation Loss: 0.2098, Validation Accuracy: 0.9167
# Epoch [121/4000] - Train Loss: 0.2365, Train Accuracy: 0.9096, Validation Loss: 0.2116, Validation Accuracy: 0.9177
# Epoch [122/4000] - Train Loss: 0.2355, Train Accuracy: 0.9097, Validation Loss: 0.2108, Validation Accuracy: 0.9163
# Epoch [123/4000] - Train Loss: 0.2348, Train Accuracy: 0.9092, Validation Loss: 0.2115, Validation Accuracy: 0.9167
# Epoch [124/4000] - Train Loss: 0.2342, Train Accuracy: 0.9102, Validation Loss: 0.2087, Validation Accuracy: 0.9171
# Epoch [125/4000] - Train Loss: 0.2342, Train Accuracy: 0.9105, Validation Loss: 0.2077, Validation Accuracy: 0.9180
# Epoch [126/4000] - Train Loss: 0.2342, Train Accuracy: 0.9104, Validation Loss: 0.2086, Validation Accuracy: 0.9173
# Epoch [127/4000] - Train Loss: 0.2349, Train Accuracy: 0.9100, Validation Loss: 0.2209, Validation Accuracy: 0.9134
# Epoch [128/4000] - Train Loss: 0.2333, Train Accuracy: 0.9110, Validation Loss: 0.2104, Validation Accuracy: 0.9172
# Epoch [129/4000] - Train Loss: 0.2347, Train Accuracy: 0.9104, Validation Loss: 0.2072, Validation Accuracy: 0.9171
# Epoch [130/4000] - Train Loss: 0.2330, Train Accuracy: 0.9105, Validation Loss: 0.2072, Validation Accuracy: 0.9181
# Epoch [131/4000] - Train Loss: 0.2325, Train Accuracy: 0.9112, Validation Loss: 0.2070, Validation Accuracy: 0.9189
# Epoch [132/4000] - Train Loss: 0.2309, Train Accuracy: 0.9119, Validation Loss: 0.2099, Validation Accuracy: 0.9174
# Epoch [133/4000] - Train Loss: 0.2327, Train Accuracy: 0.9113, Validation Loss: 0.2108, Validation Accuracy: 0.9161
# Epoch [134/4000] - Train Loss: 0.2315, Train Accuracy: 0.9117, Validation Loss: 0.2057, Validation Accuracy: 0.9192
# Epoch [135/4000] - Train Loss: 0.2310, Train Accuracy: 0.9118, Validation Loss: 0.2103, Validation Accuracy: 0.9159
# Epoch [136/4000] - Train Loss: 0.2299, Train Accuracy: 0.9127, Validation Loss: 0.2112, Validation Accuracy: 0.9181
# Epoch [137/4000] - Train Loss: 0.2326, Train Accuracy: 0.9108, Validation Loss: 0.2061, Validation Accuracy: 0.9181
# Epoch [138/4000] - Train Loss: 0.2311, Train Accuracy: 0.9119, Validation Loss: 0.2053, Validation Accuracy: 0.9186
# Epoch [139/4000] - Train Loss: 0.2298, Train Accuracy: 0.9123, Validation Loss: 0.2049, Validation Accuracy: 0.9192
# Epoch [140/4000] - Train Loss: 0.2303, Train Accuracy: 0.9123, Validation Loss: 0.2089, Validation Accuracy: 0.9190
# Epoch [141/4000] - Train Loss: 0.2294, Train Accuracy: 0.9124, Validation Loss: 0.2071, Validation Accuracy: 0.9182
# Epoch [142/4000] - Train Loss: 0.2283, Train Accuracy: 0.9123, Validation Loss: 0.2064, Validation Accuracy: 0.9183
# Epoch [143/4000] - Train Loss: 0.2305, Train Accuracy: 0.9120, Validation Loss: 0.2093, Validation Accuracy: 0.9160
# Epoch [144/4000] - Train Loss: 0.2299, Train Accuracy: 0.9121, Validation Loss: 0.2054, Validation Accuracy: 0.9187
# Epoch [145/4000] - Train Loss: 0.2288, Train Accuracy: 0.9121, Validation Loss: 0.2091, Validation Accuracy: 0.9183
# Epoch [146/4000] - Train Loss: 0.2284, Train Accuracy: 0.9126, Validation Loss: 0.2032, Validation Accuracy: 0.9204
# Epoch [147/4000] - Train Loss: 0.2282, Train Accuracy: 0.9128, Validation Loss: 0.2051, Validation Accuracy: 0.9178
# Epoch [148/4000] - Train Loss: 0.2287, Train Accuracy: 0.9120, Validation Loss: 0.2029, Validation Accuracy: 0.9200
# Epoch [149/4000] - Train Loss: 0.2273, Train Accuracy: 0.9129, Validation Loss: 0.2036, Validation Accuracy: 0.9199
# Epoch [150/4000] - Train Loss: 0.2286, Train Accuracy: 0.9128, Validation Loss: 0.2043, Validation Accuracy: 0.9191
# Epoch [151/4000] - Train Loss: 0.2274, Train Accuracy: 0.9132, Validation Loss: 0.2017, Validation Accuracy: 0.9211
# Epoch [152/4000] - Train Loss: 0.2270, Train Accuracy: 0.9135, Validation Loss: 0.2033, Validation Accuracy: 0.9199
# Epoch [153/4000] - Train Loss: 0.2269, Train Accuracy: 0.9127, Validation Loss: 0.2024, Validation Accuracy: 0.9195
# Epoch [154/4000] - Train Loss: 0.2264, Train Accuracy: 0.9135, Validation Loss: 0.2038, Validation Accuracy: 0.9207
# Epoch [155/4000] - Train Loss: 0.2264, Train Accuracy: 0.9140, Validation Loss: 0.2025, Validation Accuracy: 0.9197
# Epoch [156/4000] - Train Loss: 0.2254, Train Accuracy: 0.9140, Validation Loss: 0.2059, Validation Accuracy: 0.9190
# Epoch [157/4000] - Train Loss: 0.2273, Train Accuracy: 0.9129, Validation Loss: 0.2027, Validation Accuracy: 0.9201
# Epoch [158/4000] - Train Loss: 0.2256, Train Accuracy: 0.9132, Validation Loss: 0.2031, Validation Accuracy: 0.9201
# Epoch [159/4000] - Train Loss: 0.2259, Train Accuracy: 0.9143, Validation Loss: 0.2027, Validation Accuracy: 0.9188
# Epoch [160/4000] - Train Loss: 0.2258, Train Accuracy: 0.9134, Validation Loss: 0.2038, Validation Accuracy: 0.9192
# Epoch [161/4000] - Train Loss: 0.2241, Train Accuracy: 0.9136, Validation Loss: 0.2031, Validation Accuracy: 0.9196
# Epoch [162/4000] - Train Loss: 0.2260, Train Accuracy: 0.9139, Validation Loss: 0.2015, Validation Accuracy: 0.9204
# Epoch [163/4000] - Train Loss: 0.2243, Train Accuracy: 0.9151, Validation Loss: 0.2011, Validation Accuracy: 0.9204
# Epoch [164/4000] - Train Loss: 0.2256, Train Accuracy: 0.9134, Validation Loss: 0.2000, Validation Accuracy: 0.9212
# Epoch [165/4000] - Train Loss: 0.2239, Train Accuracy: 0.9142, Validation Loss: 0.2015, Validation Accuracy: 0.9206
# Epoch [166/4000] - Train Loss: 0.2234, Train Accuracy: 0.9147, Validation Loss: 0.2018, Validation Accuracy: 0.9192
# Epoch [167/4000] - Train Loss: 0.2250, Train Accuracy: 0.9145, Validation Loss: 0.2060, Validation Accuracy: 0.9172
# Epoch [168/4000] - Train Loss: 0.2233, Train Accuracy: 0.9150, Validation Loss: 0.2015, Validation Accuracy: 0.9209
# Epoch [169/4000] - Train Loss: 0.2233, Train Accuracy: 0.9147, Validation Loss: 0.2002, Validation Accuracy: 0.9223
# Epoch [170/4000] - Train Loss: 0.2238, Train Accuracy: 0.9146, Validation Loss: 0.1997, Validation Accuracy: 0.9222
# Epoch [171/4000] - Train Loss: 0.2230, Train Accuracy: 0.9153, Validation Loss: 0.2046, Validation Accuracy: 0.9182
# Epoch [172/4000] - Train Loss: 0.2229, Train Accuracy: 0.9146, Validation Loss: 0.2006, Validation Accuracy: 0.9203
# Epoch [173/4000] - Train Loss: 0.2232, Train Accuracy: 0.9148, Validation Loss: 0.2004, Validation Accuracy: 0.9212
# Epoch [174/4000] - Train Loss: 0.2224, Train Accuracy: 0.9148, Validation Loss: 0.1991, Validation Accuracy: 0.9220
# Epoch [175/4000] - Train Loss: 0.2230, Train Accuracy: 0.9146, Validation Loss: 0.1998, Validation Accuracy: 0.9211
# Epoch [176/4000] - Train Loss: 0.2229, Train Accuracy: 0.9148, Validation Loss: 0.2023, Validation Accuracy: 0.9207
# Epoch [177/4000] - Train Loss: 0.2225, Train Accuracy: 0.9152, Validation Loss: 0.2009, Validation Accuracy: 0.9206
# Epoch [178/4000] - Train Loss: 0.2224, Train Accuracy: 0.9151, Validation Loss: 0.1999, Validation Accuracy: 0.9219
# Epoch [179/4000] - Train Loss: 0.2218, Train Accuracy: 0.9155, Validation Loss: 0.2006, Validation Accuracy: 0.9210
# Epoch [180/4000] - Train Loss: 0.2211, Train Accuracy: 0.9157, Validation Loss: 0.1997, Validation Accuracy: 0.9209
# Epoch [181/4000] - Train Loss: 0.2222, Train Accuracy: 0.9153, Validation Loss: 0.2007, Validation Accuracy: 0.9203
# Epoch [182/4000] - Train Loss: 0.2223, Train Accuracy: 0.9148, Validation Loss: 0.2000, Validation Accuracy: 0.9208
# Epoch [183/4000] - Train Loss: 0.2217, Train Accuracy: 0.9160, Validation Loss: 0.1993, Validation Accuracy: 0.9216
# Epoch [184/4000] - Train Loss: 0.2228, Train Accuracy: 0.9147, Validation Loss: 0.2034, Validation Accuracy: 0.9168
# Epoch [185/4000] - Train Loss: 0.2210, Train Accuracy: 0.9148, Validation Loss: 0.1978, Validation Accuracy: 0.9221
# Epoch [186/4000] - Train Loss: 0.2197, Train Accuracy: 0.9163, Validation Loss: 0.1982, Validation Accuracy: 0.9223
# Epoch [187/4000] - Train Loss: 0.2201, Train Accuracy: 0.9158, Validation Loss: 0.1979, Validation Accuracy: 0.9213
# Epoch [188/4000] - Train Loss: 0.2199, Train Accuracy: 0.9161, Validation Loss: 0.1991, Validation Accuracy: 0.9220
# Epoch [189/4000] - Train Loss: 0.2205, Train Accuracy: 0.9160, Validation Loss: 0.2049, Validation Accuracy: 0.9200
# Epoch [190/4000] - Train Loss: 0.2197, Train Accuracy: 0.9156, Validation Loss: 0.1982, Validation Accuracy: 0.9219
# Epoch [191/4000] - Train Loss: 0.2193, Train Accuracy: 0.9164, Validation Loss: 0.2067, Validation Accuracy: 0.9170
# Epoch [192/4000] - Train Loss: 0.2202, Train Accuracy: 0.9150, Validation Loss: 0.1987, Validation Accuracy: 0.9212
# Epoch [193/4000] - Train Loss: 0.2201, Train Accuracy: 0.9158, Validation Loss: 0.1983, Validation Accuracy: 0.9220
# Epoch [194/4000] - Train Loss: 0.2194, Train Accuracy: 0.9159, Validation Loss: 0.1978, Validation Accuracy: 0.9208
# Epoch [195/4000] - Train Loss: 0.2190, Train Accuracy: 0.9160, Validation Loss: 0.1995, Validation Accuracy: 0.9214
# Epoch [196/4000] - Train Loss: 0.2187, Train Accuracy: 0.9161, Validation Loss: 0.1979, Validation Accuracy: 0.9215
# Epoch [197/4000] - Train Loss: 0.2194, Train Accuracy: 0.9163, Validation Loss: 0.1998, Validation Accuracy: 0.9208
# Epoch [198/4000] - Train Loss: 0.2174, Train Accuracy: 0.9160, Validation Loss: 0.1980, Validation Accuracy: 0.9217
# Epoch [199/4000] - Train Loss: 0.2183, Train Accuracy: 0.9164, Validation Loss: 0.1971, Validation Accuracy: 0.9233
# Epoch [200/4000] - Train Loss: 0.2174, Train Accuracy: 0.9168, Validation Loss: 0.1969, Validation Accuracy: 0.9219
# Epoch [201/4000] - Train Loss: 0.2169, Train Accuracy: 0.9172, Validation Loss: 0.1981, Validation Accuracy: 0.9222
# Epoch [202/4000] - Train Loss: 0.2187, Train Accuracy: 0.9163, Validation Loss: 0.1962, Validation Accuracy: 0.9231
# Epoch [203/4000] - Train Loss: 0.2171, Train Accuracy: 0.9171, Validation Loss: 0.1986, Validation Accuracy: 0.9219
# Epoch [204/4000] - Train Loss: 0.2170, Train Accuracy: 0.9164, Validation Loss: 0.1968, Validation Accuracy: 0.9234
# Epoch [205/4000] - Train Loss: 0.2184, Train Accuracy: 0.9165, Validation Loss: 0.1995, Validation Accuracy: 0.9219
# Epoch [206/4000] - Train Loss: 0.2172, Train Accuracy: 0.9167, Validation Loss: 0.1983, Validation Accuracy: 0.9220
# Epoch [207/4000] - Train Loss: 0.2181, Train Accuracy: 0.9162, Validation Loss: 0.1965, Validation Accuracy: 0.9224
# Epoch [208/4000] - Train Loss: 0.2192, Train Accuracy: 0.9160, Validation Loss: 0.1998, Validation Accuracy: 0.9212
# Epoch [209/4000] - Train Loss: 0.2173, Train Accuracy: 0.9163, Validation Loss: 0.1977, Validation Accuracy: 0.9226
# Epoch [210/4000] - Train Loss: 0.2166, Train Accuracy: 0.9173, Validation Loss: 0.1971, Validation Accuracy: 0.9221
# Epoch [211/4000] - Train Loss: 0.2164, Train Accuracy: 0.9175, Validation Loss: 0.1958, Validation Accuracy: 0.9229
# Epoch [212/4000] - Train Loss: 0.2183, Train Accuracy: 0.9169, Validation Loss: 0.1979, Validation Accuracy: 0.9211
# Epoch [213/4000] - Train Loss: 0.2175, Train Accuracy: 0.9172, Validation Loss: 0.1975, Validation Accuracy: 0.9220
# Epoch [214/4000] - Train Loss: 0.2171, Train Accuracy: 0.9164, Validation Loss: 0.1952, Validation Accuracy: 0.9228
# Epoch [215/4000] - Train Loss: 0.2156, Train Accuracy: 0.9172, Validation Loss: 0.1968, Validation Accuracy: 0.9220
# Epoch [216/4000] - Train Loss: 0.2156, Train Accuracy: 0.9172, Validation Loss: 0.1965, Validation Accuracy: 0.9233
# Epoch [217/4000] - Train Loss: 0.2160, Train Accuracy: 0.9171, Validation Loss: 0.1973, Validation Accuracy: 0.9237
# Epoch [218/4000] - Train Loss: 0.2162, Train Accuracy: 0.9174, Validation Loss: 0.1957, Validation Accuracy: 0.9242
# Epoch [219/4000] - Train Loss: 0.2168, Train Accuracy: 0.9177, Validation Loss: 0.1965, Validation Accuracy: 0.9219
# Epoch [220/4000] - Train Loss: 0.2163, Train Accuracy: 0.9176, Validation Loss: 0.1969, Validation Accuracy: 0.9226
# Epoch [221/4000] - Train Loss: 0.2163, Train Accuracy: 0.9173, Validation Loss: 0.1983, Validation Accuracy: 0.9215
# Epoch [222/4000] - Train Loss: 0.2137, Train Accuracy: 0.9187, Validation Loss: 0.1952, Validation Accuracy: 0.9235
# Epoch [223/4000] - Train Loss: 0.2151, Train Accuracy: 0.9175, Validation Loss: 0.1960, Validation Accuracy: 0.9217
# Epoch [224/4000] - Train Loss: 0.2143, Train Accuracy: 0.9178, Validation Loss: 0.1948, Validation Accuracy: 0.9232
# Epoch [225/4000] - Train Loss: 0.2149, Train Accuracy: 0.9172, Validation Loss: 0.1962, Validation Accuracy: 0.9235
# Epoch [226/4000] - Train Loss: 0.2155, Train Accuracy: 0.9178, Validation Loss: 0.1946, Validation Accuracy: 0.9231
# Epoch [227/4000] - Train Loss: 0.2153, Train Accuracy: 0.9179, Validation Loss: 0.1946, Validation Accuracy: 0.9234
# Epoch [228/4000] - Train Loss: 0.2153, Train Accuracy: 0.9178, Validation Loss: 0.1958, Validation Accuracy: 0.9229
# Epoch [229/4000] - Train Loss: 0.2145, Train Accuracy: 0.9179, Validation Loss: 0.2016, Validation Accuracy: 0.9221
# Epoch [230/4000] - Train Loss: 0.2139, Train Accuracy: 0.9180, Validation Loss: 0.1944, Validation Accuracy: 0.9228
# Epoch [231/4000] - Train Loss: 0.2149, Train Accuracy: 0.9176, Validation Loss: 0.1963, Validation Accuracy: 0.9232
# Epoch [232/4000] - Train Loss: 0.2149, Train Accuracy: 0.9177, Validation Loss: 0.1957, Validation Accuracy: 0.9223
# Epoch [233/4000] - Train Loss: 0.2141, Train Accuracy: 0.9184, Validation Loss: 0.1978, Validation Accuracy: 0.9235
# Epoch [234/4000] - Train Loss: 0.2135, Train Accuracy: 0.9177, Validation Loss: 0.1953, Validation Accuracy: 0.9238
# Epoch [235/4000] - Train Loss: 0.2136, Train Accuracy: 0.9184, Validation Loss: 0.1949, Validation Accuracy: 0.9236
# Epoch [236/4000] - Train Loss: 0.2150, Train Accuracy: 0.9180, Validation Loss: 0.1948, Validation Accuracy: 0.9234
# Epoch [237/4000] - Train Loss: 0.2133, Train Accuracy: 0.9183, Validation Loss: 0.1946, Validation Accuracy: 0.9236
# Epoch [238/4000] - Train Loss: 0.2127, Train Accuracy: 0.9182, Validation Loss: 0.1933, Validation Accuracy: 0.9240
# Epoch [239/4000] - Train Loss: 0.2136, Train Accuracy: 0.9182, Validation Loss: 0.1946, Validation Accuracy: 0.9241
# Epoch [240/4000] - Train Loss: 0.2131, Train Accuracy: 0.9187, Validation Loss: 0.1973, Validation Accuracy: 0.9225
# Epoch [241/4000] - Train Loss: 0.2136, Train Accuracy: 0.9184, Validation Loss: 0.1956, Validation Accuracy: 0.9232
# Epoch [242/4000] - Train Loss: 0.2131, Train Accuracy: 0.9190, Validation Loss: 0.1932, Validation Accuracy: 0.9234
# Epoch [243/4000] - Train Loss: 0.2118, Train Accuracy: 0.9189, Validation Loss: 0.1930, Validation Accuracy: 0.9240
# Epoch [244/4000] - Train Loss: 0.2129, Train Accuracy: 0.9188, Validation Loss: 0.1960, Validation Accuracy: 0.9239
# Epoch [245/4000] - Train Loss: 0.2135, Train Accuracy: 0.9187, Validation Loss: 0.1939, Validation Accuracy: 0.9230
# Epoch [246/4000] - Train Loss: 0.2127, Train Accuracy: 0.9184, Validation Loss: 0.1941, Validation Accuracy: 0.9228
# Epoch [247/4000] - Train Loss: 0.2125, Train Accuracy: 0.9188, Validation Loss: 0.1933, Validation Accuracy: 0.9241
# Epoch [248/4000] - Train Loss: 0.2125, Train Accuracy: 0.9190, Validation Loss: 0.1950, Validation Accuracy: 0.9241
# Epoch [249/4000] - Train Loss: 0.2126, Train Accuracy: 0.9182, Validation Loss: 0.1956, Validation Accuracy: 0.9230
# Epoch [250/4000] - Train Loss: 0.2128, Train Accuracy: 0.9190, Validation Loss: 0.1938, Validation Accuracy: 0.9234
# Epoch [251/4000] - Train Loss: 0.2123, Train Accuracy: 0.9182, Validation Loss: 0.1941, Validation Accuracy: 0.9233
# Epoch [252/4000] - Train Loss: 0.2114, Train Accuracy: 0.9193, Validation Loss: 0.1934, Validation Accuracy: 0.9238
# Epoch [253/4000] - Train Loss: 0.2112, Train Accuracy: 0.9200, Validation Loss: 0.1934, Validation Accuracy: 0.9254
# Epoch [254/4000] - Train Loss: 0.2110, Train Accuracy: 0.9191, Validation Loss: 0.1943, Validation Accuracy: 0.9252
# Epoch [255/4000] - Train Loss: 0.2116, Train Accuracy: 0.9186, Validation Loss: 0.1954, Validation Accuracy: 0.9228
# Epoch [256/4000] - Train Loss: 0.2119, Train Accuracy: 0.9187, Validation Loss: 0.1935, Validation Accuracy: 0.9236
# Epoch [257/4000] - Train Loss: 0.2114, Train Accuracy: 0.9192, Validation Loss: 0.1934, Validation Accuracy: 0.9240
# Epoch [258/4000] - Train Loss: 0.2123, Train Accuracy: 0.9190, Validation Loss: 0.1926, Validation Accuracy: 0.9242
# Epoch [259/4000] - Train Loss: 0.2094, Train Accuracy: 0.9193, Validation Loss: 0.1919, Validation Accuracy: 0.9243
# Epoch [260/4000] - Train Loss: 0.2110, Train Accuracy: 0.9186, Validation Loss: 0.1957, Validation Accuracy: 0.9225
# Epoch [261/4000] - Train Loss: 0.2108, Train Accuracy: 0.9192, Validation Loss: 0.1926, Validation Accuracy: 0.9251
# Epoch [262/4000] - Train Loss: 0.2124, Train Accuracy: 0.9190, Validation Loss: 0.1929, Validation Accuracy: 0.9256
# Epoch [263/4000] - Train Loss: 0.2109, Train Accuracy: 0.9191, Validation Loss: 0.1932, Validation Accuracy: 0.9240
# Epoch [264/4000] - Train Loss: 0.2101, Train Accuracy: 0.9190, Validation Loss: 0.1936, Validation Accuracy: 0.9240
# Epoch [265/4000] - Train Loss: 0.2098, Train Accuracy: 0.9195, Validation Loss: 0.2027, Validation Accuracy: 0.9217
# Epoch [266/4000] - Train Loss: 0.2112, Train Accuracy: 0.9192, Validation Loss: 0.1936, Validation Accuracy: 0.9232
# Epoch [267/4000] - Train Loss: 0.2096, Train Accuracy: 0.9197, Validation Loss: 0.1916, Validation Accuracy: 0.9258
# Epoch [268/4000] - Train Loss: 0.2095, Train Accuracy: 0.9196, Validation Loss: 0.1936, Validation Accuracy: 0.9242
# Epoch [269/4000] - Train Loss: 0.2107, Train Accuracy: 0.9194, Validation Loss: 0.1948, Validation Accuracy: 0.9232
# Epoch [270/4000] - Train Loss: 0.2107, Train Accuracy: 0.9190, Validation Loss: 0.1994, Validation Accuracy: 0.9208
# Epoch [271/4000] - Train Loss: 0.2098, Train Accuracy: 0.9196, Validation Loss: 0.1933, Validation Accuracy: 0.9244
# Epoch [272/4000] - Train Loss: 0.2098, Train Accuracy: 0.9192, Validation Loss: 0.1933, Validation Accuracy: 0.9235
# Epoch [273/4000] - Train Loss: 0.2094, Train Accuracy: 0.9199, Validation Loss: 0.1911, Validation Accuracy: 0.9253
# Epoch [274/4000] - Train Loss: 0.2089, Train Accuracy: 0.9201, Validation Loss: 0.1925, Validation Accuracy: 0.9247
# Epoch [275/4000] - Train Loss: 0.2094, Train Accuracy: 0.9198, Validation Loss: 0.1964, Validation Accuracy: 0.9241
# Epoch [276/4000] - Train Loss: 0.2096, Train Accuracy: 0.9197, Validation Loss: 0.1930, Validation Accuracy: 0.9249
# Epoch [277/4000] - Train Loss: 0.2098, Train Accuracy: 0.9191, Validation Loss: 0.1928, Validation Accuracy: 0.9250
# Epoch [278/4000] - Train Loss: 0.2090, Train Accuracy: 0.9196, Validation Loss: 0.1953, Validation Accuracy: 0.9230
# Epoch [279/4000] - Train Loss: 0.2089, Train Accuracy: 0.9201, Validation Loss: 0.1924, Validation Accuracy: 0.9247
# Epoch [280/4000] - Train Loss: 0.2085, Train Accuracy: 0.9201, Validation Loss: 0.1921, Validation Accuracy: 0.9246
# Epoch [281/4000] - Train Loss: 0.2084, Train Accuracy: 0.9201, Validation Loss: 0.1942, Validation Accuracy: 0.9251
# Epoch [282/4000] - Train Loss: 0.2100, Train Accuracy: 0.9202, Validation Loss: 0.1923, Validation Accuracy: 0.9258
# Epoch [283/4000] - Train Loss: 0.2100, Train Accuracy: 0.9196, Validation Loss: 0.1964, Validation Accuracy: 0.9226
# Epoch [284/4000] - Train Loss: 0.2093, Train Accuracy: 0.9198, Validation Loss: 0.1927, Validation Accuracy: 0.9253
# Epoch [285/4000] - Train Loss: 0.2090, Train Accuracy: 0.9204, Validation Loss: 0.1932, Validation Accuracy: 0.9250
# Epoch [286/4000] - Train Loss: 0.2084, Train Accuracy: 0.9202, Validation Loss: 0.1913, Validation Accuracy: 0.9248
# Epoch [287/4000] - Train Loss: 0.2086, Train Accuracy: 0.9202, Validation Loss: 0.1961, Validation Accuracy: 0.9247
# Epoch [288/4000] - Train Loss: 0.2092, Train Accuracy: 0.9198, Validation Loss: 0.1922, Validation Accuracy: 0.9259
# Epoch [289/4000] - Train Loss: 0.2075, Train Accuracy: 0.9208, Validation Loss: 0.1909, Validation Accuracy: 0.9256
# Epoch [290/4000] - Train Loss: 0.2079, Train Accuracy: 0.9207, Validation Loss: 0.1937, Validation Accuracy: 0.9251
# Epoch [291/4000] - Train Loss: 0.2074, Train Accuracy: 0.9200, Validation Loss: 0.1922, Validation Accuracy: 0.9265
# Epoch [292/4000] - Train Loss: 0.2079, Train Accuracy: 0.9196, Validation Loss: 0.1921, Validation Accuracy: 0.9251
# Epoch [293/4000] - Train Loss: 0.2080, Train Accuracy: 0.9205, Validation Loss: 0.1923, Validation Accuracy: 0.9243
# Epoch [294/4000] - Train Loss: 0.2072, Train Accuracy: 0.9207, Validation Loss: 0.1990, Validation Accuracy: 0.9213
# Epoch [295/4000] - Train Loss: 0.2078, Train Accuracy: 0.9200, Validation Loss: 0.1920, Validation Accuracy: 0.9257
# Epoch [296/4000] - Train Loss: 0.2074, Train Accuracy: 0.9198, Validation Loss: 0.1922, Validation Accuracy: 0.9254
# Epoch [297/4000] - Train Loss: 0.2068, Train Accuracy: 0.9201, Validation Loss: 0.1910, Validation Accuracy: 0.9255
# Epoch [298/4000] - Train Loss: 0.2078, Train Accuracy: 0.9211, Validation Loss: 0.1921, Validation Accuracy: 0.9258
# Epoch [299/4000] - Train Loss: 0.2052, Train Accuracy: 0.9216, Validation Loss: 0.1911, Validation Accuracy: 0.9263
# Epoch [300/4000] - Train Loss: 0.2068, Train Accuracy: 0.9203, Validation Loss: 0.1971, Validation Accuracy: 0.9211
# Epoch [301/4000] - Train Loss: 0.2076, Train Accuracy: 0.9206, Validation Loss: 0.1923, Validation Accuracy: 0.9259
# Epoch [302/4000] - Train Loss: 0.2069, Train Accuracy: 0.9211, Validation Loss: 0.1918, Validation Accuracy: 0.9249
# Epoch [303/4000] - Train Loss: 0.2076, Train Accuracy: 0.9204, Validation Loss: 0.1906, Validation Accuracy: 0.9266
# Epoch [304/4000] - Train Loss: 0.2075, Train Accuracy: 0.9204, Validation Loss: 0.1930, Validation Accuracy: 0.9256
# Epoch [305/4000] - Train Loss: 0.2071, Train Accuracy: 0.9205, Validation Loss: 0.1913, Validation Accuracy: 0.9250
# Epoch [306/4000] - Train Loss: 0.2071, Train Accuracy: 0.9205, Validation Loss: 0.1932, Validation Accuracy: 0.9255
# Epoch [307/4000] - Train Loss: 0.2075, Train Accuracy: 0.9201, Validation Loss: 0.1919, Validation Accuracy: 0.9259
# Epoch [308/4000] - Train Loss: 0.2075, Train Accuracy: 0.9205, Validation Loss: 0.1917, Validation Accuracy: 0.9244
# Epoch [309/4000] - Train Loss: 0.2063, Train Accuracy: 0.9213, Validation Loss: 0.1910, Validation Accuracy: 0.9268
# Epoch [310/4000] - Train Loss: 0.2057, Train Accuracy: 0.9208, Validation Loss: 0.1908, Validation Accuracy: 0.9249
# Epoch [311/4000] - Train Loss: 0.2059, Train Accuracy: 0.9211, Validation Loss: 0.1924, Validation Accuracy: 0.9246
# Epoch [312/4000] - Train Loss: 0.2063, Train Accuracy: 0.9214, Validation Loss: 0.1892, Validation Accuracy: 0.9270
# Epoch [313/4000] - Train Loss: 0.2060, Train Accuracy: 0.9212, Validation Loss: 0.1900, Validation Accuracy: 0.9253
# Epoch [314/4000] - Train Loss: 0.2064, Train Accuracy: 0.9215, Validation Loss: 0.1907, Validation Accuracy: 0.9251
# Epoch [315/4000] - Train Loss: 0.2055, Train Accuracy: 0.9213, Validation Loss: 0.1889, Validation Accuracy: 0.9265
# Epoch [316/4000] - Train Loss: 0.2057, Train Accuracy: 0.9208, Validation Loss: 0.1923, Validation Accuracy: 0.9260
# Epoch [317/4000] - Train Loss: 0.2052, Train Accuracy: 0.9211, Validation Loss: 0.1903, Validation Accuracy: 0.9254
# Epoch [318/4000] - Train Loss: 0.2047, Train Accuracy: 0.9213, Validation Loss: 0.1919, Validation Accuracy: 0.9257
# Epoch [319/4000] - Train Loss: 0.2057, Train Accuracy: 0.9212, Validation Loss: 0.1915, Validation Accuracy: 0.9259
# Epoch [320/4000] - Train Loss: 0.2056, Train Accuracy: 0.9214, Validation Loss: 0.1922, Validation Accuracy: 0.9260
# Epoch [321/4000] - Train Loss: 0.2059, Train Accuracy: 0.9212, Validation Loss: 0.1922, Validation Accuracy: 0.9252
# Epoch [322/4000] - Train Loss: 0.2058, Train Accuracy: 0.9210, Validation Loss: 0.1908, Validation Accuracy: 0.9255
# Epoch [323/4000] - Train Loss: 0.2045, Train Accuracy: 0.9219, Validation Loss: 0.1904, Validation Accuracy: 0.9262
# Epoch [324/4000] - Train Loss: 0.2048, Train Accuracy: 0.9216, Validation Loss: 0.1912, Validation Accuracy: 0.9261
# Epoch [325/4000] - Train Loss: 0.2056, Train Accuracy: 0.9206, Validation Loss: 0.1906, Validation Accuracy: 0.9262
# Epoch [326/4000] - Train Loss: 0.2051, Train Accuracy: 0.9220, Validation Loss: 0.1898, Validation Accuracy: 0.9257
# Epoch [327/4000] - Train Loss: 0.2052, Train Accuracy: 0.9213, Validation Loss: 0.1902, Validation Accuracy: 0.9265
# Epoch [328/4000] - Train Loss: 0.2053, Train Accuracy: 0.9213, Validation Loss: 0.1912, Validation Accuracy: 0.9260
# Epoch [329/4000] - Train Loss: 0.2051, Train Accuracy: 0.9219, Validation Loss: 0.1901, Validation Accuracy: 0.9257
# Epoch [330/4000] - Train Loss: 0.2045, Train Accuracy: 0.9217, Validation Loss: 0.1897, Validation Accuracy: 0.9262
# Epoch [331/4000] - Train Loss: 0.2040, Train Accuracy: 0.9210, Validation Loss: 0.1927, Validation Accuracy: 0.9248
# Epoch [332/4000] - Train Loss: 0.2055, Train Accuracy: 0.9205, Validation Loss: 0.1915, Validation Accuracy: 0.9264
# Epoch [333/4000] - Train Loss: 0.2057, Train Accuracy: 0.9209, Validation Loss: 0.1904, Validation Accuracy: 0.9263
# Epoch [334/4000] - Train Loss: 0.2049, Train Accuracy: 0.9218, Validation Loss: 0.1913, Validation Accuracy: 0.9259
# Epoch [335/4000] - Train Loss: 0.2042, Train Accuracy: 0.9216, Validation Loss: 0.1904, Validation Accuracy: 0.9267
# Epoch [336/4000] - Train Loss: 0.2049, Train Accuracy: 0.9214, Validation Loss: 0.1895, Validation Accuracy: 0.9260
# Epoch [337/4000] - Train Loss: 0.2039, Train Accuracy: 0.9223, Validation Loss: 0.1946, Validation Accuracy: 0.9258
# Epoch [338/4000] - Train Loss: 0.2044, Train Accuracy: 0.9212, Validation Loss: 0.1889, Validation Accuracy: 0.9264
# Epoch [339/4000] - Train Loss: 0.2050, Train Accuracy: 0.9216, Validation Loss: 0.1901, Validation Accuracy: 0.9261
# Epoch [340/4000] - Train Loss: 0.2037, Train Accuracy: 0.9223, Validation Loss: 0.1908, Validation Accuracy: 0.9263
# Epoch [341/4000] - Train Loss: 0.2044, Train Accuracy: 0.9215, Validation Loss: 0.1893, Validation Accuracy: 0.9265
# Epoch [342/4000] - Train Loss: 0.2052, Train Accuracy: 0.9213, Validation Loss: 0.1901, Validation Accuracy: 0.9268
# Epoch [343/4000] - Train Loss: 0.2047, Train Accuracy: 0.9217, Validation Loss: 0.1894, Validation Accuracy: 0.9265
# Epoch [344/4000] - Train Loss: 0.2025, Train Accuracy: 0.9222, Validation Loss: 0.1897, Validation Accuracy: 0.9267
# Epoch [345/4000] - Train Loss: 0.2033, Train Accuracy: 0.9223, Validation Loss: 0.1886, Validation Accuracy: 0.9269
# Epoch [346/4000] - Train Loss: 0.2025, Train Accuracy: 0.9222, Validation Loss: 0.1912, Validation Accuracy: 0.9248
# Epoch [347/4000] - Train Loss: 0.2030, Train Accuracy: 0.9223, Validation Loss: 0.1912, Validation Accuracy: 0.9265
# Epoch [348/4000] - Train Loss: 0.2041, Train Accuracy: 0.9220, Validation Loss: 0.1885, Validation Accuracy: 0.9271
# Epoch [349/4000] - Train Loss: 0.2032, Train Accuracy: 0.9215, Validation Loss: 0.1949, Validation Accuracy: 0.9255
# Epoch [350/4000] - Train Loss: 0.2043, Train Accuracy: 0.9218, Validation Loss: 0.1903, Validation Accuracy: 0.9267
# Epoch [351/4000] - Train Loss: 0.2025, Train Accuracy: 0.9220, Validation Loss: 0.1912, Validation Accuracy: 0.9262
# Epoch [352/4000] - Train Loss: 0.2039, Train Accuracy: 0.9215, Validation Loss: 0.1948, Validation Accuracy: 0.9234
# Epoch [353/4000] - Train Loss: 0.2036, Train Accuracy: 0.9222, Validation Loss: 0.1891, Validation Accuracy: 0.9276
# Epoch [354/4000] - Train Loss: 0.2015, Train Accuracy: 0.9232, Validation Loss: 0.1896, Validation Accuracy: 0.9265
# Epoch [355/4000] - Train Loss: 0.2018, Train Accuracy: 0.9224, Validation Loss: 0.1893, Validation Accuracy: 0.9269
# Epoch [356/4000] - Train Loss: 0.2025, Train Accuracy: 0.9224, Validation Loss: 0.1897, Validation Accuracy: 0.9270
# Epoch [357/4000] - Train Loss: 0.2015, Train Accuracy: 0.9224, Validation Loss: 0.1884, Validation Accuracy: 0.9273
# Epoch [358/4000] - Train Loss: 0.2032, Train Accuracy: 0.9221, Validation Loss: 0.1891, Validation Accuracy: 0.9272
# Epoch [359/4000] - Train Loss: 0.2018, Train Accuracy: 0.9223, Validation Loss: 0.1906, Validation Accuracy: 0.9265
# Epoch [360/4000] - Train Loss: 0.2021, Train Accuracy: 0.9226, Validation Loss: 0.1883, Validation Accuracy: 0.9273
# Epoch [361/4000] - Train Loss: 0.2019, Train Accuracy: 0.9226, Validation Loss: 0.1923, Validation Accuracy: 0.9248
# Epoch [362/4000] - Train Loss: 0.2040, Train Accuracy: 0.9214, Validation Loss: 0.1900, Validation Accuracy: 0.9258
# Epoch [363/4000] - Train Loss: 0.2020, Train Accuracy: 0.9219, Validation Loss: 0.1925, Validation Accuracy: 0.9256
# Epoch [364/4000] - Train Loss: 0.2035, Train Accuracy: 0.9221, Validation Loss: 0.1887, Validation Accuracy: 0.9266
# Epoch [365/4000] - Train Loss: 0.2024, Train Accuracy: 0.9221, Validation Loss: 0.1895, Validation Accuracy: 0.9268
# Epoch [366/4000] - Train Loss: 0.2026, Train Accuracy: 0.9228, Validation Loss: 0.1923, Validation Accuracy: 0.9254
# Epoch [367/4000] - Train Loss: 0.2021, Train Accuracy: 0.9219, Validation Loss: 0.1905, Validation Accuracy: 0.9264
# Epoch [368/4000] - Train Loss: 0.2029, Train Accuracy: 0.9224, Validation Loss: 0.1897, Validation Accuracy: 0.9271
# Epoch [369/4000] - Train Loss: 0.2024, Train Accuracy: 0.9227, Validation Loss: 0.1898, Validation Accuracy: 0.9283
# Epoch [370/4000] - Train Loss: 0.2010, Train Accuracy: 0.9231, Validation Loss: 0.1895, Validation Accuracy: 0.9267
# Epoch [371/4000] - Train Loss: 0.2009, Train Accuracy: 0.9231, Validation Loss: 0.1882, Validation Accuracy: 0.9268
# Epoch [372/4000] - Train Loss: 0.2019, Train Accuracy: 0.9226, Validation Loss: 0.1899, Validation Accuracy: 0.9268
# Epoch [373/4000] - Train Loss: 0.2012, Train Accuracy: 0.9225, Validation Loss: 0.1895, Validation Accuracy: 0.9266
# Epoch [374/4000] - Train Loss: 0.2015, Train Accuracy: 0.9227, Validation Loss: 0.1880, Validation Accuracy: 0.9274
# Epoch [375/4000] - Train Loss: 0.2006, Train Accuracy: 0.9230, Validation Loss: 0.1916, Validation Accuracy: 0.9263
# Epoch [376/4000] - Train Loss: 0.2020, Train Accuracy: 0.9224, Validation Loss: 0.1897, Validation Accuracy: 0.9257
# Epoch [377/4000] - Train Loss: 0.2015, Train Accuracy: 0.9225, Validation Loss: 0.1890, Validation Accuracy: 0.9270
# Epoch [378/4000] - Train Loss: 0.2013, Train Accuracy: 0.9223, Validation Loss: 0.1882, Validation Accuracy: 0.9269
# Epoch [379/4000] - Train Loss: 0.2009, Train Accuracy: 0.9229, Validation Loss: 0.1877, Validation Accuracy: 0.9273
# Epoch [380/4000] - Train Loss: 0.2007, Train Accuracy: 0.9230, Validation Loss: 0.1888, Validation Accuracy: 0.9259
# Epoch [381/4000] - Train Loss: 0.2003, Train Accuracy: 0.9231, Validation Loss: 0.1897, Validation Accuracy: 0.9258
# Epoch [382/4000] - Train Loss: 0.2007, Train Accuracy: 0.9232, Validation Loss: 0.1896, Validation Accuracy: 0.9262
# Epoch [383/4000] - Train Loss: 0.2004, Train Accuracy: 0.9230, Validation Loss: 0.1894, Validation Accuracy: 0.9265
# Epoch [384/4000] - Train Loss: 0.2009, Train Accuracy: 0.9233, Validation Loss: 0.1872, Validation Accuracy: 0.9284
# Epoch [385/4000] - Train Loss: 0.2000, Train Accuracy: 0.9237, Validation Loss: 0.1881, Validation Accuracy: 0.9269
# Epoch [386/4000] - Train Loss: 0.2017, Train Accuracy: 0.9227, Validation Loss: 0.1886, Validation Accuracy: 0.9265
# Epoch [387/4000] - Train Loss: 0.2009, Train Accuracy: 0.9227, Validation Loss: 0.1886, Validation Accuracy: 0.9274
# Epoch [388/4000] - Train Loss: 0.2003, Train Accuracy: 0.9232, Validation Loss: 0.1873, Validation Accuracy: 0.9276
# Epoch [389/4000] - Train Loss: 0.1993, Train Accuracy: 0.9232, Validation Loss: 0.1881, Validation Accuracy: 0.9281
# Epoch [390/4000] - Train Loss: 0.2002, Train Accuracy: 0.9235, Validation Loss: 0.1885, Validation Accuracy: 0.9276
# Epoch [391/4000] - Train Loss: 0.1999, Train Accuracy: 0.9231, Validation Loss: 0.1893, Validation Accuracy: 0.9279
# Epoch [392/4000] - Train Loss: 0.2007, Train Accuracy: 0.9229, Validation Loss: 0.1882, Validation Accuracy: 0.9274
# Epoch [393/4000] - Train Loss: 0.2003, Train Accuracy: 0.9234, Validation Loss: 0.1912, Validation Accuracy: 0.9256
# Epoch [394/4000] - Train Loss: 0.2012, Train Accuracy: 0.9226, Validation Loss: 0.1876, Validation Accuracy: 0.9275
# Epoch [395/4000] - Train Loss: 0.1991, Train Accuracy: 0.9232, Validation Loss: 0.1888, Validation Accuracy: 0.9272
# Epoch [396/4000] - Train Loss: 0.2001, Train Accuracy: 0.9234, Validation Loss: 0.1894, Validation Accuracy: 0.9258
# Epoch [397/4000] - Train Loss: 0.2001, Train Accuracy: 0.9228, Validation Loss: 0.1903, Validation Accuracy: 0.9272
# Epoch [398/4000] - Train Loss: 0.2003, Train Accuracy: 0.9230, Validation Loss: 0.1876, Validation Accuracy: 0.9275
# Epoch [399/4000] - Train Loss: 0.1996, Train Accuracy: 0.9232, Validation Loss: 0.1901, Validation Accuracy: 0.9276
# Epoch [400/4000] - Train Loss: 0.1998, Train Accuracy: 0.9232, Validation Loss: 0.1902, Validation Accuracy: 0.9263
# Epoch [401/4000] - Train Loss: 0.2000, Train Accuracy: 0.9237, Validation Loss: 0.1920, Validation Accuracy: 0.9271
# Epoch [402/4000] - Train Loss: 0.2008, Train Accuracy: 0.9227, Validation Loss: 0.1881, Validation Accuracy: 0.9278
# Epoch [403/4000] - Train Loss: 0.1984, Train Accuracy: 0.9231, Validation Loss: 0.1869, Validation Accuracy: 0.9287
# Epoch [404/4000] - Train Loss: 0.2002, Train Accuracy: 0.9234, Validation Loss: 0.1894, Validation Accuracy: 0.9270
# Epoch [405/4000] - Train Loss: 0.1999, Train Accuracy: 0.9230, Validation Loss: 0.1880, Validation Accuracy: 0.9276
# Epoch [406/4000] - Train Loss: 0.2002, Train Accuracy: 0.9229, Validation Loss: 0.1883, Validation Accuracy: 0.9278
# Epoch [407/4000] - Train Loss: 0.1996, Train Accuracy: 0.9234, Validation Loss: 0.1886, Validation Accuracy: 0.9261
# Epoch [408/4000] - Train Loss: 0.1995, Train Accuracy: 0.9234, Validation Loss: 0.1881, Validation Accuracy: 0.9273
# Epoch [409/4000] - Train Loss: 0.1993, Train Accuracy: 0.9232, Validation Loss: 0.1865, Validation Accuracy: 0.9282
# Epoch [410/4000] - Train Loss: 0.1998, Train Accuracy: 0.9231, Validation Loss: 0.1875, Validation Accuracy: 0.9278
# Epoch [411/4000] - Train Loss: 0.1994, Train Accuracy: 0.9230, Validation Loss: 0.1892, Validation Accuracy: 0.9272
# Epoch [412/4000] - Train Loss: 0.1985, Train Accuracy: 0.9239, Validation Loss: 0.1890, Validation Accuracy: 0.9264
# Epoch [413/4000] - Train Loss: 0.1987, Train Accuracy: 0.9235, Validation Loss: 0.1883, Validation Accuracy: 0.9275
# Epoch [414/4000] - Train Loss: 0.1994, Train Accuracy: 0.9230, Validation Loss: 0.1883, Validation Accuracy: 0.9270
# ...
# Epoch [514/4000] - Train Loss: 0.1933, Train Accuracy: 0.9253, Validation Loss: 0.1885, Validation Accuracy: 0.9282
# Epoch [515/4000] - Train Loss: 0.1943, Train Accuracy: 0.9248, Validation Loss: 0.1857, Validation Accuracy: 0.9294
# Epoch [516/4000] - Train Loss: 0.1938, Train Accuracy: 0.9255, Validation Loss: 0.1872, Validation Accuracy: 0.9294
# Epoch [517/4000] - Train Loss: 0.1932, Train Accuracy: 0.9258, Validation Loss: 0.1879, Validation Accuracy: 0.9291
# Epoch [518/4000] - Train Loss: 0.1945, Train Accuracy: 0.9249, Validation Loss: 0.1878, Validation Accuracy: 0.9277
# Epoch [519/4000] - Train Loss: 0.1937, Train Accuracy: 0.9257, Validation Loss: 0.1882, Validation Accuracy: 0.9278
# Epoch [520/4000] - Train Loss: 0.1925, Train Accuracy: 0.9262, Validation Loss: 0.1866, Validation Accuracy: 0.9290
# Epoch [521/4000] - Train Loss: 0.1933, Train Accuracy: 0.9260, Validation Loss: 0.1862, Validation Accuracy: 0.9288
# Epoch [522/4000] - Train Loss: 0.1930, Train Accuracy: 0.9256, Validation Loss: 0.1883, Validation Accuracy: 0.9270
# Epoch [523/4000] - Train Loss: 0.1935, Train Accuracy: 0.9255, Validation Loss: 0.1868, Validation Accuracy: 0.9282
# Epoch [524/4000] - Train Loss: 0.1938, Train Accuracy: 0.9258, Validation Loss: 0.1864, Validation Accuracy: 0.9283
# Epoch [525/4000] - Train Loss: 0.1923, Train Accuracy: 0.9261, Validation Loss: 0.1859, Validation Accuracy: 0.9286
# Epoch [526/4000] - Train Loss: 0.1926, Train Accuracy: 0.9260, Validation Loss: 0.1861, Validation Accuracy: 0.9287
# Epoch [527/4000] - Train Loss: 0.1929, Train Accuracy: 0.9255, Validation Loss: 0.1859, Validation Accuracy: 0.9291
# Epoch [528/4000] - Train Loss: 0.1921, Train Accuracy: 0.9260, Validation Loss: 0.1859, Validation Accuracy: 0.9289
# Epoch [529/4000] - Train Loss: 0.1924, Train Accuracy: 0.9253, Validation Loss: 0.1872, Validation Accuracy: 0.9279
# Epoch [530/4000] - Train Loss: 0.1928, Train Accuracy: 0.9254, Validation Loss: 0.1872, Validation Accuracy: 0.9279
# Epoch [531/4000] - Train Loss: 0.1921, Train Accuracy: 0.9258, Validation Loss: 0.1872, Validation Accuracy: 0.9278
# Epoch [532/4000] - Train Loss: 0.1930, Train Accuracy: 0.9256, Validation Loss: 0.1915, Validation Accuracy: 0.9260
# Epoch [533/4000] - Train Loss: 0.1931, Train Accuracy: 0.9254, Validation Loss: 0.1899, Validation Accuracy: 0.9261
# Epoch [534/4000] - Train Loss: 0.1917, Train Accuracy: 0.9263, Validation Loss: 0.1876, Validation Accuracy: 0.9288
# Epoch [535/4000] - Train Loss: 0.1944, Train Accuracy: 0.9256, Validation Loss: 0.1877, Validation Accuracy: 0.9275
# Epoch [536/4000] - Train Loss: 0.1936, Train Accuracy: 0.9255, Validation Loss: 0.1864, Validation Accuracy: 0.9283
# Epoch [537/4000] - Train Loss: 0.1932, Train Accuracy: 0.9256, Validation Loss: 0.1855, Validation Accuracy: 0.9289
# Epoch [538/4000] - Train Loss: 0.1932, Train Accuracy: 0.9255, Validation Loss: 0.1850, Validation Accuracy: 0.9285
# Epoch [539/4000] - Train Loss: 0.1917, Train Accuracy: 0.9267, Validation Loss: 0.1854, Validation Accuracy: 0.9281
# Epoch [540/4000] - Train Loss: 0.1924, Train Accuracy: 0.9258, Validation Loss: 0.1891, Validation Accuracy: 0.9271
# Epoch [541/4000] - Train Loss: 0.1910, Train Accuracy: 0.9261, Validation Loss: 0.1869, Validation Accuracy: 0.9281
# Epoch [542/4000] - Train Loss: 0.1925, Train Accuracy: 0.9258, Validation Loss: 0.1897, Validation Accuracy: 0.9259
# Epoch [543/4000] - Train Loss: 0.1926, Train Accuracy: 0.9267, Validation Loss: 0.1862, Validation Accuracy: 0.9277
# Epoch [544/4000] - Train Loss: 0.1931, Train Accuracy: 0.9257, Validation Loss: 0.1863, Validation Accuracy: 0.9279
# Epoch [545/4000] - Train Loss: 0.1920, Train Accuracy: 0.9262, Validation Loss: 0.1863, Validation Accuracy: 0.9291
# Epoch [546/4000] - Train Loss: 0.1911, Train Accuracy: 0.9260, Validation Loss: 0.1860, Validation Accuracy: 0.9289
# Epoch [547/4000] - Train Loss: 0.1926, Train Accuracy: 0.9258, Validation Loss: 0.1861, Validation Accuracy: 0.9287
# Epoch [548/4000] - Train Loss: 0.1916, Train Accuracy: 0.9260, Validation Loss: 0.1862, Validation Accuracy: 0.9284
# Epoch [549/4000] - Train Loss: 0.1920, Train Accuracy: 0.9261, Validation Loss: 0.1886, Validation Accuracy: 0.9267
# Epoch [550/4000] - Train Loss: 0.1923, Train Accuracy: 0.9263, Validation Loss: 0.1856, Validation Accuracy: 0.9287
# Epoch [551/4000] - Train Loss: 0.1925, Train Accuracy: 0.9257, Validation Loss: 0.1847, Validation Accuracy: 0.9289
# Epoch [552/4000] - Train Loss: 0.1910, Train Accuracy: 0.9259, Validation Loss: 0.1854, Validation Accuracy: 0.9288
# Epoch [553/4000] - Train Loss: 0.1913, Train Accuracy: 0.9258, Validation Loss: 0.1874, Validation Accuracy: 0.9284
# Epoch [554/4000] - Train Loss: 0.1919, Train Accuracy: 0.9261, Validation Loss: 0.1867, Validation Accuracy: 0.9279
# Epoch [555/4000] - Train Loss: 0.1911, Train Accuracy: 0.9258, Validation Loss: 0.1853, Validation Accuracy: 0.9288
# Epoch [556/4000] - Train Loss: 0.1923, Train Accuracy: 0.9264, Validation Loss: 0.1867, Validation Accuracy: 0.9291
# Epoch [557/4000] - Train Loss: 0.1929, Train Accuracy: 0.9250, Validation Loss: 0.1854, Validation Accuracy: 0.9287
# Epoch [558/4000] - Train Loss: 0.1920, Train Accuracy: 0.9255, Validation Loss: 0.1855, Validation Accuracy: 0.9287
# Epoch [559/4000] - Train Loss: 0.1908, Train Accuracy: 0.9266, Validation Loss: 0.1867, Validation Accuracy: 0.9287
# Epoch [560/4000] - Train Loss: 0.1910, Train Accuracy: 0.9261, Validation Loss: 0.1874, Validation Accuracy: 0.9276
# Epoch [561/4000] - Train Loss: 0.1924, Train Accuracy: 0.9260, Validation Loss: 0.1878, Validation Accuracy: 0.9290
# Epoch [562/4000] - Train Loss: 0.1908, Train Accuracy: 0.9264, Validation Loss: 0.1862, Validation Accuracy: 0.9288
# Epoch [563/4000] - Train Loss: 0.1922, Train Accuracy: 0.9259, Validation Loss: 0.1863, Validation Accuracy: 0.9291
# Epoch [564/4000] - Train Loss: 0.1911, Train Accuracy: 0.9266, Validation Loss: 0.1863, Validation Accuracy: 0.9288
# Epoch [565/4000] - Train Loss: 0.1904, Train Accuracy: 0.9263, Validation Loss: 0.1862, Validation Accuracy: 0.9290
# Epoch [566/4000] - Train Loss: 0.1920, Train Accuracy: 0.9255, Validation Loss: 0.1873, Validation Accuracy: 0.9275
# Epoch [567/4000] - Train Loss: 0.1910, Train Accuracy: 0.9269, Validation Loss: 0.1865, Validation Accuracy: 0.9291
# Epoch [568/4000] - Train Loss: 0.1915, Train Accuracy: 0.9264, Validation Loss: 0.1858, Validation Accuracy: 0.9290
# Epoch [569/4000] - Train Loss: 0.1891, Train Accuracy: 0.9270, Validation Loss: 0.1877, Validation Accuracy: 0.9277
# Epoch [570/4000] - Train Loss: 0.1908, Train Accuracy: 0.9261, Validation Loss: 0.1859, Validation Accuracy: 0.9285
# Epoch [571/4000] - Train Loss: 0.1913, Train Accuracy: 0.9268, Validation Loss: 0.1862, Validation Accuracy: 0.9287
# Epoch [572/4000] - Train Loss: 0.1903, Train Accuracy: 0.9265, Validation Loss: 0.1891, Validation Accuracy: 0.9281
# Epoch [573/4000] - Train Loss: 0.1919, Train Accuracy: 0.9259, Validation Loss: 0.1859, Validation Accuracy: 0.9292
# Epoch [574/4000] - Train Loss: 0.1914, Train Accuracy: 0.9266, Validation Loss: 0.1883, Validation Accuracy: 0.9272
# Epoch [575/4000] - Train Loss: 0.1899, Train Accuracy: 0.9265, Validation Loss: 0.1888, Validation Accuracy: 0.9267
# Epoch [576/4000] - Train Loss: 0.1910, Train Accuracy: 0.9264, Validation Loss: 0.1858, Validation Accuracy: 0.9282
# Epoch [577/4000] - Train Loss: 0.1908, Train Accuracy: 0.9265, Validation Loss: 0.1870, Validation Accuracy: 0.9287
# Epoch [578/4000] - Train Loss: 0.1902, Train Accuracy: 0.9264, Validation Loss: 0.1864, Validation Accuracy: 0.9285
# Epoch [579/4000] - Train Loss: 0.1898, Train Accuracy: 0.9261, Validation Loss: 0.1872, Validation Accuracy: 0.9282
# Epoch [580/4000] - Train Loss: 0.1903, Train Accuracy: 0.9266, Validation Loss: 0.1860, Validation Accuracy: 0.9288
# Epoch [581/4000] - Train Loss: 0.1898, Train Accuracy: 0.9264, Validation Loss: 0.1877, Validation Accuracy: 0.9287
# Epoch [582/4000] - Train Loss: 0.1904, Train Accuracy: 0.9262, Validation Loss: 0.1861, Validation Accuracy: 0.9293
# Epoch [583/4000] - Train Loss: 0.1899, Train Accuracy: 0.9265, Validation Loss: 0.1875, Validation Accuracy: 0.9284
# Epoch [584/4000] - Train Loss: 0.1906, Train Accuracy: 0.9271, Validation Loss: 0.1885, Validation Accuracy: 0.9280
# Epoch [585/4000] - Train Loss: 0.1894, Train Accuracy: 0.9269, Validation Loss: 0.1870, Validation Accuracy: 0.9295
# Epoch [586/4000] - Train Loss: 0.1907, Train Accuracy: 0.9269, Validation Loss: 0.1862, Validation Accuracy: 0.9291
# Epoch [587/4000] - Train Loss: 0.1924, Train Accuracy: 0.9262, Validation Loss: 0.1875, Validation Accuracy: 0.9286
# Epoch [588/4000] - Train Loss: 0.1901, Train Accuracy: 0.9274, Validation Loss: 0.1872, Validation Accuracy: 0.9279
# Epoch [589/4000] - Train Loss: 0.1914, Train Accuracy: 0.9260, Validation Loss: 0.1856, Validation Accuracy: 0.9300
# Epoch [590/4000] - Train Loss: 0.1895, Train Accuracy: 0.9269, Validation Loss: 0.1850, Validation Accuracy: 0.9285
# Epoch [591/4000] - Train Loss: 0.1898, Train Accuracy: 0.9268, Validation Loss: 0.1850, Validation Accuracy: 0.9290
# Epoch [592/4000] - Train Loss: 0.1896, Train Accuracy: 0.9270, Validation Loss: 0.1871, Validation Accuracy: 0.9299
# Epoch [593/4000] - Train Loss: 0.1899, Train Accuracy: 0.9266, Validation Loss: 0.1867, Validation Accuracy: 0.9303
# Epoch [594/4000] - Train Loss: 0.1895, Train Accuracy: 0.9267, Validation Loss: 0.1858, Validation Accuracy: 0.9293
# Epoch [595/4000] - Train Loss: 0.1899, Train Accuracy: 0.9271, Validation Loss: 0.1855, Validation Accuracy: 0.9293
# Epoch [596/4000] - Train Loss: 0.1905, Train Accuracy: 0.9265, Validation Loss: 0.1862, Validation Accuracy: 0.9288
# Epoch [597/4000] - Train Loss: 0.1889, Train Accuracy: 0.9264, Validation Loss: 0.1861, Validation Accuracy: 0.9297
# Epoch [598/4000] - Train Loss: 0.1885, Train Accuracy: 0.9271, Validation Loss: 0.1860, Validation Accuracy: 0.9289
# Epoch [599/4000] - Train Loss: 0.1904, Train Accuracy: 0.9264, Validation Loss: 0.1861, Validation Accuracy: 0.9292
# Epoch [600/4000] - Train Loss: 0.1898, Train Accuracy: 0.9265, Validation Loss: 0.1886, Validation Accuracy: 0.9283
# Epoch [601/4000] - Train Loss: 0.1893, Train Accuracy: 0.9271, Validation Loss: 0.1894, Validation Accuracy: 0.9273
# Epoch [602/4000] - Train Loss: 0.1898, Train Accuracy: 0.9267, Validation Loss: 0.1853, Validation Accuracy: 0.9293
# Epoch [603/4000] - Train Loss: 0.1893, Train Accuracy: 0.9269, Validation Loss: 0.1884, Validation Accuracy: 0.9268
# Epoch [604/4000] - Train Loss: 0.1894, Train Accuracy: 0.9266, Validation Loss: 0.1876, Validation Accuracy: 0.9279
# Epoch [605/4000] - Train Loss: 0.1886, Train Accuracy: 0.9271, Validation Loss: 0.1867, Validation Accuracy: 0.9286
# Epoch [606/4000] - Train Loss: 0.1895, Train Accuracy: 0.9273, Validation Loss: 0.1867, Validation Accuracy: 0.9286
# Epoch [607/4000] - Train Loss: 0.1900, Train Accuracy: 0.9266, Validation Loss: 0.1873, Validation Accuracy: 0.9281
# Epoch [608/4000] - Train Loss: 0.1887, Train Accuracy: 0.9275, Validation Loss: 0.1876, Validation Accuracy: 0.9277
# Epoch [609/4000] - Train Loss: 0.1900, Train Accuracy: 0.9270, Validation Loss: 0.1861, Validation Accuracy: 0.9291
# Epoch [610/4000] - Train Loss: 0.1896, Train Accuracy: 0.9275, Validation Loss: 0.1883, Validation Accuracy: 0.9282
# Epoch [611/4000] - Train Loss: 0.1891, Train Accuracy: 0.9266, Validation Loss: 0.1863, Validation Accuracy: 0.9285
# Epoch [612/4000] - Train Loss: 0.1899, Train Accuracy: 0.9271, Validation Loss: 0.1871, Validation Accuracy: 0.9280
# Epoch [613/4000] - Train Loss: 0.1890, Train Accuracy: 0.9266, Validation Loss: 0.1856, Validation Accuracy: 0.9287
# Epoch [614/4000] - Train Loss: 0.1881, Train Accuracy: 0.9273, Validation Loss: 0.1853, Validation Accuracy: 0.9295
# Epoch [615/4000] - Train Loss: 0.1895, Train Accuracy: 0.9271, Validation Loss: 0.1864, Validation Accuracy: 0.9288
# Epoch [616/4000] - Train Loss: 0.1895, Train Accuracy: 0.9272, Validation Loss: 0.1862, Validation Accuracy: 0.9284
# Epoch [617/4000] - Train Loss: 0.1887, Train Accuracy: 0.9271, Validation Loss: 0.1887, Validation Accuracy: 0.9274
# Epoch [618/4000] - Train Loss: 0.1890, Train Accuracy: 0.9272, Validation Loss: 0.1866, Validation Accuracy: 0.9279
# Epoch [619/4000] - Train Loss: 0.1889, Train Accuracy: 0.9272, Validation Loss: 0.1879, Validation Accuracy: 0.9282
# Epoch [620/4000] - Train Loss: 0.1901, Train Accuracy: 0.9267, Validation Loss: 0.1861, Validation Accuracy: 0.9284
# Epoch [621/4000] - Train Loss: 0.1890, Train Accuracy: 0.9270, Validation Loss: 0.1862, Validation Accuracy: 0.9282
# Epoch [622/4000] - Train Loss: 0.1885, Train Accuracy: 0.9271, Validation Loss: 0.1884, Validation Accuracy: 0.9281
# Epoch [623/4000] - Train Loss: 0.1886, Train Accuracy: 0.9267, Validation Loss: 0.1854, Validation Accuracy: 0.9302
# Epoch [624/4000] - Train Loss: 0.1879, Train Accuracy: 0.9276, Validation Loss: 0.1872, Validation Accuracy: 0.9286
# Epoch [625/4000] - Train Loss: 0.1894, Train Accuracy: 0.9272, Validation Loss: 0.1851, Validation Accuracy: 0.9285
# Epoch [626/4000] - Train Loss: 0.1896, Train Accuracy: 0.9273, Validation Loss: 0.1872, Validation Accuracy: 0.9282
# Epoch [627/4000] - Train Loss: 0.1899, Train Accuracy: 0.9273, Validation Loss: 0.1864, Validation Accuracy: 0.9287
# Epoch [628/4000] - Train Loss: 0.1881, Train Accuracy: 0.9277, Validation Loss: 0.1877, Validation Accuracy: 0.9273
# Epoch [629/4000] - Train Loss: 0.1896, Train Accuracy: 0.9267, Validation Loss: 0.1866, Validation Accuracy: 0.9287
# Epoch [630/4000] - Train Loss: 0.1885, Train Accuracy: 0.9276, Validation Loss: 0.1855, Validation Accuracy: 0.9290
# Epoch [631/4000] - Train Loss: 0.1883, Train Accuracy: 0.9269, Validation Loss: 0.1859, Validation Accuracy: 0.9286
# Epoch [632/4000] - Train Loss: 0.1889, Train Accuracy: 0.9271, Validation Loss: 0.1861, Validation Accuracy: 0.9291
# Epoch [633/4000] - Train Loss: 0.1871, Train Accuracy: 0.9282, Validation Loss: 0.1892, Validation Accuracy: 0.9289
# Epoch [634/4000] - Train Loss: 0.1893, Train Accuracy: 0.9269, Validation Loss: 0.1862, Validation Accuracy: 0.9291
# Epoch [635/4000] - Train Loss: 0.1873, Train Accuracy: 0.9279, Validation Loss: 0.1858, Validation Accuracy: 0.9291
# Epoch [636/4000] - Train Loss: 0.1878, Train Accuracy: 0.9280, Validation Loss: 0.1860, Validation Accuracy: 0.9297
# Epoch [637/4000] - Train Loss: 0.1884, Train Accuracy: 0.9275, Validation Loss: 0.1870, Validation Accuracy: 0.9288
# Epoch [638/4000] - Train Loss: 0.1884, Train Accuracy: 0.9272, Validation Loss: 0.1865, Validation Accuracy: 0.9290
# Epoch [639/4000] - Train Loss: 0.1886, Train Accuracy: 0.9272, Validation Loss: 0.1865, Validation Accuracy: 0.9287
# Epoch [640/4000] - Train Loss: 0.1886, Train Accuracy: 0.9268, Validation Loss: 0.1868, Validation Accuracy: 0.9289
# Epoch [641/4000] - Train Loss: 0.1885, Train Accuracy: 0.9269, Validation Loss: 0.1877, Validation Accuracy: 0.9287
# Epoch [642/4000] - Train Loss: 0.1879, Train Accuracy: 0.9270, Validation Loss: 0.1853, Validation Accuracy: 0.9297
# Epoch [643/4000] - Train Loss: 0.1878, Train Accuracy: 0.9275, Validation Loss: 0.1873, Validation Accuracy: 0.9282
# Epoch [644/4000] - Train Loss: 0.1874, Train Accuracy: 0.9284, Validation Loss: 0.1897, Validation Accuracy: 0.9274
# Epoch [645/4000] - Train Loss: 0.1897, Train Accuracy: 0.9266, Validation Loss: 0.1872, Validation Accuracy: 0.9281
# Epoch [646/4000] - Train Loss: 0.1871, Train Accuracy: 0.9276, Validation Loss: 0.1885, Validation Accuracy: 0.9276
# Epoch [647/4000] - Train Loss: 0.1876, Train Accuracy: 0.9275, Validation Loss: 0.1860, Validation Accuracy: 0.9292
# Epoch [648/4000] - Train Loss: 0.1873, Train Accuracy: 0.9275, Validation Loss: 0.1863, Validation Accuracy: 0.9288
# Epoch [649/4000] - Train Loss: 0.1876, Train Accuracy: 0.9281, Validation Loss: 0.1857, Validation Accuracy: 0.9292
# Epoch [650/4000] - Train Loss: 0.1877, Train Accuracy: 0.9277, Validation Loss: 0.1867, Validation Accuracy: 0.9282
# Early stopping at epoch 651

# %% [markdown]
# #### Testing the Model

# %%
# Set the model to evaluation mode
pf_model.load_state_dict(torch.load(os.path.join(out_dir, "EX1_SGQ_MargNet_DNN_Model.pth"), map_location=device))
pf_model.eval()
y_test_pred = torch.empty(0).to(device)

# Generate predictions
with torch.no_grad():
    for feats, labels in pf_test_loader:
        feats = feats.to(device)
        labels = labels.to(device)
        pred = pf_model(feats)

        y_test_pred = torch.cat((y_test_pred, pred), dim=0)

y_test_pred = y_test_pred.cpu().numpy()
y_test_pred = y_test_pred.argmax(axis=1)
print(get_metrics(y_test_pred, y_test, label_strings))

# https://www.stackvidhya.com/plot-confusion-matrix-in-python-and-why/#google_vignette
# fig = plt.figure()
cf_matrix = metrics.confusion_matrix(y_test, y_test_pred)
cf_matrix_percentage = metrics.confusion_matrix(y_test, y_test_pred, normalize='true')
group_counts = ["{0:0.0f}".format(value) for value in cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_matrix_percentage.flatten()]
labels = [f"{v1}\n({v2})\n" for v1, v2 in
          zip(group_percentages,group_counts)]
labels = np.asarray(labels).reshape(3,3)
fig, ax = plt.subplots(figsize=(8, 6))  # Adjust the size as needed

ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
ax.set_xlabel('\nPredicted', fontsize=14, weight='bold')
ax.set_ylabel('Actual', fontsize=14, weight='bold');
ax.xaxis.set_ticklabels(['GALAXY', 'QSO', 'STAR'], fontsize=14, weight='bold')
ax.yaxis.set_ticklabels(['GALAXY', 'QSO', 'STAR'], fontsize=14, weight='bold')
plt.tight_layout()
plt.savefig(os.path.join(out_dir, "EX1_SGQ_MargNet_DNN_CM.png"))
plt.show()
plt.close()
# Out:
# Identified 27869 correct labels out of 30000 labels
# Accuracy: 0.9289666666666667
# Precision: 0.929702985839718
# Recall: 0.928943653741272
# F1 Score: 0.929119109749279
# Labels are: ['GALAXY' 'QSO' 'STAR']
# Confusion Matrix:
#  [[9485  389  146]
#  [ 303 9275  423]
#  [ 123  747 9109]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95     10020
#            1       0.89      0.93      0.91     10001
#            2       0.94      0.91      0.93      9979
#
#     accuracy                           0.93     30000
#    macro avg       0.93      0.93      0.93     30000
# weighted avg       0.93      0.93      0.93     30000
#
# (array([    0,     1,     2, ..., 29997, 29998, 29999]), 0.9289666666666667, 0.929702985839718, 0.928943653741272, array([[9485,  389,  146],
#        [ 303, 9275,  423],
#        [ 123,  747, 9109]]), '              precision    recall  f1-score   support\n\n           0       0.96      0.95      0.95     10020\n           1       0.89      0.93      0.91     10001\n           2       0.94      0.91      0.93      9979\n\n    accuracy                           0.93     30000\n   macro avg       0.93      0.93      0.93     30000\nweighted avg       0.93      0.93      0.93     30000\n')

# %% [markdown]
# ### 2. CNN Model using Images

# %% [markdown]
# ##### Create dataset and dataloader for pytorch training

# %%
class SGQData_image(Dataset):
    def __init__(self, x, y, transform=None):
        self.n_samples = x.shape[0]
        self.x = torch.tensor(x, dtype=torch.float32)
        self.y = torch.tensor(y)
        self.transform = transform

    def __len__(self):
        return self.n_samples

    def __getitem__(self, i):
        inputs, targets = self.x[i], self.y[i]
        
        if self.transform:
            inputs = self.transform(inputs)

        return inputs, targets

# Define your data augmentation transformations
image_transform = transforms.Compose([    
    transforms.RandomRotation(180),
    transforms.RandomAffine(degrees = 0, translate = (0.1, 0.1)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
])

# Create DataLoader for training and validation data
image_train_dataset = SGQData_image(X_train, y_train, transform=image_transform)
image_train_loader = DataLoader(image_train_dataset, batch_size=512, shuffle=True, num_workers=8)
image_val_dataset = SGQData_image(X_val, y_val, transform=image_transform)
image_val_loader = DataLoader(image_val_dataset, batch_size=512, shuffle=False, num_workers=4)
image_test_dataset = SGQData_image(X_test, y_test, transform=None)
image_test_loader = DataLoader(image_test_dataset, batch_size=512, shuffle=False, num_workers=4)

# %% [markdown]
# #### Initialize or Define the Model

# %%
# Initialize the PyTorch model
in_channels = X_train.shape[1]
image_ht = X_train.shape[2]
image_wt = X_train.shape[3]

class InceptionLikeNet(nn.Module):
    def __init__(self, in_channels, img_height, img_width, num_classes=2):
        super().__init__()
        self.relu = nn.ReLU(inplace=True)

        # First conv
        self.conv0 = nn.Conv2d(in_channels, 64, kernel_size=5, padding=2)

        # --- Block 1 ---
        self.b1_c1_1x1 = nn.Conv2d(64, 48, kernel_size=1)
        self.b1_c2_1x1 = nn.Conv2d(64, 48, kernel_size=1)
        self.b1_c3_1x1 = nn.Conv2d(64, 48, kernel_size=1)
        self.b1_c4_1x1 = nn.Conv2d(48, 64, kernel_size=1)
        self.b1_c5_3x3 = nn.Conv2d(48, 64, kernel_size=3, padding=1)
        self.b1_c6_5x5 = nn.Conv2d(48, 64, kernel_size=5, padding=2)

        # shared pools
        self.pool1x1 = nn.AvgPool2d(kernel_size=1, stride=1)  # like AveragePooling2D((1,1))
        self.pool2x2 = nn.AvgPool2d(kernel_size=2, stride=2)

        # --- Block 2 ---
        # input channels after block1 concat: 64+64+64+48 = 240
        self.b2_c7_1x1  = nn.Conv2d(240, 64, kernel_size=1)
        self.b2_c8_1x1  = nn.Conv2d(240, 64, kernel_size=1)
        self.b2_c9_1x1  = nn.Conv2d(240, 64, kernel_size=1)
        self.b2_c10_1x1 = nn.Conv2d(64, 92, kernel_size=1)
        self.b2_c11_3x3 = nn.Conv2d(64, 92, kernel_size=3, padding=1)
        self.b2_c12_5x5 = nn.Conv2d(64, 92, kernel_size=5, padding=2)
        # after concat: 92+92+92+64 = 340, then 2x2 avg pool

        # --- Block 3 ---
        self.b3_c13_1x1 = nn.Conv2d(340, 92, kernel_size=1)
        self.b3_c14_1x1 = nn.Conv2d(340, 92, kernel_size=1)
        self.b3_c15_1x1 = nn.Conv2d(340, 92, kernel_size=1)
        self.b3_c16_1x1 = nn.Conv2d(92, 128, kernel_size=1)
        self.b3_c17_3x3 = nn.Conv2d(92, 128, kernel_size=3, padding=1)
        self.b3_c18_5x5 = nn.Conv2d(92, 128, kernel_size=5, padding=2)
        # concat: 128+128+128+92 = 476

        # --- Block 4 ---
        self.b4_c19_1x1 = nn.Conv2d(476, 92, kernel_size=1)
        self.b4_c20_1x1 = nn.Conv2d(476, 92, kernel_size=1)
        self.b4_c21_1x1 = nn.Conv2d(476, 92, kernel_size=1)
        self.b4_c22_1x1 = nn.Conv2d(92, 128, kernel_size=1)
        self.b4_c23_3x3 = nn.Conv2d(92, 128, kernel_size=3, padding=1)
        self.b4_c24_5x5 = nn.Conv2d(92, 128, kernel_size=5, padding=2)
        # concat: 128+128+128+92 = 476, then 2x2 avg pool

        # --- Block 5 ---
        self.b5_c25_1x1 = nn.Conv2d(476, 92, kernel_size=1)
        self.b5_c26_1x1 = nn.Conv2d(476, 92, kernel_size=1)
        self.b5_c27_1x1 = nn.Conv2d(476, 128, kernel_size=1)
        self.b5_c28_3x3 = nn.Conv2d(92, 128, kernel_size=3, padding=1)
        # concat: 128+128+92 = 348

        # Dense part we need to know flattened size, so we build dynamically
        self._build_fc(in_channels, img_height, img_width, num_classes)

    # run only the conv part (up to Flatten in your Keras model)
    def _forward_features(self, x):
        x = self.relu(self.conv0(x))

        # Block 1
        c1 = self.relu(self.b1_c1_1x1(x))
        c2 = self.relu(self.b1_c2_1x1(x))
        c3 = self.relu(self.b1_c3_1x1(x))
        c4 = self.relu(self.b1_c4_1x1(c1))
        c5 = self.relu(self.b1_c5_3x3(c1))
        c6 = self.relu(self.b1_c6_5x5(c2))
        p1 = self.pool1x1(c3)
        x  = torch.cat([c4, c5, c6, p1], dim=1)      # 240 ch

        # Block 2
        c7  = self.relu(self.b2_c7_1x1(x))
        c8  = self.relu(self.b2_c8_1x1(x))
        c9  = self.relu(self.b2_c9_1x1(x))
        c10 = self.relu(self.b2_c10_1x1(c7))
        c11 = self.relu(self.b2_c11_3x3(c7))
        c12 = self.relu(self.b2_c12_5x5(c8))
        p2  = self.pool1x1(c9)
        x   = torch.cat([c10, c11, c12, p2], dim=1)  # 340 ch
        x   = self.pool2x2(x)

        # Block 3
        c13 = self.relu(self.b3_c13_1x1(x))
        c14 = self.relu(self.b3_c14_1x1(x))
        c15 = self.relu(self.b3_c15_1x1(x))
        c16 = self.relu(self.b3_c16_1x1(c13))
        c17 = self.relu(self.b3_c17_3x3(c13))
        c18 = self.relu(self.b3_c18_5x5(c14))
        p3  = self.pool1x1(c15)
        x   = torch.cat([c16, c17, c18, p3], dim=1)  # 476 ch

        # Block 4
        c19 = self.relu(self.b4_c19_1x1(x))
        c20 = self.relu(self.b4_c20_1x1(x))
        c21 = self.relu(self.b4_c21_1x1(x))
        c22 = self.relu(self.b4_c22_1x1(c19))
        c23 = self.relu(self.b4_c23_3x3(c19))
        c24 = self.relu(self.b4_c24_5x5(c20))
        p4  = self.pool1x1(c21)
        x   = torch.cat([c22, c23, c24, p4], dim=1)  # 476 ch
        x   = self.pool2x2(x)

        # Block 5
        c25 = self.relu(self.b5_c25_1x1(x))
        c26 = self.relu(self.b5_c26_1x1(x))
        c27 = self.relu(self.b5_c27_1x1(x))
        c28 = self.relu(self.b5_c28_3x3(c25))
        p5  = self.pool1x1(c26)
        x   = torch.cat([c27, c28, p5], dim=1)       # 348 ch

        return x

    def _build_fc(self, in_channels, img_height, img_width, num_classes):
        # run a dummy tensor through conv part to figure out Flatten size
        with torch.no_grad():
            dummy = torch.zeros(1, in_channels, img_height, img_width)
            feats = self._forward_features(dummy)
            flatten_dim = feats.view(1, -1).shape[1]

        self.flatten = nn.Flatten()
        # Keras: Flatten -> Dense(1024) -> Dense(1024) -> Dense(2, softmax)
        # (no activations between Dense in your code; keeping that)
        self.fc1 = nn.Linear(flatten_dim, 1024)
        self.fc2 = nn.Linear(1024, 1024)
        self.fc3 = nn.Linear(1024, num_classes)

    def forward(self, x):
        x = self._forward_features(x)
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.fc2(x)
        logits = self.fc3(x)   # raw scores; use CrossEntropyLoss (includes softmax)
        return logits

image_model = InceptionLikeNet(in_channels=in_channels, img_height=image_ht, img_width=image_wt, num_classes=n_classes).to(device)

# %% [markdown]
# #### Training the Model

# %%
train_loss_arr = []
train_accuracy_arr = []
val_loss_arr = []
val_accuracy_arr = []

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(image_model.parameters())

# Early stopping parameters
patience = 30
best_val_loss = float('inf')
best_model_state = None  # Initialize a variable to store the best model state
counter = 0

# Training loop
epochs = 300
epoch1 =0
print('\n')
for epoch in range(epochs):
    epoch1+=1
    image_model.train()
    train_loss = 0.0
    correct_train = 0
    total_train = 0
    for batch_x, batch_y in image_train_loader:
        batch_x = batch_x.to(device)
        batch_y = batch_y.to(device)
        optimizer.zero_grad()
        output = image_model(batch_x)
        loss = criterion(output, batch_y)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = output.max(1)
        total_train += batch_y.size(0)
        correct_train += predicted.eq(batch_y).sum().item()

    train_loss /= len(image_train_loader)
    train_accuracy = correct_train / total_train
    train_loss_arr.append(train_loss)
    train_accuracy_arr.append(train_accuracy)
    
    image_model.eval()
    
    val_loss = 0.0
    correct_val = 0
    total_val = 0
    with torch.no_grad():
        for batch_x, batch_y in image_val_loader:
            batch_x = batch_x.to(device)
            batch_y = batch_y.to(device)
            output = image_model(batch_x)
            val_loss += criterion(output, batch_y).item()
            _, predicted = output.max(1)
            total_val += batch_y.size(0)
            correct_val += predicted.eq(batch_y).sum().item()

    val_loss /= len(image_val_loader)
    val_accuracy = correct_val / total_val
    val_loss_arr.append(val_loss)
    val_accuracy_arr.append(val_accuracy)
    
    image_model.train()
        
    #Check for early stopping and save best model state
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        counter = 0
        best_model_state = image_model.state_dict()  # Store the current best model state
        torch.save(best_model_state, os.path.join(out_dir, 'EX1_SGQ_MargNet_CNN_Model.pth'))
    else:
        counter += 1

    if counter >= patience:
        print(f'Early stopping at epoch {epoch+1}')
        if best_model_state is not None:
            image_model.load_state_dict(best_model_state)  # Restore best model state
        counter = 0  # Reset the counter    
        break

    print(f'Epoch [{epoch+1}/{epochs}] - '
      f'Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, '
      f'Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}')

# Create the range of epochs
epoch_range = range(1, epoch1+1)

# Plot training accuracy in blue
plt.figsize=(8, 6)  # Adjust the size as needed
plt.plot(epoch_range, train_accuracy_arr, label='Train Accuracy', color='blue')

# Plot validation accuracy in red
plt.plot(epoch_range, val_accuracy_arr, label='Validation Accuracy', color='red')

# Add labels and title
plt.xlabel('Epoch', fontsize=14, weight='bold')
plt.ylabel('Accuracy', fontsize=14, weight='bold')
plt.title('Model Accuracy', fontsize=14, weight='bold')

# Add a legend
plt.legend(fontsize=14, title_fontproperties={'weight':'bold'})
plt.savefig(os.path.join(out_dir, "EX1_SGQ_MargNet_CNN_Accuracy.png"))

# Show the plot
plt.show()
plt.close()

# Plot training accuracy in blue
plt.figsize=(8, 6)  # Adjust the size as needed
plt.plot(epoch_range, train_loss_arr, label='Train Loss', color='blue')

# Plot validation accuracy in red
plt.plot(epoch_range, val_loss_arr, label='Validation Loss', color='red')

# Add labels and title
plt.xlabel('Epoch', fontsize=14, weight='bold')
plt.ylabel('Loss', fontsize=14, weight='bold')
plt.title('Model Loss', fontsize=14, weight='bold')

# Add a legend
plt.legend(fontsize=14, title_fontproperties={'weight':'bold'})
plt.savefig(os.path.join(out_dir, "EX1_SGQ_MargNet_CNN_Loss.png"))
# Show the plot
plt.show()
plt.close()
# Out:
# Epoch [1/300] - Train Loss: 0.5814, Train Accuracy: 0.7536, Validation Loss: 0.3838, Validation Accuracy: 0.8548
# Epoch [2/300] - Train Loss: 0.3346, Train Accuracy: 0.8726, Validation Loss: 0.3205, Validation Accuracy: 0.8800
# Epoch [3/300] - Train Loss: 0.3159, Train Accuracy: 0.8795, Validation Loss: 0.3128, Validation Accuracy: 0.8824
# Epoch [4/300] - Train Loss: 0.2982, Train Accuracy: 0.8855, Validation Loss: 0.2982, Validation Accuracy: 0.8845
# Epoch [5/300] - Train Loss: 0.2905, Train Accuracy: 0.8884, Validation Loss: 0.2891, Validation Accuracy: 0.8889
# Epoch [6/300] - Train Loss: 0.2836, Train Accuracy: 0.8899, Validation Loss: 0.2860, Validation Accuracy: 0.8899
# Epoch [7/300] - Train Loss: 0.2806, Train Accuracy: 0.8912, Validation Loss: 0.2710, Validation Accuracy: 0.8952
# Epoch [8/300] - Train Loss: 0.2732, Train Accuracy: 0.8938, Validation Loss: 0.2953, Validation Accuracy: 0.8856
# Epoch [9/300] - Train Loss: 0.2659, Train Accuracy: 0.8961, Validation Loss: 0.2612, Validation Accuracy: 0.8989
# Epoch [10/300] - Train Loss: 0.2628, Train Accuracy: 0.8971, Validation Loss: 0.2671, Validation Accuracy: 0.8974
# Epoch [11/300] - Train Loss: 0.2600, Train Accuracy: 0.8981, Validation Loss: 0.2653, Validation Accuracy: 0.8972
# Epoch [12/300] - Train Loss: 0.2556, Train Accuracy: 0.8997, Validation Loss: 0.2547, Validation Accuracy: 0.8988
# Epoch [13/300] - Train Loss: 0.2509, Train Accuracy: 0.9016, Validation Loss: 0.2630, Validation Accuracy: 0.8972
# Epoch [14/300] - Train Loss: 0.2494, Train Accuracy: 0.9023, Validation Loss: 0.2571, Validation Accuracy: 0.8995
# Epoch [15/300] - Train Loss: 0.2472, Train Accuracy: 0.9026, Validation Loss: 0.2476, Validation Accuracy: 0.9050
# Epoch [16/300] - Train Loss: 0.2464, Train Accuracy: 0.9024, Validation Loss: 0.2522, Validation Accuracy: 0.9022
# Epoch [17/300] - Train Loss: 0.2434, Train Accuracy: 0.9036, Validation Loss: 0.2389, Validation Accuracy: 0.9068
# Epoch [18/300] - Train Loss: 0.2405, Train Accuracy: 0.9050, Validation Loss: 0.2454, Validation Accuracy: 0.9028
# Epoch [19/300] - Train Loss: 0.2407, Train Accuracy: 0.9051, Validation Loss: 0.2474, Validation Accuracy: 0.9023
# Epoch [20/300] - Train Loss: 0.2420, Train Accuracy: 0.9048, Validation Loss: 0.2496, Validation Accuracy: 0.9037
# Epoch [21/300] - Train Loss: 0.2394, Train Accuracy: 0.9055, Validation Loss: 0.2504, Validation Accuracy: 0.9055
# Epoch [22/300] - Train Loss: 0.2356, Train Accuracy: 0.9067, Validation Loss: 0.2457, Validation Accuracy: 0.9062
# Epoch [23/300] - Train Loss: 0.2342, Train Accuracy: 0.9073, Validation Loss: 0.2383, Validation Accuracy: 0.9075
# Epoch [24/300] - Train Loss: 0.2337, Train Accuracy: 0.9075, Validation Loss: 0.2418, Validation Accuracy: 0.9057
# Epoch [25/300] - Train Loss: 0.2314, Train Accuracy: 0.9079, Validation Loss: 0.2386, Validation Accuracy: 0.9064
# Epoch [26/300] - Train Loss: 0.2301, Train Accuracy: 0.9090, Validation Loss: 0.2389, Validation Accuracy: 0.9074
# Epoch [27/300] - Train Loss: 0.2329, Train Accuracy: 0.9074, Validation Loss: 0.2464, Validation Accuracy: 0.9028
# Epoch [28/300] - Train Loss: 0.2274, Train Accuracy: 0.9096, Validation Loss: 0.2538, Validation Accuracy: 0.9021
# Epoch [29/300] - Train Loss: 0.2288, Train Accuracy: 0.9089, Validation Loss: 0.2466, Validation Accuracy: 0.9055
# Epoch [30/300] - Train Loss: 0.2280, Train Accuracy: 0.9090, Validation Loss: 0.2353, Validation Accuracy: 0.9108
# Epoch [31/300] - Train Loss: 0.2275, Train Accuracy: 0.9098, Validation Loss: 0.2397, Validation Accuracy: 0.9076
# Epoch [32/300] - Train Loss: 0.2268, Train Accuracy: 0.9102, Validation Loss: 0.2370, Validation Accuracy: 0.9090
# Epoch [33/300] - Train Loss: 0.2256, Train Accuracy: 0.9102, Validation Loss: 0.2420, Validation Accuracy: 0.9078
# Epoch [34/300] - Train Loss: 0.2244, Train Accuracy: 0.9115, Validation Loss: 0.2391, Validation Accuracy: 0.9055
# Epoch [35/300] - Train Loss: 0.2244, Train Accuracy: 0.9111, Validation Loss: 0.2364, Validation Accuracy: 0.9091
# Epoch [36/300] - Train Loss: 0.2228, Train Accuracy: 0.9114, Validation Loss: 0.2296, Validation Accuracy: 0.9112
# Epoch [37/300] - Train Loss: 0.2229, Train Accuracy: 0.9109, Validation Loss: 0.2414, Validation Accuracy: 0.9061
# Epoch [38/300] - Train Loss: 0.2226, Train Accuracy: 0.9115, Validation Loss: 0.2418, Validation Accuracy: 0.9048
# Epoch [39/300] - Train Loss: 0.2386, Train Accuracy: 0.9083, Validation Loss: 0.2380, Validation Accuracy: 0.9080
# Epoch [40/300] - Train Loss: 0.2223, Train Accuracy: 0.9118, Validation Loss: 0.2377, Validation Accuracy: 0.9075
# Epoch [41/300] - Train Loss: 0.2223, Train Accuracy: 0.9116, Validation Loss: 0.2384, Validation Accuracy: 0.9070
# Epoch [42/300] - Train Loss: 0.2207, Train Accuracy: 0.9125, Validation Loss: 0.2343, Validation Accuracy: 0.9094
# Epoch [43/300] - Train Loss: 0.2286, Train Accuracy: 0.9104, Validation Loss: 0.2344, Validation Accuracy: 0.9073
# Epoch [44/300] - Train Loss: 0.2181, Train Accuracy: 0.9135, Validation Loss: 0.2346, Validation Accuracy: 0.9080
# Epoch [45/300] - Train Loss: 0.2183, Train Accuracy: 0.9127, Validation Loss: 0.2381, Validation Accuracy: 0.9061
# Epoch [46/300] - Train Loss: 0.2181, Train Accuracy: 0.9133, Validation Loss: 0.2303, Validation Accuracy: 0.9107
# Epoch [47/300] - Train Loss: 0.2167, Train Accuracy: 0.9133, Validation Loss: 0.2307, Validation Accuracy: 0.9101
# Epoch [48/300] - Train Loss: 0.2158, Train Accuracy: 0.9134, Validation Loss: 0.2332, Validation Accuracy: 0.9101
# Epoch [49/300] - Train Loss: 0.2163, Train Accuracy: 0.9141, Validation Loss: 0.2339, Validation Accuracy: 0.9095
# Epoch [50/300] - Train Loss: 0.2133, Train Accuracy: 0.9151, Validation Loss: 0.2312, Validation Accuracy: 0.9125
# Epoch [51/300] - Train Loss: 0.2146, Train Accuracy: 0.9142, Validation Loss: 0.2393, Validation Accuracy: 0.9072
# Epoch [52/300] - Train Loss: 0.2135, Train Accuracy: 0.9143, Validation Loss: 0.2309, Validation Accuracy: 0.9109
# Epoch [53/300] - Train Loss: 0.2135, Train Accuracy: 0.9149, Validation Loss: 0.2318, Validation Accuracy: 0.9116
# Epoch [54/300] - Train Loss: 0.2152, Train Accuracy: 0.9146, Validation Loss: 0.2307, Validation Accuracy: 0.9116
# Epoch [55/300] - Train Loss: 0.2118, Train Accuracy: 0.9154, Validation Loss: 0.2337, Validation Accuracy: 0.9117
# Epoch [56/300] - Train Loss: 0.2116, Train Accuracy: 0.9157, Validation Loss: 0.2361, Validation Accuracy: 0.9083
# Epoch [57/300] - Train Loss: 0.2118, Train Accuracy: 0.9155, Validation Loss: 0.2329, Validation Accuracy: 0.9094
# Epoch [58/300] - Train Loss: 0.2214, Train Accuracy: 0.9136, Validation Loss: 0.2376, Validation Accuracy: 0.9083
# Epoch [59/300] - Train Loss: 0.2148, Train Accuracy: 0.9145, Validation Loss: 0.2326, Validation Accuracy: 0.9087
# Epoch [60/300] - Train Loss: 0.2111, Train Accuracy: 0.9161, Validation Loss: 0.2357, Validation Accuracy: 0.9100
# Epoch [61/300] - Train Loss: 0.2096, Train Accuracy: 0.9157, Validation Loss: 0.2343, Validation Accuracy: 0.9098
# Epoch [62/300] - Train Loss: 0.2100, Train Accuracy: 0.9160, Validation Loss: 0.2303, Validation Accuracy: 0.9110
# Epoch [63/300] - Train Loss: 0.2082, Train Accuracy: 0.9165, Validation Loss: 0.2311, Validation Accuracy: 0.9112
# Epoch [64/300] - Train Loss: 0.2081, Train Accuracy: 0.9165, Validation Loss: 0.2341, Validation Accuracy: 0.9082
# Epoch [65/300] - Train Loss: 0.2077, Train Accuracy: 0.9171, Validation Loss: 0.2385, Validation Accuracy: 0.9083
# Early stopping at epoch 66

# %% [markdown]
# #### Testing the Model

# %%
torch.cuda.empty_cache()

# Set the model to evaluation mode
image_model.load_state_dict(torch.load(os.path.join(out_dir, 'EX1_SGQ_MargNet_CNN_Model.pth'), map_location=device))
image_model.eval()

y_test_pred = torch.empty(0).to(device)
print('\n')
# Generate predictions
with torch.no_grad():
    for images, labels in image_test_loader:
        images = images.to(device)
        labels = labels.to(device)
        pred = image_model(images)

        y_test_pred = torch.cat((y_test_pred, pred), dim=0)

y_test_pred = y_test_pred.cpu().numpy()
y_test_pred = y_test_pred.argmax(axis=1)
print(get_metrics(y_test_pred, y_test, label_strings))

# https://www.stackvidhya.com/plot-confusion-matrix-in-python-and-why/#google_vignette
# fig = plt.figure()
cf_matrix = metrics.confusion_matrix(y_test, y_test_pred)
cf_matrix_percentage = metrics.confusion_matrix(y_test, y_test_pred, normalize='true')
group_counts = ["{0:0.0f}".format(value) for value in cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_matrix_percentage.flatten()]
labels = [f"{v1}\n({v2})\n" for v1, v2 in
          zip(group_percentages,group_counts)]
labels = np.asarray(labels).reshape(3,3)
fig, ax = plt.subplots(figsize=(8, 6))  # Adjust the size as needed

ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
ax.set_xlabel('\nPredicted', fontsize=14, weight='bold')
ax.set_ylabel('Actual', fontsize=14, weight='bold');
ax.xaxis.set_ticklabels(['GALAXY', 'QSO', 'STAR'], fontsize=14, weight='bold')
ax.yaxis.set_ticklabels(['GALAXY', 'QSO', 'STAR'], fontsize=14, weight='bold')
plt.tight_layout()
plt.savefig(os.path.join(out_dir, "EX1_SGQ_MargNet_CNN_CM.png"))

plt.show()
plt.close()
# Out:
# Identified 27439 correct labels out of 30000 labels
# Accuracy: 0.9146333333333333
# Precision: 0.915935609866338
# Recall: 0.9146005647848433
# F1 Score: 0.9148146664473402
# Labels are: ['GALAXY' 'QSO' 'STAR']
# Confusion Matrix:
#  [[9383  459  178]
#  [ 415 9187  399]
#  [ 192  918 8869]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94     10020
#            1       0.87      0.92      0.89     10001
#            2       0.94      0.89      0.91      9979
#
#     accuracy                           0.91     30000
#    macro avg       0.92      0.91      0.91     30000
# weighted avg       0.92      0.91      0.91     30000
#
# (array([    0,     1,     2, ..., 29997, 29998, 29999]), 0.9146333333333333, 0.915935609866338, 0.9146005647848433, array([[9383,  459,  178],
#        [ 415, 9187,  399],
#        [ 192,  918, 8869]]), '              precision    recall  f1-score   support\n\n           0       0.94      0.94      0.94     10020\n           1       0.87      0.92      0.89     10001\n           2       0.94      0.89      0.91      9979\n\n    accuracy                           0.91     30000\n   macro avg       0.92      0.91      0.91     30000\nweighted avg       0.92      0.91      0.91     30000\n')

# %% [markdown]
# ### 3. Ensemble Model (ANN+CNN) using photometric features and Images

# %%
cnnclassifier = image_model
dnnclassifier = pf_model

# %%
checkpoint_image = torch.load(os.path.join(out_dir, 'EX1_SGQ_MargNet_CNN_Model.pth'))
checkpoint_pf = torch.load(os.path.join(out_dir, 'EX1_SGQ_MargNet_DNN_Model.pth'))

# %%
cnnclassifier.load_state_dict(checkpoint_image)
dnnclassifier.load_state_dict(checkpoint_pf)
# Out:
# <All keys matched successfully>

# %%
class StackedModel(nn.Module):
    def __init__(self, members):
        super(StackedModel, self).__init__()
        self.members = nn.ModuleList(members)

        # Create a dictionary to store renamed parameters
        renamed_params = {}

        # Freeze the layers and rename them
        for i, model in enumerate(self.members):
            for name, param in model.named_parameters():
                param.requires_grad = False
                new_name = f'ensemble_{i+1}_{name.replace(".", "_")}'  # Replace '.' with '_'
                renamed_params[new_name] = param

        # Apply the changes to the model outside the loop
        for i, model in enumerate(self.members):
            for new_name, param in renamed_params.items():
                setattr(model, new_name, param)

        # Define multi-headed input
        self.ensemble_visible = [model for model in self.members]

        # Concatenate the outputs from each model
        self.hidden = nn.Linear(len(members) * 3, 10)
        self.output = nn.Linear(10, 3)

    def forward(self, inputs):
        outputs = [model(inputs[i]) for i, model in enumerate(self.members)]
        merge = torch.cat(outputs, dim=1)
        hidden = torch.relu(self.hidden(merge))
        output = self.output(hidden)
        return output

# %%
# Create the ensemble model
members = [cnnclassifier, dnnclassifier]
model = StackedModel(members).to(device)

# %%
# Convert data to PyTorch tensors and create DataLoader
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
dnnx_val_tensor = torch.tensor(dnnx_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)

dataset = TensorDataset(X_val_tensor, dnnx_val_tensor, y_val_tensor)
dataloader = DataLoader(dataset, batch_size=512, shuffle=False)

# %% [markdown]
# #### Training the Model

# %%
# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())

# Training loop
num_epochs = 100
pf_image_best_loss = float('inf')
pf_image_best_model_state = None  # Initialize a variable to store the best model state

# filepath = "output/EnsembleClassifier.pth"

for epoch in range(num_epochs):
    train_loss = 0.0  # Initialize total loss for the epoch
    correct_train = 0
    total_train = 0    

    for X_batch, dnnx_batch, y_batch in dataloader:
        model.train()
        X_batch = X_batch.to(device)
        dnnx_batch = dnnx_batch.to(device)
        y_batch = y_batch.to(device)
        optimizer.zero_grad()
        outputs = model([X_batch, dnnx_batch])
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()

        # Accumulate the batch loss to the total loss
        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total_train += y_batch.size(0)
        correct_train += predicted.eq(y_batch).sum().item()

    # Calculate the average loss for the epoch
    train_loss /= len(dataloader)
    train_accuracy = correct_train / total_train

    #Check for early stopping and save best model state
    if train_loss < pf_image_best_loss:
        pf_image_best_loss = train_loss  # Update with the current train_loss
        pf_image_best_model_state = model.state_dict()
        torch.save(pf_image_best_model_state, os.path.join(out_dir, 'EX1_SGQ_MargNet_Model.pth'))

    # Print the average loss for the epoch
    print(f'Epoch [{epoch+1}/{num_epochs}] - 'f'Loss: {train_loss:.4f}, Accuracy: {train_accuracy:.4f} ')
# Out:
# Epoch [1/100] - Loss: 0.8858, Accuracy: 0.6010
# Epoch [2/100] - Loss: 0.4822, Accuracy: 0.9026
# Epoch [3/100] - Loss: 0.3232, Accuracy: 0.9162
# Epoch [4/100] - Loss: 0.2576, Accuracy: 0.9217
# Epoch [5/100] - Loss: 0.2252, Accuracy: 0.9245
# Epoch [6/100] - Loss: 0.2117, Accuracy: 0.9238
# Epoch [7/100] - Loss: 0.2032, Accuracy: 0.9262
# Epoch [8/100] - Loss: 0.1980, Accuracy: 0.9276
# Epoch [9/100] - Loss: 0.1947, Accuracy: 0.9268
# Epoch [10/100] - Loss: 0.1928, Accuracy: 0.9265
# Epoch [11/100] - Loss: 0.1912, Accuracy: 0.9276
# Epoch [12/100] - Loss: 0.1892, Accuracy: 0.9293
# Epoch [13/100] - Loss: 0.1878, Accuracy: 0.9292
# Epoch [14/100] - Loss: 0.1889, Accuracy: 0.9294
# Epoch [15/100] - Loss: 0.1873, Accuracy: 0.9289
# Epoch [16/100] - Loss: 0.1862, Accuracy: 0.9303
# Epoch [17/100] - Loss: 0.1862, Accuracy: 0.9299
# Epoch [18/100] - Loss: 0.1841, Accuracy: 0.9309
# Epoch [19/100] - Loss: 0.1852, Accuracy: 0.9295
# Epoch [20/100] - Loss: 0.1845, Accuracy: 0.9294
# Epoch [21/100] - Loss: 0.1848, Accuracy: 0.9297
# Epoch [22/100] - Loss: 0.1847, Accuracy: 0.9291
# Epoch [23/100] - Loss: 0.1850, Accuracy: 0.9296
# Epoch [24/100] - Loss: 0.1829, Accuracy: 0.9304
# Epoch [25/100] - Loss: 0.1841, Accuracy: 0.9291
# Epoch [26/100] - Loss: 0.1817, Accuracy: 0.9296
# Epoch [27/100] - Loss: 0.1832, Accuracy: 0.9311
# Epoch [28/100] - Loss: 0.1826, Accuracy: 0.9298
# Epoch [29/100] - Loss: 0.1832, Accuracy: 0.9300
# Epoch [30/100] - Loss: 0.1833, Accuracy: 0.9296
# Epoch [31/100] - Loss: 0.1818, Accuracy: 0.9289
# Epoch [32/100] - Loss: 0.1842, Accuracy: 0.9294
# Epoch [33/100] - Loss: 0.1825, Accuracy: 0.9304
# Epoch [34/100] - Loss: 0.1827, Accuracy: 0.9303
# Epoch [35/100] - Loss: 0.1827, Accuracy: 0.9309
# Epoch [36/100] - Loss: 0.1827, Accuracy: 0.9302
# Epoch [37/100] - Loss: 0.1816, Accuracy: 0.9316
# Epoch [38/100] - Loss: 0.1817, Accuracy: 0.9299
# Epoch [39/100] - Loss: 0.1823, Accuracy: 0.9304
# Epoch [40/100] - Loss: 0.1823, Accuracy: 0.9299
# Epoch [41/100] - Loss: 0.1824, Accuracy: 0.9299
# Epoch [42/100] - Loss: 0.1810, Accuracy: 0.9297
# Epoch [43/100] - Loss: 0.1828, Accuracy: 0.9298
# Epoch [44/100] - Loss: 0.1825, Accuracy: 0.9303
# Epoch [45/100] - Loss: 0.1815, Accuracy: 0.9316
# Epoch [46/100] - Loss: 0.1818, Accuracy: 0.9304
# Epoch [47/100] - Loss: 0.1814, Accuracy: 0.9308
# Epoch [48/100] - Loss: 0.1833, Accuracy: 0.9290
# Epoch [49/100] - Loss: 0.1809, Accuracy: 0.9309
# Epoch [50/100] - Loss: 0.1810, Accuracy: 0.9306
# Epoch [51/100] - Loss: 0.1818, Accuracy: 0.9302
# Epoch [52/100] - Loss: 0.1824, Accuracy: 0.9305
# Epoch [53/100] - Loss: 0.1810, Accuracy: 0.9310
# Epoch [54/100] - Loss: 0.1826, Accuracy: 0.9308
# Epoch [55/100] - Loss: 0.1821, Accuracy: 0.9301
# Epoch [56/100] - Loss: 0.1824, Accuracy: 0.9308
# Epoch [57/100] - Loss: 0.1815, Accuracy: 0.9310
# Epoch [58/100] - Loss: 0.1841, Accuracy: 0.9294
# Epoch [59/100] - Loss: 0.1818, Accuracy: 0.9317
# Epoch [60/100] - Loss: 0.1823, Accuracy: 0.9298
# Epoch [61/100] - Loss: 0.1823, Accuracy: 0.9309
# Epoch [62/100] - Loss: 0.1806, Accuracy: 0.9314
# Epoch [63/100] - Loss: 0.1815, Accuracy: 0.9311
# Epoch [64/100] - Loss: 0.1806, Accuracy: 0.9313
# Epoch [65/100] - Loss: 0.1808, Accuracy: 0.9299
# Epoch [66/100] - Loss: 0.1828, Accuracy: 0.9298
# Epoch [67/100] - Loss: 0.1814, Accuracy: 0.9311
# Epoch [68/100] - Loss: 0.1818, Accuracy: 0.9299
# Epoch [69/100] - Loss: 0.1818, Accuracy: 0.9298
# Epoch [70/100] - Loss: 0.1829, Accuracy: 0.9299
# Epoch [71/100] - Loss: 0.1812, Accuracy: 0.9308
# Epoch [72/100] - Loss: 0.1815, Accuracy: 0.9307
# Epoch [73/100] - Loss: 0.1835, Accuracy: 0.9288
# Epoch [74/100] - Loss: 0.1809, Accuracy: 0.9309
# Epoch [75/100] - Loss: 0.1818, Accuracy: 0.9297
# Epoch [76/100] - Loss: 0.1813, Accuracy: 0.9298
# Epoch [77/100] - Loss: 0.1812, Accuracy: 0.9305
# Epoch [78/100] - Loss: 0.1829, Accuracy: 0.9304
# Epoch [79/100] - Loss: 0.1810, Accuracy: 0.9301
# Epoch [80/100] - Loss: 0.1821, Accuracy: 0.9303
# Epoch [81/100] - Loss: 0.1819, Accuracy: 0.9309
# Epoch [82/100] - Loss: 0.1817, Accuracy: 0.9301
# Epoch [83/100] - Loss: 0.1819, Accuracy: 0.9303
# Epoch [84/100] - Loss: 0.1811, Accuracy: 0.9307
# Epoch [85/100] - Loss: 0.1824, Accuracy: 0.9306
# Epoch [86/100] - Loss: 0.1823, Accuracy: 0.9307
# Epoch [87/100] - Loss: 0.1814, Accuracy: 0.9300
# Epoch [88/100] - Loss: 0.1806, Accuracy: 0.9311
# Epoch [89/100] - Loss: 0.1818, Accuracy: 0.9300
# Epoch [90/100] - Loss: 0.1816, Accuracy: 0.9296
# Epoch [91/100] - Loss: 0.1797, Accuracy: 0.9303
# Epoch [92/100] - Loss: 0.1811, Accuracy: 0.9304
# Epoch [93/100] - Loss: 0.1821, Accuracy: 0.9309
# Epoch [94/100] - Loss: 0.1807, Accuracy: 0.9302
# Epoch [95/100] - Loss: 0.1820, Accuracy: 0.9302
# Epoch [96/100] - Loss: 0.1816, Accuracy: 0.9308
# Epoch [97/100] - Loss: 0.1807, Accuracy: 0.9310
# Epoch [98/100] - Loss: 0.1814, Accuracy: 0.9296
# Epoch [99/100] - Loss: 0.1824, Accuracy: 0.9309
# Epoch [100/100] - Loss: 0.1821, Accuracy: 0.9307

# %%
model.load_state_dict(pf_image_best_model_state)  # Restore best model state
# Out:
# <All keys matched successfully>

# %%
# Convert data to PyTorch tensors and create DataLoader
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
dnnx_test_tensor = torch.tensor(dnnx_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

dataset1 = TensorDataset(X_test_tensor, dnnx_test_tensor, y_test_tensor)
dataloader1 = DataLoader(dataset1, batch_size=512, shuffle=False)

# %% [markdown]
# #### Testing the Model

# %%
# Set the model to evaluation mode
model.load_state_dict(torch.load(os.path.join(out_dir, 'EX1_SGQ_MargNet_Model.pth'), map_location=device))
model.eval()

model.eval()
y_test_pred = torch.empty(0).to(device)

# Generate predictions
with torch.no_grad():
    for images, pfs, labels in dataloader1:
        images = images.to(device)
        pfs = pfs.to(device)
        labels = labels.to(device)
        pred = model([images, pfs])

        y_test_pred = torch.cat((y_test_pred, pred), dim=0)

y_test_pred = y_test_pred.cpu().numpy()
y_test_pred = y_test_pred.argmax(axis=1)
print(get_metrics(y_test_pred, y_test, label_strings))

# https://www.stackvidhya.com/plot-confusion-matrix-in-python-and-why/#google_vignette
# fig = plt.figure()
cf_matrix = metrics.confusion_matrix(y_test_pred, y_test)
cf_matrix_percentage = metrics.confusion_matrix(y_test_pred, y_test, normalize='true')
group_counts = ["{0:0.0f}".format(value) for value in cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_matrix_percentage.flatten()]
labels = [f"{v1}\n({v2})\n" for v1, v2 in
          zip(group_percentages,group_counts)]
labels = np.asarray(labels).reshape(3,3)
fig, ax = plt.subplots(figsize=(8, 6))  # Adjust the size as needed

ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
ax.set_xlabel('\nPredicted', fontsize=14, weight='bold')
ax.set_ylabel('Actual', fontsize=14, weight='bold');
ax.xaxis.set_ticklabels(['GALAXY', 'QSO', 'STAR'], fontsize=14, weight='bold')
ax.yaxis.set_ticklabels(['GALAXY', 'QSO', 'STAR'], fontsize=14, weight='bold')
plt.tight_layout()
plt.savefig(os.path.join(out_dir, "EX1_SGQ_MargNet_CM.png"))
plt.show()
plt.close()
# Out:
# Identified 28002 correct labels out of 30000 labels
# Accuracy: 0.9334
# Precision: 0.933423119744763
# Recall: 0.9333837456249235
# F1 Score: 0.93340237487512
# Labels are: ['GALAXY' 'QSO' 'STAR']
# Confusion Matrix:
#  [[9578  308  134]
#  [ 304 9137  560]
#  [ 111  581 9287]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96     10020
#            1       0.91      0.91      0.91     10001
#            2       0.93      0.93      0.93      9979
#
#     accuracy                           0.93     30000
#    macro avg       0.93      0.93      0.93     30000
# weighted avg       0.93      0.93      0.93     30000
#
# (array([    0,     1,     2, ..., 29997, 29998, 29999]), 0.9334, 0.933423119744763, 0.9333837456249235, array([[9578,  308,  134],
#        [ 304, 9137,  560],
#        [ 111,  581, 9287]]), '              precision    recall  f1-score   support\n\n           0       0.96      0.96      0.96     10020\n           1       0.91      0.91      0.91     10001\n           2       0.93      0.93      0.93      9979\n\n    accuracy                           0.93     30000\n   macro avg       0.93      0.93      0.93     30000\nweighted avg       0.93      0.93      0.93     30000\n')

# %%
sum(p.numel() for p in model.parameters())
# Out:
# 25875217

# %% [markdown]
# ## Result Analysis

# %%
del(dnnx_train, dnnx_val, dnnx_test, X_train, X_val, X_test)

# %%
X = np.load("/scratch/srinadb/Foundation/Dataset/Experiment1/X_exp1.npy")
dnnx = np.load("/scratch/srinadb/Foundation/Dataset/Experiment1/dnnx_exp1.npy")
objlist = np.load("/scratch/srinadb/Foundation/Dataset/Experiment1/objlist_exp1.npy")
y = np.load("/scratch/srinadb/Foundation/Dataset/Experiment1/y_exp1.npy", allow_pickle=True)

y, label_strings = pd.factorize(y,sort=True)
# y = to_categorical(y)
print('\n')
print(label_strings)

zipX = list(zip(X, dnnx))
zipy = list(zip(y, objlist))

zipX_train, zipX_test, zipy_train, zipy_test = train_test_split(zipX, zipy, test_size = 0.125,random_state=42)
zipX_train, zipX_val, zipy_train, zipy_val = train_test_split(zipX_train, zipy_train, test_size = 0.1428, random_state=42)

X_train, dnnx_train = zip(*zipX_train)
X_val, dnnx_val = zip(*zipX_val)
X_test, dnnx_test = zip(*zipX_test)

y_train, objlist_train = zip(*zipy_train)
y_val, objlist_val = zip(*zipy_val)
y_test, objlist_test = zip(*zipy_test)

X_train = np.array(X_train)
X_val = np.array(X_val)
X_test = np.array(X_test)

dnnx_train = np.array(dnnx_train)
dnnx_val = np.array(dnnx_val)
dnnx_test = np.array(dnnx_test)

y_train = np.array(y_train)
objlist_train = np.array(objlist_train)
y_val = np.array(y_val)
objlist_val = np.array(objlist_val)
y_test = np.array(y_test)
objlist_test = np.array(objlist_test)

del(zipX,zipX_test,zipX_train,zipX_val, X, zipy, zipy_test, zipy_train, zipy_val, objlist)

X_train = X_train.transpose((0, 3, 1, 2))
X_val = X_val.transpose((0, 3, 1, 2))
X_test = X_test.transpose((0, 3, 1, 2))

print('\n')
print('The shape of the Train data is:', X_train.shape)
print('The shape of the Validation data is:', X_val.shape)
print('The shape of the Test data is:', X_test.shape)

# Convert data to PyTorch tensors and create DataLoader
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
dnnx_train_tensor = torch.tensor(dnnx_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)

X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
dnnx_val_tensor = torch.tensor(dnnx_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)

X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
dnnx_test_tensor = torch.tensor(dnnx_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)


train_dataset = TensorDataset(X_train_tensor, dnnx_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=512, shuffle=False)

val_dataset = TensorDataset(X_val_tensor, dnnx_val_tensor, y_val_tensor)
val_loader = DataLoader(val_dataset, batch_size=512, shuffle=False)

test_dataset = TensorDataset(X_test_tensor, dnnx_test_tensor, y_test_tensor)
test_loader = DataLoader(test_dataset, batch_size=512, shuffle=False)
# Out:
# ['GALAXY' 'QSO' 'STAR']
#
#
# The shape of the Train data is: (180011, 5, 32, 32)
# The shape of the Validation data is: (29988, 5, 32, 32)
# The shape of the Test data is: (30000, 5, 32, 32)

# %%
def get_preds(loader):
    model.eval()
    all_logits = []

    with torch.no_grad():
        for images, pf, labels in loader:
            pf = pf.to(device)
            images = images.to(device)
            logits = model([images, pf])      # [batch, 3]
            all_logits.append(logits.cpu())

    all_logits = torch.cat(all_logits, dim=0)   # [N, 3]
    all_probs  = F.softmax(all_logits, dim=1)   # probabilities, rows sum to 1
    all_probs  = all_probs.numpy()

    pred_labels = all_probs.argmax(axis=1)
    return all_probs, pred_labels

preds_train, y_train_pred = get_preds(train_loader)
print(get_metrics(y_train_pred, y_train, label_strings))
print('\n')

preds_val, y_val_pred = get_preds(val_loader)
print(get_metrics(y_val_pred, y_val, label_strings))
print('\n')

preds_test, y_test_pred = get_preds(test_loader)
print(get_metrics(y_test_pred, y_test, label_strings))
# Out:
# Identified 168576 correct labels out of 180011 labels
# Accuracy: 0.9364761042380744
# Precision: 0.9365389237475802
# Recall: 0.9364646835485037
# F1 Score: 0.9364967662773839
# Labels are: ['GALAXY' 'QSO' 'STAR']
# Confusion Matrix:
#  [[57545  1914   602]
#  [ 1725 55055  3182]
#  [  624  3388 55976]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96     60061
#            1       0.91      0.92      0.92     59962
#            2       0.94      0.93      0.93     59988
#
#     accuracy                           0.94    180011
#    macro avg       0.94      0.94      0.94    180011
# weighted avg       0.94      0.94      0.94    180011
#
# (array([     0,      1,      2, ..., 180008, 180009, 180010]), 0.9364761042380744, 0.9365389237475802, 0.9364646835485037, array([[57545,  1914,   602],
#        [ 1725, 55055,  3182],
#        [  624,  3388, 55976]]), '              precision    recall  f1-score   support\n\n           0       0.96      0.96      0.96     60061\n           1       0.91      0.92      0.92     59962\n           2       0.94      0.93      0.93     59988\n\n    accuracy                           0.94    180011\n   macro avg       0.94      0.94      0.94    180011\nweighted avg       0.94      0.94      0.94    180011\n')
#
#
# Identified 27981 correct labels out of 29988 labels
# Accuracy: 0.9330732292917167
# Precision: 0.933257697959275
# Recall: 0.9331567752094457
# F1 Score: 0.9331991275614122
# Labels are: ['GALAXY' 'QSO' 'STAR']
# Confusion Matrix:
#  [[9465  337  116]
#  [ 318 9188  531]
#  [ 111  594 9328]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      9918
#            1       0.91      0.92      0.91     10037
#            2       0.94      0.93      0.93     10033
#
#     accuracy                           0.93     29988
#    macro avg       0.93      0.93      0.93     29988
# weighted avg       0.93      0.93      0.93     29988
#
# (array([    0,     1,     2, ..., 29985, 29986, 29987]), 0.9330732292917167, 0.933257697959275, 0.9331567752094457, array([[9465,  337,  116],
#        [ 318, 9188,  531],
#        [ 111,  594, 9328]]), '              precision    recall  f1-score   support\n\n           0       0.96      0.95      0.96      9918\n           1       0.91      0.92      0.91     10037\n           2       0.94      0.93      0.93     10033\n\n    accuracy                           0.93     29988\n   macro avg       0.93      0.93      0.93     29988\nweighted avg       0.93      0.93      0.93     29988\n')
#
#
# Identified 28002 correct labels out of 30000 labels
# Accuracy: 0.9334
# Precision: 0.933423119744763
# Recall: 0.9333837456249235
# F1 Score: 0.93340237487512
# Labels are: ['GALAXY' 'QSO' 'STAR']
# Confusion Matrix:
#  [[9578  308  134]
#  [ 304 9137  560]
#  [ 111  581 9287]]
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96     10020
#            1       0.91      0.91      0.91     10001
#            2       0.93      0.93      0.93      9979
#
#     accuracy                           0.93     30000
#    macro avg       0.93      0.93      0.93     30000
# weighted avg       0.93      0.93      0.93     30000
#
# (array([    0,     1,     2, ..., 29997, 29998, 29999]), 0.9334, 0.933423119744763, 0.9333837456249235, array([[9578,  308,  134],
#        [ 304, 9137,  560],
#        [ 111,  581, 9287]]), '              precision    recall  f1-score   support\n\n           0       0.96      0.96      0.96     10020\n           1       0.91      0.91      0.91     10001\n           2       0.93      0.93      0.93      9979\n\n    accuracy                           0.93     30000\n   macro avg       0.93      0.93      0.93     30000\nweighted avg       0.93      0.93      0.93     30000\n')

# %%
df = pd.read_csv("/scratch/srinadb/Foundation/Dataset/Experiment1/photofeatures_exp1.csv",index_col=0)

df.loc[objlist_train, ["set"]] = "TRAIN"
df.loc[objlist_val, ["set"]] = "VALIDATION"
df.loc[objlist_test, ["set"]] = "TEST"

df.loc[objlist_train, ["pred_class"]] = label_strings[preds_train.argmax(axis=1)]
df.loc[objlist_val, ["pred_class"]] = label_strings[preds_val.argmax(axis=1)]
df.loc[objlist_test, ["pred_class"]] = label_strings[preds_test.argmax(axis=1)]

pgal_train = preds_train[:,np.where(label_strings=="GALAXY")[0][0]]
pstar_train = preds_train[:,np.where(label_strings=="STAR")[0][0]]
pqso_train = preds_train[:,np.where(label_strings=="QSO")[0][0]]

pgal_val = preds_val[:,np.where(label_strings=="GALAXY")[0][0]]
pstar_val = preds_val[:,np.where(label_strings=="STAR")[0][0]]
pqso_val = preds_val[:,np.where(label_strings=="QSO")[0][0]]

pgal_test = preds_test[:,np.where(label_strings=="GALAXY")[0][0]]
pstar_test = preds_test[:,np.where(label_strings=="STAR")[0][0]]
pqso_test = preds_test[:,np.where(label_strings=="QSO")[0][0]]


df.loc[objlist_train, ["prob_gal"]] = pgal_train
df.loc[objlist_train, ["prob_star"]] = pstar_train
df.loc[objlist_train, ["prob_qso"]] = pqso_train

df.loc[objlist_val, ["prob_gal"]] = pgal_val
df.loc[objlist_val, ["prob_star"]] = pstar_val
df.loc[objlist_val, ["prob_qso"]] = pqso_val

df.loc[objlist_test, ["prob_gal"]] = pgal_test
df.loc[objlist_test, ["prob_star"]] = pstar_test
df.loc[objlist_test, ["prob_qso"]] = pqso_test
df.to_csv(os.path.join(out_dir, "EX1_SGQ_MargNet_results.csv"))

# %%
sns.set_palette("tab10")
df = pd.read_csv(os.path.join(out_dir, "EX1_SGQ_MargNet_results.csv"))

subdflist = []

bin_size = 0.1
lower_bin_list = np.arange(20,23,bin_size)
bad_lower_bin=[]
acclist = []
f1list = []
reportlist = []
num_samplelist = []
starmaglist = []
galmaglist = []
qsomaglist = []

for lower_bin in lower_bin_list:
#     print(f"******************** {lower_bin} < r <= {lower_bin+bin_size} ********************")
    subdf = df[(
        ((df["dered_r"]+df["extinction_r"]) > lower_bin) & 
        ((df["dered_r"]+df["extinction_r"]) <= lower_bin+bin_size)
    )]
    # Choose equal number of stars, galaxies and qsos
    min_num = subdf["class"].value_counts().min()
    if min_num < 50:
        bad_lower_bin.append(lower_bin)
        continue
    s1 = subdf[subdf["class"]=="GALAXY"].sample(n=min_num)
    galmaglist.append((s1["dered_r"]+s1["extinction_r"]).to_numpy())
    s2 = subdf[subdf["class"]=="STAR"].sample(n=min_num)
    starmaglist.append((s2["dered_r"]+s2["extinction_r"]).to_numpy())
    s3 = subdf[subdf["class"]=="QSO"].sample(n=min_num)
    qsomaglist.append((s2["dered_r"]+s2["extinction_r"]).to_numpy())
    num_samplelist.append(min_num)
    subdf = pd.concat([s1,s2,s3])
    subdflist.append(subdf)
    
    accuracy = metrics.accuracy_score(subdf["class"], subdf["pred_class"])
    f1score = metrics.f1_score(subdf["class"], subdf["pred_class"],average='macro')
    report = metrics.classification_report(subdf["class"], subdf["pred_class"],output_dict=True)
    reportlist.append(report)
    acclist.append(accuracy)
    f1list.append(f1score)
    
bad_lower_bin = np.array(bad_lower_bin)
lower_bin_list = lower_bin_list[~np.in1d(lower_bin_list,bad_lower_bin)]
# elems in lower_bin_list not in bad_lower_bin

galmaglist = np.concatenate(galmaglist)

starmaglist = np.concatenate(starmaglist)

qsomaglist = np.concatenate(qsomaglist)
plt.errorbar(lower_bin_list+bin_size/2, np.array(acclist)*100, xerr=bin_size/2, fmt=" ",color="black",label="Bin")
plt.errorbar(lower_bin_list+bin_size/2, np.array(acclist)*100, yerr=0.01*100,fmt=".",color="red",label="Accuracy")
# plt.errorbar(lower_bin_list+bin_size/2, f1list, yerr=0.01,label="F1 Score")
plt.legend()
plt.title("Star-Galaxy-QSO")
plt.xlabel("r magnitude bins")
plt.ylabel("Accuracy Score (%)")
plt.savefig(os.path.join(out_dir, "EX1_SGQ_MargNet_v2.png"))

# %%
subdfs = pd.concat(subdflist)
subdfs["r"]=subdfs["dered_r"]+subdfs["extinction_r"]
gal_recall_list = []
gal_precision_list = []
star_recall_list = []
star_precision_list = []
qso_precision_list = []
qso_recall_list = []
for r in reportlist:
    gal_recall_list.append(r["GALAXY"]["recall"])
    gal_precision_list.append(r["GALAXY"]["precision"])
    star_recall_list.append(r["STAR"]["recall"])
    star_precision_list.append(r["STAR"]["precision"])
    qso_recall_list.append(r["QSO"]["recall"])
    qso_precision_list.append(r["QSO"]["precision"])
    
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1,sharex=True, figsize=(8,18))

galcolor = sns.color_palette("tab10")[1]
starcolor = sns.color_palette("tab10")[2]
qsocolor = sns.color_palette("tab10")[0]
acccolor = sns.color_palette("tab10")[3]
f1color = sns.color_palette("tab10")[4]

dyfit = 0.01
x_ax = lower_bin_list+bin_size/2


d1 = subdfs[subdfs["class"]=="GALAXY"]["r"]
d2 = subdfs[subdfs["class"]=="STAR"]["r"]
d3 = subdfs[subdfs["class"]=="QSO"]["r"]

ax1.hist([d1, d2, d3], color=[galcolor,starcolor, qsocolor],
         alpha=0.8, label=["GALAXY","STAR","QSO"],bins=len(lower_bin_list))
ax1.set_ylabel("Count")

ax1.legend()


y_ax1 = np.array(gal_precision_list)
y_ax2 = np.array(star_precision_list)
y_ax3 = np.array(qso_precision_list)

ax2.errorbar(x_ax, y_ax1*100,fmt="-o", ms=4, label="Galaxy Precision",color=galcolor)
ax2.fill_between(x_ax, y_ax1*100 - dyfit*100, y_ax1*100 + dyfit*100,
             color=sns.color_palette("pastel")[1], alpha=0.3)
ax2.errorbar(x_ax, y_ax2*100,fmt="-o", ms=4, label="Star Precision",color=starcolor)
ax2.fill_between(x_ax, y_ax2*100 - dyfit*100, y_ax2*100 + dyfit*100,
                 color=sns.color_palette("pastel")[2], alpha=0.3)
ax2.errorbar(x_ax, y_ax3*100,fmt="-o", ms=4, label="QSO Precision",color=qsocolor)
ax2.fill_between(x_ax, y_ax3*100 - dyfit*100, y_ax3*100 + dyfit*100,
                 color=sns.color_palette("pastel")[0], alpha=0.3)
ax2.set_ylabel("Precision (%)")
ax2.legend()

y_ax1 = np.array(gal_recall_list)
y_ax2 = np.array(star_recall_list)
y_ax3 = np.array(qso_precision_list)

ax3.errorbar(x_ax, y_ax1*100,fmt="-o", ms=4, label="Galaxy Recall",color=galcolor)
ax3.fill_between(x_ax, y_ax1*100 - dyfit*100, y_ax1*100 + dyfit*100,
             color=sns.color_palette("pastel")[1], alpha=0.3)
ax3.errorbar(x_ax, y_ax2*100,fmt="-o", ms=4, label="Star Recall",color=starcolor)
ax3.fill_between(x_ax, y_ax2*100 - dyfit*100, y_ax2*100 + dyfit*100,
             color=sns.color_palette("pastel")[2], alpha=0.3)
ax3.errorbar(x_ax, y_ax3*100,fmt="-o", ms=4, label="QSO Recall",color=qsocolor)
ax3.fill_between(x_ax, y_ax3*100 - dyfit*100, y_ax3*100 + dyfit*100,
             color=sns.color_palette("pastel")[0], alpha=0.3)
ax3.set_ylabel("Recall (%)")
ax3.legend()



y_ax1 = np.array(acclist)
y_ax2 = np.array(f1list)
ax4.errorbar(x_ax, y_ax1*100,fmt="-o", ms=4, label="Accuracy",color=acccolor)
# ax4.errorbar(x_ax, y_ax2*100,fmt="-o", ms=4, label="F1 Score",color=f1color)
ax4.fill_between(x_ax, y_ax1*100 - dyfit*100, y_ax1*100 + dyfit*100,
             color=sns.color_palette("pastel")[3], alpha=0.3)
ax4.set_ylabel("Accuracy Score (%)")
ax4.legend()

plt.xlabel("r magnitude bins")


# plt.suptitle("Star-Galaxy-QSO")
plt.savefig(os.path.join(out_dir, "EX1_SGQ_MargNet_v2Set.png")) 
plt.show()
